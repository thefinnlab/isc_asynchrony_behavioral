# %%
# %load_ext autoreload
import os, sys, glob
import json
import re
import numpy as np
import pandas as pd
import ast

sys.path.append('/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavioral/code/utils/')
sys.path.append('/dartfs/rc/lab/F/FinnLab/tommy/utils/gentle')

import gentle
from narratives_utils import *
from text_utils import get_pos_tags, get_lemma

# %% [markdown]
# # Set directories

# %%
EXPERIMENT_NAME = 'next-word-prediction'
EXPERIMENT_VERSION = 'pilot-version-03'

base_dir = '/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavioral/'
gentle_dir = os.path.join(base_dir, 'stimuli', 'gentle')
results_dir = os.path.join(base_dir, 'experiments',  EXPERIMENT_NAME, 'results', EXPERIMENT_VERSION)
preproc_dir = os.path.join(base_dir, 'stimuli', 'preprocessed')

# for huggingface
cache_dir = '/dartfs/rc/lab/F/FinnLab/tommy/models/huggingface/transformers'

# %%
# go through each task and get participant data
EXPERIMENT_NAME = 'next-word-prediction'
EXPERIMENT_VERSION = 'pilot-version-04'
TASK = 'black'

base_dir = '/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavioral/'
results_dir = os.path.join(base_dir, 'experiments',  EXPERIMENT_NAME, 'results', EXPERIMENT_VERSION)
source_dir = os.path.join(base_dir, 'stimuli',  'presentation_orders', EXPERIMENT_VERSION, TASK)

sources_fns = sorted(glob.glob(os.path.join(source_dir, '*')))

# %%
checker = {
    'complete': [],
    'incomplete': [],
    'error': [],
    'missing': [],
}

for source_fn in sources_fns:
    
    # get the basename and split to get subject name
    sub = os.path.basename(source_fn).split('_')[0]
    
    # then load the parameters
    parameter_data = pd.read_json(source_fn, orient='records')
    
    for mod in modalities:
        sub_results_dir = os.path.join(results_dir, mod, sub)
        
        # check if the file exists
        if not os.path.exists(sub_results_dir):
            checker['missing'].append((mod, sub))
            
        # load results from the completed experiment
        try:
            current_id, results = load_participant_results(sub_results_dir, sub)
        except:
            if os.path.exists(sub_results_dir):
                checker['error'].append((mod, sub))
            continue
            
        # check that all indices of trials match
        all_values_complete = np.all(results['transcript_index'].values == parameter_data[parameter_data['NWP_Candidate']].index.values)

        # make sure all responses are there
        all_responses_complete = np.all(~pd.isnull(results['response']))
        
        if all_values_complete and all_responses_complete:
            # add to list of people completed
            checker['complete'].append((mod, sub, current_id))
        else:
            checker['incomplete'].append((mod, sub, current_id))
            
        del current_id
            
#         sys.exit(0)

# %% [markdown]
# Find people who completed the whole study or didn't

# %%
complete = pd.DataFrame(checker['complete'], columns=['modality', 'sub', 'prolific_id'])
incomplete = pd.DataFrame(checker['incomplete'], columns=['modality', 'sub', 'prolific_id'])
error = pd.DataFrame(checker['error'], columns=['modality', 'sub'])

# %%
complete[complete['prolific_id'] == '63d176dbaef5e7827cd86954']
# Out:
# Empty DataFrame
# Columns: [modality, sub, prolific_id]
# Index: []

# %%
incomplete
# Out:
# Empty DataFrame
# Columns: [modality, sub, prolific_id]
# Index: []

# %%
missing = pd.DataFrame(checker['missing'], columns=['modality', 'sub'])
missing
# Out:
#      modality        sub
# 0       audio  sub-00044
# 1       audio  sub-00101
# 2  audio-text  sub-00101

# %%
len(complete) + len(missing)
# Out:
# 303

# %% [markdown]
# Then find duplicates

# %%
# find sets of duplicates between complete and incomplete
duplicate_prolific_ids = set(complete['prolific_id']).intersection(incomplete['prolific_id'])

complete_duplicate = complete[complete['prolific_id'].isin(duplicate_prolific_ids)]
incomplete_duplicate = incomplete[incomplete['prolific_id'].isin(duplicate_prolific_ids)]

# %%
incomplete_duplicate
# Out:
# Empty DataFrame
# Columns: [modality, sub, prolific_id]
# Index: []

# %%
complete_duplicate
# Out:
# Empty DataFrame
# Columns: [modality, sub, prolific_id]
# Index: []

# %% [markdown]
# Manually look at these files

# %% [markdown]
# Cleaned completed

# %%
complete_cleaned = complete[~complete['prolific_id'].isin(duplicates)]
incomplete_cleaned = incomplete[~incomplete['prolific_id'].isin(duplicates)]

# %%
incomplete_cleaned
# Out:
#   modality        sub               prolific_id
# 0     text  sub-00079  5d519a9df20feb00180b62bc
# 1     text  sub-00088  5bacb6b9f2d97e0001c52a63
# 2    audio  sub-00101  5de33ff0cc246f3633dc01d2

# %% [markdown]
# Write out IDs to approve

# %%
complete_cleaned['prolific_id'].to_csv('completed_cleaned.txt', index=False)

# %% [markdown]
# # Get data for stories

# %%
def load_participant_results(sub_dir, sub):
    # load and filter down to response trials
    df_results = pd.read_csv(os.path.join(sub_dir, f'{sub}_next-word-prediction.csv')).fillna(False)
    prolific_id = list(set(df_results['prolific_id']))
    
    df_results = df_results[df_results['critical_trial']]
    
    # convert string to dictionary
    df_results['response'] = df_results['response'].apply(ast.literal_eval)

    # filter down to the expeirment get the responses
    df_results = df_results[df_results['experiment_phase'] == 'experiment']
    df_results['response'] = [d.get('Q0') for d in df_results['response']]
    
    df_results['transcript_index'] = df_results['transcript_index'].astype(int) - 1
    
    return prolific_id[0], df_results

def add_word_response(dict, key, value):
    
    if key in dict:
        dict[key].append(value)
    else:
        dict[key] = [value]
        
    return dict

# %%
tasks = ['black', 'bronx']
task = tasks[0]
transcript = pd.read_csv(os.path.join(preproc_dir, task, f'{task}_transcript_preprocessed.csv'))

# %%
tasks_dict = {}

for task in tasks:
    transcript = pd.read_csv(os.path.join(preproc_dir, task, f'{task}_transcript_preprocessed.csv'))
    
    # go through each task and get participant data
    sub_dirs = sorted(glob.glob(os.path.join(results_dir, task, '*')))

    accuracy_stack = []
    transcript_responses = {}

    for sub_dir in sub_dirs:
        sub = os.path.basename(sub_dir)

        results = load_participant_results(sub_dir, sub)
        
        sys.exit(0)

        # calculate prediction accuracy
        accuracy = np.sum(results['current_word'] == results['response']) / len(results['current_word'])
        accuracy_stack.append(accuracy)

        for index, response in results[['transcript_index', 'response']].values:
            transcript_responses = add_word_response(transcript_responses, index, response)
            
    tasks_dict[task] = {
        'transcript': transcript['Word_Written'].values,
        'accuracy': np.stack(accuracy_stack),
        'responses': transcript_responses
    }
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27912/2624450480.py in <module>
#      26     tasks_dict[task] = {
#      27         'transcript': transcript['Word_Written'].values,
# ---> 28         'accuracy': np.stack(accuracy_stack),
#      29         'responses': transcript_responses
#      30     }
#
# <__array_function__ internals> in stack(*args, **kwargs)
#
# ~/.local/lib/python3.7/site-packages/numpy/core/shape_base.py in stack(arrays, axis, out)
#     420     arrays = [asanyarray(arr) for arr in arrays]
#     421     if not arrays:
# --> 422         raise ValueError('need at least one array to stack')
#     423
#     424     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack

# %% [markdown]
# # Test transformer predictions

# %%
import torch
from torch.nn import functional as F
from scipy.special import rel_entr
from scipy import stats

def get_transformer_model(model_name, cache_dir=None):
    '''
    Use a model from the sentence-transformers library to get
    sentence embeddings. Models used are trained on a next-sentence
    prediction task and evaluate the likelihood of S2 following S1.
    '''
    # set the path of where to download models
    # this NEEDS to be run before loading from transformers
    if cache_dir:
        os.environ['TRANSFORMERS_CACHE'] = cache_dir
    from transformers import AutoTokenizer, AutoModelForCausalLM

    # load a tokenizer and a model
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    
    return tokenizer, model

def get_model_prediction(inputs, model, tokenizer):
    
    tokens = tokenizer(inputs, return_tensors="pt")
    
    with torch.no_grad():
        logits = model(**tokens).logits[:, -1, :]
    
    probs = F.softmax(logits, dim=-1)
    pred_id = logits.argmax().item()
    pred_word = tokenizer.decode(pred_id)
    pred_prob = probs.max()
    
    return pred_word, pred_prob, probs

def get_segment_indices(n_words, window_size):
    
    temp_window = 0
    indices = [
        np.arange(i-window_size, i) if i > window_size else np.arange(0, i)
        for i in range(1, n_words)
    ]
    return indices

def process_transcript(transcript, model, tokenizer, window_size):
    
    prev_dist = None
    kl_divergence = None
    segments = get_segment_indices(n_words=len(transcript), window_size=window_size)
    df = pd.DataFrame([np.concatenate((np.array([transcript[0]]), np.repeat(np.nan, 3)))],
        columns=['predicted_word', 'probability', 'entropy', 'kl_divergence'])
    
    for i, seg in enumerate(segments):
        inputs = transcript[seg].tolist()
        inputs = ' '.join(inputs)
    
        word, prob, dist = get_model_prediction(inputs=inputs, model=model, tokenizer=tokenizer)
        entropy = stats.entropy(dist, axis=-1)[0]

        # set as previous distribution
        if not i or prev_dist is None:
            prev_dist = dist
        else:
            kl_divergence = rel_entr(dist, prev_dist).sum()

        df.loc[len(df)] = {
            'predicted_word': word,
            'probability': prob.item(),
            'entropy': entropy,
            'kl_divergence': kl_divergence.item() if kl_divergence is not None else None,
        }
        print (f'Processed segment {i+1}/{len(segments)}')
    return df

# %% [markdown]
# Get the tokenizer and model for GPT2

# %%
window_size = 25
words = transcript['Word_Written'].values
df = process_transcript(transcript=words, model=model, tokenizer=tokenizer, window_size=window_size)

out_fn = f'task-{task}_gpt2-predictions_context-{window_size}.csv'
df.to_csv(out_fn)
# Out:
# Processed segment 1/1375
# Processed segment 2/1375
# Processed segment 3/1375
# Processed segment 4/1375
# Processed segment 5/1375
# Processed segment 6/1375
# Processed segment 7/1375
# Processed segment 8/1375
# Processed segment 9/1375
# Processed segment 10/1375
# Processed segment 11/1375
# Processed segment 12/1375
# Processed segment 13/1375
# Processed segment 14/1375
# Processed segment 15/1375
# Processed segment 16/1375
# Processed segment 17/1375
# Processed segment 18/1375
# Processed segment 19/1375
# Processed segment 20/1375
# Processed segment 21/1375
# Processed segment 22/1375
# Processed segment 23/1375
# Processed segment 24/1375
# Processed segment 25/1375
# Processed segment 26/1375
# Processed segment 27/1375
# Processed segment 28/1375
# Processed segment 29/1375
# Processed segment 30/1375
# Processed segment 31/1375
# Processed segment 32/1375
# Processed segment 33/1375
# Processed segment 34/1375
# Processed segment 35/1375
# Processed segment 36/1375
# Processed segment 37/1375
# Processed segment 38/1375
# Processed segment 39/1375
# Processed segment 40/1375
# Processed segment 41/1375
# Processed segment 42/1375
# Processed segment 43/1375
# Processed segment 44/1375
# Processed segment 45/1375
# Processed segment 46/1375
# Processed segment 47/1375
# Processed segment 48/1375
# Processed segment 49/1375
# Processed segment 50/1375
# Processed segment 51/1375
# Processed segment 52/1375
# Processed segment 53/1375
# Processed segment 54/1375
# Processed segment 55/1375
# Processed segment 56/1375
# Processed segment 57/1375
# Processed segment 58/1375
# Processed segment 59/1375
# Processed segment 60/1375
# Processed segment 61/1375
# Processed segment 62/1375
# Processed segment 63/1375
# Processed segment 64/1375
# Processed segment 65/1375
# Processed segment 66/1375
# Processed segment 67/1375
# Processed segment 68/1375
# Processed segment 69/1375
# Processed segment 70/1375
# Processed segment 71/1375
# Processed segment 72/1375
# Processed segment 73/1375
# Processed segment 74/1375
# Processed segment 75/1375
# Processed segment 76/1375
# Processed segment 77/1375
# Processed segment 78/1375
# Processed segment 79/1375
# Processed segment 80/1375
# Processed segment 81/1375
# Processed segment 82/1375
# Processed segment 83/1375
# Processed segment 84/1375
# Processed segment 85/1375
# Processed segment 86/1375
# Processed segment 87/1375
# Processed segment 88/1375
# Processed segment 89/1375
# Processed segment 90/1375
# Processed segment 91/1375
# Processed segment 92/1375
# Processed segment 93/1375
# Processed segment 94/1375
# Processed segment 95/1375
# Processed segment 96/1375
# Processed segment 97/1375
# Processed segment 98/1375
# Processed segment 99/1375
# Processed segment 100/1375
# Processed segment 101/1375
# Processed segment 102/1375
# Processed segment 103/1375
# Processed segment 104/1375
# Processed segment 105/1375
# Processed segment 106/1375
# Processed segment 107/1375
# Processed segment 108/1375
# Processed segment 109/1375
# Processed segment 110/1375
# Processed segment 111/1375
# Processed segment 112/1375
# Processed segment 113/1375
# Processed segment 114/1375
# Processed segment 115/1375
# Processed segment 116/1375
# Processed segment 117/1375
# Processed segment 118/1375
# Processed segment 119/1375
# Processed segment 120/1375
# Processed segment 121/1375
# Processed segment 122/1375
# Processed segment 123/1375
# Processed segment 124/1375
# Processed segment 125/1375
# Processed segment 126/1375
# Processed segment 127/1375
# Processed segment 128/1375
# Processed segment 129/1375
# Processed segment 130/1375
# Processed segment 131/1375
# Processed segment 132/1375
# Processed segment 133/1375
# Processed segment 134/1375
# Processed segment 135/1375
# Processed segment 136/1375
# Processed segment 137/1375
# Processed segment 138/1375
# Processed segment 139/1375
# Processed segment 140/1375
# Processed segment 141/1375
# Processed segment 142/1375
# Processed segment 143/1375
# Processed segment 144/1375
# Processed segment 145/1375
# Processed segment 146/1375
# Processed segment 147/1375
# Processed segment 148/1375
# Processed segment 149/1375
# Processed segment 150/1375
# Processed segment 151/1375
# Processed segment 152/1375
# Processed segment 153/1375
# Processed segment 154/1375
# Processed segment 155/1375
# Processed segment 156/1375
# Processed segment 157/1375
# Processed segment 158/1375
# Processed segment 159/1375
# Processed segment 160/1375
# Processed segment 161/1375
# Processed segment 162/1375
# Processed segment 163/1375
# Processed segment 164/1375
# Processed segment 165/1375
# Processed segment 166/1375
# Processed segment 167/1375
# Processed segment 168/1375
# Processed segment 169/1375
# Processed segment 170/1375
# Processed segment 171/1375
# Processed segment 172/1375
# Processed segment 173/1375
# Processed segment 174/1375
# Processed segment 175/1375
# Processed segment 176/1375
# Processed segment 177/1375
# Processed segment 178/1375
# Processed segment 179/1375
# Processed segment 180/1375
# Processed segment 181/1375
# Processed segment 182/1375
# Processed segment 183/1375
# Processed segment 184/1375
# Processed segment 185/1375
# Processed segment 186/1375
# Processed segment 187/1375
# Processed segment 188/1375
# Processed segment 189/1375
# Processed segment 190/1375
# Processed segment 191/1375
# Processed segment 192/1375
# Processed segment 193/1375
# Processed segment 194/1375
# Processed segment 195/1375
# Processed segment 196/1375
# Processed segment 197/1375
# Processed segment 198/1375
# Processed segment 199/1375
# Processed segment 200/1375
# Processed segment 201/1375
# Processed segment 202/1375
# Processed segment 203/1375
# Processed segment 204/1375
# Processed segment 205/1375
# Processed segment 206/1375
# Processed segment 207/1375
# Processed segment 208/1375
# Processed segment 209/1375
# Processed segment 210/1375
# Processed segment 211/1375
# Processed segment 212/1375
# Processed segment 213/1375
# Processed segment 214/1375
# Processed segment 215/1375
# Processed segment 216/1375
# Processed segment 217/1375
# Processed segment 218/1375
# Processed segment 219/1375
# Processed segment 220/1375
# Processed segment 221/1375
# Processed segment 222/1375
# Processed segment 223/1375
# Processed segment 224/1375
# Processed segment 225/1375
# Processed segment 226/1375
# Processed segment 227/1375
# Processed segment 228/1375
# Processed segment 229/1375
# Processed segment 230/1375
# Processed segment 231/1375
# Processed segment 232/1375
# Processed segment 233/1375
# Processed segment 234/1375
# Processed segment 235/1375
# Processed segment 236/1375
# Processed segment 237/1375
# Processed segment 238/1375
# Processed segment 239/1375
# Processed segment 240/1375
# Processed segment 241/1375
# Processed segment 242/1375
# Processed segment 243/1375
# Processed segment 244/1375
# Processed segment 245/1375
# Processed segment 246/1375
# Processed segment 247/1375
# Processed segment 248/1375
# Processed segment 249/1375
# Processed segment 250/1375
# Processed segment 251/1375
# Processed segment 252/1375
# Processed segment 253/1375
# Processed segment 254/1375
# Processed segment 255/1375
# Processed segment 256/1375
# Processed segment 257/1375
# Processed segment 258/1375
# Processed segment 259/1375
# Processed segment 260/1375
# Processed segment 261/1375
# Processed segment 262/1375
# Processed segment 263/1375
# Processed segment 264/1375
# Processed segment 265/1375
# Processed segment 266/1375
# Processed segment 267/1375
# Processed segment 268/1375
# Processed segment 269/1375
# Processed segment 270/1375
# Processed segment 271/1375
# Processed segment 272/1375
# Processed segment 273/1375
# Processed segment 274/1375
# Processed segment 275/1375
# Processed segment 276/1375
# Processed segment 277/1375
# Processed segment 278/1375
# Processed segment 279/1375
# Processed segment 280/1375
# Processed segment 281/1375
# Processed segment 282/1375
# Processed segment 283/1375
# Processed segment 284/1375
# Processed segment 285/1375
# Processed segment 286/1375
# Processed segment 287/1375
# Processed segment 288/1375
# Processed segment 289/1375
# Processed segment 290/1375
# Processed segment 291/1375
# Processed segment 292/1375
# Processed segment 293/1375
# Processed segment 294/1375
# Processed segment 295/1375
# Processed segment 296/1375
# Processed segment 297/1375
# Processed segment 298/1375
# Processed segment 299/1375
# Processed segment 300/1375
# Processed segment 301/1375
# Processed segment 302/1375
# Processed segment 303/1375
# Processed segment 304/1375
# Processed segment 305/1375
# Processed segment 306/1375
# Processed segment 307/1375
# Processed segment 308/1375
# Processed segment 309/1375
# Processed segment 310/1375
# Processed segment 311/1375
# Processed segment 312/1375
# Processed segment 313/1375
# Processed segment 314/1375
# Processed segment 315/1375
# Processed segment 316/1375
# Processed segment 317/1375
# Processed segment 318/1375
# Processed segment 319/1375
# Processed segment 320/1375
# Processed segment 321/1375
# Processed segment 322/1375
# Processed segment 323/1375
# Processed segment 324/1375
# Processed segment 325/1375
# Processed segment 326/1375
# Processed segment 327/1375
# Processed segment 328/1375
# Processed segment 329/1375
# Processed segment 330/1375
# Processed segment 331/1375
# Processed segment 332/1375
# Processed segment 333/1375
# Processed segment 334/1375
# Processed segment 335/1375
# Processed segment 336/1375
# Processed segment 337/1375
# Processed segment 338/1375
# Processed segment 339/1375
# Processed segment 340/1375
# Processed segment 341/1375
# Processed segment 342/1375
# Processed segment 343/1375
# Processed segment 344/1375
# Processed segment 345/1375
# Processed segment 346/1375
# Processed segment 347/1375
# Processed segment 348/1375
# Processed segment 349/1375
# Processed segment 350/1375
# Processed segment 351/1375
# Processed segment 352/1375
# Processed segment 353/1375
# Processed segment 354/1375
# Processed segment 355/1375
# Processed segment 356/1375
# Processed segment 357/1375
# Processed segment 358/1375
# Processed segment 359/1375
# Processed segment 360/1375
# Processed segment 361/1375
# Processed segment 362/1375
# Processed segment 363/1375
# Processed segment 364/1375
# Processed segment 365/1375
# Processed segment 366/1375
# Processed segment 367/1375
# Processed segment 368/1375
# Processed segment 369/1375
# Processed segment 370/1375
# Processed segment 371/1375
# Processed segment 372/1375
# Processed segment 373/1375
# Processed segment 374/1375
# Processed segment 375/1375
# Processed segment 376/1375
# Processed segment 377/1375
# Processed segment 378/1375
# Processed segment 379/1375
# Processed segment 380/1375
# Processed segment 381/1375
# Processed segment 382/1375
# Processed segment 383/1375
# Processed segment 384/1375
# Processed segment 385/1375
# Processed segment 386/1375
# Processed segment 387/1375
# Processed segment 388/1375
# Processed segment 389/1375
# Processed segment 390/1375
# Processed segment 391/1375
# Processed segment 392/1375
# Processed segment 393/1375
# Processed segment 394/1375
# Processed segment 395/1375
# Processed segment 396/1375
# Processed segment 397/1375
# Processed segment 398/1375
# Processed segment 399/1375
# Processed segment 400/1375
# Processed segment 401/1375
# Processed segment 402/1375
# Processed segment 403/1375
# Processed segment 404/1375
# Processed segment 405/1375
# Processed segment 406/1375
# Processed segment 407/1375
# Processed segment 408/1375
# Processed segment 409/1375
# Processed segment 410/1375
# Processed segment 411/1375
# Processed segment 412/1375
# Processed segment 413/1375
# Processed segment 414/1375
# Processed segment 415/1375
# Processed segment 416/1375
# Processed segment 417/1375
# Processed segment 418/1375
# Processed segment 419/1375
# Processed segment 420/1375
# Processed segment 421/1375
# Processed segment 422/1375
# Processed segment 423/1375
# Processed segment 424/1375
# Processed segment 425/1375
# Processed segment 426/1375
# Processed segment 427/1375
# Processed segment 428/1375
# Processed segment 429/1375
# Processed segment 430/1375
# Processed segment 431/1375
# Processed segment 432/1375
# Processed segment 433/1375
# Processed segment 434/1375
# Processed segment 435/1375
# Processed segment 436/1375
# Processed segment 437/1375
# Processed segment 438/1375
# Processed segment 439/1375
# Processed segment 440/1375
# Processed segment 441/1375
# Processed segment 442/1375
# Processed segment 443/1375
# Processed segment 444/1375
# Processed segment 445/1375
# Processed segment 446/1375
# Processed segment 447/1375
# Processed segment 448/1375
# Processed segment 449/1375
# Processed segment 450/1375
# Processed segment 451/1375
# Processed segment 452/1375
# Processed segment 453/1375
# Processed segment 454/1375
# Processed segment 455/1375
# Processed segment 456/1375
# Processed segment 457/1375
# Processed segment 458/1375
# Processed segment 459/1375
# Processed segment 460/1375
# Processed segment 461/1375
# Processed segment 462/1375
# Processed segment 463/1375
# Processed segment 464/1375
# Processed segment 465/1375
# Processed segment 466/1375
# Processed segment 467/1375
# Processed segment 468/1375
# Processed segment 469/1375
# Processed segment 470/1375
# Processed segment 471/1375
# Processed segment 472/1375
# Processed segment 473/1375
# Processed segment 474/1375
# Processed segment 475/1375
# Processed segment 476/1375
# Processed segment 477/1375
# Processed segment 478/1375
# Processed segment 479/1375
# Processed segment 480/1375
# Processed segment 481/1375
# Processed segment 482/1375
# Processed segment 483/1375
# Processed segment 484/1375
# Processed segment 485/1375
# Processed segment 486/1375
# Processed segment 487/1375
# Processed segment 488/1375
# Processed segment 489/1375
# Processed segment 490/1375
# Processed segment 491/1375
# Processed segment 492/1375
# Processed segment 493/1375
# Processed segment 494/1375
# Processed segment 495/1375
# Processed segment 496/1375
# Processed segment 497/1375
# Processed segment 498/1375
# Processed segment 499/1375
# Processed segment 500/1375
# Processed segment 501/1375
# Processed segment 502/1375
# Processed segment 503/1375
# Processed segment 504/1375
# Processed segment 505/1375
# Processed segment 506/1375
# Processed segment 507/1375
# Processed segment 508/1375
# Processed segment 509/1375
# Processed segment 510/1375
# Processed segment 511/1375
# Processed segment 512/1375
# Processed segment 513/1375
# Processed segment 514/1375
# Processed segment 515/1375
# Processed segment 516/1375
# Processed segment 517/1375
# Processed segment 518/1375
# Processed segment 519/1375
# Processed segment 520/1375
# Processed segment 521/1375
# Processed segment 522/1375
# Processed segment 523/1375
# Processed segment 524/1375
# Processed segment 525/1375
# Processed segment 526/1375
# Processed segment 527/1375
# Processed segment 528/1375
# Processed segment 529/1375
# Processed segment 530/1375
# Processed segment 531/1375
# Processed segment 532/1375
# Processed segment 533/1375
# Processed segment 534/1375
# Processed segment 535/1375
# Processed segment 536/1375
# Processed segment 537/1375
# Processed segment 538/1375
# Processed segment 539/1375
# Processed segment 540/1375
# Processed segment 541/1375
# Processed segment 542/1375
# Processed segment 543/1375
# Processed segment 544/1375
# Processed segment 545/1375
# Processed segment 546/1375
# Processed segment 547/1375
# Processed segment 548/1375
# Processed segment 549/1375
# Processed segment 550/1375
# Processed segment 551/1375
# Processed segment 552/1375
# Processed segment 553/1375
# Processed segment 554/1375
# Processed segment 555/1375
# Processed segment 556/1375
# Processed segment 557/1375
# Processed segment 558/1375
# Processed segment 559/1375
# Processed segment 560/1375
# Processed segment 561/1375
# Processed segment 562/1375
# Processed segment 563/1375
# Processed segment 564/1375
# Processed segment 565/1375
# Processed segment 566/1375
# Processed segment 567/1375
# Processed segment 568/1375
# Processed segment 569/1375
# Processed segment 570/1375
# Processed segment 571/1375
# Processed segment 572/1375
# Processed segment 573/1375
# Processed segment 574/1375
# Processed segment 575/1375
# Processed segment 576/1375
# Processed segment 577/1375
# Processed segment 578/1375
# Processed segment 579/1375
# Processed segment 580/1375
# Processed segment 581/1375
# Processed segment 582/1375
# Processed segment 583/1375
# Processed segment 584/1375
# Processed segment 585/1375
# Processed segment 586/1375
# Processed segment 587/1375
# Processed segment 588/1375
# Processed segment 589/1375
# Processed segment 590/1375
# Processed segment 591/1375
# Processed segment 592/1375
# Processed segment 593/1375
# Processed segment 594/1375
# Processed segment 595/1375
# Processed segment 596/1375
# Processed segment 597/1375
# Processed segment 598/1375
# Processed segment 599/1375
# Processed segment 600/1375
# Processed segment 601/1375
# Processed segment 602/1375
# Processed segment 603/1375
# Processed segment 604/1375
# Processed segment 605/1375
# Processed segment 606/1375
# Processed segment 607/1375
# Processed segment 608/1375
# Processed segment 609/1375
# Processed segment 610/1375
# Processed segment 611/1375
# Processed segment 612/1375
# Processed segment 613/1375
# Processed segment 614/1375
# Processed segment 615/1375
# Processed segment 616/1375
# Processed segment 617/1375
# Processed segment 618/1375
# Processed segment 619/1375
# Processed segment 620/1375
# Processed segment 621/1375
# Processed segment 622/1375
# Processed segment 623/1375
# Processed segment 624/1375
# Processed segment 625/1375
# Processed segment 626/1375
# Processed segment 627/1375
# Processed segment 628/1375
# Processed segment 629/1375
# Processed segment 630/1375
# Processed segment 631/1375
# Processed segment 632/1375
# Processed segment 633/1375
# Processed segment 634/1375
# Processed segment 635/1375
# Processed segment 636/1375
# Processed segment 637/1375
# Processed segment 638/1375
# Processed segment 639/1375
# Processed segment 640/1375
# Processed segment 641/1375
# Processed segment 642/1375
# Processed segment 643/1375
# Processed segment 644/1375
# Processed segment 645/1375
# Processed segment 646/1375
# Processed segment 647/1375
# Processed segment 648/1375
# Processed segment 649/1375
# Processed segment 650/1375
# Processed segment 651/1375
# Processed segment 652/1375
# Processed segment 653/1375
# Processed segment 654/1375
# Processed segment 655/1375
# Processed segment 656/1375
# Processed segment 657/1375
# Processed segment 658/1375
# Processed segment 659/1375
# Processed segment 660/1375
# Processed segment 661/1375
# Processed segment 662/1375
# Processed segment 663/1375
# Processed segment 664/1375
# Processed segment 665/1375
# Processed segment 666/1375
# Processed segment 667/1375
# Processed segment 668/1375
# Processed segment 669/1375
# Processed segment 670/1375
# Processed segment 671/1375
# Processed segment 672/1375
# Processed segment 673/1375
# Processed segment 674/1375
# Processed segment 675/1375
# Processed segment 676/1375
# Processed segment 677/1375
# Processed segment 678/1375
# Processed segment 679/1375
# Processed segment 680/1375
# Processed segment 681/1375
# Processed segment 682/1375
# Processed segment 683/1375
# Processed segment 684/1375
# Processed segment 685/1375
# Processed segment 686/1375
# Processed segment 687/1375
# Processed segment 688/1375
# Processed segment 689/1375
# Processed segment 690/1375
# Processed segment 691/1375
# Processed segment 692/1375
# Processed segment 693/1375
# Processed segment 694/1375
# Processed segment 695/1375
# Processed segment 696/1375
# Processed segment 697/1375
# Processed segment 698/1375
# Processed segment 699/1375
# Processed segment 700/1375
# Processed segment 701/1375
# Processed segment 702/1375
# Processed segment 703/1375
# Processed segment 704/1375
# Processed segment 705/1375
# Processed segment 706/1375
# Processed segment 707/1375
# Processed segment 708/1375
# Processed segment 709/1375
# Processed segment 710/1375
# Processed segment 711/1375
# Processed segment 712/1375
# Processed segment 713/1375
# Processed segment 714/1375
# Processed segment 715/1375
# Processed segment 716/1375
# Processed segment 717/1375
# Processed segment 718/1375
# Processed segment 719/1375
# Processed segment 720/1375
# Processed segment 721/1375
# Processed segment 722/1375
# Processed segment 723/1375
# Processed segment 724/1375
# Processed segment 725/1375
# Processed segment 726/1375
# Processed segment 727/1375
# Processed segment 728/1375
# Processed segment 729/1375
# Processed segment 730/1375
# Processed segment 731/1375
# Processed segment 732/1375
# Processed segment 733/1375
# Processed segment 734/1375
# Processed segment 735/1375
# Processed segment 736/1375
# Processed segment 737/1375
# Processed segment 738/1375
# Processed segment 739/1375
# Processed segment 740/1375
# Processed segment 741/1375
# Processed segment 742/1375
# Processed segment 743/1375
# Processed segment 744/1375
# Processed segment 745/1375
# Processed segment 746/1375
# Processed segment 747/1375
# Processed segment 748/1375
# Processed segment 749/1375
# Processed segment 750/1375
# Processed segment 751/1375
# Processed segment 752/1375
# Processed segment 753/1375
# Processed segment 754/1375
# Processed segment 755/1375
# Processed segment 756/1375
# Processed segment 757/1375
# Processed segment 758/1375
# Processed segment 759/1375
# Processed segment 760/1375
# Processed segment 761/1375
# Processed segment 762/1375
# Processed segment 763/1375
# Processed segment 764/1375
# Processed segment 765/1375
# Processed segment 766/1375
# Processed segment 767/1375
# Processed segment 768/1375
# Processed segment 769/1375
# Processed segment 770/1375
# Processed segment 771/1375
# Processed segment 772/1375
# Processed segment 773/1375
# Processed segment 774/1375
# Processed segment 775/1375
# Processed segment 776/1375
# Processed segment 777/1375
# Processed segment 778/1375
# Processed segment 779/1375
# Processed segment 780/1375
# Processed segment 781/1375
# Processed segment 782/1375
# Processed segment 783/1375
# Processed segment 784/1375
# Processed segment 785/1375
# Processed segment 786/1375
# Processed segment 787/1375
# Processed segment 788/1375
# Processed segment 789/1375
# Processed segment 790/1375
# Processed segment 791/1375
# Processed segment 792/1375
# Processed segment 793/1375
# Processed segment 794/1375
# Processed segment 795/1375
# Processed segment 796/1375
# Processed segment 797/1375
# Processed segment 798/1375
# Processed segment 799/1375
# Processed segment 800/1375
# Processed segment 801/1375
# Processed segment 802/1375
# Processed segment 803/1375
# Processed segment 804/1375
# Processed segment 805/1375
# Processed segment 806/1375
# Processed segment 807/1375
# Processed segment 808/1375
# Processed segment 809/1375
# Processed segment 810/1375
# Processed segment 811/1375
# Processed segment 812/1375
# Processed segment 813/1375
# Processed segment 814/1375
# Processed segment 815/1375
# Processed segment 816/1375
# Processed segment 817/1375
# Processed segment 818/1375
# Processed segment 819/1375
# Processed segment 820/1375
# Processed segment 821/1375
# Processed segment 822/1375
# Processed segment 823/1375
# Processed segment 824/1375
# Processed segment 825/1375
# Processed segment 826/1375
# Processed segment 827/1375
# Processed segment 828/1375
# Processed segment 829/1375
# Processed segment 830/1375
# Processed segment 831/1375
# Processed segment 832/1375
# Processed segment 833/1375
# Processed segment 834/1375
# Processed segment 835/1375
# Processed segment 836/1375
# Processed segment 837/1375
# Processed segment 838/1375
# Processed segment 839/1375
# Processed segment 840/1375
# Processed segment 841/1375
# Processed segment 842/1375
# Processed segment 843/1375
# Processed segment 844/1375
# Processed segment 845/1375
# Processed segment 846/1375
# Processed segment 847/1375
# Processed segment 848/1375
# Processed segment 849/1375
# Processed segment 850/1375
# Processed segment 851/1375
# Processed segment 852/1375
# Processed segment 853/1375
# Processed segment 854/1375
# Processed segment 855/1375
# Processed segment 856/1375
# Processed segment 857/1375
# Processed segment 858/1375
# Processed segment 859/1375
# Processed segment 860/1375
# Processed segment 861/1375
# Processed segment 862/1375
# Processed segment 863/1375
# Processed segment 864/1375
# Processed segment 865/1375
# Processed segment 866/1375
# Processed segment 867/1375
# Processed segment 868/1375
# Processed segment 869/1375
# Processed segment 870/1375
# Processed segment 871/1375
# Processed segment 872/1375
# Processed segment 873/1375
# Processed segment 874/1375
# Processed segment 875/1375
# Processed segment 876/1375
# Processed segment 877/1375
# Processed segment 878/1375
# Processed segment 879/1375
# Processed segment 880/1375
# Processed segment 881/1375
# Processed segment 882/1375
# Processed segment 883/1375
# Processed segment 884/1375
# Processed segment 885/1375
# Processed segment 886/1375
# Processed segment 887/1375
# Processed segment 888/1375
# Processed segment 889/1375
# Processed segment 890/1375
# Processed segment 891/1375
# Processed segment 892/1375
# Processed segment 893/1375
# Processed segment 894/1375
# Processed segment 895/1375
# Processed segment 896/1375
# Processed segment 897/1375
# Processed segment 898/1375
# Processed segment 899/1375
# Processed segment 900/1375
# Processed segment 901/1375
# Processed segment 902/1375
# Processed segment 903/1375
# Processed segment 904/1375
# Processed segment 905/1375
# Processed segment 906/1375
# Processed segment 907/1375
# Processed segment 908/1375
# Processed segment 909/1375
# Processed segment 910/1375
# Processed segment 911/1375
# Processed segment 912/1375
# Processed segment 913/1375
# Processed segment 914/1375
# Processed segment 915/1375
# Processed segment 916/1375
# Processed segment 917/1375
# Processed segment 918/1375
# Processed segment 919/1375
# Processed segment 920/1375
# Processed segment 921/1375
# Processed segment 922/1375
# Processed segment 923/1375
# Processed segment 924/1375
# Processed segment 925/1375
# Processed segment 926/1375
# Processed segment 927/1375
# Processed segment 928/1375
# Processed segment 929/1375
# Processed segment 930/1375
# Processed segment 931/1375
# Processed segment 932/1375
# Processed segment 933/1375
# Processed segment 934/1375
# Processed segment 935/1375
# Processed segment 936/1375
# Processed segment 937/1375
# Processed segment 938/1375
# Processed segment 939/1375
# Processed segment 940/1375
# Processed segment 941/1375
# Processed segment 942/1375
# Processed segment 943/1375
# Processed segment 944/1375
# Processed segment 945/1375
# Processed segment 946/1375
# Processed segment 947/1375
# Processed segment 948/1375
# Processed segment 949/1375
# Processed segment 950/1375
# Processed segment 951/1375
# Processed segment 952/1375
# Processed segment 953/1375
# Processed segment 954/1375
# Processed segment 955/1375
# Processed segment 956/1375
# Processed segment 957/1375
# Processed segment 958/1375
# Processed segment 959/1375
# Processed segment 960/1375
# Processed segment 961/1375
# Processed segment 962/1375
# Processed segment 963/1375
# Processed segment 964/1375
# Processed segment 965/1375
# Processed segment 966/1375
# Processed segment 967/1375
# Processed segment 968/1375
# Processed segment 969/1375
# Processed segment 970/1375
# Processed segment 971/1375
# Processed segment 972/1375
# Processed segment 973/1375
# Processed segment 974/1375
# Processed segment 975/1375
# Processed segment 976/1375
# Processed segment 977/1375
# Processed segment 978/1375
# Processed segment 979/1375
# Processed segment 980/1375
# Processed segment 981/1375
# Processed segment 982/1375
# Processed segment 983/1375
# Processed segment 984/1375
# Processed segment 985/1375
# Processed segment 986/1375
# Processed segment 987/1375
# Processed segment 988/1375
# Processed segment 989/1375
# Processed segment 990/1375
# Processed segment 991/1375
# Processed segment 992/1375
# Processed segment 993/1375
# Processed segment 994/1375
# Processed segment 995/1375
# Processed segment 996/1375
# Processed segment 997/1375
# Processed segment 998/1375
# Processed segment 999/1375
# Processed segment 1000/1375
# Processed segment 1001/1375
# Processed segment 1002/1375
# Processed segment 1003/1375
# Processed segment 1004/1375
# Processed segment 1005/1375
# Processed segment 1006/1375
# Processed segment 1007/1375
# Processed segment 1008/1375
# Processed segment 1009/1375
# Processed segment 1010/1375
# Processed segment 1011/1375
# Processed segment 1012/1375
# Processed segment 1013/1375
# Processed segment 1014/1375
# Processed segment 1015/1375
# Processed segment 1016/1375
# Processed segment 1017/1375
# Processed segment 1018/1375
# Processed segment 1019/1375
# Processed segment 1020/1375
# Processed segment 1021/1375
# Processed segment 1022/1375
# Processed segment 1023/1375
# Processed segment 1024/1375
# Processed segment 1025/1375
# Processed segment 1026/1375
# Processed segment 1027/1375
# Processed segment 1028/1375
# Processed segment 1029/1375
# Processed segment 1030/1375
# Processed segment 1031/1375
# Processed segment 1032/1375
# Processed segment 1033/1375
# Processed segment 1034/1375
# Processed segment 1035/1375
# Processed segment 1036/1375
# Processed segment 1037/1375
# Processed segment 1038/1375
# Processed segment 1039/1375
# Processed segment 1040/1375
# Processed segment 1041/1375
# Processed segment 1042/1375
# Processed segment 1043/1375
# Processed segment 1044/1375
# Processed segment 1045/1375
# Processed segment 1046/1375
# Processed segment 1047/1375
# Processed segment 1048/1375
# Processed segment 1049/1375
# Processed segment 1050/1375
# Processed segment 1051/1375
# Processed segment 1052/1375
# Processed segment 1053/1375
# Processed segment 1054/1375
# Processed segment 1055/1375
# Processed segment 1056/1375
# Processed segment 1057/1375
# Processed segment 1058/1375
# Processed segment 1059/1375
# Processed segment 1060/1375
# Processed segment 1061/1375
# Processed segment 1062/1375
# Processed segment 1063/1375
# Processed segment 1064/1375
# Processed segment 1065/1375
# Processed segment 1066/1375
# Processed segment 1067/1375
# Processed segment 1068/1375
# Processed segment 1069/1375
# Processed segment 1070/1375
# Processed segment 1071/1375
# Processed segment 1072/1375
# Processed segment 1073/1375
# Processed segment 1074/1375
# Processed segment 1075/1375
# Processed segment 1076/1375
# Processed segment 1077/1375
# Processed segment 1078/1375
# Processed segment 1079/1375
# Processed segment 1080/1375
# Processed segment 1081/1375
# Processed segment 1082/1375
# Processed segment 1083/1375
# Processed segment 1084/1375
# Processed segment 1085/1375
# Processed segment 1086/1375
# Processed segment 1087/1375
# Processed segment 1088/1375
# Processed segment 1089/1375
# Processed segment 1090/1375
# Processed segment 1091/1375
# Processed segment 1092/1375
# Processed segment 1093/1375
# Processed segment 1094/1375
# Processed segment 1095/1375
# Processed segment 1096/1375
# Processed segment 1097/1375
# Processed segment 1098/1375
# Processed segment 1099/1375
# Processed segment 1100/1375
# Processed segment 1101/1375
# Processed segment 1102/1375
# Processed segment 1103/1375
# Processed segment 1104/1375
# Processed segment 1105/1375
# Processed segment 1106/1375
# Processed segment 1107/1375
# Processed segment 1108/1375
# Processed segment 1109/1375
# Processed segment 1110/1375
# Processed segment 1111/1375
# Processed segment 1112/1375
# Processed segment 1113/1375
# Processed segment 1114/1375
# Processed segment 1115/1375
# Processed segment 1116/1375
# Processed segment 1117/1375
# Processed segment 1118/1375
# Processed segment 1119/1375
# Processed segment 1120/1375
# Processed segment 1121/1375
# Processed segment 1122/1375
# Processed segment 1123/1375
# Processed segment 1124/1375
# Processed segment 1125/1375
# Processed segment 1126/1375
# Processed segment 1127/1375
# Processed segment 1128/1375
# Processed segment 1129/1375
# Processed segment 1130/1375
# Processed segment 1131/1375
# Processed segment 1132/1375
# Processed segment 1133/1375
# Processed segment 1134/1375
# Processed segment 1135/1375
# Processed segment 1136/1375
# Processed segment 1137/1375
# Processed segment 1138/1375
# Processed segment 1139/1375
# Processed segment 1140/1375
# Processed segment 1141/1375
# Processed segment 1142/1375
# Processed segment 1143/1375
# Processed segment 1144/1375
# Processed segment 1145/1375
# Processed segment 1146/1375
# Processed segment 1147/1375
# Processed segment 1148/1375
# Processed segment 1149/1375
# Processed segment 1150/1375
# Processed segment 1151/1375
# Processed segment 1152/1375
# Processed segment 1153/1375
# Processed segment 1154/1375
# Processed segment 1155/1375
# Processed segment 1156/1375
# Processed segment 1157/1375
# Processed segment 1158/1375
# Processed segment 1159/1375
# Processed segment 1160/1375
# Processed segment 1161/1375
# Processed segment 1162/1375
# Processed segment 1163/1375
# Processed segment 1164/1375
# Processed segment 1165/1375
# Processed segment 1166/1375
# Processed segment 1167/1375
# Processed segment 1168/1375
# Processed segment 1169/1375
# Processed segment 1170/1375
# Processed segment 1171/1375
# Processed segment 1172/1375
# Processed segment 1173/1375
# Processed segment 1174/1375
# Processed segment 1175/1375
# Processed segment 1176/1375
# Processed segment 1177/1375
# Processed segment 1178/1375
# Processed segment 1179/1375
# Processed segment 1180/1375
# Processed segment 1181/1375
# Processed segment 1182/1375
# Processed segment 1183/1375
# Processed segment 1184/1375
# Processed segment 1185/1375
# Processed segment 1186/1375
# Processed segment 1187/1375
# Processed segment 1188/1375
# Processed segment 1189/1375
# Processed segment 1190/1375
# Processed segment 1191/1375
# Processed segment 1192/1375
# Processed segment 1193/1375
# Processed segment 1194/1375
# Processed segment 1195/1375
# Processed segment 1196/1375
# Processed segment 1197/1375
# Processed segment 1198/1375
# Processed segment 1199/1375
# Processed segment 1200/1375
# Processed segment 1201/1375
# Processed segment 1202/1375
# Processed segment 1203/1375
# Processed segment 1204/1375
# Processed segment 1205/1375
# Processed segment 1206/1375
# Processed segment 1207/1375
# Processed segment 1208/1375
# Processed segment 1209/1375
# Processed segment 1210/1375
# Processed segment 1211/1375
# Processed segment 1212/1375
# Processed segment 1213/1375
# Processed segment 1214/1375
# Processed segment 1215/1375
# Processed segment 1216/1375
# Processed segment 1217/1375
# Processed segment 1218/1375
# Processed segment 1219/1375
# Processed segment 1220/1375
# Processed segment 1221/1375
# Processed segment 1222/1375
# Processed segment 1223/1375
# Processed segment 1224/1375
# Processed segment 1225/1375
# Processed segment 1226/1375
# Processed segment 1227/1375
# Processed segment 1228/1375
# Processed segment 1229/1375
# Processed segment 1230/1375
# Processed segment 1231/1375
# Processed segment 1232/1375
# Processed segment 1233/1375
# Processed segment 1234/1375
# Processed segment 1235/1375
# Processed segment 1236/1375
# Processed segment 1237/1375
# Processed segment 1238/1375
# Processed segment 1239/1375
# Processed segment 1240/1375
# Processed segment 1241/1375
# Processed segment 1242/1375
# Processed segment 1243/1375
# Processed segment 1244/1375
# Processed segment 1245/1375
# Processed segment 1246/1375
# Processed segment 1247/1375
# Processed segment 1248/1375
# Processed segment 1249/1375
# Processed segment 1250/1375
# Processed segment 1251/1375
# Processed segment 1252/1375
# Processed segment 1253/1375
# Processed segment 1254/1375
# Processed segment 1255/1375
# Processed segment 1256/1375
# Processed segment 1257/1375
# Processed segment 1258/1375
# Processed segment 1259/1375
# Processed segment 1260/1375
# Processed segment 1261/1375
# Processed segment 1262/1375
# Processed segment 1263/1375
# Processed segment 1264/1375
# Processed segment 1265/1375
# Processed segment 1266/1375
# Processed segment 1267/1375
# Processed segment 1268/1375
# Processed segment 1269/1375
# Processed segment 1270/1375
# Processed segment 1271/1375
# Processed segment 1272/1375
# Processed segment 1273/1375
# Processed segment 1274/1375
# Processed segment 1275/1375
# Processed segment 1276/1375
# Processed segment 1277/1375
# Processed segment 1278/1375
# Processed segment 1279/1375
# Processed segment 1280/1375
# Processed segment 1281/1375
# Processed segment 1282/1375
# Processed segment 1283/1375
# Processed segment 1284/1375
# Processed segment 1285/1375
# Processed segment 1286/1375
# Processed segment 1287/1375
# Processed segment 1288/1375
# Processed segment 1289/1375
# Processed segment 1290/1375
# Processed segment 1291/1375
# Processed segment 1292/1375
# Processed segment 1293/1375
# Processed segment 1294/1375
# Processed segment 1295/1375
# Processed segment 1296/1375
# Processed segment 1297/1375
# Processed segment 1298/1375
# Processed segment 1299/1375
# Processed segment 1300/1375
# Processed segment 1301/1375
# Processed segment 1302/1375
# Processed segment 1303/1375
# Processed segment 1304/1375
# Processed segment 1305/1375
# Processed segment 1306/1375
# Processed segment 1307/1375
# Processed segment 1308/1375
# Processed segment 1309/1375
# Processed segment 1310/1375
# Processed segment 1311/1375
# Processed segment 1312/1375
# Processed segment 1313/1375
# Processed segment 1314/1375
# Processed segment 1315/1375
# Processed segment 1316/1375
# Processed segment 1317/1375
# Processed segment 1318/1375
# Processed segment 1319/1375
# Processed segment 1320/1375
# Processed segment 1321/1375
# Processed segment 1322/1375
# Processed segment 1323/1375
# Processed segment 1324/1375
# Processed segment 1325/1375
# Processed segment 1326/1375
# Processed segment 1327/1375
# Processed segment 1328/1375
# Processed segment 1329/1375
# Processed segment 1330/1375
# Processed segment 1331/1375
# Processed segment 1332/1375
# Processed segment 1333/1375
# Processed segment 1334/1375
# Processed segment 1335/1375
# Processed segment 1336/1375
# Processed segment 1337/1375
# Processed segment 1338/1375
# Processed segment 1339/1375
# Processed segment 1340/1375
# Processed segment 1341/1375
# Processed segment 1342/1375
# Processed segment 1343/1375
# Processed segment 1344/1375
# Processed segment 1345/1375
# Processed segment 1346/1375
# Processed segment 1347/1375
# Processed segment 1348/1375
# Processed segment 1349/1375
# Processed segment 1350/1375
# Processed segment 1351/1375
# Processed segment 1352/1375
# Processed segment 1353/1375
# Processed segment 1354/1375
# Processed segment 1355/1375
# Processed segment 1356/1375
# Processed segment 1357/1375
# Processed segment 1358/1375
# Processed segment 1359/1375
# Processed segment 1360/1375
# Processed segment 1361/1375
# Processed segment 1362/1375
# Processed segment 1363/1375
# Processed segment 1364/1375
# Processed segment 1365/1375
# Processed segment 1366/1375
# Processed segment 1367/1375
# Processed segment 1368/1375
# Processed segment 1369/1375
# Processed segment 1370/1375
# Processed segment 1371/1375
# Processed segment 1372/1375
# Processed segment 1373/1375
# Processed segment 1374/1375
# Processed segment 1375/1375

# %% [markdown]
# # Process participant data

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_accuracy = pd.DataFrame(columns=['task','accuracy'])

for task in tasks:
    
    accuracy = tasks_dict[task]['accuracy']
    df_temp = pd.DataFrame(
        np.stack((np.repeat(task, len(accuracy)), accuracy)).T, 
        columns=columns
    )
    
    df_accuracy = pd.concat([df_accuracy, df_temp])
    
df_accuracy['accuracy'] = df_accuracy['accuracy'].astype(float)

# %%
sns.set(style='white', rc={'figure.figsize':(6,6), "axes.titlesize":18}, font_scale=1.25)

ax = sns.barplot(data=df_accuracy, x='task', y='accuracy', palette='BuPu', alpha=0.75) #, kwargs=dict(alpha=0.5))
ax = sns.stripplot(data=df_accuracy, x='task', y='accuracy', palette='BuPu', size=5, edgecolor='black', linewidth=1,  dodge=True, alpha=0.6, ax=ax)
plt.xlabel('Story')
plt.ylabel('Accuracy')
plt.title('Next word prediction accuracy')
plt.ylim(0, 0.4)

sns.despine()

# %% [markdown]
# # Plot example word distributions

# %%
import random

# %%
# Out:
# (0.248032, 0.014439, 0.612868)

# %%
cm
# Out:
# [(0.7480046136101499, 0.8267435601691656, 0.9015916955017301),
#  (0.5490196078431373, 0.5855901576316801, 0.7751787773933103),
#  (0.5326874279123414, 0.2502883506343714, 0.612641291810842)]

# %%
sns.set(style='white', rc={'figure.figsize':(12,4), "axes.titlesize":12})

n_indices = 3

fig, axes = plt.subplots(1, n_indices)
axes = axes.flatten()
counter = 0

# for task in tasks:
task = tasks[1]

cmap = sns.color_palette("BuPu",n_indices) #Splitting the palette in the same amount of numbers bins


task_transcript = tasks_dict[task]['transcript']
task_responses = tasks_dict[task]['responses']
response_indices = random.sample(list(task_responses.keys()), n_indices)

for ax, cm, idx in zip(axes, cmap, response_indices):
    sns.histplot(task_responses[idx], stat="probability", ax=ax, color=cm, alpha=0.8)
    ax.set_ylabel('Probability')
    ax.tick_params(axis='x', rotation=45)
    ax.legend()
    
    sns.despine()
    ax.title.set_text(f'Correct word: {task_transcript[idx]}')
    counter += 1
    
plt.tight_layout()
plt.suptitle(f'Behavioral predictions - {task.capitalize()}', y=1.05)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Text(0.5, 1.05, 'Behavioral predictions - Bronx')

# %% [markdown]
# # Compare responses to GPT

# %%
from scipy.stats import pearsonr
task = tasks[0]

model_fn = f'task-{task}_gpt2-predictions_context-{window_size}.csv'
df_model = pd.read_csv(model_fn)

# %%
task_transcript = tasks_dict[task]['transcript']
task_responses = tasks_dict[task]['responses']
response_idxs = list(task_responses.keys())

df_comparison = pd.DataFrame(
    columns=['ground_truth', 'prob_human', 'prob_model', 'pred_human', 'pred_model', 'entropy', 'kl_divergence']
)

for idx in response_idxs:

    unique, counts = np.unique(task_responses[idx], return_counts=True)
    probs = counts / sum(counts)
    
    ground_truth = task_transcript[idx]

    pred_human = unique[probs.argmax()]
    pred_model = df_model.loc[idx]['predicted_word']
    
    prob_human = probs.max()
    prob_model = df_model.loc[idx]['probability']
    
    df_comparison.loc[len(df_comparison)] = {
        'ground_truth': ground_truth,
        'prob_human': prob_human,
        'prob_model': prob_model,
        'pred_human': pred_human,
        'pred_model': pred_model,
        'entropy': df_model.loc[idx]['entropy'],
        'kl_divergence': df_model.loc[idx]['kl_divergence'],
    }

df_comparison['pred_model'] = df_comparison['pred_model'].str.strip()

# %%
colors = df_comparison['prob_human'] - df_comparison['prob_model']
cmap = sns.color_palette("BuPu",9) #Splitting the palette in the same amount of numbers bins

# %%
human_right = (df_comparison['pred_human'] == df_comparison['ground_truth']).values
model_right = (df_comparison['pred_model'] == df_comparison['ground_truth']).values

both_right = np.logical_and(human_right, model_right)
both_wrong = np.logical_and(~human_right, ~model_right)

df_comparison['response_comparisons'] = ''
df_comparison['response_comparisons'][both_wrong] = 'Both incorrect'
df_comparison['response_comparisons'][human_right] = 'Human correct'
df_comparison['response_comparisons'][model_right] = 'Model correct'
df_comparison['response_comparisons'][both_right] = 'Both correct'
# Out:
# /dartfs/rc/lab/F/FinnLab/tommy/conda/envs/narratives/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /dartfs/rc/lab/F/FinnLab/tommy/conda/envs/narratives/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# /dartfs/rc/lab/F/FinnLab/tommy/conda/envs/narratives/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /dartfs/rc/lab/F/FinnLab/tommy/conda/envs/narratives/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
sns.set(style='white', rc={'figure.figsize':(8,6), "axes.titlesize":16}, font_scale=1.25)

# fig, axes = plt.subplots(2,3)
# axes = axes.flatten()



df_comparison = df_comparison.sort_values(by='response_comparisons')

ax = sns.scatterplot(
    data=df_comparison, x="prob_human", y="prob_model",
    s=35, edgecolor='gray', alpha=0.75, #color=cmap[2],
    palette='hls', hue="response_comparisons", 
)

ax.legend_.set_title(None)
ax.legend(fontsize=10, loc=4)


r, pval = pearsonr(df_comparison['prob_human'], df_comparison['prob_model'])

# # f'Pearson r = {r:.2f}'
sns.regplot(data=df_comparison, x="prob_human", y="prob_model",  scatter=False, label=f'Pearson r = {r:.2f}', color=".1", ax=ax)
plt.title(f'Word predictability - {task.capitalize()}')
plt.xlabel('Human prediction')
plt.ylabel('GPT prediction')

# # Hide the right and top spines
sns.despine()
# plt.legend(handlelength=0, handletextpad=0, loc=4,  prop={'size': 16})

# plt.tight_layout()

# %%
task_transcript
# Out:
# array(['So', 'I', 'was', ..., 'do', 'Thank', 'you'], dtype=object)

# %%
human_prediction
# Out:
# 'know'

# %%
ground_truth
# Out:
# 'was'

# %%
# Out:
#       Unnamed: 0 predicted_word  probability   entropy  kl_divergence
# 2              2             'm     0.098329  4.578187       3.378128
# 6              6           high     0.697481  1.547684       7.076402
# 9              9            was     0.147181  4.066482       4.340055
# 23            23           easy     0.075210  6.078683       4.947401
# 25            25            not     0.128821  4.625387       3.348750
# ...          ...            ...          ...       ...            ...
# 1508        1508            can     0.217412  3.176548       4.263406
# 324          324           much     0.728475  1.655667       5.022173
# 100          100             of     0.648846  2.623734       3.157355
# 173          173            put     0.121370  5.184013       2.259360
# 394          394             's     0.824224  1.286051       4.088149
#
# [643 rows x 5 columns]

# %% [markdown]
# # Show some probability distributions

# %%
df = df.append(last.iloc[-1], ignore_index=True)

# %%
from matplotlib import pyplot as plt

# %%
trial_index = 35
sns.histplot(transcript_responses[trial_index], stat="probability")
plt.title(f'Correct word: {all_words[trial_index]}')

# %%
sns.histplot(transcript_responses[45])

# %%
all_words[35]

# %%
import seaborn as sns

# %%
transcript_responses[26]

# %%
sns.histplot(transcript_responses[26])

# %%
for k, v in transcript_responses.items():
    print (len(v))

# %%
results

# %%
accuracy_stack

# %%
critical_trials.response.iloc[0]

# %%
df.apply(lambda x: ast.literal_eval(x))

# %%
dist.sum()
# Out:
# tensor(1.0000)

# %%
[d.get('Q0') for d in df_results.response]

# %%
task = 'black' # replace this string with those above

# set directories
base_dir = '/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavioral/'
# narratives_dir = '/dartfs/rc/lab/D/DBIC/DBIC/archive/narratives'

gentle_dir = os.path.join(base_dir, 'stimuli', 'gentle')
preproc_dir = os.path.join(base_dir, 'stimuli', 'preprocessed')

task_out_dir = os.path.join(preproc_dir, task)

if not os.path.exists(task_out_dir):
    os.makedirs(task_out_dir)
