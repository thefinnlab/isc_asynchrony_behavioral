# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings("ignore")
    
import os, sys, glob
import json
import re
import numpy as np
import pandas as pd
from natsort import natsorted
from manual_spellchecker import spell_checker
import inflect
from scipy import stats

sys.path.append('/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavior/code/utils/')

from config import *
# import dataset_utils as utils
from tommy_utils import nlp, statistics
from preproc_utils import load_model_results, divide_nwp_dataframe
import analysis_utils as analysis
# Out:
# 2024-11-17 18:23:02.221150: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-17 18:23:02.221228: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-17 18:23:02.221259: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-17 18:23:02.231024: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-17 18:23:07.807878: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Functions -- cleaning, aggregation, and analysis

# %% [markdown]
# ### Check and clean meta file

# %%
# importing shutil module  
import shutil
from pathlib import Path

def check_used_files(experiment_name, experiment_version, task, clean_errors=False, max_missing_responses=5):
    '''
    Grabs used files based on the meta file and results directory
    Returns list of subjects that were used and ones that had errors
    '''
    
    checker = {
        'complete': [],
        'incomplete': [],
        'error': [],
        'missing': [],
    }

    meta_dir = os.path.join('/dartfs/rc/lab/F/FinnLab/tommy/jspsych_experiments/utils/experiment_meta/', experiment_name)
    meta_file = pd.read_csv(os.path.join(meta_dir, f'{experiment_version}-{task}.csv'))
    
    source_dir = os.path.join(BASE_DIR, 'stimuli',  'presentation_orders', experiment_version, task, 'jspsych')
    results_dir = os.path.join(BASE_DIR, 'experiments',  experiment_name, 'results', experiment_version)
    
    # grab the used files
    used_fns = meta_file[meta_file['used'].fillna(0).astype(bool)]
    
    approve_ids = []
    
    # go through each used file
    for i, fn in used_fns.iterrows():
        # grab info regarding subject name and modality
        curr_path = Path(fn['subject_fns'])
        sub = curr_path.stem.split('_')[0]
        modality = curr_path.parents[0].stem
        
        # find the corresponding parameter file for the current subject
        parameter_fn = glob.glob(os.path.join(source_dir, f'{sub}*.json'))
        assert (len(parameter_fn) == 1)
        
        # load the parameter file to compare to the subject's results
        df_parameters = pd.read_json(parameter_fn[0], orient='records')
        df_parameters = df_parameters.dropna()
        df_parameters['word_index'] = df_parameters['word_index'].dropna().astype(int)
        
        # then grab the subject results
        sub_results_dir = os.path.join(results_dir, task, modality, sub)
        
        # load results from the completed experiment
        try:
            current_id, demographics, experience, responses = load_participant_results(sub_results_dir, sub)
            
            # append if approving
            approve_ids.append(current_id)
        except:
#             if os.path.exists(sub_results_dir):
            checker['error'].append((i, modality, sub))
            continue
            
        # check that all indices of trials match and all responses are there
        all_trials_complete = np.all(responses['word_index'] == df_parameters['word_index'])
        missing_response_threshold = sum(pd.isnull(responses['response'])) <= max_missing_responses
        
#         all_responses_complete = np.all(~pd.isnull(responses['response']))
        
        # also ensure that we have the right amount of demographics/experience questions
        all_checks_complete = np.all([
            all_trials_complete, 
            missing_response_threshold, 
            len(demographics)==4,
            len(experience)==2,
        ])
        
        if all_trials_complete and missing_response_threshold:
            # add to list of people completed
            checker['complete'].append((i, modality, sub, current_id))
        else:
            checker['incomplete'].append((i, modality, sub, current_id))
            
        del current_id
        
    if clean_errors:
        clean_meta_errors(checker, experiment_name, experiment_version, task)
        
        # run again and return from here now that its updated
        return check_used_files(experiment_name, experiment_version, task, clean_errors=False)
    else:
        return checker, approve_ids

def clean_meta_errors(checker, experiment_name, experiment_version, task):
    
    meta_dir = os.path.join('/dartfs/rc/lab/F/FinnLab/tommy/jspsych_experiments/utils/experiment_meta/', experiment_name)
    meta_fn = os.path.join(meta_dir, f'{experiment_version}-{task}.csv')
    
    meta_file = pd.read_csv(meta_fn)
    
    results_dir = os.path.join(BASE_DIR, 'experiments',  experiment_name, 'results', experiment_version)
    
    errors = checker['error']
    modalities = ['text', 'audio']
    
    if any(checker['error']):
        
        remove_idxs, _, _ = zip(*checker['error']) 
        remove_idxs = list(remove_idxs)
        
        for modality in modalities:

            # get errors for the current modality
            modality_errors = [error for error in errors if error[1] == modality]
            errors_dir = os.path.join(results_dir, task, modality, 'error')

            # get new errors dir if previous has files in it
            batch_errors = sorted(glob.glob(os.path.join(errors_dir, '*')))

            if any(batch_errors):
                last_error_dir = Path(batch_errors[-1]).stem
            else:
                last_error_dir = 'batch_1'

            if any(glob.glob(os.path.join(errors_dir, last_error_dir, '*'))):
                curr_batch_num = int(last_error_dir.split('_')[-1]) + 1
                curr_error_dir = os.path.join(errors_dir, f'batch_{curr_batch_num}')
                os.makedirs(curr_error_dir)
            else:
                curr_error_dir = os.path.join(errors_dir, last_error_dir)

            for item in modality_errors:
                file_idx, modality, sub = item

                # then grab the subject results
                sub_results_dir = os.path.join(results_dir, task, modality, sub)

                if os.path.exists(sub_results_dir):
                    print ('Here')
                    shutil.move(sub_results_dir, curr_error_dir)


        print (f'Cleaned meta file!')
        meta_file.loc[list(remove_idxs), 'used'] = None
        meta_file['used'] = meta_file['used'].astype('Int64')
        meta_file.to_csv(meta_fn, index=False)

# %% [markdown]
# ### Loading data

# %%
# def load_participant_results(sub_dir, sub):
    
#     # load and filter down to response trials
#     df_results = pd.read_csv(os.path.join(sub_dir, f'{sub}_next-word-prediction.csv')).fillna(False)
#     df_results['word_index'] = df_results['word_index'].astype(int)
    
#     # grab the prolific id
#     prolific_id = list(set(df_results['prolific_id']))

#     # filter down demographics
#     demographics = df_results[df_results['experiment_phase'].str.contains('demographics').fillna(False)]
#     demographics = demographics[['experiment_phase', 'response']].reset_index(drop=True)
    
#     # age, race, ethnicity, gender
#     assert (len(demographics) == 4)
    
#     # filter down to questinos about moth/story experience
#     experience = df_results[df_results['experiment_phase'].str.contains('experience').fillna(False)]
#     experience = experience[['experiment_phase', 'response']].reset_index(drop=True)
    
#     # moth experience + story experience
#     assert (len(experience) == 2)
    
#     # filter down to get the responses
#     responses = df_results[df_results['experiment_phase'] == 'test']
#     responses.loc[:,'response'] = responses['response'].str.lower()
#     responses = responses[['critical_word', 'word_index', 'entropy_group', 'accuracy_group', 'response', 'rt']].reset_index(drop=True)
    
#     return prolific_id[0], demographics, experience, responses


# import librosa

# def get_audio_duration(filepath):
#     """Gets the duration of an audio file in seconds."""
#     y, sr = librosa.load(filepath, sr=None)
#     return librosa.get_duration(y=y, sr=sr)

# def get_subject_audio_durations(stim_dir, n_orders=3):

#     orders = np.arange(1, n_orders + 1) # 3 orders for all tasks except black
#     df = pd.DataFrame(columns=['stim_order', 'audio_filename', 'duration'])

#     for order in orders:
#         fns = sorted(glob.glob(os.path.join(stim_dir, f'sub-{str(order).zfill(5)}', '*')))

#         for fn in fns:
#             duration = get_audio_duration(fn)

#             df.loc[len(df)] = {
#                 'stim_order': order - 1,
#                 'audio_filename': fn,
#                 'duration': duration * 1000
#             }
#     return df

# def aggregate_participant_responses(results_dir, stim_dir, task, sub_mod_list, n_orders=3):
    
#     df_results = pd.DataFrame(columns=['prolific_id', 'modality', 'subject',  'word_index', 'response', 'ground_truth', 'entropy_group', 'accuracy_group', 'rt'])
    
#     all_ids = []

#     df_order_durations = get_subject_audio_durations(os.path.join(stim_dir, task), n_orders=n_orders)
    
#     for sub, mod in sub_mod_list: 

#         # go through each task and get participant data
#         sub_dir = os.path.join(results_dir, task, mod, sub)
#         sub_stim_dir = os.path.join(stim_dir, task, sub)

#         current_order = (int(sub.split('-')[-1]) - 1) % n_orders
#         print (f'Current order: {current_order}')
        
#         df_duration = df_order_durations[df_order_durations['stim_order'] == current_order].reset_index(drop=True)

#         print (sub, mod)
#         if os.path.exists(sub_dir):
#             current_id, demographics, experience, responses = load_participant_results(sub_dir, sub)
#             responses['response'] = responses['response'].fillna('')

#             # for right now only focus on responses
#             for i, (index, response, critical_word, entropy_group, accuracy_group, rt) in enumerate(responses[['word_index', 'response', 'critical_word', 'entropy_group', 'accuracy_group', 'rt']].values):
                
#                 df_results.loc[len(df_results)] = {
#                     'prolific_id': current_id,
#                     'modality': mod,
#                     'subject': sub,
#                     'word_index': index,
#                     'response': response,
#                     'ground_truth': critical_word.lower(),
#                     'entropy_group': entropy_group, 
#                     'accuracy_group': accuracy_group,
#                     'rt': float(rt) - df_duration.loc[i, 'duration']
#                 }
            
#             all_ids.append(current_id)
#         else:
#             print (f'File not exists: {mod}, {sub}')
            
#     return df_results

# def strip_punctuation(text):
    
#     full_text = re.sub('[^A-Za-z0-9]+', '', text)
    
#     return full_text

# %% [markdown]
# ### Interactive data cleaning

# %%
import enchant, string, time
from IPython.display import clear_output

AUTO_REPLACE = {
    'mum': 'mom',
    'mums': 'mom',
    'okay': 'ok',
    'sh': 'she',
    'barefoote': 'barefoot',
    'cellphone': 'phone',
    'fag': 'cigarette',
    'lite': 'light',
    'yea': 'yes',
    'yeah': 'yes'
}

def clean_participant_responses(df_results, df_transcript):
    
    # grab indices of responses --> used to index back in
    response_indices = df_results['experiment_phase'] == 'test'
    response_indices = np.where(response_indices)[0]

    checked_indices = []
    
    # filter down to get the responses
    df_responses = df_results.iloc[response_indices, :].reset_index(drop=True)
    df_responses.loc[df_responses['response'] == False, 'response'] = ""
    df_responses['response'] = df_responses['response'].apply(lambda x: x.strip().lower())

    inflect_engine = inflect.engine()
    enc_dict = enchant.Dict("en_US")

    ##############################
    ###### Run autoreplace #######
    ##############################

    for k, v in AUTO_REPLACE.items():
        df_responses.loc[df_responses['response'] == k, 'response'] = v

    ##############################
    #### Run numbers replace #####
    ##############################

    for index, df in df_responses.iterrows():
        response = df['response']
         
        if response.isdigit():
            response = inflect_engine.number_to_words(response)
            df['response'] = response
            df_responses.iloc[df.name] = df
            checked_indices.append(index)

    ##############################
    ###### Run spell-check #######
    ##############################

    print (f'##########################\n' +
           f'### Running spellcheck ###\n' +
           f'##########################\n\n')

    time.sleep(2)

    for index, df in df_responses.iterrows():

        response = df['response']
        
        if response == '':
            continue
        
        # tokens = df['response'].split()
        if not enc_dict.check(response) or response in string.punctuation and index not in checked_indices:
            df = prompt_correct_response(df, df_transcript, enc_dict, prompt_correction=False)
            df_responses.iloc[df.name] = df
            checked_indices.append(index)
            

    ##############################
    ######## Find phrases ########
    ##############################

    clear_output(wait=False)
    print (f'##########################\n' +
           f'####### Find phrases #####\n' +
           f'##########################\n\n')

    time.sleep(2)

    # go through each row
    for index, df in df_responses.iterrows():
        response = df['response'].split()

        if len(response) > 1 and index not in checked_indices:
            df = prompt_correct_response(df, df_transcript, enc_dict, prompt_correction=False)
            df_responses.iloc[df.name] = df
            checked_indices.append(index)
        else:
            continue

    ##############################
    ######## Final check #########
    ##############################

    clear_output(wait=False)
    print (f'##########################\n' +
           f'####### Final check ######\n' +
           f'##########################\n\n')

    time.sleep(2)

    # go through each row
    for index, df in df_responses.iterrows():

        if index not in checked_indices:
            df = prompt_correct_response(df, df_transcript, enc_dict, prompt_correction=True)
            df_responses.iloc[df.name] = df
            checked_indices.append(index)
        
    df_results.iloc[response_indices] = df_responses

    return df_results

def prompt_correct_response(df_response, df_transcript, enc_dict, range_display=7, prompt_correction=False):
    
    word_index = df_response['word_index']
    response = df_response['response']
    ground_truth = df_response['critical_word']
    
    start_index = (word_index - range_display) if (word_index - range_display) >= 0 else 0 
    end_index = (word_index + range_display) if (word_index + range_display) - len(df_transcript) <= 0 else None
    
    # grab the context    
    start_context = df_transcript['Word_Written'].iloc[start_index:word_index]
    end_context = df_transcript['Word_Written'].iloc[word_index + 1:end_index]
    
    # display the word
    string_to_print = ""
    
    if start_index > 0:
        string_to_print+= ".... "
    
    string_to_print+= " ".join(start_context) + " " + "\033[43;30m" + response + "\033[m" + " " + " ".join(end_context)
    
    if end_index is not None and end_index < len(df_transcript):
        string_to_print+= " ...."

    clear_output(wait=False)

    print("\n\nCurrent Word: " + string_to_print)
    print ("Ground Truth: ", ground_truth)
    
    # suggestions = enc_dict.suggest(misspelled_word)
    if prompt_correction:
        prompt_correction = input('\nNeeds correction? [y/n]: ')
    
    if prompt_correction == 'y' or prompt_correction == False:
        suggestions = enc_dict.suggest(response)
        print("\Suggestions: ", suggestions)
        correct_word = input("\nCorrect Version: ")
        
        if correct_word == "-999":
            break_flag = True
            sys.exit(0)
        elif correct_word.isdigit() and int(correct_word) - 1 < len(suggestions): # User wants to use suggestion
            print (f'Using word: {suggestions[int(correct_word)-1]}')
            df_response['response'] = df_response['response'].replace(response, suggestions[int(correct_word)-1])
            time.sleep(2)
        elif len(correct_word) == 0: # User wants to Skip
            return df_response
        elif correct_word == "''" or correct_word == '""': # User wants to remove the word
            df_response['response'] = df_response['response'].replace(response, "")
        else:
            time.sleep(2)
            df_response['response'] = df_response['response'].replace(response, correct_word)

    return df_response

# %% [markdown]
# ### Lemmatization and accuracy functions

# %%
# from nltk import pos_tag
# from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
# from collections import defaultdict
# import re
# import spacy

# STOP_WORDS = stopwords.words('english')

# # Load the spaCy model globally
# SPACY_MODEL = spacy.load("en_core_web_sm")

# def get_pos_tags(text, strip_punc=True):
#     """
#     Creates POS tags of words in a text corpus. Before tagging,
#     performs case and white space normalization and punctuation
#     removal before tagging text.
    
#     Parameters
#     ----------
#     text : list of str
#         List of text samples (lecture transcript lines, quiz questions,
#         or quiz answers) to be processed.

#     Returns
#     -------
#     words_tags : list of tuples
#         The word-postag pairings for the list of text samples with 
#         preprocessing steps applied to each element.
#     """

#     # clean spacing, normalize case, strip puncutation
#     # (temporarily leave punctuation useful for POS tagging)
#     full_text = ' '.join(text) #.lower()
    
#     if strip_punc:
#         # TLB 10/26/22 - removing ignoring of apostrophe
#         # re.sub("[^a-zA-Z\s'-]+", '', full_text)
#         full_text = re.sub("[^a-zA-Z\s'-]+", '', full_text)
    
#     # POS tagging (works better on full transcript, more context provided)
#     words_tags = pos_tag(full_text.split())

#     #case normalize word -> case doesn't matter anymore
#     return [(word.lower(), tag) for word, tag in words_tags]

# def get_lemma(word, tag, remove_stopwords=True, backend='spacy'):
#     """
#     Handles lemmatization of words. Removes stopwords and alpha-numeric
#     words from the text.
    
#     Parameters
#     ----------
#     word_tag : tuple of str
#         Tuple containing the word to be lemmatized and the accompanying
#         WordNet POS.

#     Returns
#     -------
#     lemma : str
#         The word-postag pairings for the list of text samples with 
#         preprocessing steps applied to each element.
#     """

#     # if "'" in word:
#     #     word = word.split("'")[0]

#     if "'" in word and "n't" in word:
#         lemma = word #"not"
#         return lemma
        
#     # remove stop words & digits
#     if remove_stopwords and word in STOP_WORDS or any(c.isdigit() for c in word):
#         return None
    
#     if backend == 'spacy':

#         doc = SPACY_MODEL(word)
#         lemma = doc[0].lemma_

#     elif backend == 'nltk':

#         lemmatizer = WordNetLemmatizer()
        
#         # POS tag mapping, format: {Treebank tag (1st letter only): Wordnet}
#         tagset_mapping = defaultdict(
#             lambda: 'n',   # defaults to noun
#             {
#                 'N': 'n',  # noun types
#                 'P': 'n',  # pronoun types, predeterminers
#                 'V': 'v',  # verb types
#                 'J': 'a',  # adjective types
#                 'D': 'a',  # determiner
#                 'R': 'r'   # adverb types
#             })

#         # convert Treebank POS tags to WordNet POS tags; lemmatize
#         tag = tagset_mapping[tag[0]]
#         lemma = lemmatizer.lemmatize(word, tag)
    
#     return lemma

def make_transcript_context(word, df_transcript, word_index, range_display=10):
    start_index = (word_index - range_display) if (word_index - range_display) >= 0 else 0 
    end_index = (word_index + range_display) if (word_index + range_display) - len(df_transcript) <= 0 else None

    # grab the context    
    start_context = df_transcript['word'].iloc[start_index:word_index]
    end_context = df_transcript['word'].iloc[word_index + 1:end_index]

    context = " ".join(start_context) + " " + str(word) + " " + " ".join(end_context)

    index = word_index - start_index

    return context, index

def lemmatize_responses(df_results, df_transcript, response_column='response'):
    
    for i, df in df_results.iterrows():
        response = df[response_column]
        ground_truth = df['ground_truth']
        word_index = df['word_index']

        # find the lemma of the response
        context, index = make_transcript_context(response, df_transcript, word_index)
        response, response_tag = get_pos_tags([context])[index]
        response_lemma = get_lemma(response, response_tag, remove_stopwords=False)
        df_results.loc[i, response_column] = response_lemma

        print (f'Word: {response} \t Lemma: {response_lemma}')
        
        # find the lemma of the ground truth
        context, index = make_transcript_context(ground_truth, df_transcript, word_index)
        ground_truth, ground_truth_tag = get_pos_tags([context])[index]
        ground_truth_lemma = get_lemma(ground_truth, ground_truth_tag, remove_stopwords=False)
        df_results.loc[i, 'ground_truth'] = ground_truth_lemma

        print (f'GT: {ground_truth} \t GTLemma: {ground_truth_lemma}')


    return df_results

def calculate_results_accuracy(df_results):

    # compare response to ground truth
    df_results['accuracy'] = df_results['response'] == df_results['ground_truth']
    df_results['accuracy'] = df_results['accuracy'].astype(int)

    df_accuracy = df_results.groupby(['prolific_id', 'modality', 'subject'])['accuracy'].mean() \
    .reset_index() \
    .sort_values(by='accuracy', ascending=True)

    return df_results, df_accuracy

# %% [markdown]
# ### Analysis of human data

# %%
from scipy.spatial.distance import cdist

def get_human_probs(responses):
    
    unique, counts = np.unique(responses, return_counts=True)
    probs = counts / sum(counts)
    
    return probs, unique

def strip_punctuation(text):
    
    full_text = re.sub('[^A-Za-z0-9]+', '', text)
    
    return full_text

def analyze_human_results(df_transcript, df_results, word_model_info, window_size=25, top_n=5, drop_rt=None):

    if drop_rt:
        print (f'Dropping trials with RTs longer than {drop_rt} seconds')
        drop_rt = drop_rt * 1000
    
    word_model_name, word_model = word_model_info
    
    # load the masked language model
    tokenizer, model = nlp.load_mlm_model(model_name='sentence-transformers/all-mpnet-base-v2', cache_dir=CACHE_DIR)
    
    df_collapse = pd.DataFrame(columns=[
        'modality',
        'word_index',
        'ground_truth',
        'n_predictions',
        'top_pred',
        'top_prob',
        'distribution_std',
        'entropy',
        'normalized_entropy',
        'all_response_entropy',
        'predictability',
        'accuracy',
        'bert_top_word_accuracy',
        f'{word_model_name}_top_word_accuracy',
        f'{word_model_name}_avg_accuracy',
        f'{word_model_name}_max_accuracy',
        f'{word_model_name}_weighted_pred-gt_accuracy',
        f'{word_model_name}_prediction_distances',
        f'{word_model_name}_weighted_prediction_distances',
        f'{word_model_name}_centroid_prediction_distances',
        'entropy_accuracy_group',
        'n_rt_drops',
        'average_rt',
        'std_rt',
    ])
    
    df_results['response'] = df_results['response'].apply(lambda x: strip_punctuation(x) if isinstance(x, str) else '')
    
    # get segments for BERT embedding
    segments = nlp.get_segment_indices(n_words=len(df_transcript), window_size=window_size, bidirectional=True)
    
    for index, df_index in df_results.groupby('word_index'):

        print (f'Word {index}')
    
        # get all responses regardless of modality
        all_responses = list(np.unique(df_index['response']))
        ground_truth = np.unique(df_index['ground_truth'])
    
        # ensure only one ground truth word
        assert (len(ground_truth) == 1)
    
        # get bert ground-truth embedding
        word_index = np.where(segments[index] == index)[0]
        inputs = nlp.transcript_to_input(df_transcript, idxs=segments[index])
        bert_gt_embedding = nlp.extract_word_embeddings([inputs], tokenizer, model, word_indices=word_index).squeeze()
        bert_gt_embedding = bert_gt_embedding[-1, :][np.newaxis]
    
        # go through each modality and calculate results
        for modality, df_modality in df_index.groupby('modality'):

            if drop_rt:
                rt_filter = df_modality['rt'] <= drop_rt
                df_modality = df_modality.loc[rt_filter, :]
            
                print (f'Kept {sum(rt_filter)} responses')
    
            human_responses = df_modality['response']
            rts = df_modality['rt']
    
            #######################################
            ### Get probabilities for each word ###
            #######################################
    
            # get probabilities and unique words for current modality
            human_probs, unique_words = get_human_probs(human_responses)
    
            # reconcile the modality responses with all human responses --> 
            # lets us calculate entropy over same number of words
            word_idxs = [all_responses.index(word) for word in unique_words]    
            temp = np.zeros(len(all_responses))
            temp[:] = 1e-100
            temp[word_idxs] = human_probs
            all_response_probs = temp / temp.sum()
    
            #######################################
            #### Calculate probability metrics ####
            #### 1. Predictability             ####
            #### 2. Entropy                    ####
            #### 3. Top probabiltity           ####
            #######################################
    
            # get predictability scores --> 
            # predictability is the count of number of accurate predictions over total predictions
            predictability =  sum(np.asarray(human_responses) == ground_truth) / len(human_responses)
            
            # calculate entropy
            entropy = stats.entropy(human_probs)
            norm_entropy = entropy / np.log(len(human_probs))

            # calculate entropy over all responses
            all_response_entropy = stats.entropy(all_response_probs)
    
            #######################################
            #### Calculate accuracy metrics    ####
            #### 1. Binary accuracy            ####
            #### 2. Continuous accuracy        ####
            ####     - fasttext/word-model     ####
            ####     - BERT                    ####
            #### 3. Top probabiltity           ####
            #######################################
    
            # sort the probabilities from highest to lowest
            sorted_prob_idxs = np.argsort(human_probs)[::-1]
            sorted_probs = human_probs[sorted_prob_idxs]
    
            # first trim down to the number of top words to use
            if top_n is not None and len(unique_words) < top_n:
                # grab all the unique words
                all_word_idxs = sorted_prob_idxs[:len(unique_words)]
                top_n_words = unique_words[all_word_idxs]
            else:
                # grab the top words
                top_word_idxs = sorted_prob_idxs[:top_n]
                top_n_words = unique_words[top_word_idxs]
    
            top_word = top_n_words[0]
            top_prob = sorted_probs[0]
            
            # 1. Binary accuracy: top-1 accuracy 
            binary_accuracy = top_word == ground_truth

            # 2. Continuous accuracy (word-model):
            #    Given a word model (e.g., word2vec, fasttext), 
            #    get the cosine similarity b/w top prediction and ground-truth
            top_word_accuracy, _ = nlp.get_word_vector_metrics(word_model, [top_word], ground_truth[0])
            max_pred_similarity, _ = nlp.get_word_vector_metrics(word_model, top_n_words, ground_truth[0], method='max')
            
            # 3. Prediction density: density of word vectors produced from 
            pred_similarity, pred_distances = nlp.get_word_vector_metrics(word_model, top_n_words, ground_truth[0])
            
            # get average similarity and distance weighted by the respective proportion of 
            # participants that predicted it
            weighted_pred_distances = np.nanmean(pred_distances * sorted_probs)
            weighted_pred_similarity = np.nanmean(pred_similarity * sorted_probs)

            # get distance to centroid
            predicted_vectors = [word_model[word] for word in unique_words if word in word_model]
            predicted_vectors = np.stack(predicted_vectors)

            centroid_distance = cdist(predicted_vectors.mean(0)[np.newaxis], predicted_vectors, metric='cosine')
            centroid_distance = np.nanmean(centroid_distance)

            if np.isnan(pred_distances):
                pred_distances = 0
    
            # create a copy and substitute word in
            df_substitute = df_transcript.copy()
            df_substitute.loc[index, 'word'] = top_word
    
            # embed the word into BERT space and get similarity
            inputs = nlp.transcript_to_input(df_substitute, idxs=segments[index])
            bert_top_word_embedding = nlp.extract_word_embeddings([inputs], tokenizer, model, word_indices=word_index).squeeze()
            bert_top_word_embedding = bert_top_word_embedding[-1, :][np.newaxis]
            
            bert_similarity = 1 - cdist(bert_gt_embedding, bert_top_word_embedding, metric='cosine').squeeze()
    
            #######################################
            ##### Add to the overall dataframe ####
            #######################################
    
            # binary accuracy of 1 or 0
            accuracy = (top_word == ground_truth).astype(int).squeeze()
            entropy_accuracy_group = df_modality['entropy_group'].iloc[0] + '-' + df_modality['accuracy_group'].iloc[0]
    
            df_collapse.loc[len(df_collapse)] = {
                'modality': modality,
                'word_index': index,
                'ground_truth': ground_truth[0],
                'n_predictions': len(unique_words),
                'top_pred': top_word,
                'top_prob': top_prob,
                'distribution_std': np.std(human_probs),
                'entropy': entropy,
                'normalized_entropy': np.nan_to_num(norm_entropy), 
                'all_response_entropy': all_response_entropy,
                'predictability': predictability,
                'accuracy': accuracy,
                'bert_top_word_accuracy': bert_similarity,
                f'{word_model_name}_top_word_accuracy': top_word_accuracy,
                f'{word_model_name}_avg_accuracy': np.nanmean(pred_similarity),
                f'{word_model_name}_max_accuracy': max_pred_similarity,
                f'{word_model_name}_weighted_pred-gt_accuracy': weighted_pred_similarity,
                f'{word_model_name}_prediction_distances': pred_distances,
                f'{word_model_name}_weighted_prediction_distances': weighted_pred_distances,
                f'{word_model_name}_centroid_prediction_distances': centroid_distance,
                'entropy_accuracy_group': entropy_accuracy_group,
                'n_rt_drops': sum(rt_filter) if drop_rt is not None else 0,
                'average_rt': rts.mean(),
                'std_rt': rts.std(),
            }
    
    return df_collapse

# %% [markdown]
# ### Aggregation of human and LLM data

# %%
def get_model_word_quadrants(model_name, task, selected_idxs=None, accuracy_type='word2vec_avg_accuracy'):
    
    # FOR DIVIDING THE MODEL RESULTS INTO QUADRANTS
    ACCURACY_TYPE = accuracy_type
    ACCURACY_PERCENTILE = 50
    WINDOW_SIZE = 100
    TOP_N = 5
    
    preproc_dir = os.path.join(BASE_DIR, 'stimuli', 'preprocessed')
    
    # load our preprocessed file --> get the indices of the prediction words
    df_preproc = pd.read_csv(os.path.join(preproc_dir, task, f'{task}_transcript-preprocessed.csv'))
    nwp_idxs = np.where(df_preproc['NWP_Candidate'])[0]
    
    # select based on model quadrants --> trim down to only the words of interest
    model_results = load_model_results(models_dir, model_name=model_name, task=task, window_size=WINDOW_SIZE, top_n=TOP_N)
    model_results.loc[:, 'binary_accuracy'] = model_results['binary_accuracy'].astype(bool)
    model_results = model_results.iloc[nwp_idxs]
    
    # now grab the current model divided over the 50th percentile
    # while we originally divided words on the 45th percentile of gpt2, we want to see patterns across models
    df_divide = divide_nwp_dataframe(model_results, accuracy_type=ACCURACY_TYPE, percentile=ACCURACY_PERCENTILE, drop=False)
    
    return df_divide.loc[selected_idxs, ['entropy_group', 'accuracy_group']]
    
def compare_human_model_accuracy(human_results, model_names, word_model_info, task, top_n=1, window_size=25, lemmatize=False):
    
    # set the directories we need
    models_dir = os.path.join(BASE_DIR, 'derivatives/model-predictions')
    preproc_dir = os.path.join(BASE_DIR, 'stimuli/preprocessed', task)

    # load our preprocessed file --> get the indices of the prediction words
    df_transcript = pd.read_csv(os.path.join(preproc_dir, f'{task}_transcript-preprocessed.csv'))
    df_transcript = df_transcript.rename(columns={'Word_Written': 'word', 'Punctuation': 'punctuation'})

    df_selected = pd.read_csv(os.path.join(preproc_dir, f'{task}_transcript-selected.csv'))
    selected_idxs = np.where(df_selected['NWP_Candidate'])[0]
    
    # first get top 1 prediction for humans within each modality
    df_collapsed_results = analyze_human_results(df_transcript, human_results, word_model_info, top_n=top_n)
    word_model_name, word_model = word_model_info
    
    ## TLB THIS IS A HACK CHANG IT
    ### YOU KNOW IT IS CHANGE IT
    all_ground_truth_words = df_collapsed_results[df_collapsed_results['modality'] == 'audio']['ground_truth'].tolist()

    # start the list with the human results
    human_model_combined = [df_collapsed_results]
    
    for model_name in model_names:
        
        # load the results for the current model
        model_results = load_model_results(models_dir, model_name=model_name, task=task, top_n=top_n, window_size=window_size)
        model_results['top_pred'] = model_results['top_n_predictions'].str[0]
        model_results = model_results.rename(columns={'ground_truth_prob': 'predictability'})
        # model_results_trimmed = model_results.loc[selected_idxs, :]
        
        # trim down to only predicted word accuracies
        model_results_trimmed = model_results.loc[selected_idxs, ['top_pred', 'top_prob', 'predictability', f'{word_model_name}_avg_accuracy', 'entropy']]
        model_results_trimmed = model_results_trimmed.reset_index().rename(columns={'index': 'word_index'})
        model_results_trimmed['modality'] = model_name

        # get the quadrants and determine entropy accuracy groups
        model_quadrants = get_model_word_quadrants(model_name, task, selected_idxs, accuracy_type=f'{word_model_name}_max_accuracy').reset_index(drop=True)
        entropy_accuracy_groups = model_quadrants['entropy_group'] + '-' +  model_quadrants['accuracy_group']

        # add in entropy accuracy quadrant organization to the dataframe
        model_results_trimmed['entropy_accuracy_group'] = entropy_accuracy_groups    
        model_results_trimmed['ground_truth'] = all_ground_truth_words

        # lemmatize if wanted
        if lemmatize:
            model_results_trimmed = lemmatize_responses(model_results_trimmed, df_transcript, response_column='top_pred')
        
        human_model_combined.append(model_results_trimmed)
    
    # concatenate all dataframes 
    human_model_combined = pd.concat(human_model_combined).reset_index(drop=True)
    
    # use gpt2-xl as our model of organizing human results
    if 'prosody' not in model_names[0]:
        entropy_accuracy = human_model_combined[human_model_combined['modality'] == 'gpt2-xl']['entropy_accuracy_group'].tolist()   
        human_model_combined.loc[human_model_combined['modality'] == 'audio', 'entropy_accuracy_group'] = entropy_accuracy
        human_model_combined.loc[human_model_combined['modality'] == 'text', 'entropy_accuracy_group'] = entropy_accuracy

    # calculate accuracy
    human_model_combined['accuracy'] = human_model_combined['top_pred'] == human_model_combined['ground_truth']
    human_model_combined['accuracy'] = human_model_combined['accuracy'].astype(int) * 100

    print (f"Total missing values: {human_model_combined[f'{word_model_name}_avg_accuracy'].isna().sum()}")

    # select the columns that we want to save out for gross-comparison
    selected_columns = ['modality', 'word_index', 'top_pred', 'ground_truth', 'accuracy', f'{word_model_name}_avg_accuracy', 
                        'top_prob', 'predictability', 'entropy', 'entropy_accuracy_group']
    
    human_model_combined = human_model_combined.loc[:, selected_columns]
    
    return human_model_combined

# %% [markdown]
# ### Comparison of probability distributions

# %%
import torch
from torch.nn import functional as F
from scipy.special import kl_div, rel_entr
from scipy import stats
from scipy.spatial import distance

def load_logits(model_dir, model_name, task, window_size, word_index):
    '''
    Loads model data from directory
    '''

    if 'prosody' in model_name:
        model_dir = os.path.join(model_dir, task, 'prosody-models', model_name, f'window-size-{window_size}')
    else:
        model_dir = os.path.join(model_dir, task, model_name, f'window-size-{window_size}')

    logits_fns = natsorted(glob.glob(os.path.join(model_dir, 'logits', f'*{str(word_index).zfill(5)}*.pt')))
    
    assert (len(logits_fns) == 1)
    
    return torch.load(logits_fns[0])

def compare_human_model_distributions(tokenizer, word_model, human_responses, all_responses, model_logits, ground_truth):
    
    df = pd.DataFrame(columns=[
        'top_word_human', 
        'top_word_model',
        'top_word_model_adjusted',
        'prob_human',
        'prob_model',
        'prob_model_adjusted', 
        'prob_model_human_pred',
        'predictability_model',
        'predictability_human',
        'continuous_predictability_human',
        'log_odds_predictability_model',
        'log_odds_predictability_human',
        'log_odds_continuous_predictability_human',
        'entropy',
        'kl_divergence',
        'relative_entropy',
        'wasserstein_dist',
        'jensenshannon_dist',
        'ks_stat'
    ])
    
    pre_filter = len(human_responses)
    human_responses = list(filter(None, human_responses))
    post_filter = len(human_responses)
    
    if pre_filter != post_filter:
        print (f'Removed {pre_filter - post_filter} empty responses')
    
    model_probs = F.softmax(model_logits, dim=-1).squeeze()
    prob_model = model_probs.max().item()
    top_word_model = tokenizer.decode(model_probs.argmax())

    entropy = stats.entropy(model_probs)
    
    ## get ground truth word prob
    gt_token = tokenizer.encode(ground_truth)
    gt_predictability_model = model_probs[gt_token].mean(0).item()
   
    # continuous predictability - average semantic distance of words from ground truth word
    human_predictability = sum(np.asarray(human_responses) == ground_truth) / len(human_responses)
    continuous_predictability = (1 - distance.cdist(word_model[ground_truth][np.newaxis], word_model[human_responses], metric='cosine')).mean()

    if human_predictability == 0:
        log_odds_human_predictability = statistics.log_odds(1e-2)
    else:
        log_odds_human_predictability = statistics.log_odds(human_predictability)

    log_odds_model_predictability = statistics.log_odds(gt_predictability_model)
    log_odds_continuous_predictability = statistics.log_odds(continuous_predictability)
        
    # get the probability distribution of the human responses --> also return the unique words
    human_probs, unique_words = get_human_probs(human_responses)
    prob_human = human_probs.max()
    
    # get the words indices in the overall array then add in the human probs
    word_idxs = [all_responses.index(word) for word in unique_words]    
    temp = np.zeros(len(all_responses))
    temp[word_idxs] = human_probs
    human_probs = temp
    
    # get probability of the words humans chose within the model distribution
    # then normalize to the number of samples
    model_adjusted_probs = np.asarray([nlp.get_word_prob(tokenizer, word, model_logits) for word in all_responses])
    model_adjusted_probs = model_adjusted_probs / model_adjusted_probs.sum()

    # select the probability of the top word that humans chose
    prob_model_adjusted = model_adjusted_probs[model_adjusted_probs.argmax()]
    prob_model_human_pred = model_adjusted_probs[human_probs.argmax()]

    # grab the human and model top words
    top_word_human = all_responses[human_probs.argmax()]
    top_word_model_adjusted = all_responses[model_adjusted_probs.argmax()]

    # now calculate kl divergence between the human and adjusted model distribution
    # measures how different P (human) is from Q (model) distribution
    #  KL divergence of P from Q is the expected excess surprise from 
    #  using Q as a model when the actual distribution is P
    kl_divergence = kl_div(human_probs, model_adjusted_probs)
    kl_divergence[np.isinf(kl_divergence)] = 0
    kl_divergence = kl_divergence.sum().item()
    
    relative_entropy = rel_entr(human_probs, model_adjusted_probs).sum().item()
    
    # earth movers distance between adjusted probs
    wasserstein_dist = stats.wasserstein_distance(human_probs, model_adjusted_probs)
    
    jensenshannon_dist = distance.jensenshannon(human_probs, model_adjusted_probs)
    
    ks_stats = stats.kstest(human_probs, model_adjusted_probs)
    
    df.loc[len(df)] = {
        'top_word_human': top_word_human,
        'top_word_model': top_word_model,
        'top_word_model_adjusted': top_word_model,
        'prob_human': prob_human,
        'prob_model': prob_model,
        'prob_model_adjusted': prob_model_adjusted, 
        'prob_model_human_pred': prob_model_human_pred,
        'predictability_model': gt_predictability_model,
        'predictability_human': human_predictability,
        'continuous_predictability_human': continuous_predictability,
        'log_odds_predictability_human': log_odds_human_predictability.astype(float),
        'log_odds_predictability_model': log_odds_model_predictability.astype(float),
        'log_odds_continuous_predictability_human': log_odds_continuous_predictability.astype(float),
        'entropy': entropy,
        'kl_divergence': kl_divergence,
        'relative_entropy': relative_entropy,
        'wasserstein_dist': wasserstein_dist,
        'jensenshannon_dist': jensenshannon_dist,
        'ks_stat': ks_stats[0]
    }
    
    return df

# %% [markdown]
# ## Data cleaning

# %%
EXPERIMENT_NAME = 'next-word-prediction'
EXPERIMENT_VERSION = 'final-multimodal-01'
TASK = 'wheretheressmoke'

# set the directories we need
gentle_dir = os.path.join(BASE_DIR, 'stimuli/gentle')
results_dir = os.path.join(BASE_DIR, 'experiments',  EXPERIMENT_NAME, 'results', EXPERIMENT_VERSION)
preproc_dir = os.path.join(BASE_DIR, 'stimuli/preprocessed')
models_dir = os.path.join(BASE_DIR, 'derivatives/model-predictions')

# make directories
cleaned_results_dir = os.path.join(BASE_DIR, 'experiments',  EXPERIMENT_NAME, 'cleaned-results', EXPERIMENT_VERSION)
behavioral_dir = os.path.join(BASE_DIR, 'derivatives/results/behavioral/')
stim_dir = os.path.join(BASE_DIR, f'stimuli/cut_audio/{EXPERIMENT_VERSION}')

# utils.attempt_makedirs(behavioral_dir)

# %%
word_model_name = 'fasttext'
word_model = nlp.load_word_model(model_name=word_model_name, cache_dir=CACHE_DIR)
word_model_info = (word_model_name, word_model)
# Out:
# Loading fasttext from saved .bin file.

# %%
# load transcript
df_transcript = pd.read_csv(os.path.join(preproc_dir, TASK, f'{TASK}_transcript-selected_prosody.csv'))
# df_transcript = df_transcript.rename(columns={'Word_Written': 'word', 'Punctuation': 'punctuation'})

prosody_columns = [
    'prominence', 'prominence_mean', 'prominence_std', 
    'relative_prominence', 'relative_prominence_norm',
    'boundary', 'boundary_mean', 'boundary_std', 
]

# %%
df_transcript.loc[df_aggregated_results['word_index'], prosody_columns]
# Out:
#       prominence  prominence_mean  prominence_std  relative_prominence  \
# 4          1.210           0.4808        0.537948               0.7292
# 38         1.147           0.1800        0.312102               0.9670
# 61         0.870           0.2798        0.303629               0.5902
# 83         1.718           0.3008        0.547868               1.4172
# 130        1.056           0.5346        0.703242               0.5214
# ...          ...              ...             ...                  ...
# 1683       1.754           0.6616        0.965895               1.0924
# 1701       1.772           0.4068        0.620155               1.3652
# 1732       0.004           0.2988        0.313628              -0.2948
# 1745       2.668           0.2258        0.475963               2.4422
# 1817       0.634           0.3794        0.361388               0.2546
#
#       relative_prominence_norm  boundary  boundary_mean  boundary_std
# 4                     1.355520     1.091         0.5164      0.514090
# 38                    3.098347     1.383         0.1868      0.297223
# 61                    1.943820     0.710         0.0676      0.096442
# 83                    2.586756     0.034         0.4524      0.561306
# 130                   0.741423     1.285         0.4748      0.609704
# ...                        ...       ...            ...           ...
# 1683                  1.130972     0.000         1.0280      0.851370
# 1701                  2.201386     2.250         0.5082      0.604410
# 1732                 -0.939967     0.214         0.2392      0.305504
# 1745                  5.131069     1.571         0.1776      0.355200
# 1817                  0.704507     0.955         0.3444      0.358531
#
# [23700 rows x 8 columns]

# %%
logits_dir = models_dir.replace(BASE_DIR, SCRATCH_DIR)

df_distribution_comparison = analysis.compare_human_model_distributions(
    df_aggregated_results, word_model_info, models_dir=logits_dir, model_name='gpt2', task=TASK)
# Out:
# Index(['word', 'Case', 'POS', 'POS_Definition', 'punctuation', 'Stop_Word',
#        'Digit', 'Word_Vocab', 'Onset', 'Offset', 'Duration', 'Named_Entity',
#        'NWP_Candidate', 'entropy_group', 'accuracy_group', 'prominence',
#        'boundary', 'prosody_mean', 'prosody_std', 'relative_prosody',
#        'relative_norm', 'boundary_mean', 'boundary_std'],
#       dtype='object')

# %%
df_aggregated_results = []

for modality in ['audio', 'text']:
    df = analysis.aggregate_participant_responses(cleaned_results_dir, stim_dir, task=TASK, modality=modality, n_orders=3)
    df_aggregated_results.append(df)

df_aggregated_results = pd.concat(df_aggregated_results).reset_index(drop=True)
df_analyzed_results = analysis.analyze_human_results(df_transcript, df_aggregated_results, word_model_info)
# Out:
# Aggregating wheretheressmoke - audio
# Total of 150 subjects
# 100%|██████████| 150/150 [00:59<00:00,  2.51it/s]
# Aggregating wheretheressmoke - text
# Total of 150 subjects
# 100%|██████████| 150/150 [00:58<00:00,  2.55it/s]

# %%
# load transcript
df_preproc_transcript = pd.read_csv(os.path.join(preproc_dir, TASK, f'{TASK}_transcript-preprocessed.csv'))
candidate_rows = np.where(df_preproc_transcript['NWP_Candidate'])[0]

df_model_results = analysis.analyze_model_accuracy(df_transcript, word_model_info=word_model_info, models_dir=models_dir, model_name='gpt2', task=TASK, candidate_rows=candidate_rows, lemmatize=True)
# Out:
# Total missing values: 1
# Lemmatizing column: top_pred
# 237it [00:01, 179.54it/s]
# Lemmatizing column: ground_truth
# 237it [00:01, 182.13it/s]
# 237it [00:00, 635.15it/s]

# %%
df_distribution_comparison
# Out:
#     model_name modality word_index ground_truth entropy_group accuracy_group  \
# 0         gpt2    audio          4     secretly          high            low
# 1         gpt2    audio         11         foot          high            low
# 2         gpt2    audio         30        shoes           low            low
# 3         gpt2    audio         34       crying          high            low
# 4         gpt2    audio         38       wallet          high            low
# ..         ...      ...        ...          ...           ...            ...
# 469       gpt2     text       1738          gas           low            low
# 470       gpt2     text       1745         baby          high            low
# 471       gpt2     text       1758        seven           low            low
# 472       gpt2     text       1783         held          high            low
# 473       gpt2     text       1817         quit           low           high
#
#     human_top_word  human_prob  human_predictability  \
# 0          grabbed        0.42                  0.00
# 1             hand        0.44                  0.08
# 2            shoes        0.24                  0.24
# 3             cold        0.30                  0.02
# 4            money        0.30                  0.00
# ..             ...         ...                   ...
# 469          money        0.44                  0.28
# 470           baby        0.20                  0.20
# 471            the        0.42                  0.16
# 472           know        0.26                  0.02
# 473           quit        0.32                  0.32
#
#      human_log_odds_predictability  ...  model_prob model_predictability  \
# 0                        -4.595120  ...    0.081928         1.601153e-07
# 1                        -2.442347  ...    0.099520         3.467208e-06
# 2                        -1.152680  ...    0.252326         7.632860e-08
# 3                        -3.891820  ...    0.074556         8.813146e-08
# 4                        -4.595120  ...    0.112758         8.223946e-09
# ..                             ...  ...         ...                  ...
# 469                      -0.944462  ...    0.284312         1.413005e-07
# 470                      -1.386294  ...    0.124569         2.310813e-09
# 471                      -1.658228  ...    0.426694         7.775363e-09
# 472                      -3.891820  ...    0.179073         2.181768e-08
# 473                      -0.753772  ...    0.048528         3.634355e-08
#
#      model_log_odds_predictability  model_entropy  model_prob_adjusted  \
# 0                       -15.647372       5.113877             0.043796
# 1                       -12.572158       6.071649             0.022090
# 2                       -16.388218       4.969536             0.061560
# 3                       -16.244436       5.680669             0.109407
# 4                       -18.616216       5.458792             0.142400
# ..                             ...            ...                  ...
# 469                     -15.772377       4.558704             0.113624
# 470                     -19.885666       5.940462             0.062317
# 471                     -18.672306       2.373669             0.115283
# 472                     -17.640545       4.787670             0.072488
# 473                     -17.130249       5.201656             0.116893
#
#      model_prob_human_prediction  kl_divergence  earthmovers_dist  \
# 0                       0.012390       2.874845          0.014823
# 1                       0.022090       3.511974          0.013749
# 2                       0.000812       4.817594          0.010244
# 3                       0.000909       4.066211          0.009090
# 4                       0.005130       3.257522          0.009298
# ..                           ...            ...               ...
# 469                     0.019861       4.114797          0.013755
# 470                     0.000154       4.235922          0.008550
# 471                     0.024490       4.355853          0.010940
# 472                     0.007105       3.794607          0.008117
# 473                     0.001033       3.372348          0.005816
#
#      jensenshannon_dist  ks_stat
# 0              0.737965     0.85
# 1              0.783414     0.85
# 2              0.777128     0.86
# 3              0.739773     0.84
# 4              0.731761     0.81
# ..                  ...      ...
# 469            0.776092     0.89
# 470            0.734537     0.82
# 471            0.746320     0.88
# 472            0.760187     0.79
# 473            0.698515     0.80
#
# [474 rows x 22 columns]

# %%
df_lemmatized_results = pd.read_csv(os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior_lemmatized.csv'))

# %%
logits_dir = models_dir.replace(BASE_DIR, SCRATCH_DIR)

df_distribution_comparison = analysis.compare_human_model_distributions(
    df_lemmatized_results, word_model_info, models_dir=logits_dir, model_name='gpt2', task=TASK)
# Out:
#   0%|          | 0/474 [00:00<?, ?it/s]

# %%
from scipy.spatial import distance

human_word, model_word = df_distribution_comparison

human_word = human_word
model_word = model_word

human_vector = word_model[human_word]
model_vector = word_model[model_word]

1 - distance.cdist(human_vector[np.newaxis], model_vector[np.newaxis], metric='cosine')
# Out:
# array([[0.6583414]])
# array([[0.07402906]])

# %% [markdown]
# ### Clean meta file and remove errors

# %%
# check all the files
checker, approve_ids = check_used_files(EXPERIMENT_NAME, EXPERIMENT_VERSION, TASK, clean_errors=True)
approve_ids = list(map(str, approve_ids))

# find the subject list based on complete files
file_idx, modality, sub_list, prolific_ids = zip(*checker['complete'])
sub_mod_list = list(zip(sub_list, modality))

print (len(set(approve_ids)))
print ('\n'.join(approve_ids))
# Out:
# 400
# 5a5679b58e6259000175bec5
# 604ceec4b2028fd4ddbbd1d4
# 60956679c5e66352f1aba6f1
# 60fd17aabf0cf899ab257db4
# 5f84e472052cf81ae5752252
# 5d75555c99bf5b0018864ed3
# 60af9bae67a5ae86b0c4bd68
# 63dab0380b8791f9560fd329
# 6071d0e406363ac1fd4bdc00
# 66d04b4f8c9b90e6012a510e
# 5e695632d40a492070942196
# 58497529bd87380001552f71
# 6483605a0d0e43c659c92801
# 543e5938fdf99b73557f2136
# 605ab9d5c01d0b0fc69930c5
# 6413603a62c72120012e05be
# 5483702ffdf99b24c654b810
# 60cb6eb4aa635f7ad59164e9
# 56f699e876348f000c883bba
# 6109a00f2f5ee8436e836a0c
# 59eb9c7a6a6c3a000154bb97
# 62fb7a00e90a516a23cfa123
# 6617a07b82321144ac5c41e0
# 650864268a31fd9d2b8f84ee
# 55a29d4dfdf99b602e6b069b
# 5a9ad69adbdb470001eee577
# 5877066b1ed9d10001050b9a
# 5d3e47ba29130a00015cd41d
# 5cc39aa64d7a7f0001817c43
# 60b1073cfd6d4ef92a3fed74
# 62861bcc5f0edf6340c914df
# 5a94d2e989de8200013ecab6
# 66588b59be1d4eb7055c8163
# 63f7bbc4fdef28a0923b7166
# 654d3a401d8c1ce5b38925b3
# 63d7b5321ace6099e3a83386
# 62e154b0682e270b4acdf5ee
# 59497c498fb2140001afda85
# 5e1e5c3c80e02e1c36679187
# 62fe6312269d0e4ae894297b
# 622a35c96d9060c175184c93
# 597a5a62ae36d500016cb0a7
# 5b2bf419993d7f00012a94ef
# 665a2de64db1af60265a9ddb
# 5ce19a7691250a001d8e1096
# 5af2f6c0c36b060001f80163
# 5a9bbda1f6dfdd0001ea9639
# 5a771465eea3d300016de2e1
# 66b288cf788b139df178ce5e
# 5ceecd8f12495000011572be
# 65393cc9ac4ed49ba28f54ae
# 6643c77e0c522dd6c4be1bd1
# 5dbf692c2a1dd63f64ef5ae4
# 5fda057989ec4c35a700f69f
# 668ae77d36b52c2937a6599f
# 60b542b8fbb1a6a2678f5054
# 578950e925cb7100012895cf
# 58542426733c730001a5d1f4
# 6438831795f1371e7745c477
# 66ae700d42e57234e691d55e
# 66f47421b650b6c39e80fa0d
# 613e495d5991ed54f860fe9d
# 5de01c3d5253b00996930a50
# 63d4dd70ccdfaf4af606f42a
# 640105daa923d3f5f2669039
# 5ac8a695e1099600016aaae4
# 66435e2e5c5b5aceb2195908
# 644b1022f52845c480dcbf6c
# 5e6fabc4f3fe5202f1346543
# 56a7da16c89737000b22953c
# 628db649ec2ce46bc626570f
# 63468c2501e33edb7ecf1907
# 587d4ed4e4404c0001c9d1b9
# 5d442839a8faa30001131e8a
# 63672693c8f402f62b4c54f9
# 598c4b28cceb0f0001b39675
# 63d3fb12ac52371a49e65860
# 652e868653b2172546f9b5a0
# 6507192ea3f0470b3b481648
# 5d53bdc9b18d590018dac171
# 607f63ce9ffa404fca0400a9
# 5cca199061e0b90017809cb7
# 5d3b784f80a6250001de7e29
# 5c7eb988ac63960015004d03
# 66d6eca0724772a1edfe14f9
# 59a5d372c094d800013f1c47
# 651ab2bd0b692181129161dd
# 5efe3d722e800832404ef5bb
# 62d9be690206e1b4f007eacb
# 5d30559f95d88f0019378e9c
# 628d14b52b5bd1d83ed1f7d2
# 647cbfb3ecf2e79ea968eae0
# 5ca73fcf7067e70001f7a41f
# 5e0a660615ef40301fb71812
# 66e464861f78048b57ab0f50
# 57be9976c5234c00014706c1
# 5cb988a6b3e70d0001715d79
# 5cedaba627d8ce00018469bb
# 5e70473df54fa862f0bb0fbe
# 637f7d10665738cfea163256
# 62da79cb2e28aefb55569ce1
# 5b99663d4cefb60001e7a214
# 5c5b4e360f2bab0001f01ffa
# 63d43025b2f2972612fe84f2
# 62c5ca2ab3fa26ff1e37d054
# 5f4b9740fdda0b04d86a533c
# 6418dc6fd0f852a233a10350
# 5c5d36bc034e280001644c3b
# 5ebc2405690bf0025dad6a1a
# 5cae6a77b38ea60016e54889
# 589f019c69733b0001af54df
# 5dcf0f73af16d3067b87757f
# 5c5ff87f8c0552000109d7de
# 6596c3663bd4674351a26eb8
# 60c682d13eac136dcb62df4b
# 56b4fd68a9d33a000a891ff9
# 5ec9bdbf4bd36711c1fc716a
# 5f6912baefd1c50f7f3b83f7
# 63effcaddd063d35ebc365d8
# 5d7695cc7ae60f001bc4bde6
# 5ffb432901d8311622530a52
# 5788c16f275be600013590a8
# 5c377642bc6444000133aae9
# 5e9397d303807b2006e77d5a
# 61484ba1d7d6230c20389c30
# 60e55bb59cfd0aa9803b4470
# 669e145ae371f3230bb7eb6a
# 5ac9e0299534ba0001c76e80
# 652fe805e19cd8c9d83c1456
# 653eaadbaae7783176b45d3e
# 6128188a420f8d3f27f8d8b1
# 66cc188a299b596f5682ef8c
# 66c5d1accc092f147f94b363
# 654651ca7a889724c907f144
# 6413799cf7721ee0ce637e09
# 5f479b66ccae1c18c6c17105
# 645d03acd1302079adbc39f9
# 5c17c149f596b100011ca8b8
# 5de3c83c2033793be6591e53
# 6616d9fdba3ae8945cba4a08
# 5d542c3a5af5900019bc80c4
# 5f50159de247cd17cf2ff86a
# 62a72693ad239d8873b2d0bc
# 669bdbdfad2ba350a4c544b0
# 5d3ee89122ed84000172272a
# 62a12aee913c1c1a20613418
# 631f9f50e32a53a43badde1e
# 64217d8202361ad4dbed3596
# 5c4c57609446be00017e6746
# 645d76901063f7fdff9ce59b
# 62029c60ef1cb18a1337c9d4
# 615cb147f04efc8a8c2ff1e5
# 5fcfb1fe79b8060e0662270a
# 58713c5e58ca4c00018ce3ea
# 640103805957bbf6a1326ed0
# 636d39168fe0bc0570ee8da0
# 634afa5b289f73af3f29058e
# 5b48a9e14acd54000132a67f
# 62989d142aedce04d304cabf
# 5fb249cbf1bb8b7db9bb8d13
# 5f9fdfd04296cb0102563f84
# 6147af12d1ac8cbd9f1ba046
# 62f3b543dce069211e8e982c
# 617406fbfced12169896d158
# 62e0326dbbda328df3ceade2
# 5e42f74f5b772a18434cabf7
# 5f9ac9de923dca223848cf19
# 5ec403bb09d0e02a060bd5e6
# 62e09943165d4dadd8b8f096
# 6234a3d5cd2f63c705e5842d
# 63bde0097a3d8b55bdef4a9e
# 62eed9e3e4c704bcef237b74
# 614a8c315301f6c3b736a6d3
# 66aabe2faf233515e0d6bf9a
# 648028bc524faa07ef0547eb
# 627e7e91d0e389328983e765
# 650affc9502d6cbe607d5a7b
# 5ea32a0ea7b59a0c92e82ac8
# 5dcfaad2dd9a740c2493fc28
# 665abe039916896b8700ac59
# 656236a7660ac47612ad934a
# 62869a1b7fff9c9a48fe6087
# 5d447bda2dc88900016f1f6e
# 653581671571d347299832d7
# 5b22d2c260c40e000103b157
# 669a922a697a692bd615677c
# 6658bad85669d166e3c1583d
# 6044dfc230e44b5793804ba6
# 64142d1fb56521aab6be9b64
# 61f2ae4aa09e72f23cbafa9a
# 5ea8154dcfd4dd20473ed88e
# 614de785b8b89e4aba599f03
# 5c266261101408000140ce6e
# 612bb0cdecc9e45781bbf511
# 5d62561ef0dd0700192ebf3f
# 6568e45732cfdb6ad37b77ce
# 611a8d23c1d17506a23df589
# 5d879c06e645c60019847113
# 5f3ec93efbd299158253f283
# 5b0710e7a84dcf0001beee8a
# 62d13e52521b5aba46b2d532
# 5a6725d4c0d836000107f6e7
# 648ae805d9e92af3789c074e
# 55ac3198fdf99b6de3b68b23
# 6558c9e19407ed92d4d18aa0
# 5d53e2d15b17d500168df632
# 63e5af4b0c4e4d5232be8ee9
# 5a8ff02e4fcb2f0001d8bb9b
# 5da0369db1088f00122344c5
# 60a56db43083c0ff59dded00
# 5cf02982efff0b00177ac692
# 5f5118e954b2e12ef9c52231
# 64eb7975f0171c1552c78e48
# 633f5252efab6885fedfad7d
# 6053e01a6a8e8516ba7d47a7
# 646b21b29b9c859da9e74e8f
# 655e09fc282e4139c82f834a
# 63cd461c5f597e27b2a054fb
# 62fccb9647eb07d62e9b6baa
# 59269aac7724de000109190f
# 652fd6db8f5f2657e3ce2f0e
# 66f9d051fb016969f5078ea9
# 57d5ab3a722df500017f3622
# 5a993b151eda410001365a23
# 655943f4bcf508d6091a6b02
# 653bee4e20de33bbd08c46c5
# 6100158db3080c7b157e85f1
# 6658b1a43cec84f2328ac6b4
# 5dd9f0e719eecb97dfab7b48
# 63cfff24ff982236dc481d96
# 62b224142b613b1ffb985ed2
# 65313bdcb9fd825a8c1d4981
# 59f71f797086f80001941493
# 62750ea2970d5935122e7163
# 58ae37d8e6afe00001d36ac9
# 609140cea1442672dd2141d7
# 65802f497b769e78c1b9517b
# 65e3910c5d614adb119cf9ad
# 5eb6df62c23fbf5e87db6b4b
# 644cdee223c4b93bf46c7301
# 641384b3dffcf39ec42d3c23
# 656b9bb4622228a7227c224e
# 5720a9f6fd3a5200113c1891
# 5f48f497fae2763d537d2e6b
# 6495b20dcbfda549afea6f6b
# 55e5d5fdc70c7a000b2a5bac
# 613713a660ee306c2817c891
# 666344916bdba2e2c980dcd0
# 65a700a7fa22d5f150d08b09
# 629f2d6a8d790f69182e8b3e
# 66f8522292767238ed42ebbd
# 5d66f49c531d6e0001e99e8a
# 653cd7c97da5636bc74b4257
# 6674299302998987b13990d0
# 62e1670db59638aaed7d8533
# 582f8bbd4cadc80001b0fbd3
# 5d4b14caed2dfc0001a22c1a
# 57d2edf35e9bc90001f76b06
# 5a3bdd2c8d005a0001829f3e
# 63fa6269a045cb36f1757a59
# 651ab30084e96fef80196fba
# 5d038adefda4bb00013f8afb
# 6444b1e677ebe8b4e2c23abd
# 63207c8968ec10d3b9d54151
# 63852498bcb698988baa11c2
# 664fa6197cd2ac12ab45da27
# 65650785d7aaf3ae0ba9697f
# 5f0c86cbe4af1361b7158f3e
# 66c4983fcfe8496bbb589e8f
# 612fd7e2ff930c4ce9acfa4e
# 5ecb8ed5b18cd7000cc83552
# 66ae3fb9006e6fc44a2b56df
# 66d890366a2497885067a8f8
# 63d7a55aac703039f14c6705
# 5f61371454efa10bdcfc588d
# 6665904b0e63103ee5dd67e4
# 66b0829f976a969235a5ca75
# 62da69819c36ec2d675a3a13
# 66854ca22a0b1e7e87b469a4
# 66eb24d93cf3e118289817f2
# 5e32c95c87b8ef28e5aff6ea
# 66c786e3726ae7cd5cea05b2
# 66d1fa4800313b08b2288d87
# 604938ac63ef0de4b710e653
# 66551d3f336446c73dbbb74c
# 66d70e9a391df9623425b8e8
# 66b9f5d5facd4c9b2c2d6ecd
# 612b5a2c55286e4cf74a63ee
# 662541c6975ebd95757df17d
# 5eea6867fd8990107ab4ba0d
# 6699463ffb192c53ccd0c28c
# 5d09895e65eb3400189cc207
# 5ae09751e0feeb0001caf94d
# 5cfbf333ac28dd00196e807b
# 6659907a878333b4b4a53b91
# 5b3ba372c49ecb00010a9f49
# 65045a402fd7cc0edb90962b
# 66cd8bcf6e7f944d2fa9acfe
# 6109ab5c911c8036b524515c
# 63b6d3746c5d6b520bcf0320
# 6401e7719c0cc074162322fc
# 5d4200b0f1006e00196a9322
# 6658cb3b550b0dbb23386050
# 5af28311c36b060001f7f98d
# 57027b6768c641000e0c894a
# 59d866c4e2762800015eb6e3
# 668e596e0af437f0fd23fac6
# 60dcb4ac13a927a0d099f2c0
# 666d1b17c23301fd272607ae
# 66ba355c3a0c226afeb4c0c7
# 60caec876f8c6f2ab3c937b5
# 60e042e96ad6807c0c63b1c8
# 6447b4178fa8801a09a7066e
# 66b21f89ba393b28774094b9
# 6685aad125f8ccf01b106098
# 667ac735f82ad2db9e918be1
# 66b37c47f0e47f5ebfb39e0e
# 66d9596bc59d5b7770ba7bc0
# 5ddb6cd57cc973aace60252d
# 6030cf35e7fec0f5c6d201c5
# 60d0709ffc9b494cf65a266c
# 5e88d0b981f7de570bc58fd6
# 66cd796477705fac5ba9aa65
# 63b2d4d4820e318e0fb676a5
# 5ba2a1c8c96df90001ce9159
# 6633fa4ebe0a692fc1a5f422
# 66ea0b51a8edb61efc65002c
# 59ffb939517dfb00013dadda
# 61528277afcb4906d01e0442
# 665f06c2a051d97050f313a7
# 5ff1c311e7fadb60fb6a3990
# 66e8ab881b2f3a27ce5ffb32
# 5cb489ff0cd1ed0017465d19
# 66ad56ec2f9173a8896b0071
# 5bc151ece6491a00013a21f3
# 5933d3c4ed2e9a0001d37ab4
# 66a3be9e0c9a1b33fc24ea97
# 60c29201092d523e3b08a603
# 59baf1a2178f1b0001828a26
# 66cc7fbe78be09cb3ad5092f
# 63039577b518c6981e54da62
# 62c34c176c6a4ea6a71fd01a
# 662939c49821886e0246c494
# 578e9a9bfa4465000113f154
# 668f0d397de9e8878fa2a5de
# 66d1c35e8418c8cd0cfde24d
# 644805884189b40893adfa53
# 66622235c898afd7212de1d6
# 5a4d6973f4c9dc0001649fc7
# 644165bc29af5764483dc6b4
# 5e3c447f33122a0230476441
# 61487c32eb8b5db8e9e2ff59
# 64514dd03f467fe3cf0cf364
# 668c391fa1489b577862fff4
# 66bb0c7b86671e6343567b78
# 62b45a29e4013893bfd73a48
# 66b019e0cd2f5c993247072c
# 5f2ea9c0a638c92312e4ae5c
# 5f062fad1145f916fd34cebc
# 5c28cac3867f660001ae9c4a
# 65c10ccc76646afc7d043bd3
# 60ad344265fa9865ff45c0bf
# 64842455e8ac69503a5c65f0
# 660ff63054ed385eb3393bb7
# 63eaace3d44d695631f32db0
# 6659eff2a571ba97019fa233
# 63e5356ce15946b456f4740d
# 66fa6955223d6a12ab0abe94
# 61656042f505fd7fa53e8628
# 66839058a88759d4987e3e1c
# 653c000482098e271126e2e0
# 60f764081e56258bdc779cc4
# 665e07f848d4ef23b23477a7
# 66a0302eb014e06ead5559c3
# 657b31d3363aace295f9106e
# 667eb91e3db4b82021840853
# 5d0d4f6fcab1b50001e97333
# 5d7a1fce27fb8a000196993e
# 5ca0de7d8001d50018c69031
# 66b0fee11fefcf5586763c55
# 667b24c6c25f7a12d08d9ab6
# 63978402e524eebeace93868
# 66b37344796f45313433abc8
# 665c050b07508f6c4f8d01e0
# 65562356bbad98b7c6f5cb54
# 62b8cd151b5fd0f9be7d1f11
# 66a7abb383fda32ced03e410
# 5bc690392885710001a0bb76
# 5af0372776b763000133175a
# 6658b384584cdcaff511fee6
# 6466a87b80cdf3d7f07c1e96
# 66b8e2fd7ed9ec6e6bb94a9d
# 5b15d20c444cef0001cb1153
# 6614fb6af3c5aa23b962ea2d
# 65dc99d0191a135ab835bf69
# 66420f13760bbfe0ee3af466
# 5a9ea9fe1ade740001b92063
# 65ebbbc0a6328372037a40c1
# 6681857831f07d96e59bdda6
# 66759f09781e25aaf1ebf081

# %% [markdown]
# #### Specific modification for stimulus black

# %%
import os
import datetime
def modification_date(filename):
    t = os.path.getmtime(filename)
    return datetime.datetime.fromtimestamp(t)


all_indices = []

for i, (sub, mod) in enumerate(sub_mod_list):
    sub_results_dir = os.path.join(results_dir, TASK, mod, sub)
    info = modification_date(os.path.join(sub_results_dir, f'{sub}_next-word-prediction.csv'))

    if info.year == 2024:
        all_indices.append(i)

current_ids = [approve_ids[idx] for idx in all_indices]
print ('\n'.join(current_ids))
# Out:
# 63dab0380b8791f9560fd329
# 66d04b4f8c9b90e6012a510e
# 605ab9d5c01d0b0fc69930c5
# 56f699e876348f000c883bba
# 6617a07b82321144ac5c41e0
# 5cc39aa64d7a7f0001817c43
# 66588b59be1d4eb7055c8163
# 62fe6312269d0e4ae894297b
# 665a2de64db1af60265a9ddb
# 66b288cf788b139df178ce5e
# 6643c77e0c522dd6c4be1bd1
# 668ae77d36b52c2937a6599f
# 6438831795f1371e7745c477
# 66ae700d42e57234e691d55e
# 66f47421b650b6c39e80fa0d
# 5de01c3d5253b00996930a50
# 66435e2e5c5b5aceb2195908
# 5d53bdc9b18d590018dac171
# 5d3b784f80a6250001de7e29
# 66d6eca0724772a1edfe14f9
# 59a5d372c094d800013f1c47
# 5efe3d722e800832404ef5bb
# 628d14b52b5bd1d83ed1f7d2
# 5ca73fcf7067e70001f7a41f
# 66e464861f78048b57ab0f50
# 62da79cb2e28aefb55569ce1
# 6418dc6fd0f852a233a10350
# 5ebc2405690bf0025dad6a1a
# 5dcf0f73af16d3067b87757f
# 6596c3663bd4674351a26eb8
# 56b4fd68a9d33a000a891ff9
# 60e55bb59cfd0aa9803b4470
# 669e145ae371f3230bb7eb6a
# 5ac9e0299534ba0001c76e80
# 66cc188a299b596f5682ef8c
# 66c5d1accc092f147f94b363
# 5de3c83c2033793be6591e53
# 6616d9fdba3ae8945cba4a08
# 669bdbdfad2ba350a4c544b0
# 5d3ee89122ed84000172272a
# 63bde0097a3d8b55bdef4a9e
# 66aabe2faf233515e0d6bf9a
# 665abe039916896b8700ac59
# 5d447bda2dc88900016f1f6e
# 669a922a697a692bd615677c
# 6658bad85669d166e3c1583d
# 614de785b8b89e4aba599f03
# 5d62561ef0dd0700192ebf3f
# 63e5af4b0c4e4d5232be8ee9
# 59269aac7724de000109190f
# 66f9d051fb016969f5078ea9
# 6100158db3080c7b157e85f1
# 6658b1a43cec84f2328ac6b4
# 5dd9f0e719eecb97dfab7b48
# 65313bdcb9fd825a8c1d4981
# 62750ea2970d5935122e7163
# 65802f497b769e78c1b9517b
# 65e3910c5d614adb119cf9ad
# 5f48f497fae2763d537d2e6b
# 613713a660ee306c2817c891
# 666344916bdba2e2c980dcd0
# 65a700a7fa22d5f150d08b09
# 66f8522292767238ed42ebbd
# 6674299302998987b13990d0
# 62e1670db59638aaed7d8533
# 582f8bbd4cadc80001b0fbd3
# 5d4b14caed2dfc0001a22c1a
# 57d2edf35e9bc90001f76b06
# 651ab30084e96fef80196fba
# 664fa6197cd2ac12ab45da27
# 5f0c86cbe4af1361b7158f3e
# 66c4983fcfe8496bbb589e8f
# 612fd7e2ff930c4ce9acfa4e
# 5ecb8ed5b18cd7000cc83552
# 66ae3fb9006e6fc44a2b56df
# 66d890366a2497885067a8f8
# 63d7a55aac703039f14c6705
# 5f61371454efa10bdcfc588d
# 6665904b0e63103ee5dd67e4
# 66b0829f976a969235a5ca75
# 62da69819c36ec2d675a3a13
# 66854ca22a0b1e7e87b469a4
# 66eb24d93cf3e118289817f2
# 5e32c95c87b8ef28e5aff6ea
# 66c786e3726ae7cd5cea05b2
# 66d1fa4800313b08b2288d87
# 604938ac63ef0de4b710e653
# 66551d3f336446c73dbbb74c
# 66d70e9a391df9623425b8e8
# 66b9f5d5facd4c9b2c2d6ecd
# 612b5a2c55286e4cf74a63ee
# 662541c6975ebd95757df17d
# 5eea6867fd8990107ab4ba0d
# 6699463ffb192c53ccd0c28c
# 5d09895e65eb3400189cc207
# 5ae09751e0feeb0001caf94d
# 5cfbf333ac28dd00196e807b
# 6659907a878333b4b4a53b91
# 5b3ba372c49ecb00010a9f49
# 65045a402fd7cc0edb90962b
# 66cd8bcf6e7f944d2fa9acfe
# 6109ab5c911c8036b524515c
# 63b6d3746c5d6b520bcf0320
# 6401e7719c0cc074162322fc
# 5d4200b0f1006e00196a9322
# 6658cb3b550b0dbb23386050
# 5af28311c36b060001f7f98d
# 57027b6768c641000e0c894a
# 59d866c4e2762800015eb6e3
# 668e596e0af437f0fd23fac6
# 60dcb4ac13a927a0d099f2c0
# 666d1b17c23301fd272607ae
# 66ba355c3a0c226afeb4c0c7
# 60caec876f8c6f2ab3c937b5
# 60e042e96ad6807c0c63b1c8
# 6447b4178fa8801a09a7066e
# 66b21f89ba393b28774094b9
# 6685aad125f8ccf01b106098
# 667ac735f82ad2db9e918be1
# 66b37c47f0e47f5ebfb39e0e
# 66d9596bc59d5b7770ba7bc0
# 5ddb6cd57cc973aace60252d
# 6030cf35e7fec0f5c6d201c5
# 60d0709ffc9b494cf65a266c
# 5e88d0b981f7de570bc58fd6
# 66cd796477705fac5ba9aa65
# 63b2d4d4820e318e0fb676a5
# 5ba2a1c8c96df90001ce9159
# 6633fa4ebe0a692fc1a5f422
# 66ea0b51a8edb61efc65002c
# 59ffb939517dfb00013dadda
# 61528277afcb4906d01e0442
# 665f06c2a051d97050f313a7
# 5ff1c311e7fadb60fb6a3990
# 66e8ab881b2f3a27ce5ffb32
# 5cb489ff0cd1ed0017465d19
# 66ad56ec2f9173a8896b0071
# 5bc151ece6491a00013a21f3
# 5933d3c4ed2e9a0001d37ab4
# 66a3be9e0c9a1b33fc24ea97
# 60c29201092d523e3b08a603
# 59baf1a2178f1b0001828a26
# 66cc7fbe78be09cb3ad5092f
# 63039577b518c6981e54da62
# 62c34c176c6a4ea6a71fd01a
# 662939c49821886e0246c494
# 578e9a9bfa4465000113f154
# 668f0d397de9e8878fa2a5de
# 66d1c35e8418c8cd0cfde24d
# 644805884189b40893adfa53
# 66622235c898afd7212de1d6
# 5a4d6973f4c9dc0001649fc7
# 644165bc29af5764483dc6b4
# 5e3c447f33122a0230476441
# 61487c32eb8b5db8e9e2ff59
# 64514dd03f467fe3cf0cf364
# 668c391fa1489b577862fff4
# 66bb0c7b86671e6343567b78
# 62b45a29e4013893bfd73a48
# 66b019e0cd2f5c993247072c
# 5f2ea9c0a638c92312e4ae5c
# 5f062fad1145f916fd34cebc
# 5c28cac3867f660001ae9c4a
# 65c10ccc76646afc7d043bd3
# 60ad344265fa9865ff45c0bf
# 64842455e8ac69503a5c65f0
# 660ff63054ed385eb3393bb7
# 63eaace3d44d695631f32db0
# 6659eff2a571ba97019fa233
# 63e5356ce15946b456f4740d
# 66fa6955223d6a12ab0abe94
# 61656042f505fd7fa53e8628
# 66839058a88759d4987e3e1c
# 653c000482098e271126e2e0
# 60f764081e56258bdc779cc4
# 665e07f848d4ef23b23477a7
# 66a0302eb014e06ead5559c3
# 657b31d3363aace295f9106e
# 667eb91e3db4b82021840853
# 5d0d4f6fcab1b50001e97333
# 5d7a1fce27fb8a000196993e
# 5ca0de7d8001d50018c69031
# 66b0fee11fefcf5586763c55
# 667b24c6c25f7a12d08d9ab6
# 63978402e524eebeace93868
# 66b37344796f45313433abc8
# 665c050b07508f6c4f8d01e0
# 65562356bbad98b7c6f5cb54
# 62b8cd151b5fd0f9be7d1f11
# 66a7abb383fda32ced03e410
# 5bc690392885710001a0bb76
# 5af0372776b763000133175a
# 6658b384584cdcaff511fee6
# 6466a87b80cdf3d7f07c1e96
# 66b8e2fd7ed9ec6e6bb94a9d
# 5b15d20c444cef0001cb1153
# 6614fb6af3c5aa23b962ea2d
# 65dc99d0191a135ab835bf69
# 66420f13760bbfe0ee3af466
# 5a9ea9fe1ade740001b92063
# 65ebbbc0a6328372037a40c1
# 6681857831f07d96e59bdda6
# 66759f09781e25aaf1ebf081

# %% [markdown]
# ### Manually spell-check participants data

# %%
df_transcript = pd.read_csv(os.path.join(preproc_dir, TASK, f'{TASK}_transcript-preprocessed.csv'))

for i, (sub, modality) in enumerate(sub_mod_list):

    sub_cleaned_dir = os.path.join(cleaned_results_dir, TASK, modality, sub)
    out_fn = os.path.join(sub_cleaned_dir, f'{sub}_next-word-prediction.csv')
    
    utils.attempt_makedirs(sub_cleaned_dir)

    ############################
    #### Load subject data #####
    ############################

    if os.path.exists(out_fn):
        print (f'File exists: {modality} {sub}')
        df_results = pd.read_csv(out_fn)

        for k, v in AUTO_REPLACE.items():
            df_results.loc[df_results['response'] == k, 'response'] = v
        
        df_results.to_csv(out_fn, index=False)

        print (f'Saved file for {modality} {sub}')
        continue
    else:
        print (f'Correcting: {modality} {sub}')
        # load and filter down to response trials 
        sub_dir = os.path.join(results_dir, TASK, modality, sub)
        df_results = pd.read_csv(os.path.join(sub_dir, f'{sub}_next-word-prediction.csv')).fillna(False)

    ############################
    ###### Check responses #####
    ############################

    df_results['word_index'] = df_results['word_index'].astype(int)
    df_results = clean_participant_responses(df_results, df_transcript)
    ############################
    #### Save cleaned data #####
    ############################
    
    df_results.to_csv(out_fn, index=False)

    print (f'Saved file for {modality} {sub}')
    # if os.path.exists(sub_dir):
    #     current_id, demographics, experience, responses = load_participant_results(sub_dir, sub)
    #     responses['response'] = responses['response'].fillna('')
# Out:
# File exists: audio sub-00001
# Saved file for audio sub-00001
# File exists: text sub-00001
# Saved file for text sub-00001
# File exists: audio sub-00002
# Saved file for audio sub-00002
# File exists: text sub-00002
# Saved file for text sub-00002
# File exists: audio sub-00003
# Saved file for audio sub-00003
# File exists: text sub-00003
# Saved file for text sub-00003
# File exists: audio sub-00004
# Saved file for audio sub-00004
# File exists: text sub-00004
# Saved file for text sub-00004
# File exists: audio sub-00005
# Saved file for audio sub-00005
# File exists: text sub-00005
# Saved file for text sub-00005
# File exists: audio sub-00006
# Saved file for audio sub-00006
# File exists: text sub-00006
# Saved file for text sub-00006
# File exists: audio sub-00007
# Saved file for audio sub-00007
# File exists: text sub-00007
# Saved file for text sub-00007
# File exists: audio sub-00008
# Saved file for audio sub-00008
# File exists: text sub-00008
# Saved file for text sub-00008
# File exists: audio sub-00009
# Saved file for audio sub-00009
# File exists: text sub-00009
# Saved file for text sub-00009
# File exists: audio sub-00010
# Saved file for audio sub-00010
# File exists: text sub-00010
# Saved file for text sub-00010
# File exists: audio sub-00011
# Saved file for audio sub-00011
# File exists: text sub-00011
# Saved file for text sub-00011
# File exists: audio sub-00012
# Saved file for audio sub-00012
# File exists: text sub-00012
# Saved file for text sub-00012
# File exists: audio sub-00013
# Saved file for audio sub-00013
# File exists: text sub-00013
# Saved file for text sub-00013
# File exists: audio sub-00014
# Saved file for audio sub-00014
# File exists: text sub-00014
# Saved file for text sub-00014
# File exists: audio sub-00015
# Saved file for audio sub-00015
# File exists: text sub-00015
# Saved file for text sub-00015
# File exists: audio sub-00016
# Saved file for audio sub-00016
# File exists: text sub-00016
# Saved file for text sub-00016
# File exists: audio sub-00017
# Saved file for audio sub-00017
# File exists: text sub-00017
# Saved file for text sub-00017
# File exists: audio sub-00018
# Saved file for audio sub-00018
# File exists: text sub-00018
# Saved file for text sub-00018
# File exists: audio sub-00019
# Saved file for audio sub-00019
# File exists: text sub-00019
# Saved file for text sub-00019
# File exists: audio sub-00020
# Saved file for audio sub-00020
# File exists: text sub-00020
# Saved file for text sub-00020
# File exists: audio sub-00021
# Saved file for audio sub-00021
# File exists: text sub-00021
# Saved file for text sub-00021
# File exists: audio sub-00022
# Saved file for audio sub-00022
# File exists: text sub-00022
# Saved file for text sub-00022
# File exists: audio sub-00023
# Saved file for audio sub-00023
# File exists: text sub-00023
# Saved file for text sub-00023
# File exists: audio sub-00024
# Saved file for audio sub-00024
# File exists: text sub-00024
# Saved file for text sub-00024
# File exists: audio sub-00025
# Saved file for audio sub-00025
# File exists: text sub-00025
# Saved file for text sub-00025
# File exists: audio sub-00026
# Saved file for audio sub-00026
# File exists: text sub-00026
# Saved file for text sub-00026
# File exists: audio sub-00027
# Saved file for audio sub-00027
# File exists: text sub-00027
# Saved file for text sub-00027
# File exists: audio sub-00028
# Saved file for audio sub-00028
# File exists: text sub-00028
# Saved file for text sub-00028
# File exists: audio sub-00029
# Saved file for audio sub-00029
# File exists: text sub-00029
# Saved file for text sub-00029
# File exists: audio sub-00030
# Saved file for audio sub-00030
# File exists: text sub-00030
# Saved file for text sub-00030
# File exists: audio sub-00031
# Saved file for audio sub-00031
# File exists: text sub-00031
# Saved file for text sub-00031
# File exists: audio sub-00032
# Saved file for audio sub-00032
# File exists: text sub-00032
# Saved file for text sub-00032
# File exists: audio sub-00033
# Saved file for audio sub-00033
# File exists: text sub-00033
# Saved file for text sub-00033
# File exists: audio sub-00034
# Saved file for audio sub-00034
# File exists: text sub-00034
# Saved file for text sub-00034
# File exists: audio sub-00035
# Saved file for audio sub-00035
# File exists: text sub-00035
# Saved file for text sub-00035
# File exists: audio sub-00036
# Saved file for audio sub-00036
# File exists: text sub-00036
# Saved file for text sub-00036
# File exists: audio sub-00037
# Saved file for audio sub-00037
# File exists: text sub-00037
# Saved file for text sub-00037
# File exists: audio sub-00038
# Saved file for audio sub-00038
# File exists: text sub-00038
# Saved file for text sub-00038
# File exists: audio sub-00039
# Saved file for audio sub-00039
# File exists: text sub-00039
# Saved file for text sub-00039
# File exists: audio sub-00040
# Saved file for audio sub-00040
# File exists: text sub-00040
# Saved file for text sub-00040
# File exists: audio sub-00041
# Saved file for audio sub-00041
# File exists: text sub-00041
# Saved file for text sub-00041
# File exists: audio sub-00042
# Saved file for audio sub-00042
# File exists: text sub-00042
# Saved file for text sub-00042
# File exists: audio sub-00043
# Saved file for audio sub-00043
# File exists: text sub-00043
# Saved file for text sub-00043
# File exists: audio sub-00044
# Saved file for audio sub-00044
# File exists: text sub-00044
# Saved file for text sub-00044
# File exists: audio sub-00045
# Saved file for audio sub-00045
# File exists: text sub-00045
# Saved file for text sub-00045
# File exists: audio sub-00046
# Saved file for audio sub-00046
# File exists: text sub-00046
# Saved file for text sub-00046
# File exists: audio sub-00047
# Saved file for audio sub-00047
# File exists: text sub-00047
# Saved file for text sub-00047
# File exists: audio sub-00048
# Saved file for audio sub-00048
# File exists: text sub-00048
# Saved file for text sub-00048
# File exists: audio sub-00049
# Saved file for audio sub-00049
# File exists: text sub-00049
# Saved file for text sub-00049
# File exists: audio sub-00050
# Saved file for audio sub-00050
# File exists: text sub-00050
# Saved file for text sub-00050
# File exists: audio sub-00051
# Saved file for audio sub-00051
# File exists: text sub-00051
# Saved file for text sub-00051
# File exists: audio sub-00052
# Saved file for audio sub-00052
# File exists: text sub-00052
# Saved file for text sub-00052
# File exists: audio sub-00053
# Saved file for audio sub-00053
# File exists: text sub-00053
# Saved file for text sub-00053
# File exists: audio sub-00054
# Saved file for audio sub-00054
# File exists: text sub-00054
# Saved file for text sub-00054
# File exists: audio sub-00055
# Saved file for audio sub-00055
# File exists: text sub-00055
# Saved file for text sub-00055
# File exists: audio sub-00056
# Saved file for audio sub-00056
# File exists: text sub-00056
# Saved file for text sub-00056
# File exists: audio sub-00057
# Saved file for audio sub-00057
# File exists: text sub-00057
# Saved file for text sub-00057
# File exists: audio sub-00058
# Saved file for audio sub-00058
# File exists: text sub-00058
# Saved file for text sub-00058
# File exists: audio sub-00059
# Saved file for audio sub-00059
# File exists: text sub-00059
# Saved file for text sub-00059
# File exists: audio sub-00060
# Saved file for audio sub-00060
# File exists: text sub-00060
# Saved file for text sub-00060
# File exists: audio sub-00061
# Saved file for audio sub-00061
# File exists: text sub-00061
# Saved file for text sub-00061
# File exists: audio sub-00062
# Saved file for audio sub-00062
# File exists: text sub-00062
# Saved file for text sub-00062
# File exists: audio sub-00063
# Saved file for audio sub-00063
# File exists: text sub-00063
# Saved file for text sub-00063
# File exists: audio sub-00064
# Saved file for audio sub-00064
# File exists: text sub-00064
# Saved file for text sub-00064
# File exists: audio sub-00065
# Saved file for audio sub-00065
# File exists: text sub-00065
# Saved file for text sub-00065
# File exists: audio sub-00066
# Saved file for audio sub-00066
# File exists: text sub-00066
# Saved file for text sub-00066
# File exists: audio sub-00067
# Saved file for audio sub-00067
# File exists: text sub-00067
# Saved file for text sub-00067
# File exists: audio sub-00068
# Saved file for audio sub-00068
# File exists: text sub-00068
# Saved file for text sub-00068
# File exists: audio sub-00069
# Saved file for audio sub-00069
# File exists: text sub-00069
# Saved file for text sub-00069
# File exists: audio sub-00070
# Saved file for audio sub-00070
# File exists: text sub-00070
# Saved file for text sub-00070
# File exists: audio sub-00071
# Saved file for audio sub-00071
# File exists: text sub-00071
# Saved file for text sub-00071
# File exists: audio sub-00072
# Saved file for audio sub-00072
# File exists: text sub-00072
# Saved file for text sub-00072
# File exists: audio sub-00073
# Saved file for audio sub-00073
# File exists: text sub-00073
# Saved file for text sub-00073
# File exists: audio sub-00074
# Saved file for audio sub-00074
# File exists: text sub-00074
# Saved file for text sub-00074
# File exists: audio sub-00075
# Saved file for audio sub-00075
# File exists: text sub-00075
# Saved file for text sub-00075
# File exists: audio sub-00076
# Saved file for audio sub-00076
# File exists: text sub-00076
# Saved file for text sub-00076
# File exists: audio sub-00077
# Saved file for audio sub-00077
# File exists: text sub-00077
# Saved file for text sub-00077
# File exists: audio sub-00078
# Saved file for audio sub-00078
# File exists: text sub-00078
# Saved file for text sub-00078
# File exists: audio sub-00079
# Saved file for audio sub-00079
# File exists: text sub-00079
# Saved file for text sub-00079
# File exists: audio sub-00080
# Saved file for audio sub-00080
# File exists: text sub-00080
# Saved file for text sub-00080
# File exists: audio sub-00081
# Saved file for audio sub-00081
# File exists: text sub-00081
# Saved file for text sub-00081
# File exists: audio sub-00082
# Saved file for audio sub-00082
# File exists: text sub-00082
# Saved file for text sub-00082
# File exists: audio sub-00083
# Saved file for audio sub-00083
# File exists: text sub-00083
# Saved file for text sub-00083
# File exists: audio sub-00084
# Saved file for audio sub-00084
# File exists: text sub-00084
# Saved file for text sub-00084
# File exists: audio sub-00085
# Saved file for audio sub-00085
# File exists: text sub-00085
# Saved file for text sub-00085
# File exists: audio sub-00086
# Saved file for audio sub-00086
# File exists: text sub-00086
# Saved file for text sub-00086
# File exists: audio sub-00087
# Saved file for audio sub-00087
# File exists: text sub-00087
# Saved file for text sub-00087
# File exists: audio sub-00088
# Saved file for audio sub-00088
# File exists: text sub-00088
# Saved file for text sub-00088
# File exists: audio sub-00089
# Saved file for audio sub-00089
# File exists: text sub-00089
# Saved file for text sub-00089
# File exists: audio sub-00090
# Saved file for audio sub-00090
# File exists: text sub-00090
# Saved file for text sub-00090
# File exists: audio sub-00091
# Saved file for audio sub-00091
# File exists: text sub-00091
# Saved file for text sub-00091
# File exists: audio sub-00092
# Saved file for audio sub-00092
# File exists: text sub-00092
# Saved file for text sub-00092
# File exists: audio sub-00093
# Saved file for audio sub-00093
# File exists: text sub-00093
# Saved file for text sub-00093
# File exists: audio sub-00094
# Saved file for audio sub-00094
# File exists: text sub-00094
# Saved file for text sub-00094
# File exists: audio sub-00095
# Saved file for audio sub-00095
# File exists: text sub-00095
# Saved file for text sub-00095
# File exists: audio sub-00096
# Saved file for audio sub-00096
# File exists: text sub-00096
# Saved file for text sub-00096
# File exists: audio sub-00097
# Saved file for audio sub-00097
# File exists: text sub-00097
# Saved file for text sub-00097
# File exists: audio sub-00098
# Saved file for audio sub-00098
# File exists: text sub-00098
# Saved file for text sub-00098
# File exists: audio sub-00099
# Saved file for audio sub-00099
# File exists: text sub-00099
# Saved file for text sub-00099
# File exists: audio sub-00100
# Saved file for audio sub-00100
# File exists: text sub-00100
# Saved file for text sub-00100
# File exists: audio sub-00101
# Saved file for audio sub-00101
# File exists: text sub-00101
# Saved file for text sub-00101
# File exists: audio sub-00102
# Saved file for audio sub-00102
# File exists: text sub-00102
# Saved file for text sub-00102
# File exists: audio sub-00103
# Saved file for audio sub-00103
# File exists: text sub-00103
# Saved file for text sub-00103
# File exists: audio sub-00104
# Saved file for audio sub-00104
# File exists: text sub-00104
# Saved file for text sub-00104
# File exists: audio sub-00105
# Saved file for audio sub-00105
# File exists: text sub-00105
# Saved file for text sub-00105
# File exists: audio sub-00106
# Saved file for audio sub-00106
# File exists: text sub-00106
# Saved file for text sub-00106
# File exists: audio sub-00107
# Saved file for audio sub-00107
# File exists: text sub-00107
# Saved file for text sub-00107
# File exists: audio sub-00108
# Saved file for audio sub-00108
# File exists: text sub-00108
# Saved file for text sub-00108
# File exists: audio sub-00109
# Saved file for audio sub-00109
# File exists: text sub-00109
# Saved file for text sub-00109
# File exists: audio sub-00110
# Saved file for audio sub-00110
# File exists: text sub-00110
# Saved file for text sub-00110
# File exists: audio sub-00111
# Saved file for audio sub-00111
# File exists: text sub-00111
# Saved file for text sub-00111
# File exists: audio sub-00112
# Saved file for audio sub-00112
# File exists: text sub-00112
# Saved file for text sub-00112
# File exists: audio sub-00113
# Saved file for audio sub-00113
# File exists: text sub-00113
# Saved file for text sub-00113
# File exists: audio sub-00114
# Saved file for audio sub-00114
# File exists: text sub-00114
# Saved file for text sub-00114
# File exists: audio sub-00115
# Saved file for audio sub-00115
# File exists: text sub-00115
# Saved file for text sub-00115
# File exists: audio sub-00116
# Saved file for audio sub-00116
# File exists: text sub-00116
# Saved file for text sub-00116
# File exists: audio sub-00117
# Saved file for audio sub-00117
# File exists: text sub-00117
# Saved file for text sub-00117
# File exists: audio sub-00118
# Saved file for audio sub-00118
# File exists: text sub-00118
# Saved file for text sub-00118
# File exists: audio sub-00119
# Saved file for audio sub-00119
# File exists: text sub-00119
# Saved file for text sub-00119
# File exists: audio sub-00120
# Saved file for audio sub-00120
# File exists: text sub-00120
# Saved file for text sub-00120
# File exists: audio sub-00121
# Saved file for audio sub-00121
# File exists: text sub-00121
# Saved file for text sub-00121
# File exists: audio sub-00122
# Saved file for audio sub-00122
# File exists: text sub-00122
# Saved file for text sub-00122
# File exists: audio sub-00123
# Saved file for audio sub-00123
# File exists: text sub-00123
# Saved file for text sub-00123
# File exists: audio sub-00124
# Saved file for audio sub-00124
# File exists: text sub-00124
# Saved file for text sub-00124
# File exists: audio sub-00125
# Saved file for audio sub-00125
# File exists: text sub-00125
# Saved file for text sub-00125
# File exists: audio sub-00126
# Saved file for audio sub-00126
# File exists: text sub-00126
# Saved file for text sub-00126
# File exists: audio sub-00127
# Saved file for audio sub-00127
# File exists: text sub-00127
# Saved file for text sub-00127
# File exists: audio sub-00128
# Saved file for audio sub-00128
# File exists: text sub-00128
# Saved file for text sub-00128
# File exists: audio sub-00129
# Saved file for audio sub-00129
# File exists: text sub-00129
# Saved file for text sub-00129
# File exists: audio sub-00130
# Saved file for audio sub-00130
# File exists: text sub-00130
# Saved file for text sub-00130
# File exists: audio sub-00131
# Saved file for audio sub-00131
# File exists: text sub-00131
# Saved file for text sub-00131
# File exists: audio sub-00132
# Saved file for audio sub-00132
# File exists: text sub-00132
# Saved file for text sub-00132
# File exists: audio sub-00133
# Saved file for audio sub-00133
# File exists: text sub-00133
# Saved file for text sub-00133
# File exists: audio sub-00134
# Saved file for audio sub-00134
# File exists: text sub-00134
# Saved file for text sub-00134
# File exists: audio sub-00135
# Saved file for audio sub-00135
# File exists: text sub-00135
# Saved file for text sub-00135
# File exists: audio sub-00136
# Saved file for audio sub-00136
# File exists: text sub-00136
# Saved file for text sub-00136
# File exists: audio sub-00137
# Saved file for audio sub-00137
# File exists: text sub-00137
# Saved file for text sub-00137
# File exists: audio sub-00138
# Saved file for audio sub-00138
# File exists: text sub-00138
# Saved file for text sub-00138
# File exists: audio sub-00139
# Saved file for audio sub-00139
# File exists: text sub-00139
# Saved file for text sub-00139
# File exists: audio sub-00140
# Saved file for audio sub-00140
# File exists: text sub-00140
# Saved file for text sub-00140
# File exists: audio sub-00141
# Saved file for audio sub-00141
# File exists: text sub-00141
# Saved file for text sub-00141
# File exists: audio sub-00142
# Saved file for audio sub-00142
# File exists: text sub-00142
# Saved file for text sub-00142
# File exists: audio sub-00143
# Saved file for audio sub-00143
# File exists: text sub-00143
# Saved file for text sub-00143
# File exists: audio sub-00144
# Saved file for audio sub-00144
# File exists: text sub-00144
# Saved file for text sub-00144
# File exists: audio sub-00145
# Saved file for audio sub-00145
# File exists: text sub-00145
# Saved file for text sub-00145
# File exists: audio sub-00146
# Saved file for audio sub-00146
# File exists: text sub-00146
# Saved file for text sub-00146
# File exists: audio sub-00147
# Saved file for audio sub-00147
# File exists: text sub-00147
# Saved file for text sub-00147
# File exists: audio sub-00148
# Saved file for audio sub-00148
# File exists: text sub-00148
# Saved file for text sub-00148
# File exists: audio sub-00149
# Saved file for audio sub-00149
# File exists: text sub-00149
# Saved file for text sub-00149
# File exists: audio sub-00150
# Saved file for audio sub-00150
# File exists: text sub-00150
# Saved file for text sub-00150
# File exists: audio sub-00151
# Saved file for audio sub-00151
# File exists: text sub-00151
# Saved file for text sub-00151
# File exists: audio sub-00152
# Saved file for audio sub-00152
# File exists: text sub-00152
# Saved file for text sub-00152
# File exists: audio sub-00153
# Saved file for audio sub-00153
# File exists: text sub-00153
# Saved file for text sub-00153
# File exists: audio sub-00154
# Saved file for audio sub-00154
# File exists: text sub-00154
# Saved file for text sub-00154
# File exists: audio sub-00155
# Saved file for audio sub-00155
# File exists: text sub-00155
# Saved file for text sub-00155
# File exists: audio sub-00156
# Saved file for audio sub-00156
# File exists: text sub-00156
# Saved file for text sub-00156
# File exists: audio sub-00157
# Saved file for audio sub-00157
# File exists: text sub-00157
# Saved file for text sub-00157
# File exists: audio sub-00158
# Saved file for audio sub-00158
# File exists: text sub-00158
# Saved file for text sub-00158
# File exists: audio sub-00159
# Saved file for audio sub-00159
# File exists: text sub-00159
# Saved file for text sub-00159
# File exists: audio sub-00160
# Saved file for audio sub-00160
# File exists: text sub-00160
# Saved file for text sub-00160
# File exists: audio sub-00161
# Saved file for audio sub-00161
# File exists: text sub-00161
# Saved file for text sub-00161
# File exists: audio sub-00162
# Saved file for audio sub-00162
# File exists: text sub-00162
# Saved file for text sub-00162
# File exists: audio sub-00163
# Saved file for audio sub-00163
# File exists: text sub-00163
# Saved file for text sub-00163
# File exists: audio sub-00164
# Saved file for audio sub-00164
# File exists: text sub-00164
# Saved file for text sub-00164
# File exists: audio sub-00165
# Saved file for audio sub-00165
# File exists: text sub-00165
# Saved file for text sub-00165
# File exists: audio sub-00166
# Saved file for audio sub-00166
# File exists: text sub-00166
# Saved file for text sub-00166
# File exists: audio sub-00167
# Saved file for audio sub-00167
# File exists: text sub-00167
# Saved file for text sub-00167
# File exists: audio sub-00168
# Saved file for audio sub-00168
# File exists: text sub-00168
# Saved file for text sub-00168
# File exists: audio sub-00169
# Saved file for audio sub-00169
# File exists: text sub-00169
# Saved file for text sub-00169
# File exists: audio sub-00170
# Saved file for audio sub-00170
# File exists: text sub-00170
# Saved file for text sub-00170
# File exists: audio sub-00171
# Saved file for audio sub-00171
# File exists: text sub-00171
# Saved file for text sub-00171
# File exists: audio sub-00172
# Saved file for audio sub-00172
# File exists: text sub-00172
# Saved file for text sub-00172
# File exists: audio sub-00173
# Saved file for audio sub-00173
# File exists: text sub-00173
# Saved file for text sub-00173
# File exists: audio sub-00174
# Saved file for audio sub-00174
# File exists: text sub-00174
# Saved file for text sub-00174
# File exists: audio sub-00175
# Saved file for audio sub-00175
# File exists: text sub-00175
# Saved file for text sub-00175
# File exists: audio sub-00176
# Saved file for audio sub-00176
# File exists: text sub-00176
# Saved file for text sub-00176
# File exists: audio sub-00177
# Saved file for audio sub-00177
# File exists: text sub-00177
# Saved file for text sub-00177
# File exists: audio sub-00178
# Saved file for audio sub-00178
# File exists: text sub-00178
# Saved file for text sub-00178
# File exists: audio sub-00179
# Saved file for audio sub-00179
# File exists: text sub-00179
# Saved file for text sub-00179
# File exists: audio sub-00180
# Saved file for audio sub-00180
# File exists: text sub-00180
# Saved file for text sub-00180
# File exists: audio sub-00181
# Saved file for audio sub-00181
# File exists: text sub-00181
# Saved file for text sub-00181
# File exists: audio sub-00182
# Saved file for audio sub-00182
# File exists: text sub-00182
# Saved file for text sub-00182
# File exists: audio sub-00183
# Saved file for audio sub-00183
# File exists: text sub-00183
# Saved file for text sub-00183
# File exists: audio sub-00184
# Saved file for audio sub-00184
# File exists: text sub-00184
# Saved file for text sub-00184
# File exists: audio sub-00185
# Saved file for audio sub-00185
# File exists: text sub-00185
# Saved file for text sub-00185
# File exists: audio sub-00186
# Saved file for audio sub-00186
# File exists: text sub-00186
# Saved file for text sub-00186
# File exists: audio sub-00187
# Saved file for audio sub-00187
# File exists: text sub-00187
# Saved file for text sub-00187
# File exists: audio sub-00188
# Saved file for audio sub-00188
# File exists: text sub-00188
# Saved file for text sub-00188
# File exists: audio sub-00189
# Saved file for audio sub-00189
# File exists: text sub-00189
# Saved file for text sub-00189
# File exists: audio sub-00190
# Saved file for audio sub-00190
# File exists: text sub-00190
# Saved file for text sub-00190
# File exists: audio sub-00191
# Saved file for audio sub-00191
# File exists: text sub-00191
# Saved file for text sub-00191
# File exists: audio sub-00192
# Saved file for audio sub-00192
# File exists: text sub-00192
# Saved file for text sub-00192
# File exists: audio sub-00193
# Saved file for audio sub-00193
# File exists: text sub-00193
# Saved file for text sub-00193
# File exists: audio sub-00194
# Saved file for audio sub-00194
# File exists: text sub-00194
# Saved file for text sub-00194
# File exists: audio sub-00195
# Saved file for audio sub-00195
# File exists: text sub-00195
# Saved file for text sub-00195
# File exists: audio sub-00196
# Saved file for audio sub-00196
# File exists: text sub-00196
# Saved file for text sub-00196
# File exists: audio sub-00197
# Saved file for audio sub-00197
# File exists: text sub-00197
# Saved file for text sub-00197
# File exists: audio sub-00198
# Saved file for audio sub-00198
# File exists: text sub-00198
# Saved file for text sub-00198
# File exists: audio sub-00199
# Saved file for audio sub-00199
# File exists: text sub-00199
# Saved file for text sub-00199
# File exists: audio sub-00200
# Saved file for audio sub-00200
# File exists: text sub-00200
# Saved file for text sub-00200

# %% [markdown]
# ## Compile data across participants

# %% [markdown]
# ### Load word models for semantic comparisons

# %%
word_model_name = 'fasttext'
word_model = nlp.load_word_model(model_name=word_model_name, cache_dir=CACHE_DIR)
word_model_info = (word_model_name, word_model)
# Out:
# Loading fasttext from saved .bin file.

# %% [markdown]
# ### Load all participants data and save file

# %%
out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior.csv')
df_clean = pd.read_csv(out_fn)

# %%
x
# Out:
# (('audio', 4),
#                      prolific_id modality    subject  word_index response  \
#  0      5df0932af9a01d0dabd9313d    audio  sub-00001           4  grabbed
#  237    62a999b8ed876efe5ffe9599    audio  sub-00004           4  grabbed
#  474    62682277645054f5802459b8    audio  sub-00007           4     held
#  711    5d8e154af2858200171fdb95    audio  sub-00010           4  grabbed
#  948    5dcddf9f4d51e40a5292727d    audio  sub-00013           4   picked
#  1185   5a1342b7f2e3460001edbfd2    audio  sub-00016           4  touched
#  1422   6147c5874b61952e42e9b2bd    audio  sub-00019           4  grabbed
#  1659   65562141ae0a6660324ce572    audio  sub-00022           4   picked
#  1896   6002e90144049f32edaf9ccf    audio  sub-00025           4  grabbed
#  2133   5c9623dd35599200175642e4    audio  sub-00028           4       to
#  2370   5ce9b0e4be5a6b00163f6870    audio  sub-00031           4   picked
#  2607   5fd8ea198512a801831f6b85    audio  sub-00034           4  grabbed
#  2844   5ebeeaaf1f300410fffb8d9e    audio  sub-00037           4  grabbed
#  3081   6547a4f91dc8dbde395fe617    audio  sub-00040           4     took
#  3318   654d3b4c7746d227147f3a12    audio  sub-00043           4  grabbed
#  3555   57d88513995a0b0001635002    audio  sub-00046           4  touched
#  3792   65107bf7698f1e129de87140    audio  sub-00049           4      got
#  4029   5be59ce3520a3300010e28a9    audio  sub-00052           4  touched
#  4266   5e7dba4f1d6961436474c8f2    audio  sub-00055           4  touched
#  4503   6579e03fad6f19194fa44c26    audio  sub-00058           4     took
#  4740   5e14f72f557425b04528df9a    audio  sub-00061           4      got
#  4977   63cfee94707bca4ddee3eb05    audio  sub-00064           4  touched
#  5214   5f20817e92b4d83793b52912    audio  sub-00067           4  grabbed
#  5451   659c0c2dc64119b56219c743    audio  sub-00070           4     fell
#  5688   5f61f7f59df6ca1bfe6a8a89    audio  sub-00073           4  grabbed
#  5925   5b258c9ba7cee100011d8aad    audio  sub-00076           4      and
#  6162   65676fba8308e02bbd3675bf    audio  sub-00079           4  grabbed
#  6399   5ff45beefdb6e6b063b4c520    audio  sub-00082           4  grabbed
#  6636   60f816ff1fa74fcfab532378    audio  sub-00085           4  touched
#  6873   6581a367a62877b8742ec59a    audio  sub-00088           4  grabbed
#  7110   5eac84ff4efbe80ffd3962f1    audio  sub-00091           4  touched
#  7347   5ed2bb7a67d51b24b2ac4037    audio  sub-00094           4     took
#  7584   63ed35a73e8bacd8d4661f91    audio  sub-00097           4      the
#  7821   6122b9ffce05d8e56860755a    audio  sub-00100           4   pulled
#  8058   5f8e16511b3c641de0918ccd    audio  sub-00103           4  grabbed
#  8295   5e1a39f62b01352b6c9e14bf    audio  sub-00106           4  grabbed
#  8532   58d3d69a47aa1e00010476f4    audio  sub-00109           4      and
#  8769   6575c69e259bc98ce720601c    audio  sub-00112           4        i
#  9006   63e6132468f99695fc58b132    audio  sub-00115           4     took
#  9243   656ddbbc2e1b03788c77a652    audio  sub-00118           4      her
#  9480   63d7bea144b8a11f63c2a763    audio  sub-00121           4     felt
#  9717   5f11eb333c6e2c0df5b92270    audio  sub-00124           4      and
#  9954   5d612ae16512d700159face7    audio  sub-00127           4  grabbed
#  10191  6346be8dc544a1c320c370d3    audio  sub-00130           4  grabbed
#  10428  5e24fbd4e1f467771c234e5f    audio  sub-00133           4  grabbed
#  10665  5b14532ce9270900013c5bf6    audio  sub-00136           4  grabbed
#  10902  63f77cac11a2ddb8e7276c44    audio  sub-00139           4      and
#  11139  6117efedb574017076d5b499    audio  sub-00142           4     like
#  11376  5c26ac6163e1d8000103824f    audio  sub-00145           4  grabbed
#  11613  5e5521580ee1b951df544c3c    audio  sub-00148           4  grabbed
#
#        ground_truth entropy_group accuracy_group            rt  accuracy  \
#  0         secretly          high            low   4611.079365         0
#  237       secretly          high            low   6631.079365         0
#  474       secretly          high            low   8557.079365         0
#  711       secretly          high            low   5754.079365         0
#  948       secretly          high            low  13527.079365         0
#  1185      secretly          high            low  12009.079365         0
#  1422      secretly          high            low   6617.079365         0
#  1659      secretly          high            low   3736.079365         0
#  1896      secretly          high            low   3129.079365         0
#  2133      secretly          high            low   3486.079365         0
#  2370      secretly          high            low   7978.079365         0
#  2607      secretly          high            low   5108.079365         0
#  2844      secretly          high            low   8622.079365         0
#  3081      secretly          high            low   4509.079365         0
#  3318      secretly          high            low   6181.079365         0
#  3555      secretly          high            low  12285.079365         0
#  3792      secretly          high            low   4392.079365         0
#  4029      secretly          high            low   3816.079365         0
#  4266      secretly          high            low   5130.079365         0
#  4503      secretly          high            low  11254.079365         0
#  4740      secretly          high            low  10098.079365         0
#  4977      secretly          high            low   6100.079365         0
#  5214      secretly          high            low   5137.079365         0
#  5451      secretly          high            low  10014.079365         0
#  5688      secretly          high            low   6147.079365         0
#  5925      secretly          high            low   4344.079365         0
#  6162      secretly          high            low   6737.079365         0
#  6399      secretly          high            low   2337.079365         0
#  6636      secretly          high            low   4388.079365         0
#  6873      secretly          high            low   3237.079365         0
#  7110      secretly          high            low   4613.079365         0
#  7347      secretly          high            low   3980.079365         0
#  7584      secretly          high            low   6988.079365         0
#  7821      secretly          high            low   5663.079365         0
#  8058      secretly          high            low  10694.079365         0
#  8295      secretly          high            low   3756.079365         0
#  8532      secretly          high            low   5453.079365         0
#  8769      secretly          high            low   7338.079365         0
#  9006      secretly          high            low   2773.079365         0
#  9243      secretly          high            low   6899.079365         0
#  9480      secretly          high            low   7133.079365         0
#  9717      secretly          high            low   6016.079365         0
#  9954      secretly          high            low  49844.079365         0
#  10191     secretly          high            low   4608.079365         0
#  10428     secretly          high            low   3734.079365         0
#  10665     secretly          high            low   7190.079365         0
#  10902     secretly          high            low  20874.079365         0
#  11139     secretly          high            low   7085.079365         0
#  11376     secretly          high            low  11377.079365         0
#  11613     secretly          high            low   7742.079365         0
#
#         prominence  prominence_mean  prominence_std  relative_prominence  \
#  0            1.21           0.4808        0.537948               0.7292
#  237          1.21           0.4808        0.537948               0.7292
#  474          1.21           0.4808        0.537948               0.7292
#  711          1.21           0.4808        0.537948               0.7292
#  948          1.21           0.4808        0.537948               0.7292
#  1185         1.21           0.4808        0.537948               0.7292
#  1422         1.21           0.4808        0.537948               0.7292
#  1659         1.21           0.4808        0.537948               0.7292
#  1896         1.21           0.4808        0.537948               0.7292
#  2133         1.21           0.4808        0.537948               0.7292
#  2370         1.21           0.4808        0.537948               0.7292
#  2607         1.21           0.4808        0.537948               0.7292
#  2844         1.21           0.4808        0.537948               0.7292
#  3081         1.21           0.4808        0.537948               0.7292
#  3318         1.21           0.4808        0.537948               0.7292
#  3555         1.21           0.4808        0.537948               0.7292
#  3792         1.21           0.4808        0.537948               0.7292
#  4029         1.21           0.4808        0.537948               0.7292
#  4266         1.21           0.4808        0.537948               0.7292
#  4503         1.21           0.4808        0.537948               0.7292
#  4740         1.21           0.4808        0.537948               0.7292
#  4977         1.21           0.4808        0.537948               0.7292
#  5214         1.21           0.4808        0.537948               0.7292
#  5451         1.21           0.4808        0.537948               0.7292
#  5688         1.21           0.4808        0.537948               0.7292
#  5925         1.21           0.4808        0.537948               0.7292
#  6162         1.21           0.4808        0.537948               0.7292
#  6399         1.21           0.4808        0.537948               0.7292
#  6636         1.21           0.4808        0.537948               0.7292
#  6873         1.21           0.4808        0.537948               0.7292
#  7110         1.21           0.4808        0.537948               0.7292
#  7347         1.21           0.4808        0.537948               0.7292
#  7584         1.21           0.4808        0.537948               0.7292
#  7821         1.21           0.4808        0.537948               0.7292
#  8058         1.21           0.4808        0.537948               0.7292
#  8295         1.21           0.4808        0.537948               0.7292
#  8532         1.21           0.4808        0.537948               0.7292
#  8769         1.21           0.4808        0.537948               0.7292
#  9006         1.21           0.4808        0.537948               0.7292
#  9243         1.21           0.4808        0.537948               0.7292
#  9480         1.21           0.4808        0.537948               0.7292
#  9717         1.21           0.4808        0.537948               0.7292
#  9954         1.21           0.4808        0.537948               0.7292
#  10191        1.21           0.4808        0.537948               0.7292
#  10428        1.21           0.4808        0.537948               0.7292
#  10665        1.21           0.4808        0.537948               0.7292
#  10902        1.21           0.4808        0.537948               0.7292
#  11139        1.21           0.4808        0.537948               0.7292
#  11376        1.21           0.4808        0.537948               0.7292
#  11613        1.21           0.4808        0.537948               0.7292
#
#         relative_prominence_norm  boundary  boundary_mean  boundary_std
#  0                       1.35552     1.091         0.5164       0.51409
#  237                     1.35552     1.091         0.5164       0.51409
#  474                     1.35552     1.091         0.5164       0.51409
#  711                     1.35552     1.091         0.5164       0.51409
#  948                     1.35552     1.091         0.5164       0.51409
#  1185                    1.35552     1.091         0.5164       0.51409
#  1422                    1.35552     1.091         0.5164       0.51409
#  1659                    1.35552     1.091         0.5164       0.51409
#  1896                    1.35552     1.091         0.5164       0.51409
#  2133                    1.35552     1.091         0.5164       0.51409
#  2370                    1.35552     1.091         0.5164       0.51409
#  2607                    1.35552     1.091         0.5164       0.51409
#  2844                    1.35552     1.091         0.5164       0.51409
#  3081                    1.35552     1.091         0.5164       0.51409
#  3318                    1.35552     1.091         0.5164       0.51409
#  3555                    1.35552     1.091         0.5164       0.51409
#  3792                    1.35552     1.091         0.5164       0.51409
#  4029                    1.35552     1.091         0.5164       0.51409
#  4266                    1.35552     1.091         0.5164       0.51409
#  4503                    1.35552     1.091         0.5164       0.51409
#  4740                    1.35552     1.091         0.5164       0.51409
#  4977                    1.35552     1.091         0.5164       0.51409
#  5214                    1.35552     1.091         0.5164       0.51409
#  5451                    1.35552     1.091         0.5164       0.51409
#  5688                    1.35552     1.091         0.5164       0.51409
#  5925                    1.35552     1.091         0.5164       0.51409
#  6162                    1.35552     1.091         0.5164       0.51409
#  6399                    1.35552     1.091         0.5164       0.51409
#  6636                    1.35552     1.091         0.5164       0.51409
#  6873                    1.35552     1.091         0.5164       0.51409
#  7110                    1.35552     1.091         0.5164       0.51409
#  7347                    1.35552     1.091         0.5164       0.51409
#  7584                    1.35552     1.091         0.5164       0.51409
#  7821                    1.35552     1.091         0.5164       0.51409
#  8058                    1.35552     1.091         0.5164       0.51409
#  8295                    1.35552     1.091         0.5164       0.51409
#  8532                    1.35552     1.091         0.5164       0.51409
#  8769                    1.35552     1.091         0.5164       0.51409
#  9006                    1.35552     1.091         0.5164       0.51409
#  9243                    1.35552     1.091         0.5164       0.51409
#  9480                    1.35552     1.091         0.5164       0.51409
#  9717                    1.35552     1.091         0.5164       0.51409
#  9954                    1.35552     1.091         0.5164       0.51409
#  10191                   1.35552     1.091         0.5164       0.51409
#  10428                   1.35552     1.091         0.5164       0.51409
#  10665                   1.35552     1.091         0.5164       0.51409
#  10902                   1.35552     1.091         0.5164       0.51409
#  11139                   1.35552     1.091         0.5164       0.51409
#  11376                   1.35552     1.091         0.5164       0.51409
#  11613                   1.35552     1.091         0.5164       0.51409  )

# %%
a
# Out:
# ('audio', 4)

# %%
for a, b, c in df_clean.groupby(['modality', 'word_index']):
    sys.exit(0)
    # print (x[0])
    if i == 2:
        sys.exit(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 for a, b, c in df_clean.groupby(['modality', 'word_index']):
#       2     sys.exit(0)
#       3     # print (x[0])
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
stim_dir = os.path.join(BASE_DIR, f'stimuli/cut_audio/{EXPERIMENT_VERSION}')

# load transcript
df_transcript = pd.read_csv(os.path.join(preproc_dir, TASK, f'{TASK}_transcript-preprocessed.csv'))
df_transcript = df_transcript.rename(columns={'Word_Written': 'word', 'Punctuation': 'punctuation'})

# load all results, calculate accuracy, then save
df_all_results = aggregate_participant_responses(cleaned_results_dir, stim_dir, TASK, sub_mod_list, n_orders=4 if TASK == 'black' else 3)
# df_all_results, df_all_accuracy = calculate_results_accuracy(df_all_results)

# save compiled cleaned results
out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior.csv')
df_all_results.to_csv(out_fn, index=False)
# Out:
# Current order: 0
# sub-00001 audio
# Current order: 0
# sub-00001 text
# Current order: 1
# sub-00002 audio
# Current order: 1
# sub-00002 text
# Current order: 2
# sub-00003 audio
# Current order: 2
# sub-00003 text
# Current order: 3
# sub-00004 audio
# Current order: 3
# sub-00004 text
# Current order: 0
# sub-00005 audio
# Current order: 0
# sub-00005 text
# Current order: 1
# sub-00006 audio
# Current order: 1
# sub-00006 text
# Current order: 2
# sub-00007 audio
# Current order: 2
# sub-00007 text
# Current order: 3
# sub-00008 audio
# Current order: 3
# sub-00008 text
# Current order: 0
# sub-00009 audio
# Current order: 0
# sub-00009 text
# Current order: 1
# sub-00010 audio
# Current order: 1
# sub-00010 text
# Current order: 2
# sub-00011 audio
# Current order: 2
# sub-00011 text
# Current order: 3
# sub-00012 audio
# Current order: 3
# sub-00012 text
# Current order: 0
# sub-00013 audio
# Current order: 0
# sub-00013 text
# Current order: 1
# sub-00014 audio
# Current order: 1
# sub-00014 text
# Current order: 2
# sub-00015 audio
# Current order: 2
# sub-00015 text
# Current order: 3
# sub-00016 audio
# Current order: 3
# sub-00016 text
# Current order: 0
# sub-00017 audio
# Current order: 0
# sub-00017 text
# Current order: 1
# sub-00018 audio
# Current order: 1
# sub-00018 text
# Current order: 2
# sub-00019 audio
# Current order: 2
# sub-00019 text
# Current order: 3
# sub-00020 audio
# Current order: 3
# sub-00020 text
# Current order: 0
# sub-00021 audio
# Current order: 0
# sub-00021 text
# Current order: 1
# sub-00022 audio
# Current order: 1
# sub-00022 text
# Current order: 2
# sub-00023 audio
# Current order: 2
# sub-00023 text
# Current order: 3
# sub-00024 audio
# Current order: 3
# sub-00024 text
# Current order: 0
# sub-00025 audio
# Current order: 0
# sub-00025 text
# Current order: 1
# sub-00026 audio
# Current order: 1
# sub-00026 text
# Current order: 2
# sub-00027 audio
# Current order: 2
# sub-00027 text
# Current order: 3
# sub-00028 audio
# Current order: 3
# sub-00028 text
# Current order: 0
# sub-00029 audio
# Current order: 0
# sub-00029 text
# Current order: 1
# sub-00030 audio
# Current order: 1
# sub-00030 text
# Current order: 2
# sub-00031 audio
# Current order: 2
# sub-00031 text
# Current order: 3
# sub-00032 audio
# Current order: 3
# sub-00032 text
# Current order: 0
# sub-00033 audio
# Current order: 0
# sub-00033 text
# Current order: 1
# sub-00034 audio
# Current order: 1
# sub-00034 text
# Current order: 2
# sub-00035 audio
# Current order: 2
# sub-00035 text
# Current order: 3
# sub-00036 audio
# Current order: 3
# sub-00036 text
# Current order: 0
# sub-00037 audio
# Current order: 0
# sub-00037 text
# Current order: 1
# sub-00038 audio
# Current order: 1
# sub-00038 text
# Current order: 2
# sub-00039 audio
# Current order: 2
# sub-00039 text
# Current order: 3
# sub-00040 audio
# Current order: 3
# sub-00040 text
# Current order: 0
# sub-00041 audio
# Current order: 0
# sub-00041 text
# Current order: 1
# sub-00042 audio
# Current order: 1
# sub-00042 text
# Current order: 2
# sub-00043 audio
# Current order: 2
# sub-00043 text
# Current order: 3
# sub-00044 audio
# Current order: 3
# sub-00044 text
# Current order: 0
# sub-00045 audio
# Current order: 0
# sub-00045 text
# Current order: 1
# sub-00046 audio
# Current order: 1
# sub-00046 text
# Current order: 2
# sub-00047 audio
# Current order: 2
# sub-00047 text
# Current order: 3
# sub-00048 audio
# Current order: 3
# sub-00048 text
# Current order: 0
# sub-00049 audio
# Current order: 0
# sub-00049 text
# Current order: 1
# sub-00050 audio
# Current order: 1
# sub-00050 text
# Current order: 2
# sub-00051 audio
# Current order: 2
# sub-00051 text
# Current order: 3
# sub-00052 audio
# Current order: 3
# sub-00052 text
# Current order: 0
# sub-00053 audio
# Current order: 0
# sub-00053 text
# Current order: 1
# sub-00054 audio
# Current order: 1
# sub-00054 text
# Current order: 2
# sub-00055 audio
# Current order: 2
# sub-00055 text
# Current order: 3
# sub-00056 audio
# Current order: 3
# sub-00056 text
# Current order: 0
# sub-00057 audio
# Current order: 0
# sub-00057 text
# Current order: 1
# sub-00058 audio
# Current order: 1
# sub-00058 text
# Current order: 2
# sub-00059 audio
# Current order: 2
# sub-00059 text
# Current order: 3
# sub-00060 audio
# Current order: 3
# sub-00060 text
# Current order: 0
# sub-00061 audio
# Current order: 0
# sub-00061 text
# Current order: 1
# sub-00062 audio
# Current order: 1
# sub-00062 text
# Current order: 2
# sub-00063 audio
# Current order: 2
# sub-00063 text
# Current order: 3
# sub-00064 audio
# Current order: 3
# sub-00064 text
# Current order: 0
# sub-00065 audio
# Current order: 0
# sub-00065 text
# Current order: 1
# sub-00066 audio
# Current order: 1
# sub-00066 text
# Current order: 2
# sub-00067 audio
# Current order: 2
# sub-00067 text
# Current order: 3
# sub-00068 audio
# Current order: 3
# sub-00068 text
# Current order: 0
# sub-00069 audio
# Current order: 0
# sub-00069 text
# Current order: 1
# sub-00070 audio
# Current order: 1
# sub-00070 text
# Current order: 2
# sub-00071 audio
# Current order: 2
# sub-00071 text
# Current order: 3
# sub-00072 audio
# Current order: 3
# sub-00072 text
# Current order: 0
# sub-00073 audio
# Current order: 0
# sub-00073 text
# Current order: 1
# sub-00074 audio
# Current order: 1
# sub-00074 text
# Current order: 2
# sub-00075 audio
# Current order: 2
# sub-00075 text
# Current order: 3
# sub-00076 audio
# Current order: 3
# sub-00076 text
# Current order: 0
# sub-00077 audio
# Current order: 0
# sub-00077 text
# Current order: 1
# sub-00078 audio
# Current order: 1
# sub-00078 text
# Current order: 2
# sub-00079 audio
# Current order: 2
# sub-00079 text
# Current order: 3
# sub-00080 audio
# Current order: 3
# sub-00080 text
# Current order: 0
# sub-00081 audio
# Current order: 0
# sub-00081 text
# Current order: 1
# sub-00082 audio
# Current order: 1
# sub-00082 text
# Current order: 2
# sub-00083 audio
# Current order: 2
# sub-00083 text
# Current order: 3
# sub-00084 audio
# Current order: 3
# sub-00084 text
# Current order: 0
# sub-00085 audio
# Current order: 0
# sub-00085 text
# Current order: 1
# sub-00086 audio
# Current order: 1
# sub-00086 text
# Current order: 2
# sub-00087 audio
# Current order: 2
# sub-00087 text
# Current order: 3
# sub-00088 audio
# Current order: 3
# sub-00088 text
# Current order: 0
# sub-00089 audio
# Current order: 0
# sub-00089 text
# Current order: 1
# sub-00090 audio
# Current order: 1
# sub-00090 text
# Current order: 2
# sub-00091 audio
# Current order: 2
# sub-00091 text
# Current order: 3
# sub-00092 audio
# Current order: 3
# sub-00092 text
# Current order: 0
# sub-00093 audio
# Current order: 0
# sub-00093 text
# Current order: 1
# sub-00094 audio
# Current order: 1
# sub-00094 text
# Current order: 2
# sub-00095 audio
# Current order: 2
# sub-00095 text
# Current order: 3
# sub-00096 audio
# Current order: 3
# sub-00096 text
# Current order: 0
# sub-00097 audio
# Current order: 0
# sub-00097 text
# Current order: 1
# sub-00098 audio
# Current order: 1
# sub-00098 text
# Current order: 2
# sub-00099 audio
# Current order: 2
# sub-00099 text
# Current order: 3
# sub-00100 audio
# Current order: 3
# sub-00100 text
# Current order: 0
# sub-00101 audio
# Current order: 0
# sub-00101 text
# Current order: 1
# sub-00102 audio
# Current order: 1
# sub-00102 text
# Current order: 2
# sub-00103 audio
# Current order: 2
# sub-00103 text
# Current order: 3
# sub-00104 audio
# Current order: 3
# sub-00104 text
# Current order: 0
# sub-00105 audio
# Current order: 0
# sub-00105 text
# Current order: 1
# sub-00106 audio
# Current order: 1
# sub-00106 text
# Current order: 2
# sub-00107 audio
# Current order: 2
# sub-00107 text
# Current order: 3
# sub-00108 audio
# Current order: 3
# sub-00108 text
# Current order: 0
# sub-00109 audio
# Current order: 0
# sub-00109 text
# Current order: 1
# sub-00110 audio
# Current order: 1
# sub-00110 text
# Current order: 2
# sub-00111 audio
# Current order: 2
# sub-00111 text
# Current order: 3
# sub-00112 audio
# Current order: 3
# sub-00112 text
# Current order: 0
# sub-00113 audio
# Current order: 0
# sub-00113 text
# Current order: 1
# sub-00114 audio
# Current order: 1
# sub-00114 text
# Current order: 2
# sub-00115 audio
# Current order: 2
# sub-00115 text
# Current order: 3
# sub-00116 audio
# Current order: 3
# sub-00116 text
# Current order: 0
# sub-00117 audio
# Current order: 0
# sub-00117 text
# Current order: 1
# sub-00118 audio
# Current order: 1
# sub-00118 text
# Current order: 2
# sub-00119 audio
# Current order: 2
# sub-00119 text
# Current order: 3
# sub-00120 audio
# Current order: 3
# sub-00120 text
# Current order: 0
# sub-00121 audio
# Current order: 0
# sub-00121 text
# Current order: 1
# sub-00122 audio
# Current order: 1
# sub-00122 text
# Current order: 2
# sub-00123 audio
# Current order: 2
# sub-00123 text
# Current order: 3
# sub-00124 audio
# Current order: 3
# sub-00124 text
# Current order: 0
# sub-00125 audio
# Current order: 0
# sub-00125 text
# Current order: 1
# sub-00126 audio
# Current order: 1
# sub-00126 text
# Current order: 2
# sub-00127 audio
# Current order: 2
# sub-00127 text
# Current order: 3
# sub-00128 audio
# Current order: 3
# sub-00128 text
# Current order: 0
# sub-00129 audio
# Current order: 0
# sub-00129 text
# Current order: 1
# sub-00130 audio
# Current order: 1
# sub-00130 text
# Current order: 2
# sub-00131 audio
# Current order: 2
# sub-00131 text
# Current order: 3
# sub-00132 audio
# Current order: 3
# sub-00132 text
# Current order: 0
# sub-00133 audio
# Current order: 0
# sub-00133 text
# Current order: 1
# sub-00134 audio
# Current order: 1
# sub-00134 text
# Current order: 2
# sub-00135 audio
# Current order: 2
# sub-00135 text
# Current order: 3
# sub-00136 audio
# Current order: 3
# sub-00136 text
# Current order: 0
# sub-00137 audio
# Current order: 0
# sub-00137 text
# Current order: 1
# sub-00138 audio
# Current order: 1
# sub-00138 text
# Current order: 2
# sub-00139 audio
# Current order: 2
# sub-00139 text
# Current order: 3
# sub-00140 audio
# Current order: 3
# sub-00140 text
# Current order: 0
# sub-00141 audio
# Current order: 0
# sub-00141 text
# Current order: 1
# sub-00142 audio
# Current order: 1
# sub-00142 text
# Current order: 2
# sub-00143 audio
# Current order: 2
# sub-00143 text
# Current order: 3
# sub-00144 audio
# Current order: 3
# sub-00144 text
# Current order: 0
# sub-00145 audio
# Current order: 0
# sub-00145 text
# Current order: 1
# sub-00146 audio
# Current order: 1
# sub-00146 text
# Current order: 2
# sub-00147 audio
# Current order: 2
# sub-00147 text
# Current order: 3
# sub-00148 audio
# Current order: 3
# sub-00148 text
# Current order: 0
# sub-00149 audio
# Current order: 0
# sub-00149 text
# Current order: 1
# sub-00150 audio
# Current order: 1
# sub-00150 text
# Current order: 2
# sub-00151 audio
# Current order: 2
# sub-00151 text
# Current order: 3
# sub-00152 audio
# Current order: 3
# sub-00152 text
# Current order: 0
# sub-00153 audio
# Current order: 0
# sub-00153 text
# Current order: 1
# sub-00154 audio
# Current order: 1
# sub-00154 text
# Current order: 2
# sub-00155 audio
# Current order: 2
# sub-00155 text
# Current order: 3
# sub-00156 audio
# Current order: 3
# sub-00156 text
# Current order: 0
# sub-00157 audio
# Current order: 0
# sub-00157 text
# Current order: 1
# sub-00158 audio
# Current order: 1
# sub-00158 text
# Current order: 2
# sub-00159 audio
# Current order: 2
# sub-00159 text
# Current order: 3
# sub-00160 audio
# Current order: 3
# sub-00160 text
# Current order: 0
# sub-00161 audio
# Current order: 0
# sub-00161 text
# Current order: 1
# sub-00162 audio
# Current order: 1
# sub-00162 text
# Current order: 2
# sub-00163 audio
# Current order: 2
# sub-00163 text
# Current order: 3
# sub-00164 audio
# Current order: 3
# sub-00164 text
# Current order: 0
# sub-00165 audio
# Current order: 0
# sub-00165 text
# Current order: 1
# sub-00166 audio
# Current order: 1
# sub-00166 text
# Current order: 2
# sub-00167 audio
# Current order: 2
# sub-00167 text
# Current order: 3
# sub-00168 audio
# Current order: 3
# sub-00168 text
# Current order: 0
# sub-00169 audio
# Current order: 0
# sub-00169 text
# Current order: 1
# sub-00170 audio
# Current order: 1
# sub-00170 text
# Current order: 2
# sub-00171 audio
# Current order: 2
# sub-00171 text
# Current order: 3
# sub-00172 audio
# Current order: 3
# sub-00172 text
# Current order: 0
# sub-00173 audio
# Current order: 0
# sub-00173 text
# Current order: 1
# sub-00174 audio
# Current order: 1
# sub-00174 text
# Current order: 2
# sub-00175 audio
# Current order: 2
# sub-00175 text
# Current order: 3
# sub-00176 audio
# Current order: 3
# sub-00176 text
# Current order: 0
# sub-00177 audio
# Current order: 0
# sub-00177 text
# Current order: 1
# sub-00178 audio
# Current order: 1
# sub-00178 text
# Current order: 2
# sub-00179 audio
# Current order: 2
# sub-00179 text
# Current order: 3
# sub-00180 audio
# Current order: 3
# sub-00180 text
# Current order: 0
# sub-00181 audio
# Current order: 0
# sub-00181 text
# Current order: 1
# sub-00182 audio
# Current order: 1
# sub-00182 text
# Current order: 2
# sub-00183 audio
# Current order: 2
# sub-00183 text
# Current order: 3
# sub-00184 audio
# Current order: 3
# sub-00184 text
# Current order: 0
# sub-00185 audio
# Current order: 0
# sub-00185 text
# Current order: 1
# sub-00186 audio
# Current order: 1
# sub-00186 text
# Current order: 2
# sub-00187 audio
# Current order: 2
# sub-00187 text
# Current order: 3
# sub-00188 audio
# Current order: 3
# sub-00188 text
# Current order: 0
# sub-00189 audio
# Current order: 0
# sub-00189 text
# Current order: 1
# sub-00190 audio
# Current order: 1
# sub-00190 text
# Current order: 2
# sub-00191 audio
# Current order: 2
# sub-00191 text
# Current order: 3
# sub-00192 audio
# Current order: 3
# sub-00192 text
# Current order: 0
# sub-00193 audio
# Current order: 0
# sub-00193 text
# Current order: 1
# sub-00194 audio
# Current order: 1
# sub-00194 text
# Current order: 2
# sub-00195 audio
# Current order: 2
# sub-00195 text
# Current order: 3
# sub-00196 audio
# Current order: 3
# sub-00196 text
# Current order: 0
# sub-00197 audio
# Current order: 0
# sub-00197 text
# Current order: 1
# sub-00198 audio
# Current order: 1
# sub-00198 text
# Current order: 2
# sub-00199 audio
# Current order: 2
# sub-00199 text
# Current order: 3
# sub-00200 audio
# Current order: 3
# sub-00200 text

# %% [markdown]
# ### Lemmatize data (responses + ground truth) and save

# %%
# use transcript to lemmatize responses, then calculate accuracy
df_lemmatized_results = lemmatize_responses(df_all_results.copy(), df_transcript)
df_lemmatized_results, df_lemmatized_accuracy = calculate_results_accuracy(df_lemmatized_results)

# save compiled lemmatized results
out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior_lemmatized.csv')
df_lemmatized_results.to_csv(out_fn, index=False)
# Out:
# Word: rocks 	 Lemma: rock
# GT: radio 	 GTLemma: radio
# Word: prepare 	 Lemma: prepare
# GT: play 	 GTLemma: play
# Word: sleeve 	 Lemma: sleeve
# GT: sleeve 	 GTLemma: sleeve
# Word: record 	 Lemma: record
# GT: side 	 GTLemma: side
# Word: one 	 Lemma: one
# GT: largest 	 GTLemma: large
# Word: get 	 Lemma: get
# GT: get 	 GTLemma: get
# Word: events 	 Lemma: event
# GT: events 	 GTLemma: event
# Word: wanting 	 Lemma: want
# GT: black 	 GTLemma: black
# Word: were 	 Lemma: be
# GT: sound 	 GTLemma: sound
# Word: and 	 Lemma: and
# GT: people 	 GTLemma: people
# Word: wanted 	 Lemma: want
# GT: convinced 	 GTLemma: convince
# Word: and 	 Lemma: and
# GT: dreams 	 GTLemma: dream
# Word: written 	 Lemma: write
# GT: read 	 GTLemma: read
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: getting 	 Lemma: get
# GT: town 	 GTLemma: town
# Word: friend 	 Lemma: friend
# GT: kids 	 GTLemma: kid
# Word: kids 	 Lemma: kid
# GT: voice 	 GTLemma: voice
# Word: what 	 Lemma: what
# GT: trying 	 GTLemma: try
# Word: and 	 Lemma: and
# GT: know 	 GTLemma: know
# Word: sole 	 Lemma: sole
# GT: stomach 	 GTLemma: stomach
# Word: meaning 	 Lemma: mean
# GT: referring 	 GTLemma: refer
# Word: meant 	 Lemma: mean
# GT: say 	 GTLemma: say
# Word: really 	 Lemma: really
# GT: threatening 	 GTLemma: threaten
# Word: god 	 Lemma: god
# GT: little 	 GTLemma: little
# Word: conversation 	 Lemma: conversation
# GT: drop 	 GTLemma: drop
# Word: want 	 Lemma: want
# GT: drop 	 GTLemma: drop
# Word: it 	 Lemma: it
# GT: said 	 GTLemma: say
# Word: said 	 Lemma: say
# GT: got 	 GTLemma: get
# Word: was 	 Lemma: be
# GT: making 	 GTLemma: make
# Word: wanting 	 Lemma: want
# GT: looking 	 GTLemma: look
# Word: there 	 Lemma: there
# GT: looking 	 GTLemma: look
# Word: then 	 Lemma: then
# GT: one 	 GTLemma: one
# Word: time 	 Lemma: time
# GT: time 	 GTLemma: time
# Word: not 	 Lemma: not
# GT: truly 	 GTLemma: truly
# Word: it 	 Lemma: it
# GT: chastise 	 GTLemma: chastise
# Word: wanting 	 Lemma: want
# GT: also 	 GTLemma: also
# Word: wanting 	 Lemma: want
# GT: black 	 GTLemma: black
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: and 	 Lemma: and
# GT: right 	 GTLemma: right
# Word: car 	 Lemma: car
# GT: car 	 GTLemma: car
# Word: then 	 Lemma: then
# GT: friend 	 GTLemma: friend
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: one 	 Lemma: one
# GT: woman 	 GTLemma: woman
# Word: there 	 Lemma: there
# GT: looking 	 GTLemma: look
# Word: mind 	 Lemma: mind
# GT: driveway 	 GTLemma: driveway
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: thought 	 Lemma: think
# GT: know 	 GTLemma: know
# Word: and 	 Lemma: and
# GT: thank 	 GTLemma: thank
# Word: course 	 Lemma: course
# GT: radio 	 GTLemma: radio
# Word: talk 	 Lemma: talk
# GT: play 	 GTLemma: play
# Word: file 	 Lemma: file
# GT: sleeve 	 GTLemma: sleeve
# Word: it 	 Lemma: it
# GT: side 	 GTLemma: side
# Word: best 	 Lemma: good
# GT: largest 	 GTLemma: large
# Word: work 	 Lemma: work
# GT: get 	 GTLemma: get
# Word: events 	 Lemma: event
# GT: events 	 GTLemma: event
# Word: young 	 Lemma: young
# GT: black 	 GTLemma: black
# Word: are 	 Lemma: be
# GT: sound 	 GTLemma: sound
# Word: it 	 Lemma: it
# GT: people 	 GTLemma: people
# Word: despite 	 Lemma: despite
# GT: convinced 	 GTLemma: convince
# Word: own 	 Lemma: own
# GT: dreams 	 GTLemma: dream
# Word: read 	 Lemma: read
# GT: read 	 GTLemma: read
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: letting 	 Lemma: let
# GT: town 	 GTLemma: town
# Word: dog 	 Lemma: dog
# GT: kids 	 GTLemma: kid
# Word: voice 	 Lemma: voice
# GT: voice 	 GTLemma: voice
# Word: my 	 Lemma: my
# GT: trying 	 GTLemma: try
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: heart 	 Lemma: heart
# GT: stomach 	 GTLemma: stomach
# Word: referring 	 Lemma: refer
# GT: referring 	 GTLemma: refer
# Word: acknowledge 	 Lemma: acknowledge
# GT: say 	 GTLemma: say
# Word: really 	 Lemma: really
# GT: threatening 	 GTLemma: threaten
# Word: the 	 Lemma: the
# GT: little 	 GTLemma: little
# Word: new 	 Lemma: new
# GT: drop 	 GTLemma: drop
# Word: next 	 Lemma: next
# GT: drop 	 GTLemma: drop
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: was 	 Lemma: be
# GT: got 	 GTLemma: get
# Word: who 	 Lemma: who
# GT: making 	 GTLemma: make
# Word: still 	 Lemma: still
# GT: looking 	 GTLemma: look
# Word: still 	 Lemma: still
# GT: looking 	 GTLemma: look
# Word: we 	 Lemma: we
# GT: one 	 GTLemma: one
# Word: course 	 Lemma: course
# GT: time 	 GTLemma: time
# Word: learning 	 Lemma: learn
# GT: truly 	 GTLemma: truly
# Word: keep 	 Lemma: keep
# GT: chastise 	 GTLemma: chastise
# Word: radio 	 Lemma: radio
# GT: also 	 GTLemma: also
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: might 	 Lemma: might
# GT: know 	 GTLemma: know
# Word: there 	 Lemma: there
# GT: right 	 GTLemma: right
# Word: car 	 Lemma: car
# GT: car 	 GTLemma: car
# Word: history 	 Lemma: history
# GT: friend 	 GTLemma: friend
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: lady 	 Lemma: lady
# GT: woman 	 GTLemma: woman
# Word: looking 	 Lemma: look
# GT: looking 	 GTLemma: look
# Word: driveway 	 Lemma: driveway
# GT: driveway 	 GTLemma: driveway
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: way 	 Lemma: way
# GT: lot 	 GTLemma: lot
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: i 	 Lemma: I
# GT: thank 	 GTLemma: thank
# Word: hard 	 Lemma: hard
# GT: country 	 GTLemma: country
# Word: radio 	 Lemma: radio
# GT: weekends 	 GTLemma: weekend
# Word: board 	 Lemma: board
# GT: two 	 GTLemma: two
# Word: mind 	 Lemma: mind
# GT: getting 	 GTLemma: get
# Word: teach 	 Lemma: teach
# GT: teach 	 GTLemma: teach
# Word: ends 	 Lemma: end
# GT: break 	 GTLemma: break
# Word: ever 	 Lemma: ever
# GT: ever 	 GTLemma: ever
# Word: think 	 Lemma: think
# GT: think 	 GTLemma: think
# Word: and 	 Lemma: and
# GT: outside 	 GTLemma: outside
# Word: heard 	 Lemma: hear
# GT: heard 	 GTLemma: hear
# Word: never 	 Lemma: never
# GT: never 	 GTLemma: never
# Word: occurring 	 Lemma: occur
# GT: going 	 GTLemma: go
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: didn't 	 Lemma: didn't
# GT: tell 	 GTLemma: tell
# Word: like 	 Lemma: like
# GT: air 	 GTLemma: air
# Word: friends 	 Lemma: friend
# GT: first 	 GTLemma: first
# Word: course 	 Lemma: course
# GT: course 	 GTLemma: course
# Word: to 	 Lemma: to
# GT: rest 	 GTLemma: rest
# Word: to 	 Lemma: to
# GT: people 	 GTLemma: people
# Word: listeners 	 Lemma: listener
# GT: many 	 GTLemma: many
# Word: speaking 	 Lemma: speak
# GT: talking 	 GTLemma: talk
# Word: feel 	 Lemma: feel
# GT: feel 	 GTLemma: feel
# Word: him 	 Lemma: he
# GT: wanted 	 GTLemma: want
# Word: getting 	 Lemma: get
# GT: gurgling 	 GTLemma: gurgle
# Word: father 	 Lemma: father
# GT: siblings 	 GTLemma: sibling
# Word: on 	 Lemma: on
# GT: moment 	 GTLemma: moment
# Word: put 	 Lemma: put
# GT: took 	 GTLemma: take
# Word: through 	 Lemma: through
# GT: go 	 GTLemma: go
# Word: proud 	 Lemma: proud
# GT: proud 	 GTLemma: proud
# Word: them 	 Lemma: they
# GT: history 	 GTLemma: history
# Word: this 	 Lemma: this
# GT: debate 	 GTLemma: debate
# Word: small 	 Lemma: small
# GT: controversy 	 GTLemma: controversy
# Word: said 	 Lemma: say
# GT: organizations 	 GTLemma: organization
# Word: thinking 	 Lemma: think
# GT: thinking 	 GTLemma: think
# Word: speak 	 Lemma: speak
# GT: educate 	 GTLemma: educate
# Word: i 	 Lemma: I
# GT: also 	 GTLemma: also
# Word: black 	 Lemma: black
# GT: angry 	 GTLemma: angry
# Word: stand 	 Lemma: stand
# GT: speak 	 GTLemma: speak
# Word: look 	 Lemma: look
# GT: look 	 GTLemma: look
# Word: and 	 Lemma: and
# GT: and 	 GTLemma: and
# Word: office 	 Lemma: office
# GT: house 	 GTLemma: house
# Word: he 	 Lemma: he
# GT: driveway 	 GTLemma: driveway
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: form 	 Lemma: form
# GT: form 	 GTLemma: form
# Word: utter 	 Lemma: utter
# GT: ever 	 GTLemma: ever
# Word: on 	 Lemma: on
# GT: stake 	 GTLemma: stake
# Word: place 	 Lemma: place
# GT: job 	 GTLemma: job
# Word: job 	 Lemma: job
# GT: country 	 GTLemma: country
# Word: weekends 	 Lemma: weekend
# GT: weekends 	 GTLemma: weekend
# Word: b 	 Lemma: b
# GT: two 	 GTLemma: two
# Word: happy 	 Lemma: happy
# GT: getting 	 GTLemma: get
# Word: teach 	 Lemma: teach
# GT: teach 	 GTLemma: teach
# Word: break 	 Lemma: break
# GT: break 	 GTLemma: break
# Word: seen 	 Lemma: see
# GT: ever 	 GTLemma: ever
# Word: find 	 Lemma: find
# GT: think 	 GTLemma: think
# Word: to 	 Lemma: to
# GT: outside 	 GTLemma: outside
# Word: heard 	 Lemma: hear
# GT: heard 	 GTLemma: hear
# Word: never 	 Lemma: never
# GT: never 	 GTLemma: never
# Word: to 	 Lemma: to
# GT: going 	 GTLemma: go
# Word: not 	 Lemma: not
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: know 	 Lemma: know
# GT: tell 	 GTLemma: tell
# Word: radio 	 Lemma: radio
# GT: air 	 GTLemma: air
# Word: fans 	 Lemma: fan
# GT: first 	 GTLemma: first
# Word: course 	 Lemma: course
# GT: course 	 GTLemma: course
# Word: rest 	 Lemma: rest
# GT: rest 	 GTLemma: rest
# Word: and 	 Lemma: and
# GT: people 	 GTLemma: people
# Word: events 	 Lemma: event
# GT: many 	 GTLemma: many
# Word: talking 	 Lemma: talk
# GT: talking 	 GTLemma: talk
# Word: not 	 Lemma: not
# GT: feel 	 GTLemma: feel
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: not 	 Lemma: not
# GT: gurgling 	 GTLemma: gurgle
# Word: brother 	 Lemma: brother
# GT: siblings 	 GTLemma: sibling
# Word: session 	 Lemma: session
# GT: moment 	 GTLemma: moment
# Word: say 	 Lemma: say
# GT: took 	 GTLemma: take
# Word: not 	 Lemma: not
# GT: go 	 GTLemma: go
# Word: similar 	 Lemma: similar
# GT: proud 	 GTLemma: proud
# Word: them 	 Lemma: they
# GT: history 	 GTLemma: history
# Word: together 	 Lemma: together
# GT: debate 	 GTLemma: debate
# Word: theory 	 Lemma: theory
# GT: controversy 	 GTLemma: controversy
# Word: people 	 Lemma: people
# GT: organizations 	 GTLemma: organization
# Word: only 	 Lemma: only
# GT: thinking 	 GTLemma: think
# Word: stop 	 Lemma: stop
# GT: educate 	 GTLemma: educate
# Word: concerned 	 Lemma: concern
# GT: also 	 GTLemma: also
# Word: people 	 Lemma: people
# GT: angry 	 GTLemma: angry
# Word: know 	 Lemma: know
# GT: speak 	 GTLemma: speak
# Word: search 	 Lemma: search
# GT: look 	 GTLemma: look
# Word: and 	 Lemma: and
# GT: and 	 GTLemma: and
# Word: studio 	 Lemma: studio
# GT: house 	 GTLemma: house
# Word: garage 	 Lemma: garage
# GT: driveway 	 GTLemma: driveway
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: lying 	 Lemma: lie
# GT: white 	 GTLemma: white
# Word: minds 	 Lemma: mind
# GT: form 	 GTLemma: form
# Word: say 	 Lemma: say
# GT: ever 	 GTLemma: ever
# Word: stake 	 Lemma: stake
# GT: stake 	 GTLemma: stake
# Word: life 	 Lemma: life
# GT: job 	 GTLemma: job
# Word: boyfriend 	 Lemma: boyfriend
# GT: paying 	 GTLemma: pay
# Word: week 	 Lemma: week
# GT: week 	 GTLemma: week
# Word: scratch 	 Lemma: scratch
# GT: scratch 	 GTLemma: scratch
# Word: flip 	 Lemma: flip
# GT: lift 	 GTLemma: lift
# Word: commercials 	 Lemma: commercial
# GT: commercials 	 GTLemma: commercial
# Word: turntable 	 Lemma: turntable
# GT: turntable 	 GTLemma: turntable
# Word: kinds 	 Lemma: kind
# GT: kinds 	 GTLemma: kind
# Word: turn 	 Lemma: turn
# GT: flip 	 GTLemma: flip
# Word: excited 	 Lemma: excite
# GT: excited 	 GTLemma: excite
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: only 	 Lemma: only
# GT: heard 	 GTLemma: hear
# Word: time 	 Lemma: time
# GT: debate 	 GTLemma: debate
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: met 	 Lemma: meet
# GT: met 	 GTLemma: meet
# Word: right 	 Lemma: right
# GT: right 	 GTLemma: right
# Word: head 	 Lemma: head
# GT: head 	 GTLemma: head
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: magazine 	 Lemma: magazine
# GT: magazine 	 GTLemma: magazine
# Word: grocery 	 Lemma: grocery
# GT: grocery 	 GTLemma: grocery
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: cornbread 	 Lemma: cornbread
# GT: collard 	 GTLemma: collard
# Word: woman 	 Lemma: woman
# GT: woman 	 GTLemma: woman
# Word: felt 	 Lemma: feel
# GT: said 	 GTLemma: say
# Word: heart 	 Lemma: heart
# GT: heart 	 GTLemma: heart
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: speak 	 Lemma: speak
# GT: know 	 GTLemma: know
# Word: enraged 	 Lemma: enrage
# GT: embarrassed 	 GTLemma: embarrassed
# Word: can 	 Lemma: can
# GT: could 	 GTLemma: could
# Word: and 	 Lemma: and
# GT: dressing 	 GTLemma: dress
# Word: big 	 Lemma: big
# GT: touch 	 GTLemma: touch
# Word: could 	 Lemma: could
# GT: could 	 GTLemma: could
# Word: feel 	 Lemma: feel
# GT: feel 	 GTLemma: feel
# Word: had 	 Lemma: have
# GT: decided 	 GTLemma: decide
# Word: way 	 Lemma: way
# GT: lack 	 GTLemma: lack
# Word: time 	 Lemma: time
# GT: time 	 GTLemma: time
# Word: so 	 Lemma: so
# GT: truly 	 GTLemma: truly
# Word: moment 	 Lemma: moment
# GT: moment 	 GTLemma: moment
# Word: three 	 Lemma: three
# GT: three 	 GTLemma: three
# Word: didn't 	 Lemma: didn't
# GT: dive 	 GTLemma: dive
# Word: union 	 Lemma: union
# GT: yellow 	 GTLemma: yellow
# Word: weeks 	 Lemma: week
# GT: weeks 	 GTLemma: week
# Word: night 	 Lemma: night
# GT: news 	 GTLemma: news
# Word: thinking 	 Lemma: think
# GT: sizing 	 GTLemma: size
# Word: type 	 Lemma: type
# GT: debate 	 GTLemma: debate
# Word: or 	 Lemma: or
# GT: fashion 	 GTLemma: fashion
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: really 	 Lemma: really
# GT: try 	 GTLemma: try
# Word: job 	 Lemma: job
# GT: job 	 GTLemma: job
# Word: car 	 Lemma: car
# GT: paying 	 GTLemma: pay
# Word: week 	 Lemma: week
# GT: week 	 GTLemma: week
# Word: damage 	 Lemma: damage
# GT: scratch 	 GTLemma: scratch
# Word: turn 	 Lemma: turn
# GT: lift 	 GTLemma: lift
# Word: tape 	 Lemma: tape
# GT: commercials 	 GTLemma: commercial
# Word: other 	 Lemma: other
# GT: turntable 	 GTLemma: turntable
# Word: about 	 Lemma: about
# GT: kinds 	 GTLemma: kind
# Word: play 	 Lemma: play
# GT: flip 	 GTLemma: flip
# Word: employed 	 Lemma: employ
# GT: excited 	 GTLemma: excite
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: only 	 Lemma: only
# GT: heard 	 GTLemma: hear
# Word: new 	 Lemma: new
# GT: debate 	 GTLemma: debate
# Word: not 	 Lemma: not
# GT: white 	 GTLemma: white
# Word: seen 	 Lemma: see
# GT: met 	 GTLemma: meet
# Word: right 	 Lemma: right
# GT: right 	 GTLemma: right
# Word: confidence 	 Lemma: confidence
# GT: head 	 GTLemma: head
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: about 	 Lemma: about
# GT: magazine 	 GTLemma: magazine
# Word: store 	 Lemma: store
# GT: grocery 	 GTLemma: grocery
# Word: show 	 Lemma: show
# GT: air 	 GTLemma: air
# Word: hair 	 Lemma: hair
# GT: collard 	 GTLemma: collard
# Word: woman 	 Lemma: woman
# GT: woman 	 GTLemma: woman
# Word: did 	 Lemma: do
# GT: said 	 GTLemma: say
# Word: head 	 Lemma: head
# GT: heart 	 GTLemma: heart
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: so 	 Lemma: so
# GT: embarrassed 	 GTLemma: embarrassed
# Word: can 	 Lemma: can
# GT: could 	 GTLemma: could
# Word: stuffing 	 Lemma: stuff
# GT: dressing 	 GTLemma: dress
# Word: handbag 	 Lemma: handbag
# GT: touch 	 GTLemma: touch
# Word: could 	 Lemma: could
# GT: could 	 GTLemma: could
# Word: see 	 Lemma: see
# GT: feel 	 GTLemma: feel
# Word: trying 	 Lemma: try
# GT: decided 	 GTLemma: decide
# Word: change 	 Lemma: change
# GT: lack 	 GTLemma: lack
# Word: radio 	 Lemma: radio
# GT: time 	 GTLemma: time
# Word: like 	 Lemma: like
# GT: truly 	 GTLemma: truly
# Word: moment 	 Lemma: moment
# GT: moment 	 GTLemma: moment
# Word: three 	 Lemma: three
# GT: three 	 GTLemma: three
# Word: almost 	 Lemma: almost
# GT: dive 	 GTLemma: dive
# Word: business 	 Lemma: business
# GT: yellow 	 GTLemma: yellow
# Word: days 	 Lemma: day
# GT: weeks 	 GTLemma: week
# Word: debate 	 Lemma: debate
# GT: news 	 GTLemma: news
# Word: looking 	 Lemma: look
# GT: sizing 	 GTLemma: size
# Word: moment 	 Lemma: moment
# GT: debate 	 GTLemma: debate
# Word: other 	 Lemma: other
# GT: fashion 	 GTLemma: fashion
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: can't 	 Lemma: can't
# GT: try 	 GTLemma: try
# Word: job 	 Lemma: job
# GT: job 	 GTLemma: job
# Word: chemistry 	 Lemma: chemistry
# GT: college 	 GTLemma: college
# Word: advertisement 	 Lemma: advertisement
# GT: internship 	 GTLemma: internship
# Word: was 	 Lemma: be
# GT: though 	 GTLemma: though
# Word: hourly 	 Lemma: hourly
# GT: album 	 GTLemma: album
# Word: then 	 Lemma: then
# GT: put 	 GTLemma: put
# Word: record 	 Lemma: record
# GT: part 	 GTLemma: part
# Word: flip 	 Lemma: flip
# GT: read 	 GTLemma: read
# Word: flip 	 Lemma: flip
# GT: flip 	 GTLemma: flip
# Word: nervous 	 Lemma: nervous
# GT: nervous 	 GTLemma: nervous
# Word: walking 	 Lemma: walk
# GT: going 	 GTLemma: go
# Word: event 	 Lemma: event
# GT: young 	 GTLemma: young
# Word: a 	 Lemma: a
# GT: black 	 GTLemma: black
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: first 	 Lemma: first
# GT: first 	 GTLemma: first
# Word: so 	 Lemma: so
# GT: sounds 	 GTLemma: sound
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: broadcaster 	 Lemma: broadcaster
# GT: market 	 GTLemma: market
# Word: thought 	 Lemma: think
# GT: hatch 	 GTLemma: hatch
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: park 	 Lemma: park
# GT: zoo 	 GTLemma: zoo
# Word: state 	 Lemma: state
# GT: small 	 GTLemma: small
# Word: color 	 Lemma: color
# GT: people 	 GTLemma: people
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: mouth 	 Lemma: mouth
# GT: mouth 	 GTLemma: mouth
# Word: dare 	 Lemma: dare
# GT: dare 	 GTLemma: dare
# Word: my 	 Lemma: my
# GT: father 	 GTLemma: father
# Word: still 	 Lemma: still
# GT: still 	 GTLemma: still
# Word: recipes 	 Lemma: recipe
# GT: recipes 	 GTLemma: recipe
# Word: off 	 Lemma: off
# GT: air 	 GTLemma: air
# Word: hand 	 Lemma: hand
# GT: hand 	 GTLemma: hand
# Word: said 	 Lemma: say
# GT: knew 	 GTLemma: know
# Word: town 	 Lemma: town
# GT: big 	 GTLemma: big
# Word: said 	 Lemma: say
# GT: seen 	 GTLemma: see
# Word: seen 	 Lemma: see
# GT: see 	 GTLemma: see
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: man 	 Lemma: man
# GT: movement 	 GTLemma: movement
# Word: new 	 Lemma: new
# GT: new 	 GTLemma: new
# Word: same 	 Lemma: same
# GT: stereotype 	 GTLemma: stereotype
# Word: around 	 Lemma: around
# GT: around 	 GTLemma: around
# Word: he 	 Lemma: he
# GT: left 	 GTLemma: leave
# Word: stir 	 Lemma: stir
# GT: service 	 GTLemma: service
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: said 	 Lemma: say
# GT: sized 	 GTLemma: size
# Word: find 	 Lemma: find
# GT: find 	 GTLemma: find
# Word: a 	 Lemma: a
# GT: lot 	 GTLemma: lot
# Word: school 	 Lemma: school
# GT: college 	 GTLemma: college
# Word: actual 	 Lemma: actual
# GT: internship 	 GTLemma: internship
# Word: which 	 Lemma: which
# GT: though 	 GTLemma: though
# Word: odd 	 Lemma: odd
# GT: album 	 GTLemma: album
# Word: then 	 Lemma: then
# GT: put 	 GTLemma: put
# Word: it 	 Lemma: it
# GT: part 	 GTLemma: part
# Word: flip 	 Lemma: flip
# GT: read 	 GTLemma: read
# Word: flip 	 Lemma: flip
# GT: flip 	 GTLemma: flip
# Word: ready 	 Lemma: ready
# GT: nervous 	 GTLemma: nervous
# Word: joining 	 Lemma: join
# GT: going 	 GTLemma: go
# Word: great 	 Lemma: great
# GT: young 	 GTLemma: young
# Word: going 	 Lemma: go
# GT: black 	 GTLemma: black
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: was 	 Lemma: be
# GT: first 	 GTLemma: first
# Word: is 	 Lemma: be
# GT: sounds 	 GTLemma: sound
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: confused 	 Lemma: confuse
# GT: market 	 GTLemma: market
# Word: guess 	 Lemma: guess
# GT: hatch 	 GTLemma: hatch
# Word: would 	 Lemma: would
# GT: know 	 GTLemma: know
# Word: park 	 Lemma: park
# GT: zoo 	 GTLemma: zoo
# Word: booth 	 Lemma: booth
# GT: small 	 GTLemma: small
# Word: race 	 Lemma: race
# GT: people 	 GTLemma: people
# Word: felt 	 Lemma: feel
# GT: said 	 GTLemma: say
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: refused 	 Lemma: refuse
# GT: said 	 GTLemma: say
# Word: mouth 	 Lemma: mouth
# GT: mouth 	 GTLemma: mouth
# Word: would 	 Lemma: would
# GT: dare 	 GTLemma: dare
# Word: anger 	 Lemma: anger
# GT: father 	 GTLemma: father
# Word: trying 	 Lemma: try
# GT: still 	 GTLemma: still
# Word: dishes 	 Lemma: dish
# GT: recipes 	 GTLemma: recipe
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: hand 	 Lemma: hand
# GT: hand 	 GTLemma: hand
# Word: said 	 Lemma: say
# GT: knew 	 GTLemma: know
# Word: world 	 Lemma: world
# GT: big 	 GTLemma: big
# Word: would 	 Lemma: would
# GT: seen 	 GTLemma: see
# Word: endure 	 Lemma: endure
# GT: see 	 GTLemma: see
# Word: station 	 Lemma: station
# GT: air 	 GTLemma: air
# Word: bad 	 Lemma: bad
# GT: movement 	 GTLemma: movement
# Word: scared 	 Lemma: scare
# GT: new 	 GTLemma: new
# Word: other 	 Lemma: other
# GT: stereotype 	 GTLemma: stereotype
# Word: really 	 Lemma: really
# GT: around 	 GTLemma: around
# Word: started 	 Lemma: start
# GT: left 	 GTLemma: leave
# Word: meeting 	 Lemma: meet
# GT: service 	 GTLemma: service
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: just 	 Lemma: just
# GT: sized 	 GTLemma: size
# Word: see 	 Lemma: see
# GT: find 	 GTLemma: find
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: radio 	 Lemma: radio
# GT: radio 	 GTLemma: radio
# Word: choose 	 Lemma: choose
# GT: play 	 GTLemma: play
# Word: sleeve 	 Lemma: sleeve
# GT: sleeve 	 GTLemma: sleeve
# Word: vinyl 	 Lemma: vinyl
# GT: side 	 GTLemma: side
# Word: last 	 Lemma: last
# GT: largest 	 GTLemma: large
# Word: keep 	 Lemma: keep
# GT: get 	 GTLemma: get
# Word: events 	 Lemma: event
# GT: events 	 GTLemma: event
# Word: wearing 	 Lemma: wear
# GT: black 	 GTLemma: black
# Word: say 	 Lemma: say
# GT: sound 	 GTLemma: sound
# Word: and 	 Lemma: and
# GT: people 	 GTLemma: people
# Word: is 	 Lemma: be
# GT: convinced 	 GTLemma: convince
# Word: dreams 	 Lemma: dream
# GT: dreams 	 GTLemma: dream
# Word: written 	 Lemma: write
# GT: read 	 GTLemma: read
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: the 	 Lemma: the
# GT: town 	 GTLemma: town
# Word: tail 	 Lemma: tail
# GT: kids 	 GTLemma: kid
# Word: voice 	 Lemma: voice
# GT: voice 	 GTLemma: voice
# Word: myself 	 Lemma: myself
# GT: trying 	 GTLemma: try
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: self 	 Lemma: self
# GT: stomach 	 GTLemma: stomach
# Word: referring 	 Lemma: refer
# GT: referring 	 GTLemma: refer
# Word: say 	 Lemma: say
# GT: say 	 GTLemma: say
# Word: trembling 	 Lemma: tremble
# GT: threatening 	 GTLemma: threaten
# Word: me 	 Lemma: I
# GT: little 	 GTLemma: little
# Word: task 	 Lemma: task
# GT: drop 	 GTLemma: drop
# Word: know 	 Lemma: know
# GT: drop 	 GTLemma: drop
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: can't 	 Lemma: can't
# GT: got 	 GTLemma: get
# Word: who 	 Lemma: who
# GT: making 	 GTLemma: make
# Word: not 	 Lemma: not
# GT: looking 	 GTLemma: look
# Word: looking 	 Lemma: look
# GT: looking 	 GTLemma: look
# Word: we 	 Lemma: we
# GT: one 	 GTLemma: one
# Word: day 	 Lemma: day
# GT: time 	 GTLemma: time
# Word: really 	 Lemma: really
# GT: truly 	 GTLemma: truly
# Word: ruin 	 Lemma: ruin
# GT: chastise 	 GTLemma: chastise
# Word: also 	 Lemma: also
# GT: also 	 GTLemma: also
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: and 	 Lemma: and
# GT: right 	 GTLemma: right
# Word: car 	 Lemma: car
# GT: car 	 GTLemma: car
# Word: feeling 	 Lemma: feel
# GT: friend 	 GTLemma: friend
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: woman 	 Lemma: woman
# GT: woman 	 GTLemma: woman
# Word: looking 	 Lemma: look
# GT: looking 	 GTLemma: look
# Word: town 	 Lemma: town
# GT: driveway 	 GTLemma: driveway
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: idea 	 Lemma: idea
# GT: know 	 GTLemma: know
# Word: thanks 	 Lemma: thank
# GT: thank 	 GTLemma: thank
# Word: campus 	 Lemma: campus
# GT: radio 	 GTLemma: radio
# Word: talk 	 Lemma: talk
# GT: play 	 GTLemma: play
# Word: sleeve 	 Lemma: sleeve
# GT: sleeve 	 GTLemma: sleeve
# Word: the 	 Lemma: the
# GT: side 	 GTLemma: side
# Word: start 	 Lemma: start
# GT: largest 	 GTLemma: large
# Word: keep 	 Lemma: keep
# GT: get 	 GTLemma: get
# Word: events 	 Lemma: event
# GT: events 	 GTLemma: event
# Word: anxious 	 Lemma: anxious
# GT: black 	 GTLemma: black
# Word: sound 	 Lemma: sound
# GT: sound 	 GTLemma: sound
# Word: most 	 Lemma: most
# GT: people 	 GTLemma: people
# Word: was 	 Lemma: be
# GT: convinced 	 GTLemma: convince
# Word: dreams 	 Lemma: dream
# GT: dreams 	 GTLemma: dream
# Word: read 	 Lemma: read
# GT: read 	 GTLemma: read
# Word: realize 	 Lemma: realize
# GT: know 	 GTLemma: know
# Word: making 	 Lemma: make
# GT: town 	 GTLemma: town
# Word: paperboy 	 Lemma: paperboy
# GT: kids 	 GTLemma: kid
# Word: voice 	 Lemma: voice
# GT: voice 	 GTLemma: voice
# Word: my 	 Lemma: my
# GT: trying 	 GTLemma: try
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: heart 	 Lemma: heart
# GT: stomach 	 GTLemma: stomach
# Word: talking 	 Lemma: talk
# GT: referring 	 GTLemma: refer
# Word: confirm 	 Lemma: confirm
# GT: say 	 GTLemma: say
# Word: right 	 Lemma: right
# GT: threatening 	 GTLemma: threaten
# Word: natural 	 Lemma: natural
# GT: little 	 GTLemma: little
# Word: little 	 Lemma: little
# GT: drop 	 GTLemma: drop
# Word: start 	 Lemma: start
# GT: drop 	 GTLemma: drop
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: started 	 Lemma: start
# GT: got 	 GTLemma: get
# Word: and 	 Lemma: and
# GT: making 	 GTLemma: make
# Word: crying 	 Lemma: cry
# GT: looking 	 GTLemma: look
# Word: emotional 	 Lemma: emotional
# GT: looking 	 GTLemma: look
# Word: they 	 Lemma: they
# GT: one 	 GTLemma: one
# Word: radio 	 Lemma: radio
# GT: time 	 GTLemma: time
# Word: unsure 	 Lemma: unsure
# GT: truly 	 GTLemma: truly
# Word: stop 	 Lemma: stop
# GT: chastise 	 GTLemma: chastise
# Word: sure 	 Lemma: sure
# GT: also 	 GTLemma: also
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: anytime 	 Lemma: anytime
# GT: right 	 GTLemma: right
# Word: car 	 Lemma: car
# GT: car 	 GTLemma: car
# Word: friend 	 Lemma: friend
# GT: friend 	 GTLemma: friend
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: news 	 Lemma: news
# GT: woman 	 GTLemma: woman
# Word: surprised 	 Lemma: surprised
# GT: looking 	 GTLemma: look
# Word: driveway 	 Lemma: driveway
# GT: driveway 	 GTLemma: driveway
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: belief 	 Lemma: belief
# GT: lot 	 GTLemma: lot
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: i 	 Lemma: I
# GT: thank 	 GTLemma: thank
# Word: big 	 Lemma: big
# GT: country 	 GTLemma: country
# Word: recess 	 Lemma: recess
# GT: weekends 	 GTLemma: weekend
# Word: two 	 Lemma: two
# GT: two 	 GTLemma: two
# Word: hear 	 Lemma: hear
# GT: getting 	 GTLemma: get
# Word: sound 	 Lemma: sound
# GT: teach 	 GTLemma: teach
# Word: break 	 Lemma: break
# GT: break 	 GTLemma: break
# Word: ever 	 Lemma: ever
# GT: ever 	 GTLemma: ever
# Word: think 	 Lemma: think
# GT: think 	 GTLemma: think
# Word: and 	 Lemma: and
# GT: outside 	 GTLemma: outside
# Word: thought 	 Lemma: think
# GT: heard 	 GTLemma: hear
# Word: not 	 Lemma: not
# GT: never 	 GTLemma: never
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: white 	 Lemma: white
# GT: black 	 GTLemma: black
# Word: to 	 Lemma: to
# GT: tell 	 GTLemma: tell
# Word: new 	 Lemma: new
# GT: air 	 GTLemma: air
# Word: plan 	 Lemma: plan
# GT: first 	 GTLemma: first
# Word: choice 	 Lemma: choice
# GT: course 	 GTLemma: course
# Word: like 	 Lemma: like
# GT: rest 	 GTLemma: rest
# Word: loudly 	 Lemma: loudly
# GT: people 	 GTLemma: people
# Word: white 	 Lemma: white
# GT: many 	 GTLemma: many
# Word: all 	 Lemma: all
# GT: talking 	 GTLemma: talk
# Word: smell 	 Lemma: smell
# GT: feel 	 GTLemma: feel
# Word: black 	 Lemma: black
# GT: wanted 	 GTLemma: want
# Word: strange 	 Lemma: strange
# GT: gurgling 	 GTLemma: gurgle
# Word: grandparents 	 Lemma: grandparent
# GT: siblings 	 GTLemma: sibling
# Word: debate 	 Lemma: debate
# GT: moment 	 GTLemma: moment
# Word: made 	 Lemma: make
# GT: took 	 GTLemma: take
# Word: smart 	 Lemma: smart
# GT: go 	 GTLemma: go
# Word: proud 	 Lemma: proud
# GT: proud 	 GTLemma: proud
# Word: them 	 Lemma: they
# GT: history 	 GTLemma: history
# Word: case 	 Lemma: case
# GT: debate 	 GTLemma: debate
# Word: lot 	 Lemma: lot
# GT: controversy 	 GTLemma: controversy
# Word: officials 	 Lemma: official
# GT: organizations 	 GTLemma: organization
# Word: couldn't 	 Lemma: couldn't
# GT: thinking 	 GTLemma: think
# Word: give 	 Lemma: give
# GT: educate 	 GTLemma: educate
# Word: determined 	 Lemma: determine
# GT: also 	 GTLemma: also
# Word: black 	 Lemma: black
# GT: angry 	 GTLemma: angry
# Word: fit 	 Lemma: fit
# GT: speak 	 GTLemma: speak
# Word: look 	 Lemma: look
# GT: look 	 GTLemma: look
# Word: and 	 Lemma: and
# GT: and 	 GTLemma: and
# Word: round 	 Lemma: round
# GT: house 	 GTLemma: house
# Word: took 	 Lemma: take
# GT: driveway 	 GTLemma: driveway
# Word: recognize 	 Lemma: recognize
# GT: know 	 GTLemma: know
# Word: kidding 	 Lemma: kid
# GT: white 	 GTLemma: white
# Word: quarters 	 Lemma: quarter
# GT: form 	 GTLemma: form
# Word: deal 	 Lemma: deal
# GT: ever 	 GTLemma: ever
# Word: than 	 Lemma: than
# GT: stake 	 GTLemma: stake
# Word: life 	 Lemma: life
# GT: job 	 GTLemma: job
# Word: exciting 	 Lemma: exciting
# GT: country 	 GTLemma: country
# Word: weekend 	 Lemma: weekend
# GT: weekends 	 GTLemma: weekend
# Word: two 	 Lemma: two
# GT: two 	 GTLemma: two
# Word: really 	 Lemma: really
# GT: getting 	 GTLemma: get
# Word: teach 	 Lemma: teach
# GT: teach 	 GTLemma: teach
# Word: break 	 Lemma: break
# GT: break 	 GTLemma: break
# Word: worked 	 Lemma: work
# GT: ever 	 GTLemma: ever
# Word: find 	 Lemma: find
# GT: think 	 GTLemma: think
# Word: and 	 Lemma: and
# GT: outside 	 GTLemma: outside
# Word: believed 	 Lemma: believe
# GT: heard 	 GTLemma: hear
# Word: not 	 Lemma: not
# GT: never 	 GTLemma: never
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: tell 	 Lemma: tell
# GT: tell 	 GTLemma: tell
# Word: radio 	 Lemma: radio
# GT: air 	 GTLemma: air
# Word: plan 	 Lemma: plan
# GT: first 	 GTLemma: first
# Word: course 	 Lemma: course
# GT: course 	 GTLemma: course
# Word: end 	 Lemma: end
# GT: rest 	 GTLemma: rest
# Word: running 	 Lemma: run
# GT: people 	 GTLemma: people
# Word: events 	 Lemma: event
# GT: many 	 GTLemma: many
# Word: talking 	 Lemma: talk
# GT: talking 	 GTLemma: talk
# Word: have 	 Lemma: have
# GT: feel 	 GTLemma: feel
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: out 	 Lemma: out
# GT: gurgling 	 GTLemma: gurgle
# Word: parents 	 Lemma: parent
# GT: siblings 	 GTLemma: sibling
# Word: moment 	 Lemma: moment
# GT: moment 	 GTLemma: moment
# Word: say 	 Lemma: say
# GT: took 	 GTLemma: take
# Word: feel 	 Lemma: feel
# GT: go 	 GTLemma: go
# Word: alike 	 Lemma: alike
# GT: proud 	 GTLemma: proud
# Word: two 	 Lemma: two
# GT: history 	 GTLemma: history
# Word: world 	 Lemma: world
# GT: debate 	 GTLemma: debate
# Word: moment 	 Lemma: moment
# GT: controversy 	 GTLemma: controversy
# Word: people 	 Lemma: people
# GT: organizations 	 GTLemma: organization
# Word: angry 	 Lemma: angry
# GT: thinking 	 GTLemma: think
# Word: say 	 Lemma: say
# GT: educate 	 GTLemma: educate
# Word: undecided 	 Lemma: undecided
# GT: also 	 GTLemma: also
# Word: black 	 Lemma: black
# GT: angry 	 GTLemma: angry
# Word: have 	 Lemma: have
# GT: speak 	 GTLemma: speak
# Word: imagine 	 Lemma: imagine
# GT: look 	 GTLemma: look
# Word: and 	 Lemma: and
# GT: and 	 GTLemma: and
# Word: studio 	 Lemma: studio
# GT: house 	 GTLemma: house
# Word: windshield 	 Lemma: windshield
# GT: driveway 	 GTLemma: driveway
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: someone 	 Lemma: someone
# GT: white 	 GTLemma: white
# Word: quarters 	 Lemma: quarter
# GT: form 	 GTLemma: form
# Word: believe 	 Lemma: believe
# GT: ever 	 GTLemma: ever
# Word: stake 	 Lemma: stake
# GT: stake 	 GTLemma: stake
# Word: life 	 Lemma: life
# GT: job 	 GTLemma: job
# Word: job 	 Lemma: job
# GT: paying 	 GTLemma: pay
# Word: week 	 Lemma: week
# GT: week 	 GTLemma: week
# Word: music 	 Lemma: music
# GT: scratch 	 GTLemma: scratch
# Word: turn 	 Lemma: turn
# GT: lift 	 GTLemma: lift
# Word: commercials 	 Lemma: commercial
# GT: commercials 	 GTLemma: commercial
# Word: turntable 	 Lemma: turntable
# GT: turntable 	 GTLemma: turntable
# Word: about 	 Lemma: about
# GT: kinds 	 GTLemma: kind
# Word: turn 	 Lemma: turn
# GT: flip 	 GTLemma: flip
# Word: excited 	 Lemma: excite
# GT: excited 	 GTLemma: excite
# Word: spoke 	 Lemma: speak
# GT: said 	 GTLemma: say
# Word: white 	 Lemma: white
# GT: heard 	 GTLemma: hear
# Word: place 	 Lemma: place
# GT: debate 	 GTLemma: debate
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: met 	 Lemma: meet
# GT: met 	 GTLemma: meet
# Word: right 	 Lemma: right
# GT: right 	 GTLemma: right
# Word: head 	 Lemma: head
# GT: head 	 GTLemma: head
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: magazine 	 Lemma: magazine
# GT: magazine 	 GTLemma: magazine
# Word: drive-through 	 Lemma: drive
# GT: grocery 	 GTLemma: grocery
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: food 	 Lemma: food
# GT: collard 	 GTLemma: collard
# Word: person 	 Lemma: person
# GT: woman 	 GTLemma: woman
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: head 	 Lemma: head
# GT: heart 	 GTLemma: heart
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: mad 	 Lemma: mad
# GT: embarrassed 	 GTLemma: embarrassed
# Word: could 	 Lemma: could
# GT: could 	 GTLemma: could
# Word: grilled 	 Lemma: grill
# GT: dressing 	 GTLemma: dress
# Word: handbag 	 Lemma: handbag
# GT: touch 	 GTLemma: touch
# Word: could 	 Lemma: could
# GT: could 	 GTLemma: could
# Word: feel 	 Lemma: feel
# GT: feel 	 GTLemma: feel
# Word: which 	 Lemma: which
# GT: decided 	 GTLemma: decide
# Word: the 	 Lemma: the
# GT: lack 	 GTLemma: lack
# Word: the 	 Lemma: the
# GT: time 	 GTLemma: time
# Word: aghast 	 Lemma: aghast
# GT: truly 	 GTLemma: truly
# Word: historic 	 Lemma: historic
# GT: moment 	 GTLemma: moment
# Word: three 	 Lemma: three
# GT: three 	 GTLemma: three
# Word: don't 	 Lemma: don't
# GT: dive 	 GTLemma: dive
# Word: year 	 Lemma: year
# GT: yellow 	 GTLemma: yellow
# Word: steps 	 Lemma: step
# GT: weeks 	 GTLemma: week
# Word: woman 	 Lemma: woman
# GT: news 	 GTLemma: news
# Word: thinking 	 Lemma: think
# GT: sizing 	 GTLemma: size
# Word: thing 	 Lemma: thing
# GT: debate 	 GTLemma: debate
# Word: of 	 Lemma: of
# GT: fashion 	 GTLemma: fashion
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: don't 	 Lemma: don't
# GT: try 	 GTLemma: try
# Word: job 	 Lemma: job
# GT: job 	 GTLemma: job
# Word: ticket 	 Lemma: ticket
# GT: paying 	 GTLemma: pay
# Word: week 	 Lemma: week
# GT: week 	 GTLemma: week
# Word: scratch 	 Lemma: scratch
# GT: scratch 	 GTLemma: scratch
# Word: take 	 Lemma: take
# GT: lift 	 GTLemma: lift
# Word: music 	 Lemma: music
# GT: commercials 	 GTLemma: commercial
# Word: player 	 Lemma: player
# GT: turntable 	 GTLemma: turntable
# Word: this 	 Lemma: this
# GT: kinds 	 GTLemma: kind
# Word: work 	 Lemma: work
# GT: flip 	 GTLemma: flip
# Word: keen 	 Lemma: keen
# GT: excited 	 GTLemma: excite
# Word: was 	 Lemma: be
# GT: said 	 GTLemma: say
# Word: just 	 Lemma: just
# GT: heard 	 GTLemma: hear
# Word: story 	 Lemma: story
# GT: debate 	 GTLemma: debate
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: heard 	 Lemma: hear
# GT: met 	 GTLemma: meet
# Word: right 	 Lemma: right
# GT: right 	 GTLemma: right
# Word: thoughts 	 Lemma: thought
# GT: head 	 GTLemma: head
# Word: silent 	 Lemma: silent
# GT: going 	 GTLemma: go
# Word: magazine 	 Lemma: magazine
# GT: magazine 	 GTLemma: magazine
# Word: office 	 Lemma: office
# GT: grocery 	 GTLemma: grocery
# Word: radio 	 Lemma: radio
# GT: air 	 GTLemma: air
# Word: chicken 	 Lemma: chicken
# GT: collard 	 GTLemma: collard
# Word: man 	 Lemma: man
# GT: woman 	 GTLemma: woman
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: throat 	 Lemma: throat
# GT: heart 	 GTLemma: heart
# Word: still 	 Lemma: still
# GT: wanted 	 GTLemma: want
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: mad 	 Lemma: mad
# GT: embarrassed 	 GTLemma: embarrassed
# Word: think 	 Lemma: think
# GT: could 	 GTLemma: could
# Word: fritters 	 Lemma: fritter
# GT: dressing 	 GTLemma: dress
# Word: look 	 Lemma: look
# GT: touch 	 GTLemma: touch
# Word: could 	 Lemma: could
# GT: could 	 GTLemma: could
# Word: feel 	 Lemma: feel
# GT: feel 	 GTLemma: feel
# Word: can 	 Lemma: can
# GT: decided 	 GTLemma: decide
# Word: racism 	 Lemma: racism
# GT: lack 	 GTLemma: lack
# Word: show 	 Lemma: show
# GT: time 	 GTLemma: time
# Word: shocked 	 Lemma: shock
# GT: truly 	 GTLemma: truly
# Word: time 	 Lemma: time
# GT: moment 	 GTLemma: moment
# Word: i 	 Lemma: I
# GT: three 	 GTLemma: three
# Word: am 	 Lemma: be
# GT: dive 	 GTLemma: dive
# Word: minority 	 Lemma: minority
# GT: yellow 	 GTLemma: yellow
# Word: people 	 Lemma: people
# GT: weeks 	 GTLemma: week
# Word: he 	 Lemma: he
# GT: news 	 GTLemma: news
# Word: shocked 	 Lemma: shock
# GT: sizing 	 GTLemma: size
# Word: way 	 Lemma: way
# GT: debate 	 GTLemma: debate
# Word: another 	 Lemma: another
# GT: fashion 	 GTLemma: fashion
# Word: problem 	 Lemma: problem
# GT: lot 	 GTLemma: lot
# Word: couldn't 	 Lemma: couldn't
# GT: try 	 GTLemma: try
# Word: job 	 Lemma: job
# GT: job 	 GTLemma: job
# Word: work 	 Lemma: work
# GT: college 	 GTLemma: college
# Word: first 	 Lemma: first
# GT: internship 	 GTLemma: internship
# Word: was 	 Lemma: be
# GT: though 	 GTLemma: though
# Word: weekend 	 Lemma: weekend
# GT: album 	 GTLemma: album
# Word: putting 	 Lemma: put
# GT: put 	 GTLemma: put
# Word: sound 	 Lemma: sound
# GT: part 	 GTLemma: part
# Word: turn 	 Lemma: turn
# GT: read 	 GTLemma: read
# Word: learn 	 Lemma: learn
# GT: flip 	 GTLemma: flip
# Word: motivated 	 Lemma: motivate
# GT: nervous 	 GTLemma: nervous
# Word: socializing 	 Lemma: socialize
# GT: going 	 GTLemma: go
# Word: center 	 Lemma: center
# GT: young 	 GTLemma: young
# Word: on 	 Lemma: on
# GT: black 	 GTLemma: black
# Word: solicitor 	 Lemma: solicitor
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: spoke 	 Lemma: speak
# GT: first 	 GTLemma: first
# Word: white 	 Lemma: white
# GT: sounds 	 GTLemma: sound
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: in 	 Lemma: in
# GT: market 	 GTLemma: market
# Word: decided 	 Lemma: decide
# GT: hatch 	 GTLemma: hatch
# Word: will 	 Lemma: will
# GT: know 	 GTLemma: know
# Word: school 	 Lemma: school
# GT: zoo 	 GTLemma: zoo
# Word: cafe 	 Lemma: cafe
# GT: small 	 GTLemma: small
# Word: race 	 Lemma: race
# GT: people 	 GTLemma: people
# Word: thought 	 Lemma: think
# GT: said 	 GTLemma: say
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: mouth 	 Lemma: mouth
# GT: mouth 	 GTLemma: mouth
# Word: dare 	 Lemma: dare
# GT: dare 	 GTLemma: dare
# Word: words 	 Lemma: word
# GT: father 	 GTLemma: father
# Word: speaking 	 Lemma: speak
# GT: still 	 GTLemma: still
# Word: pastimes 	 Lemma: pastime
# GT: recipes 	 GTLemma: recipe
# Word: next 	 Lemma: next
# GT: air 	 GTLemma: air
# Word: hand 	 Lemma: hand
# GT: hand 	 GTLemma: hand
# Word: thought 	 Lemma: think
# GT: knew 	 GTLemma: know
# Word: radio 	 Lemma: radio
# GT: big 	 GTLemma: big
# Word: style 	 Lemma: style
# GT: seen 	 GTLemma: see
# Word: see 	 Lemma: see
# GT: see 	 GTLemma: see
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: unfair 	 Lemma: unfair
# GT: movement 	 GTLemma: movement
# Word: niggled 	 Lemma: niggle
# GT: new 	 GTLemma: new
# Word: state 	 Lemma: state
# GT: stereotype 	 GTLemma: stereotype
# Word: waiting 	 Lemma: wait
# GT: around 	 GTLemma: around
# Word: then 	 Lemma: then
# GT: left 	 GTLemma: leave
# Word: supper 	 Lemma: supper
# GT: service 	 GTLemma: service
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: working 	 Lemma: work
# GT: sized 	 GTLemma: size
# Word: find 	 Lemma: find
# GT: find 	 GTLemma: find
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: middle 	 Lemma: middle
# GT: college 	 GTLemma: college
# Word: ordinary 	 Lemma: ordinary
# GT: internship 	 GTLemma: internship
# Word: was 	 Lemma: be
# GT: though 	 GTLemma: though
# Word: evening 	 Lemma: evening
# GT: album 	 GTLemma: album
# Word: play 	 Lemma: play
# GT: put 	 GTLemma: put
# Word: the 	 Lemma: the
# GT: part 	 GTLemma: part
# Word: play 	 Lemma: play
# GT: read 	 GTLemma: read
# Word: ready 	 Lemma: ready
# GT: flip 	 GTLemma: flip
# Word: getting 	 Lemma: get
# GT: nervous 	 GTLemma: nervous
# Word: talking 	 Lemma: talk
# GT: going 	 GTLemma: go
# Word: person 	 Lemma: person
# GT: young 	 GTLemma: young
# Word: the 	 Lemma: the
# GT: black 	 GTLemma: black
# Word: black 	 Lemma: black
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: arrived 	 Lemma: arrive
# GT: first 	 GTLemma: first
# Word: is 	 Lemma: be
# GT: sounds 	 GTLemma: sound
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: player 	 Lemma: player
# GT: market 	 GTLemma: market
# Word: socialized 	 Lemma: socialize
# GT: hatch 	 GTLemma: hatch
# Word: notice 	 Lemma: notice
# GT: know 	 GTLemma: know
# Word: market 	 Lemma: market
# GT: zoo 	 GTLemma: zoo
# Word: school 	 Lemma: school
# GT: small 	 GTLemma: small
# Word: age 	 Lemma: age
# GT: people 	 GTLemma: people
# Word: am 	 Lemma: be
# GT: said 	 GTLemma: say
# Word: like 	 Lemma: like
# GT: know 	 GTLemma: know
# Word: spoke 	 Lemma: speak
# GT: said 	 GTLemma: say
# Word: mouth 	 Lemma: mouth
# GT: mouth 	 GTLemma: mouth
# Word: can 	 Lemma: can
# GT: dare 	 GTLemma: dare
# Word: coach 	 Lemma: coach
# GT: father 	 GTLemma: father
# Word: not 	 Lemma: not
# GT: still 	 GTLemma: still
# Word: memories 	 Lemma: memory
# GT: recipes 	 GTLemma: recipe
# Word: road 	 Lemma: road
# GT: air 	 GTLemma: air
# Word: palm 	 Lemma: palm
# GT: hand 	 GTLemma: hand
# Word: listened 	 Lemma: listen
# GT: knew 	 GTLemma: know
# Word: journey 	 Lemma: journey
# GT: big 	 GTLemma: big
# Word: distinct 	 Lemma: distinct
# GT: seen 	 GTLemma: see
# Word: look 	 Lemma: look
# GT: see 	 GTLemma: see
# Word: way 	 Lemma: way
# GT: air 	 GTLemma: air
# Word: terrible 	 Lemma: terrible
# GT: movement 	 GTLemma: movement
# Word: wondering 	 Lemma: wonder
# GT: new 	 GTLemma: new
# Word: baby 	 Lemma: baby
# GT: stereotype 	 GTLemma: stereotype
# Word: doing 	 Lemma: do
# GT: around 	 GTLemma: around
# Word: left 	 Lemma: leave
# GT: left 	 GTLemma: leave
# Word: discussion 	 Lemma: discussion
# GT: service 	 GTLemma: service
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: looked 	 Lemma: look
# GT: sized 	 GTLemma: size
# Word: see 	 Lemma: see
# GT: find 	 GTLemma: find
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: back 	 Lemma: back
# GT: radio 	 GTLemma: radio
# Word: produce 	 Lemma: produce
# GT: play 	 GTLemma: play
# Word: tape 	 Lemma: tape
# GT: sleeve 	 GTLemma: sleeve
# Word: the 	 Lemma: the
# GT: side 	 GTLemma: side
# Word: most 	 Lemma: most
# GT: largest 	 GTLemma: large
# Word: concentrate 	 Lemma: concentrate
# GT: get 	 GTLemma: get
# Word: events 	 Lemma: event
# GT: events 	 GTLemma: event
# Word: enthusiastic 	 Lemma: enthusiastic
# GT: black 	 GTLemma: black
# Word: can't 	 Lemma: can't
# GT: sound 	 GTLemma: sound
# Word: whether 	 Lemma: whether
# GT: people 	 GTLemma: people
# Word: was 	 Lemma: be
# GT: convinced 	 GTLemma: convince
# Word: radio 	 Lemma: radio
# GT: dreams 	 GTLemma: dream
# Word: read 	 Lemma: read
# GT: read 	 GTLemma: read
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: making 	 Lemma: make
# GT: town 	 GTLemma: town
# Word: cat 	 Lemma: cat
# GT: kids 	 GTLemma: kid
# Word: tone 	 Lemma: tone
# GT: voice 	 GTLemma: voice
# Word: a 	 Lemma: a
# GT: trying 	 GTLemma: try
# Word: fry 	 Lemma: fry
# GT: know 	 GTLemma: know
# Word: soul 	 Lemma: soul
# GT: stomach 	 GTLemma: stomach
# Word: referring 	 Lemma: refer
# GT: referring 	 GTLemma: refer
# Word: say 	 Lemma: say
# GT: say 	 GTLemma: say
# Word: boiling 	 Lemma: boil
# GT: threatening 	 GTLemma: threaten
# Word: genuine 	 Lemma: genuine
# GT: little 	 GTLemma: little
# Word: little 	 Lemma: little
# GT: drop 	 GTLemma: drop
# Word: decide 	 Lemma: decide
# GT: drop 	 GTLemma: drop
# Word: asking 	 Lemma: ask
# GT: said 	 GTLemma: say
# Word: thought 	 Lemma: think
# GT: got 	 GTLemma: get
# Word: and 	 Lemma: and
# GT: making 	 GTLemma: make
# Word: just 	 Lemma: just
# GT: looking 	 GTLemma: look
# Word: only 	 Lemma: only
# GT: looking 	 GTLemma: look
# Word: when 	 Lemma: when
# GT: one 	 GTLemma: one
# Word: first 	 Lemma: first
# GT: time 	 GTLemma: time
# Word: wondering 	 Lemma: wonder
# GT: truly 	 GTLemma: truly
# Word: admonish 	 Lemma: admonish
# GT: chastise 	 GTLemma: chastise
# Word: asking 	 Lemma: ask
# GT: also 	 GTLemma: also
# Word: inexperienced 	 Lemma: inexperienced
# GT: black 	 GTLemma: black
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: if 	 Lemma: if
# GT: right 	 GTLemma: right
# Word: car 	 Lemma: car
# GT: car 	 GTLemma: car
# Word: funny 	 Lemma: funny
# GT: friend 	 GTLemma: friend
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: news 	 Lemma: news
# GT: woman 	 GTLemma: woman
# Word: asking 	 Lemma: ask
# GT: looking 	 GTLemma: look
# Word: own 	 Lemma: own
# GT: driveway 	 GTLemma: driveway
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: line 	 Lemma: line
# GT: lot 	 GTLemma: lot
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: thank 	 Lemma: thank
# GT: thank 	 GTLemma: thank
# Word: campus 	 Lemma: campus
# GT: radio 	 GTLemma: radio
# Word: late 	 Lemma: late
# GT: play 	 GTLemma: play
# Word: cover 	 Lemma: cover
# GT: sleeve 	 GTLemma: sleeve
# Word: top 	 Lemma: top
# GT: side 	 GTLemma: side
# Word: biggest 	 Lemma: big
# GT: largest 	 GTLemma: large
# Word: do 	 Lemma: do
# GT: get 	 GTLemma: get
# Word: events 	 Lemma: event
# GT: events 	 GTLemma: event
# Word: tall 	 Lemma: tall
# GT: black 	 GTLemma: black
# Word: should 	 Lemma: should
# GT: sound 	 GTLemma: sound
# Word: he 	 Lemma: he
# GT: people 	 GTLemma: people
# Word: being 	 Lemma: be
# GT: convinced 	 GTLemma: convince
# Word: dreams 	 Lemma: dream
# GT: dreams 	 GTLemma: dream
# Word: written 	 Lemma: write
# GT: read 	 GTLemma: read
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: trying 	 Lemma: try
# GT: town 	 GTLemma: town
# Word: dog 	 Lemma: dog
# GT: kids 	 GTLemma: kid
# Word: voice 	 Lemma: voice
# GT: voice 	 GTLemma: voice
# Word: my 	 Lemma: my
# GT: trying 	 GTLemma: try
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: bones 	 Lemma: bone
# GT: stomach 	 GTLemma: stomach
# Word: talking 	 Lemma: talk
# GT: referring 	 GTLemma: refer
# Word: realize 	 Lemma: realize
# GT: say 	 GTLemma: say
# Word: funny 	 Lemma: funny
# GT: threatening 	 GTLemma: threaten
# Word: life 	 Lemma: life
# GT: little 	 GTLemma: little
# Word: little 	 Lemma: little
# GT: drop 	 GTLemma: drop
# Word: decide 	 Lemma: decide
# GT: drop 	 GTLemma: drop
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: smiled 	 Lemma: smile
# GT: got 	 GTLemma: get
# Word: making 	 Lemma: make
# GT: making 	 GTLemma: make
# Word: worried 	 Lemma: worried
# GT: looking 	 GTLemma: look
# Word: glad 	 Lemma: glad
# GT: looking 	 GTLemma: look
# Word: they 	 Lemma: they
# GT: one 	 GTLemma: one
# Word: station 	 Lemma: station
# GT: time 	 GTLemma: time
# Word: guessing 	 Lemma: guess
# GT: truly 	 GTLemma: truly
# Word: fail 	 Lemma: fail
# GT: chastise 	 GTLemma: chastise
# Word: trying 	 Lemma: try
# GT: also 	 GTLemma: also
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: sir 	 Lemma: sir
# GT: know 	 GTLemma: know
# Word: easily 	 Lemma: easily
# GT: right 	 GTLemma: right
# Word: car 	 Lemma: car
# GT: car 	 GTLemma: car
# Word: nice 	 Lemma: nice
# GT: friend 	 GTLemma: friend
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: way 	 Lemma: way
# GT: woman 	 GTLemma: woman
# Word: shocked 	 Lemma: shock
# GT: looking 	 GTLemma: look
# Word: skin 	 Lemma: skin
# GT: driveway 	 GTLemma: driveway
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: slight 	 Lemma: slight
# GT: lot 	 GTLemma: lot
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: i 	 Lemma: I
# GT: thank 	 GTLemma: thank
# Word: contract 	 Lemma: contract
# GT: country 	 GTLemma: country
# Word: weekends 	 Lemma: weekend
# GT: weekends 	 GTLemma: weekend
# Word: two 	 Lemma: two
# GT: two 	 GTLemma: two
# Word: really 	 Lemma: really
# GT: getting 	 GTLemma: get
# Word: teach 	 Lemma: teach
# GT: teach 	 GTLemma: teach
# Word: break 	 Lemma: break
# GT: break 	 GTLemma: break
# Word: ever 	 Lemma: ever
# GT: ever 	 GTLemma: ever
# Word: find 	 Lemma: find
# GT: think 	 GTLemma: think
# Word: and 	 Lemma: and
# GT: outside 	 GTLemma: outside
# Word: heard 	 Lemma: hear
# GT: heard 	 GTLemma: hear
# Word: never 	 Lemma: never
# GT: never 	 GTLemma: never
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: know 	 Lemma: know
# GT: tell 	 GTLemma: tell
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: first 	 Lemma: first
# GT: first 	 GTLemma: first
# Word: course 	 Lemma: course
# GT: course 	 GTLemma: course
# Word: and 	 Lemma: and
# GT: rest 	 GTLemma: rest
# Word: calling 	 Lemma: call
# GT: people 	 GTLemma: people
# Word: events 	 Lemma: event
# GT: many 	 GTLemma: many
# Word: discussing 	 Lemma: discuss
# ...
# GT: driveway 	 GTLemma: driveway
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: problem 	 Lemma: problem
# GT: lot 	 GTLemma: lot
# Word: guess 	 Lemma: guess
# GT: know 	 GTLemma: know
# Word: i 	 Lemma: I
# GT: thank 	 GTLemma: thank
# Word: great 	 Lemma: great
# GT: country 	 GTLemma: country
# Word: weekend 	 Lemma: weekend
# GT: weekends 	 GTLemma: weekend
# Word: two 	 Lemma: two
# GT: two 	 GTLemma: two
# Word: listening 	 Lemma: listen
# GT: getting 	 GTLemma: get
# Word: teach 	 Lemma: teach
# GT: teach 	 GTLemma: teach
# Word: break 	 Lemma: break
# GT: break 	 GTLemma: break
# Word: ever 	 Lemma: ever
# GT: ever 	 GTLemma: ever
# Word: find 	 Lemma: find
# GT: think 	 GTLemma: think
# Word: and 	 Lemma: and
# GT: outside 	 GTLemma: outside
# Word: heard 	 Lemma: hear
# GT: heard 	 GTLemma: hear
# Word: never 	 Lemma: never
# GT: never 	 GTLemma: never
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: tell 	 Lemma: tell
# GT: tell 	 GTLemma: tell
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: first 	 Lemma: first
# GT: first 	 GTLemma: first
# Word: course 	 Lemma: course
# GT: course 	 GTLemma: course
# Word: vote 	 Lemma: vote
# GT: rest 	 GTLemma: rest
# Word: i'm 	 Lemma: I
# GT: people 	 GTLemma: people
# Word: hints 	 Lemma: hint
# GT: many 	 GTLemma: many
# Word: talking 	 Lemma: talk
# GT: talking 	 GTLemma: talk
# Word: feel 	 Lemma: feel
# GT: feel 	 GTLemma: feel
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: going 	 Lemma: go
# GT: gurgling 	 GTLemma: gurgle
# Word: sister 	 Lemma: sister
# GT: siblings 	 GTLemma: sibling
# Word: moment 	 Lemma: moment
# GT: moment 	 GTLemma: moment
# Word: thought 	 Lemma: think
# GT: took 	 GTLemma: take
# Word: stop 	 Lemma: stop
# GT: go 	 GTLemma: go
# Word: proud 	 Lemma: proud
# GT: proud 	 GTLemma: proud
# Word: them 	 Lemma: they
# GT: history 	 GTLemma: history
# Word: room 	 Lemma: room
# GT: debate 	 GTLemma: debate
# Word: comment 	 Lemma: comment
# GT: controversy 	 GTLemma: controversy
# Word: organizers 	 Lemma: organizer
# GT: organizations 	 GTLemma: organization
# Word: trying 	 Lemma: try
# GT: thinking 	 GTLemma: think
# Word: change 	 Lemma: change
# GT: educate 	 GTLemma: educate
# Word: determined 	 Lemma: determine
# GT: also 	 GTLemma: also
# Word: african 	 Lemma: african
# GT: angry 	 GTLemma: angry
# Word: speak 	 Lemma: speak
# GT: speak 	 GTLemma: speak
# Word: look 	 Lemma: look
# GT: look 	 GTLemma: look
# Word: and 	 Lemma: and
# GT: and 	 GTLemma: and
# Word: house 	 Lemma: house
# GT: house 	 GTLemma: house
# Word: driveway 	 Lemma: driveway
# GT: driveway 	 GTLemma: driveway
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: form 	 Lemma: form
# GT: form 	 GTLemma: form
# Word: ever 	 Lemma: ever
# GT: ever 	 GTLemma: ever
# Word: stake 	 Lemma: stake
# GT: stake 	 GTLemma: stake
# Word: job 	 Lemma: job
# GT: job 	 GTLemma: job
# Word: apprenticeship 	 Lemma: apprenticeship
# GT: country 	 GTLemma: country
# Word: early 	 Lemma: early
# GT: weekends 	 GTLemma: weekend
# Word: two 	 Lemma: two
# GT: two 	 GTLemma: two
# Word: presenting 	 Lemma: present
# GT: getting 	 GTLemma: get
# Word: give 	 Lemma: give
# GT: teach 	 GTLemma: teach
# Word: ends 	 Lemma: end
# GT: break 	 GTLemma: break
# Word: visited 	 Lemma: visit
# GT: ever 	 GTLemma: ever
# Word: manage 	 Lemma: manage
# GT: think 	 GTLemma: think
# Word: directly 	 Lemma: directly
# GT: outside 	 GTLemma: outside
# Word: agree 	 Lemma: agree
# GT: heard 	 GTLemma: hear
# Word: never 	 Lemma: never
# GT: never 	 GTLemma: never
# Word: taking 	 Lemma: take
# GT: going 	 GTLemma: go
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: know 	 Lemma: know
# GT: tell 	 GTLemma: tell
# Word: airwaves 	 Lemma: airwave
# GT: air 	 GTLemma: air
# Word: plan 	 Lemma: plan
# GT: first 	 GTLemma: first
# Word: color 	 Lemma: color
# GT: course 	 GTLemma: course
# Word: audience 	 Lemma: audience
# GT: rest 	 GTLemma: rest
# Word: stop 	 Lemma: stop
# GT: people 	 GTLemma: people
# Word: markets 	 Lemma: market
# GT: many 	 GTLemma: many
# Word: black 	 Lemma: black
# GT: talking 	 GTLemma: talk
# Word: hear 	 Lemma: hear
# GT: feel 	 GTLemma: feel
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: awkward 	 Lemma: awkward
# GT: gurgling 	 GTLemma: gurgle
# Word: entire 	 Lemma: entire
# GT: siblings 	 GTLemma: sibling
# Word: test 	 Lemma: test
# GT: moment 	 GTLemma: moment
# Word: say 	 Lemma: say
# GT: took 	 GTLemma: take
# Word: hear 	 Lemma: hear
# GT: go 	 GTLemma: go
# Word: proud 	 Lemma: proud
# GT: proud 	 GTLemma: proud
# Word: them 	 Lemma: they
# GT: history 	 GTLemma: history
# Word: moment 	 Lemma: moment
# GT: debate 	 GTLemma: debate
# Word: chore 	 Lemma: chore
# GT: controversy 	 GTLemma: controversy
# Word: protesters 	 Lemma: protester
# GT: organizations 	 GTLemma: organization
# Word: getting 	 Lemma: get
# GT: thinking 	 GTLemma: think
# Word: acknowledge 	 Lemma: acknowledge
# GT: educate 	 GTLemma: educate
# Word: seething 	 Lemma: seethe
# GT: also 	 GTLemma: also
# Word: state 	 Lemma: state
# GT: angry 	 GTLemma: angry
# Word: have 	 Lemma: have
# GT: speak 	 GTLemma: speak
# Word: look 	 Lemma: look
# GT: look 	 GTLemma: look
# Word: and 	 Lemma: and
# GT: and 	 GTLemma: and
# Word: station 	 Lemma: station
# GT: house 	 GTLemma: house
# Word: garage 	 Lemma: garage
# GT: driveway 	 GTLemma: driveway
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: lying 	 Lemma: lie
# GT: white 	 GTLemma: white
# Word: quarters 	 Lemma: quarter
# GT: form 	 GTLemma: form
# Word: go 	 Lemma: go
# GT: ever 	 GTLemma: ever
# Word: stake 	 Lemma: stake
# GT: stake 	 GTLemma: stake
# Word: place 	 Lemma: place
# GT: job 	 GTLemma: job
# Word: assignment 	 Lemma: assignment
# GT: paying 	 GTLemma: pay
# Word: week 	 Lemma: week
# GT: week 	 GTLemma: week
# Word: songs 	 Lemma: song
# GT: scratch 	 GTLemma: scratch
# Word: turn 	 Lemma: turn
# GT: lift 	 GTLemma: lift
# Word: same 	 Lemma: same
# GT: commercials 	 GTLemma: commercial
# Word: turntable 	 Lemma: turntable
# GT: turntable 	 GTLemma: turntable
# Word: forms 	 Lemma: form
# GT: kinds 	 GTLemma: kind
# Word: flip 	 Lemma: flip
# GT: flip 	 GTLemma: flip
# Word: nervous 	 Lemma: nervous
# GT: excited 	 GTLemma: excite
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: never 	 Lemma: never
# GT: heard 	 GTLemma: hear
# Word: time 	 Lemma: time
# GT: debate 	 GTLemma: debate
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: seen 	 Lemma: see
# GT: met 	 GTLemma: meet
# Word: right 	 Lemma: right
# GT: right 	 GTLemma: right
# Word: head 	 Lemma: head
# GT: head 	 GTLemma: head
# Word: nervous 	 Lemma: nervous
# GT: going 	 GTLemma: go
# Word: magazine 	 Lemma: magazine
# GT: magazine 	 GTLemma: magazine
# Word: grocery 	 Lemma: grocery
# GT: grocery 	 GTLemma: grocery
# Word: air 	 Lemma: air
# GT: air 	 GTLemma: air
# Word: recipe 	 Lemma: recipe
# GT: collard 	 GTLemma: collard
# Word: woman 	 Lemma: woman
# GT: woman 	 GTLemma: woman
# Word: felt 	 Lemma: feel
# GT: said 	 GTLemma: say
# Word: head 	 Lemma: head
# GT: heart 	 GTLemma: heart
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: should 	 Lemma: should
# GT: know 	 GTLemma: know
# Word: furious 	 Lemma: furious
# GT: embarrassed 	 GTLemma: embarrassed
# Word: say 	 Lemma: say
# GT: could 	 GTLemma: could
# Word: during 	 Lemma: during
# GT: dressing 	 GTLemma: dress
# Word: handbag 	 Lemma: handbag
# GT: touch 	 GTLemma: touch
# Word: could 	 Lemma: could
# GT: could 	 GTLemma: could
# Word: feel 	 Lemma: feel
# GT: feel 	 GTLemma: feel
# Word: that 	 Lemma: that
# GT: decided 	 GTLemma: decide
# Word: right 	 Lemma: right
# GT: lack 	 GTLemma: lack
# Word: time 	 Lemma: time
# GT: time 	 GTLemma: time
# Word: confused 	 Lemma: confuse
# GT: truly 	 GTLemma: truly
# Word: sign 	 Lemma: sign
# GT: moment 	 GTLemma: moment
# Word: three 	 Lemma: three
# GT: three 	 GTLemma: three
# Word: don't 	 Lemma: don't
# GT: dive 	 GTLemma: dive
# Word: minority 	 Lemma: minority
# GT: yellow 	 GTLemma: yellow
# Word: seconds 	 Lemma: second
# GT: weeks 	 GTLemma: week
# Word: new 	 Lemma: new
# GT: news 	 GTLemma: news
# Word: thinking 	 Lemma: think
# GT: sizing 	 GTLemma: size
# Word: only 	 Lemma: only
# GT: debate 	 GTLemma: debate
# Word: other 	 Lemma: other
# GT: fashion 	 GTLemma: fashion
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: don't 	 Lemma: don't
# GT: try 	 GTLemma: try
# Word: job 	 Lemma: job
# GT: job 	 GTLemma: job
# Word: job 	 Lemma: job
# GT: paying 	 GTLemma: pay
# Word: time 	 Lemma: time
# GT: week 	 GTLemma: week
# Word: scratch 	 Lemma: scratch
# GT: scratch 	 GTLemma: scratch
# Word: play 	 Lemma: play
# GT: lift 	 GTLemma: lift
# Word: commercials 	 Lemma: commercial
# GT: commercials 	 GTLemma: commercial
# Word: turntable 	 Lemma: turntable
# GT: turntable 	 GTLemma: turntable
# Word: this 	 Lemma: this
# GT: kinds 	 GTLemma: kind
# Word: dj 	 Lemma: dj
# GT: flip 	 GTLemma: flip
# Word: new 	 Lemma: new
# GT: excited 	 GTLemma: excite
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: been 	 Lemma: be
# GT: heard 	 GTLemma: hear
# Word: job 	 Lemma: job
# GT: debate 	 GTLemma: debate
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: seen 	 Lemma: see
# GT: met 	 GTLemma: meet
# Word: right 	 Lemma: right
# GT: right 	 GTLemma: right
# Word: head 	 Lemma: head
# GT: head 	 GTLemma: head
# Word: going 	 Lemma: go
# GT: going 	 GTLemma: go
# Word: about 	 Lemma: about
# GT: magazine 	 GTLemma: magazine
# Word: grocery 	 Lemma: grocery
# GT: grocery 	 GTLemma: grocery
# Word: radio 	 Lemma: radio
# GT: air 	 GTLemma: air
# Word: dress 	 Lemma: dress
# GT: collard 	 GTLemma: collard
# Word: woman 	 Lemma: woman
# GT: woman 	 GTLemma: woman
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: chest 	 Lemma: chest
# GT: heart 	 GTLemma: heart
# Word: wanted 	 Lemma: want
# GT: wanted 	 GTLemma: want
# Word: black 	 Lemma: black
# GT: know 	 GTLemma: know
# Word: thinking 	 Lemma: think
# GT: embarrassed 	 GTLemma: embarrassed
# Word: knew 	 Lemma: know
# GT: could 	 GTLemma: could
# Word: cake 	 Lemma: cake
# GT: dressing 	 GTLemma: dress
# Word: purse 	 Lemma: purse
# GT: touch 	 GTLemma: touch
# Word: speak 	 Lemma: speak
# GT: could 	 GTLemma: could
# Word: see 	 Lemma: see
# GT: feel 	 GTLemma: feel
# Word: black 	 Lemma: black
# GT: decided 	 GTLemma: decide
# Word: new 	 Lemma: new
# GT: lack 	 GTLemma: lack
# Word: time 	 Lemma: time
# GT: time 	 GTLemma: time
# Word: not 	 Lemma: not
# GT: truly 	 GTLemma: truly
# Word: time 	 Lemma: time
# GT: moment 	 GTLemma: moment
# Word: three 	 Lemma: three
# GT: three 	 GTLemma: three
# Word: know 	 Lemma: know
# GT: dive 	 GTLemma: dive
# Word: top 	 Lemma: top
# GT: yellow 	 GTLemma: yellow
# Word: minutes 	 Lemma: minute
# GT: weeks 	 GTLemma: week
# Word: before 	 Lemma: before
# GT: news 	 GTLemma: news
# Word: confused 	 Lemma: confuse
# GT: sizing 	 GTLemma: size
# Word: same 	 Lemma: same
# GT: debate 	 GTLemma: debate
# Word: fashion 	 Lemma: fashion
# GT: fashion 	 GTLemma: fashion
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot
# Word: know 	 Lemma: know
# GT: try 	 GTLemma: try
# Word: job 	 Lemma: job
# GT: job 	 GTLemma: job
# Word: school 	 Lemma: school
# GT: college 	 GTLemma: college
# Word: anyone 	 Lemma: anyone
# GT: internship 	 GTLemma: internship
# Word: was 	 Lemma: be
# GT: though 	 GTLemma: though
# Word: national 	 Lemma: national
# GT: album 	 GTLemma: album
# Word: that 	 Lemma: that
# GT: put 	 GTLemma: put
# Word: let 	 Lemma: let
# GT: part 	 GTLemma: part
# Word: play 	 Lemma: play
# GT: read 	 GTLemma: read
# Word: play 	 Lemma: play
# GT: flip 	 GTLemma: flip
# Word: happy 	 Lemma: happy
# GT: nervous 	 GTLemma: nervous
# Word: decided 	 Lemma: decide
# GT: going 	 GTLemma: go
# Word: everyone 	 Lemma: everyone
# GT: young 	 GTLemma: young
# Word: doing 	 Lemma: do
# GT: black 	 GTLemma: black
# Word: person 	 Lemma: person
# GT: white 	 GTLemma: white
# Word: where 	 Lemma: where
# GT: black 	 GTLemma: black
# Word: decided 	 Lemma: decide
# GT: first 	 GTLemma: first
# Word: white 	 Lemma: white
# GT: sounds 	 GTLemma: sound
# Word: very 	 Lemma: very
# GT: black 	 GTLemma: black
# Word: working 	 Lemma: work
# GT: market 	 GTLemma: market
# Word: brain 	 Lemma: brain
# GT: hatch 	 GTLemma: hatch
# Word: decided 	 Lemma: decide
# GT: know 	 GTLemma: know
# Word: kids 	 Lemma: kid
# GT: zoo 	 GTLemma: zoo
# Word: much 	 Lemma: much
# GT: small 	 GTLemma: small
# Word: ok 	 Lemma: ok
# GT: people 	 GTLemma: people
# Word: spirit 	 Lemma: spirit
# GT: said 	 GTLemma: say
# Word: black 	 Lemma: black
# GT: know 	 GTLemma: know
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: mouth 	 Lemma: mouth
# GT: mouth 	 GTLemma: mouth
# Word: how 	 Lemma: how
# GT: dare 	 GTLemma: dare
# Word: mind 	 Lemma: mind
# GT: father 	 GTLemma: father
# Word: saying 	 Lemma: say
# GT: still 	 GTLemma: still
# Word: when 	 Lemma: when
# GT: recipes 	 GTLemma: recipe
# Word: mommy 	 Lemma: mommy
# GT: air 	 GTLemma: air
# Word: when 	 Lemma: when
# GT: hand 	 GTLemma: hand
# Word: work 	 Lemma: work
# GT: knew 	 GTLemma: know
# Word: spot 	 Lemma: spot
# GT: big 	 GTLemma: big
# Word: something 	 Lemma: something
# GT: seen 	 GTLemma: see
# Word: ready 	 Lemma: ready
# GT: see 	 GTLemma: see
# Word: debate 	 Lemma: debate
# GT: air 	 GTLemma: air
# Word: matter 	 Lemma: matter
# GT: movement 	 GTLemma: movement
# Word: worried 	 Lemma: worried
# GT: new 	 GTLemma: new
# Word: situation 	 Lemma: situation
# GT: stereotype 	 GTLemma: stereotype
# Word: going 	 Lemma: go
# GT: around 	 GTLemma: around
# Word: closed 	 Lemma: close
# GT: left 	 GTLemma: leave
# Word: first 	 Lemma: first
# GT: service 	 GTLemma: service
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: looking 	 Lemma: look
# GT: sized 	 GTLemma: size
# Word: a 	 Lemma: a
# GT: find 	 GTLemma: find
# Word: very 	 Lemma: very
# GT: lot 	 GTLemma: lot
# Word: school 	 Lemma: school
# GT: college 	 GTLemma: college
# Word: employment 	 Lemma: employment
# GT: internship 	 GTLemma: internship
# Word: is 	 Lemma: be
# GT: though 	 GTLemma: though
# Word: even 	 Lemma: even
# GT: album 	 GTLemma: album
# Word: keep 	 Lemma: keep
# GT: put 	 GTLemma: put
# Word: the 	 Lemma: the
# GT: part 	 GTLemma: part
# Word: listen 	 Lemma: listen
# GT: read 	 GTLemma: read
# Word: listen 	 Lemma: listen
# GT: flip 	 GTLemma: flip
# Word: expecting 	 Lemma: expect
# GT: nervous 	 GTLemma: nervous
# Word: living 	 Lemma: live
# GT: going 	 GTLemma: go
# Word: museum 	 Lemma: museum
# GT: young 	 GTLemma: young
# Word: going 	 Lemma: go
# GT: black 	 GTLemma: black
# Word: white 	 Lemma: white
# GT: white 	 GTLemma: white
# Word: black 	 Lemma: black
# GT: black 	 GTLemma: black
# Word: young 	 Lemma: young
# GT: first 	 GTLemma: first
# Word: shouted 	 Lemma: shout
# GT: sounds 	 GTLemma: sound
# Word: white 	 Lemma: white
# GT: black 	 GTLemma: black
# Word: member 	 Lemma: member
# GT: market 	 GTLemma: market
# Word: asked 	 Lemma: ask
# GT: hatch 	 GTLemma: hatch
# Word: know 	 Lemma: know
# GT: know 	 GTLemma: know
# Word: missouri 	 Lemma: missouri
# GT: zoo 	 GTLemma: zoo
# Word: ditch 	 Lemma: ditch
# GT: small 	 GTLemma: small
# Word: people 	 Lemma: people
# GT: people 	 GTLemma: people
# Word: said 	 Lemma: say
# GT: said 	 GTLemma: say
# Word: have 	 Lemma: have
# GT: know 	 GTLemma: know
# Word: knows 	 Lemma: know
# GT: said 	 GTLemma: say
# Word: stomach 	 Lemma: stomach
# GT: mouth 	 GTLemma: mouth
# Word: come 	 Lemma: come
# GT: dare 	 GTLemma: dare
# Word: mouth 	 Lemma: mouth
# GT: father 	 GTLemma: father
# Word: young 	 Lemma: young
# GT: still 	 GTLemma: still
# Word: friend 	 Lemma: friend
# GT: recipes 	 GTLemma: recipe
# Word: know 	 Lemma: know
# GT: air 	 GTLemma: air
# Word: recipe 	 Lemma: recipe
# GT: hand 	 GTLemma: hand
# Word: said 	 Lemma: say
# GT: knew 	 GTLemma: know
# Word: event 	 Lemma: event
# GT: big 	 GTLemma: big
# Word: heard 	 Lemma: hear
# GT: seen 	 GTLemma: see
# Word: know 	 Lemma: know
# GT: see 	 GTLemma: see
# Word: moment 	 Lemma: moment
# GT: air 	 GTLemma: air
# Word: false 	 Lemma: false
# GT: movement 	 GTLemma: movement
# Word: believing 	 Lemma: believe
# GT: new 	 GTLemma: new
# Word: movement 	 Lemma: movement
# GT: stereotype 	 GTLemma: stereotype
# Word: involved 	 Lemma: involve
# GT: around 	 GTLemma: around
# Word: returned 	 Lemma: return
# GT: left 	 GTLemma: leave
# Word: drink 	 Lemma: drink
# GT: service 	 GTLemma: service
# Word: know 	 Lemma: know
# GT: said 	 GTLemma: say
# Word: just 	 Lemma: just
# GT: sized 	 GTLemma: size
# Word: know 	 Lemma: know
# GT: find 	 GTLemma: find
# Word: lot 	 Lemma: lot
# GT: lot 	 GTLemma: lot

# %% [markdown]
# ### Analyze human data and save

# %%
# load transcript
df_transcript = pd.read_csv(os.path.join(preproc_dir, TASK, f'{TASK}_transcript-preprocessed.csv'))
df_transcript = df_transcript.rename(columns={'Word_Written': 'word', 'Punctuation': 'punctuation'})

# load lemmatized file and analyze human results --> use all words
lemmatized_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior_lemmatized.csv')
df_lemmatized_results = pd.read_csv(lemmatized_fn)

# combine the data and lemmatize model results
df_analyzed_lemmatized = analyze_human_results(df_transcript, df_lemmatized_results, word_model_info, top_n=None, drop_rt=None)

# save lemmatized human-model results
out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-analyzed-behavior_human-lemmatized.csv')
df_analyzed_lemmatized.to_csv(out_fn, index=False)
# Out:
# Word 6
#
# audio
# ['college' 'high' 'school' 'work' 'intern' 'collage' 'class' 'chemistry']
# [0.48 0.26 0.16 0.02 0.02 0.02 0.02 0.02]
# 1.3869596872523586
#
# text
# ['school' 'high' 'college' 'a' 'team' 'middle' 'medicine' 'construction']
# [0.48 0.22 0.18 0.04 0.02 0.02 0.02 0.02]
# 1.435793895702573
# Word 12
#
# audio
# ['job' 'assignment' 'boyfriend' 'car' 'degree' 'taste' 'period' 'kiss' 'f'
#  'crush' 'traumatic' 'award' 'book' 'challenge' 'experience' 'diploma'
#  'exam' 'tattoo' 'fail' 'injury' 'lesson' 'qualification' 'a']
# [0.18 0.12 0.1  0.08 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.825117931635182
#
# text
# ['job' 'kiss' 'girlfriend' 'car' 'boyfriend' 'tattoo' 'ticket' 'crush'
#  'assignment' 'bike' 'certificate' 'dog' 'degree' 'drink' 'f'
#  'scholarship' 'std' 'apartment']
# [0.3  0.14 0.12 0.1  0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.357582972136478
# Word 19
#
# audio
# ['road' 'campus' 'job' 'right' 'radio' 'role' 'farm' 'field' 'moment'
#  'fifth' 'department' 'cheek' 'first' 'hoof' 'internet' 'board' 'market'
#  'wrong' 'monday' 'work' 'railway' 'register' 'reserve' 'rock' 'royal'
#  'subject' 'surgery' 'television' 'ward' 'woman' 'back']
# [0.2  0.1  0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 3.1032769465009578
#
# text
# ['campus' 'weekend' 'day' 'job' 'internet' 'field' 'course' 'team'
#  'company' 'class' 'book' 'friday' 'ground' 'industry' 'institution'
#  'board' 'work' 'line' 'merit' 'newspaper' 'placement' 'program'
#  'recommendation' 'research' 'school' 'side' 'sly' 'subject' 'summer'
#  'track' 'ward' 'back']
# [0.2  0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 3.1810430760771746
# Word 24
#
# audio
# ['interesting' 'advertisement' 'story' 'job' 'indication' 'ordinary'
#  'introduction' 'interview' 'lie' 'new' 'exciting' 'actual' 'proper'
#  'anecdote' 'angry' 'any' 'anyone' 'brag' 'challenge' 'easy' 'endorsement'
#  'first' 'experiment' 'full' 'imaginary' 'radio' 'industry' 'overnight'
#  'internet' 'internship' 'invitation' 'lesson' 'accident']
# [0.1  0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 3.331521904445294
#
# text
# ['internship' 'unusual' 'actual' 'advert' 'advertisement' 'exaggeration'
#  'experiment' 'idea' 'ordinary' 'real' 'typical' 'task' 'study' 'advice'
#  'average' 'check' 'easy' 'employment' 'entry' 'error' 'excuse' 'option'
#  'experience' 'permanent' 'fabulous' 'understatement' 'important' 'intern'
#  'part' 'item' 'normal' 'obvious' 'accident']
# [0.16 0.08 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 3.2638626364377057
# Word 32
#
# audio
# ['great' 'job' 'hard' 'cold' 'good' 'small' 'college' 'full' 'big' 'tough'
#  'reporter' 'real' 'calm' 'clean' 'student' 'comedy' 'considerable'
#  'contract' 'convenient' 'crappy' 'steep' 'fun' 'start' 'rise' 'reward'
#  'unique' 'junior' 'large' 'low' 'nice' 'weird']
# [0.12 0.06 0.06 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 3.2565246336307547
#
# text
# ['job' 'good' 'great' 'real' 'pay' 'way' 'assistant' 'career' 'chance'
#  'easy' 'entry' 'exciting' 'fortunate' 'fun' 'hard' 'surprise'
#  'internship' 'lucky' 'permanent' 'position' 'relief' 'rubbish' 'start'
#  'apprenticeship']
# [0.34 0.1  0.1  0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.571391111517417
# Word 40
#
# audio
# ['be' 'need' 'consist']
# [0.96 0.02 0.02]
# 0.19567003495657082
#
# text
# ['be' 'dj' 'presenter' 'pay' 'broadcaster' 'involve' 'engineer' 'which'
#  'full' 'begin' 'check' 'consist' 'editor' 'entail' 'field' 'host'
#  'honestly' 'take' 'in' 'include' 'intern' 'it' 'janitor' 'junior'
#  'newsreader' 'researcher' 'start' 'announcer']
# [0.28 0.08 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.8853631180366044
# Word 46
#
# audio
# ['weekend' 'radio' 'lower' 'west' 'wireless' 'one' 'bad' 'easy' 'evening'
#  'graveyard' 'night' 'recess' 'region' 'side' 'small' 'way' 'web'
#  'weekday' 'admin']
# [0.46 0.14 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.103625620690509
#
# text
# ['weekend' 'radio' 'side' 'reception' 'night' 'local' 'volume' 'set'
#  'overnight' 'ground' 'evening' 'early' 'campus' 'basic' 'background']
# [0.36 0.3  0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 1.9481705633652724
# Word 49
#
# audio
# ['play' 'read' 'talk' 'prepare' 'host' 'present' 'produce' 'research'
#  'speak' 'choose' 'tell' 'perform' 'entertain' 'flip' 'dj' 'introduce'
#  'make' 'write' 'pester' 'pick' 'weekend' 'put' 'runner' 'sort' 'take'
#  'check']
# [0.18 0.08 0.08 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.9965266857538837
#
# text
# ['talk' 'play' 'host' 'clean' 'present' 'dj' 'tidy' 'produce' 'last'
#  'earn' 'find' 'chat' 'happy' 'help' 'broadcast' 'answer' 'introduce'
#  'make' 'late' 'manage' 'million' 'monitor' 'practice' 'read' 'record'
#  'select' 'sound' 'speak' 'start' 'anchor']
# [0.1  0.1  0.08 0.08 0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 3.1810430760771746
# Word 56
#
# audio
# ['week' 'world' 'year' 'worldwide' 'west' 'time' 'south' 'radio' 'nation'
#  'country' 'chart']
# [0.72 0.1  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.1709455784963367
#
# text
# ['week' 'world' 'time' 'decade' 'day' 'month' 'year' 'state' 'radio'
#  'ninety' 'nation' 'moment' 'era' 'chart' 'century' 'big']
# [0.48 0.08 0.08 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 2.0051907072193784
# Word 64
#
# audio
# ['afternoon' 'hourly' 'hour' 'advert' 'album' 'radio' 'disc'
#  'advertisement' 'anniversary' 'another' 'april' 'at' 'day' 'weekly'
#  'easy' 'weekend' 'ipad' 'national' 'offer' 'opportune' 'podcast' 'record'
#  'saturday' 'under' 'a']
# [0.16 0.16 0.1  0.08 0.08 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.836124935845608
#
# text
# ['evening' 'saturday' 'afternoon' 'monday' 'station' 'hour' 'automatic'
#  'end' 'email' 'early' 'weekend' 'episode' 'alert' 'album' 'advertisement'
#  'advert' 'audio' 'exciting' 'even' 'expert' 'friday' 'infrequent'
#  'interesting' 'occasional' 'odd' 'off' 'peak' 'people' 'recommendation'
#  'actual']
# [0.16 0.1  0.1  0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 3.0910694529381653
# Word 75
#
# audio
# ['sleeve' 'case' 'studio' 'stereo' 'player' 'box' 'cd' 'list' 'cassette'
#  'chart' 'disc' 'tape' 'package' 'system' 'song' 'station' 'storage'
#  'story' 'album']
# [0.4  0.12 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.283707823391816
#
# text
# ['sleeve' 'case' 'album' 'box' 'cover' 'file' 'holder' 'archive'
#  'cassette' 'envelope' 'wrap' 'studio' 'laptop' 'library' 'list' 'radio'
#  'rubbish' 'storage' 'storeroom' 'jacket']
# [0.28 0.24 0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.389424108101785
# Word 85
#
# audio
# ['then' 'play' 'when' 'I' 'start' 'it' 'put' 'that' 'sound' 'there' 'turn'
#  'people' 'lift' 'we' 'every' 'and' 'although' 'whilst']
# [0.3  0.16 0.12 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.3750658759116647
#
# text
# ['play' 'then' 'press' 'start' 'put' 'listen' 'keep' 'choose' 'drop'
#  'have' 'it' 'when' 'place' 'wait' 'the' 'turn' 'carefully']
# [0.5  0.08 0.08 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 1.9976003335476697
# Word 90
#
# audio
# ['the' 'record' 'vinyl' 'disc' 'table' 'something' 'platter' 'desk' 'edge'
#  'it' 'jukebox' 'needle' 'side' 'turntable' 'so' 'some' 'song' 'top'
#  'track' 'button']
# [0.28 0.28 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.32324735195401
#
# text
# ['the' 'record' 'it' 'vinyl' 'top' 'disk' 'disc' 'time' 'table' 'song'
#  'set' 'play' 'gently' 'cue']
# [0.24 0.18 0.18 0.06 0.06 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.2332517251352426
# Word 95
#
# audio
# ['scratch' 'one' 'song' 'any' 'about' 'to' 'hit' 'music' 'carefully'
#  'first' 'for' 'how' 'just' 'water' 'not' 'vinyl' 'record' 'say' 'sound'
#  'the' 'track' 'nothing']
# [0.24 0.14 0.1  0.08 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.6500021367133986
#
# text
# ['scratch' 'damage' 'break' 'play' 'skip' 'see' 'ruin' 'cut' 'catch']
# [0.62 0.12 0.12 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.3252027788102243
# Word 100
#
# audio
# ['the' 'play' 'music' 'let' 'record' 'it' 'album' 'they' 'that' 'sound'
#  'place' 'needle' 'lower' 'go' 'all']
# [0.32 0.12 0.12 0.1  0.08 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 2.229282377021197
#
# text
# ['the' 'it' 'go' 'play' 'turntable' 'turn' 'man']
# [0.4  0.38 0.12 0.04 0.02 0.02 0.02]
# 1.3521062603935379
# Word 123
#
# audio
# ['flip' 'turn' 'switch' 'put' 'lift' 'turnover' 'take' 'start' 'repeat'
#  'remove' 'play' 'just' 'get' 'change']
# [0.46 0.22 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.8207901943202134
#
# text
# ['turn' 'flip' 'take' 'lift' 'change' 'try' 'talk' 'stop' 'start' 'speak'
#  'remove' 'play' 'give']
# [0.4  0.32 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.7433240432226262
# Word 133
#
# audio
# ['flip' 'turn' 'read' 'record' 'play' 'replay' 'remove' 'turnover'
#  'reveal' 'rotate' 'recite' 'say' 'side' 'listen' 'introduce' 'grab'
#  'sing' 'comment' 'announce']
# [0.22 0.18 0.1  0.08 0.08 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.5230570708021984
#
# text
# ['turn' 'flip' 'speak' 'play' 'start' 'the' 'talk' 'switch' 'sing' 'shine'
#  'replace' 'listen' 'lift' 'enjoy' 'do' 'choose' 'change' 'announce']
# [0.22 0.16 0.12 0.08 0.06 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.5003846143641155
# Word 148
#
# audio
# ['commercial' 'advert' 'time' 'song' 'people' 'music' 'wild' 'junk' 'bad'
#  'bore' 'buzz' 'city' 'fuss' 'other' 'weather' 'record' 'rubbish' 'same'
#  'show' 'the' 'train' 'ad']
# [0.44 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.33695318964312
#
# text
# ['commercial' 'ad' 'music' 'record' 'advert' 'advertisement' 'break'
#  'news' 'clock' 'host' 'tape' 'sound' 'people' 'play' 'prepare'
#  'presenter' 'radio' 'song' 'other']
# [0.3  0.14 0.12 0.08 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.418088177365588
# Word 154
#
# audio
# ['flip' 'read' 'listen' 'play' 'turn' 'find' 'reset' 'figure' 'turnover'
#  'wait' 'think' 'ready' 'say' 'select' 'look' 'sing' 'lineup' 'learn'
#  'improvise' 'sort' 'speak' 'choose' 'change' 'carefully' 'add']
# [0.16 0.1  0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.971085370554122
#
# text
# ['turn' 'prepare' 'flip' 'listen' 'find' 'get' 'read' 'change' 'replace'
#  'recite' 'ready' 'select' 'queue' 'set' 'party' 'make' 'sort' 'stop'
#  'switch' 'take' 'decide' 'choose' 'wait']
# [0.18 0.16 0.08 0.08 0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.7747195879747015
# Word 163
#
# audio
# ['turntable' 'player' 'table' 'work' 'platter' 'pin' 'deck']
# [0.74 0.12 0.06 0.02 0.02 0.02 0.02]
# 0.9590158764439667
#
# text
# ['turntable' 'table' 'player' 'record' 'other' 'side' 'recorder' 'holder'
#  'deck' 'b']
# [0.54 0.1  0.1  0.08 0.08 0.02 0.02 0.02 0.02 0.02]
# 1.5885764175198056
# Word 172
#
# audio
# ['two' 'b' 'way' 'turner' 'table' 'side' 'room' 'board']
# [0.5  0.36 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.2343253729290287
#
# text
# ['two' 'b' 'one' 'table' 'holder']
# [0.54 0.32 0.1  0.02 0.02]
# 1.0840989154256684
# Word 190
#
# audio
# ['work' 'try' 'excite' 'listen' 'nervous' 'wait' 'play' 'concentrate'
#  'feel' 'new' 'bore' 'really' 'hear' 'top' 'distract' 'do' 'tired' 'test'
#  'go' 'good' 'radio' 'overqualifie' 'learn' 'so' 'mind' 'sit' 'not' 'on'
#  'just']
# [0.12 0.06 0.06 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 3.2010728591859596
#
# text
# ['happy' 'nervous' 'excite' 'play' 'do' 'tired' 'finish' 'ready' 'busy'
#  'listen' 'bore' 'popular' 'onto' 'want' 'little' 'present' 'really'
#  'good' 'go' 'right' 'think' 'enjoy' 'drive' 'try' 'value' 'work']
# [0.12 0.08 0.08 0.06 0.06 0.06 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.0624434230739705
# Word 201
#
# audio
# ['kind' 'sort' 'how' 'about' 'the' 'of' 'nothing' 'manner' 'type' 'join'
#  'trick' 'form' 'everything' 'different' 'always' 'all' 'you']
# [0.54 0.1  0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 1.8776846819999138
#
# text
# ['the' 'about' 'this' 'type' 'trick' 'that' 'manner' 'knowledge' 'basic'
#  'how' 'information' 'kind' 'you' 'lesson' 'media' 'word' 'these' 'thing'
#  'sort']
# [0.24 0.18 0.12 0.08 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.472861788596666
# Word 208
#
# audio
# ['teach' 'prepare' 'the' 'sound' 'learn' 'interact' 'believe']
# [0.84 0.06 0.02 0.02 0.02 0.02 0.02]
# 0.70646378875003
#
# text
# ['teach' 'tell' 'prepare' 'show' 'rely' 'really' 'pay' 'listen' 'let'
#  'help' 'give' 'actually']
# [0.62 0.12 0.08 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.4570362534503976
# Word 212
#
# audio
# ['flip' 'turn' 'play' 'lift' 'put' 'use' 'react' 'be' 'change'
#  'communicate' 'figure' 'operate' 'host' 'ready' 'run' 'show' 'think'
#  'actually']
# [0.24 0.18 0.14 0.08 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.415445504036289
#
# text
# ['play' 'work' 'turn' 'talk' 'flip' 'use' 'speak' 'broadcast' 'present'
#  'dj' 'lift' 'be' 'change' 'communicate' 'do' 'operate' 'mix' 'music'
#  'wait' 'read' 'run' 'sing' 'time' 'actually']
# [0.16 0.1  0.08 0.08 0.08 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.9088376346375107
# Word 221
#
# audio
# ['break' 'end' 'start' 'finish' 'stop' 'come']
# [0.46 0.42 0.04 0.04 0.02 0.02]
# 1.1355444678121038
#
# text
# ['end' 'break' 'start' 'stop' 'slot' 'play' 'finish' 'brake' 'begin']
# [0.54 0.28 0.06 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.3274183081734494
# Word 235
#
# audio
# ['last' 'good' 'one' 'bad' 'though' 'only' 'beautiful' 'big' 'career'
#  'center' 'first' 'world' 'long' 'weird' 'most' 'place' 'progression'
#  'ridiculous' 'same' 'lousiest']
# [0.26 0.2  0.1  0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.45732003931154
#
# text
# ['good' 'city' 'big' 'capital' 'first' 'place' 'music' 'great' 'gateway'
#  'center' 'department' 'end' 'winter' 'goal' 'time' 'heart' 'moment' 'old'
#  'pit' 'proud' 'start' 'begin']
# [0.34 0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.5568990459319876
# Word 239
#
# audio
# ['ever' 'play' 'be']
# [0.96 0.02 0.02]
# 0.19567003495657082
#
# text
# ['ever' 'work' 'see' 'visit' 'to' 'be' 'encounter' 'experience'
#  'broadcast' 'enter' 'for' 'find' 'investigate' 'near' 'opportunity'
#  'play' 'access']
# [0.36 0.14 0.12 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 2.2349562164231362
# Word 244
#
# audio
# ['excite' 'nervous' 'ecstatic' 'happy' 'scare' 'overwhelmed' 'amaze'
#  'ready' 'blow' 'part' 'terrify' 'often' 'shock' 'feel' 'so' 'surprised'
#  'work']
# [0.28 0.1  0.08 0.08 0.08 0.06 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 2.4539564160410325
#
# text
# ['excite' 'amaze' 'surprised' 'so' 'scare' 'work' 'new' 'interested'
#  'bear' 'employ' 'fifteen' 'happy' 'young' 'just' 'keen' 'overwhelmed'
#  'shock' 'stun' 'terrify' 'nervous']
# [0.3  0.12 0.1  0.06 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.4981769183640488
# Word 248
#
# audio
# ['nervous' 'ready' 'eager' 'happy' 'look' 'thrill' 'enthuse' 'try' 'be'
#  'curious' 'ecstatic' 'elated' 'keen' 'hopeful' 'inexperienced' 'motivate'
#  'overwhelmed' 'prepare' 'pump' 'really' 'anxious']
# [0.3  0.16 0.08 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.506899350551838
#
# text
# ['nervous' 'happy' 'ready' 'scare' 'thrill' 'surprised' 'determine' 'keen'
#  'anticipate' 'anxious' 'eager' 'expect' 'full' 'get' 'look' 'hire'
#  'terrify' 'new' 'prepare' 'preppe' 'proud' 'so' 'able']
# [0.26 0.1  0.1  0.08 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.701441492222144
# Word 255
#
# audio
# ['be' 'find' 'tell' 'come' 'learn' 'understand' 'figure' 'keep' 'fit'
#  'prove' 'get' 'explore' 'grasp' 'do' 'concentrate' 'compose' 'behave'
#  'go' 'impress' 'help' 'immerse' 'turn' 'nervous' 'network' 'play' 'relax'
#  'settle' 'show' 'start' 'stay' 'take' 'think' 'balance']
# [0.08 0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 3.353836259576715
#
# text
# ['calm' 'learn' 'keep' 'do' 'make' 'play' 'contain' 'fit' 'work' 'succeed'
#  'remember' 'settle' 'practice' 'excel' 'compose' 'concentrate' 'stay'
#  'control' 'start' 'figure' 'remain' 'find' 'gain' 'impress' 'win' 'look'
#  'adapt']
# [0.16 0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.076577387352736
# Word 263
#
# audio
# ['look' 'go' 'try' 'meet' 'talk' 'speak' 'walk' 'socialize' 'play' 'out'
#  'wonder' 'explore' 'embrace' 'here' 'keen' 'learn' 'listen' 'read'
#  'network' 'watch' 'ready' 'research' 'rush' 'think' 'turn' 'visit'
#  'decide']
# [0.12 0.1  0.06 0.06 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.0955808423873448
#
# text
# ['talk' 'go' 'try' 'ready' 'meet' 'grateful' 'excite' 'here' 'determine'
#  'communicate' 'do' 'comfortable' 'find' 'friend' 'get' 'give' 'chatty'
#  'work' 'involve' 'hope' 'walk' 'join' 'keen' 'learn' 'listen' 'live'
#  'please' 'reach' 'sociable' 'start' 'ask']
# [0.12 0.12 0.08 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 3.194276897714144
# Word 272
#
# audio
# ['think' 'find' 'attend' 'go' 'get' 'remember' 'manage' 'ever' 'be']
# [0.4  0.34 0.08 0.06 0.04 0.02 0.02 0.02 0.02]
# 1.5458913855953607
#
# text
# ['find' 'manage' 'go' 'get' 'attend' 'to' 'think' 'so' 'reach' 'possibly'
#  'participate' 'fit']
# [0.28 0.16 0.14 0.12 0.12 0.04 0.04 0.02 0.02 0.02 0.02 0.02]
# 2.082474838539827
# Word 279
#
# audio
# ['event' 'fundraiser' 'title' 'new' 'interview' 'exciting' 'early']
# [0.86 0.04 0.02 0.02 0.02 0.02 0.02]
# 0.6496650187092845
#
# text
# ['event' 'party' 'fundraiser' 'I' 'time' 'occasion' 'network' 'meeting'
#  'hum' 'heavy' 'evening']
# [0.74 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.1567660884042263
# Word 295
#
# audio
# ['and' 'I' 'at' 'meet' 'event' 'man' 'a' 'center' 'charity' 'club'
#  'everyone' 'find' 'gentleman' 'go' 'group' 'would' 'where' 'one' 'person'
#  'place' 'shindig' 'sit' 'start' 'that' 'then' 'there' 'think' 'this'
#  'travel' 'when' 'night']
# [0.22 0.1  0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 3.0744478551818144
#
# text
# ['man' 'hotel' 'producer' 'small' 'listener' 'person' 'college' 'great'
#  'friend' 'famous' 'day' 'woman' 'club' 'chance' 'carnival' 'build'
#  'beautiful' 'bar' 'charity' 'little' 'large' 'venue' 'masterpiece'
#  'mecca' 'moment' 'museum' 'nice' 'place' 'prime' 'record' 'state'
#  'stranger' 'tall' 'bag']
# [0.12 0.1  0.08 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 3.303796017222896
# Word 299
#
# audio
# ['and' 'ask' 'out' 'say' 'to' 'that' 'from' 'be']
# [0.58 0.24 0.06 0.04 0.02 0.02 0.02 0.02]
# 1.2689712035443867
#
# text
# ['and' 'to' 'ask' 'say' 'in' 'from' 'after' 'by' 'chris' 'directly'
#  'first' 'yesterday' 'with' 'offer' 'one' 'shout' 'smile' 'there' 'today'
#  'about']
# [0.46 0.08 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.1992327553485747
# Word 305
#
# audio
# ['black' 'wear' 'tall' 'young' 'friendly' 'nervous' 'happy' 'walk' 'smile'
#  'event' 'approach' 'ask' 'bald' 'big' 'well' 'bore' 'brilliant'
#  'enthusiastic' 'excite' 'polite' 'want' 'from' 'willing' 'kind' 'look'
#  'pass' 'petrify' 'about']
# [0.24 0.1  0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.9501554448035403
#
# text
# ['young' 'wear' 'tall' 'dress' 'drunk' 'nice' 'very' 'friendly' 'handsome'
#  'interested' 'hold' 'actually' 'anxious' 'eager' 'excite' 'happy' 'old'
#  'wonder' 'polite' 'present' 'say' 'singer' 'smile' 'stand' 'strange'
#  'wait' 'about']
# [0.12 0.1  0.1  0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.066470525784108
# Word 308
#
# audio
# ['say' 'ask' 'speak' 'start' 'stand' 'smell' 'seem' 'look']
# [0.8  0.06 0.04 0.02 0.02 0.02 0.02 0.02]
# 0.8672768175945126
#
# text
# ['say' 'ask' 'be' 'talk' 'wear' 'speak' 'smile' 'have' 'look' 'help'
#  'come' 'give' 'tell' 'know' 'teach' 'very' 'sing' 'suggest' 'play']
# [0.24 0.16 0.14 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.5059611685104324
# Word 315
#
# audio
# ['black' 'famous' 'go' 'white' 'come' 'play' 'work' 'from' 'be'
#  'broadcaster' 'destine' 'dj' 'do' 'funny' 'fucking' 'late' 'on' 'pretty'
#  'racist' 'real' 'that' 'the' 'trouble' 'a']
# [0.24 0.12 0.08 0.08 0.06 0.06 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.746993700752304
#
# text
# ['here' 'new' 'a' 'go' 'the' 'amazing' 'black' 'come' 'ready' 'famous'
#  'on' 'he' 'enjoy' 'good' 'work' 'interested' 'white' 'play' 'radio'
#  'talente' 'that' 'trouble' 'wait' 'nervous']
# [0.14 0.12 0.08 0.08 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.942779402596982
# Word 323
#
# audio
# ['never' 'only' 'not' 'just' 'be' 'would' 'many' 'bit' 'blue' 'child'
#  'expect' 'hear' 'idea' 'no' 'work' 'nothing' 'picture' 'quite' 'say'
#  'start' 'try' 'white' 'always']
# [0.3  0.18 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.5445481593143926
#
# text
# ['never' 'no' 'not' 'only' 'be' 'just' 'say' 'walk' 'to' 'mask' 'light'
#  'grown' 'always']
# [0.38 0.14 0.1  0.08 0.08 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.044315258912078
# Word 331
#
# audio
# ['sound' 'dont' 'should' 'black' 'shouldnt' 'think' 'cant' 'can'
#  'certainly' 'fall' 'must' 'say' 'you' 'work' 'start' 'stay' 'stop' 'suck'
#  'tell' 'to' 'use' 'be']
# [0.34 0.12 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.518708195834299
#
# text
# ['be' 'black' 'dont' 'sound' 'should' 'say' 'know' 'there' 'terrible'
#  'play' 'pass' 'like' 'will' 'idiot' 'honky' 'have' 'go' 'different'
#  'cant' 'brother' 'think' 'yell']
# [0.18 0.14 0.14 0.1  0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.699820399639137
# Word 337
#
# audio
# ['hear' 'never' 'tell' 'expect' 'wasnt' 'want' 'think' 'have' 'for' 'feel'
#  'definitely' 'couldnt' 'be' 'and']
# [0.64 0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.527596704301934
#
# text
# ['hear' 'never' 'be' 'always' 'think' 'believe' 'get' 'wonder' 'assume'
#  'become' 'bet' 'change' 'learn' 'want' 'not' 'often' 'say' 'sound'
#  'start' 'stop' 'understand' 'agree']
# [0.2  0.16 0.12 0.1  0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.6596627509425925
# Word 346
#
# audio
# ['white' 'woman' 'person' 'whitey' 'teacher' 'solicitor' 'posh' 'pale'
#  'man' 'honky' 'funny' 'fucking' 'different' 'academic']
# [0.68 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.420455224146672
#
# text
# ['white' 'woman' 'country' 'black' 'young' 'whitey' 'radio' 'politician'
#  'normal' 'native' 'middle' 'lecturer' 'kid' 'familiar' 'cracker']
# [0.64 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 1.5725835158714387
# Word 354
#
# audio
# ['never' 'not' 'no' 'hear']
# [0.84 0.1  0.04 0.02]
# 0.5837108476043089
#
# text
# ['never' 'not' 'hear' 'ignore' 'always' 'think' 'smile' 'learn' 'enough'
#  'different']
# [0.62 0.1  0.1  0.04 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.4056115817157395
# Word 361
#
# audio
# ['black' 'where' 'go']
# [0.96 0.02 0.02]
# 0.19567003495657082
#
# text
# ['black' 'white']
# [0.98 0.02]
# 0.098039113279732
# Word 368
#
# audio
# ['time' 'thing' 'story' 'person' 'woman' 'new' 'theory' 'song' 'idea'
#  'guy' 'dream' 'event' 'wonderful' 'family' 'broadcast' 'black' 'bet'
#  'girl' 'one' 'himself' 'hit' 'place' 'radio' 'record' 'show' 'singer'
#  'ability']
# [0.16 0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.076577387352737
#
# text
# ['time' 'song' 'club' 'radio' 'job' 'person' 'event' 'story' 'show' 'new'
#  'man' 'city' 'family' 'feel' 'girl' 'guy' 'woman' 'music' 'opportunity'
#  'voice' 'place' 'situation' 'station' 'thing' 'town' 'venue' 'black']
# [0.2  0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.0042227898674967
# Word 373
#
# audio
# ['go' 'happen' 'rage' 'discuss' 'talk' 'take' 'play' 'organize' 'occur'
#  'new' 'mean' 'listen' 'in' 'controversial' 'come']
# [0.48 0.1  0.08 0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 1.948354503393744
#
# text
# ['go' 'on' 'happen' 'have' 'intense' 'broadcast' 'hold' 'attend' 'brew'
#  'circulate' 'do' 'year' 'what' 'last' 'occur' 'ongoing' 'rage' 'say'
#  'take' 'to' 'unusual' 'air']
# [0.34 0.12 0.08 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.5014472714871925
# Word 380
#
# audio
# ['first' 'find' 'arrive' 'be' 'speak' 'interrupt' 'hear' 'read' 'learn'
#  'join' 'see' 'talk' 'flip' 'show' 'start' 'finally' 'figure' 'decide'
#  'broadcast' 'begin' 'stop' 'turn']
# [0.34 0.1  0.06 0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.534584690800567
#
# text
# ['be' 'arrive' 'hear' 'read' 'speak' 'play' 'young' 'realize' 'live'
#  'interrupt' 'talk' 'get' 'first' 'exclaim' 'debut' 'begin' 'start' 'ask']
# [0.3  0.22 0.08 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.3120730372049705
# Word 383
#
# audio
# ['and' 'about' 'that' 'he' 'st' 'although' 'as' 'at' 'back' 'be' 'before'
#  'debate' 'year' 'man' 'whether' 'radio' 'recently' 'so' 'some' 'talk'
#  'they' 'when' 'over']
# [0.34 0.14 0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.5099477242469015
#
# text
# ['I' 'people' 'he' 'it' 'then' 'that' 'after' 'apparently' 'they' 'today'
#  'whether' 'about' 'anyway' 'be' 'decide' 'eventually' 'everyone' 'if'
#  'how' 'interesting' 'year' 'last' 'most' 'one' 'when' 'some' 'there'
#  'yesterday']
# [0.16 0.08 0.08 0.08 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.0697814258809206
# Word 390
#
# audio
# ['white' 'black' 'not' 'wrong' 'she' 'say' 'just' 'cant']
# [0.76 0.08 0.06 0.02 0.02 0.02 0.02 0.02]
# 0.9706372378264152
#
# text
# ['white' 'black' 'not' 'too' 'go' 'from']
# [0.76 0.12 0.06 0.02 0.02 0.02]
# 0.8665296504086396
# Word 393
#
# audio
# ['white' 'not' 'definitely' 'whiter' 'cant']
# [0.84 0.08 0.04 0.02 0.02]
# 0.6337510899581276
#
# text
# ['white' 'definitely' 'not' 'black' 'obviously' 'as' 'a']
# [0.52 0.26 0.08 0.08 0.02 0.02 0.02]
# 1.3291188749377933
# Word 395
#
# audio
# ['white' 'definitely' 'she' 'not' 'get' 'whiter' 'totally' 'too' 'so'
#  'safe' 'really' 'play' 'clearly' 'black']
# [0.48 0.2  0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.8046716364974407
#
# text
# ['be' 'white' 'sound' 'definitely' 'cant' 'not' 'isnt' 'will' 'talk'
#  'shout' 'say' 'have' 'can' 'aint']
# [0.32 0.22 0.12 0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.094961268903439
# Word 401
#
# audio
# ['say' 'disagree' 'be' 'insist' 'tell' 'laugh' 'know' 'argue' 'black'
#  'debate' 'didnt' 'white' 'do' 'want' 'never' 'refuse' 'vehemently'
#  'always']
# [0.38 0.12 0.1  0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.268086866806842
#
# text
# ['say' 'be' 'would' 'argue' 'black' 'sound' 'smile' 'no' 'you' 'insist'
#  'confidently' 'deny' 'despite' 'didnt' 'he' 'might' 'know' 'laugh'
#  'obviously' 'sorry' 'tell' 'think' 'this' 'unbeknownst' 'adamant']
# [0.34 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.67826755769687
# Word 404
#
# audio
# ['see' 'meet' 'hear' 'win' 'white' 'tell' 'never' 'be']
# [0.5  0.36 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.2343253729290287
#
# text
# ['see' 'meet' 'hear' 'say' 'believe']
# [0.72 0.14 0.1  0.02 0.02]
# 0.898518157628593
# Word 409
#
# audio
# ['black' 'white' 'be']
# [0.82 0.16 0.02]
# 0.53418326406184
#
# text
# ['black' 'white']
# [0.76 0.24]
# 0.5510799280869728
# Word 417
#
# audio
# ['right' 'wrong' 'correct' 'white' 'go' 'free' 'black']
# [0.78 0.1  0.04 0.02 0.02 0.02 0.02]
# 0.865775242981214
#
# text
# ['right' 'black' 'wrong' 'white' 'a']
# [0.8  0.12 0.04 0.02 0.02]
# 0.7181824186072325
# Word 421
#
# audio
# ['black' 'very' 'most' 'in' 'definitely' 'a']
# [0.9  0.02 0.02 0.02 0.02 0.02]
# 0.48602676463485817
#
# text
# ['black' 'white' 'wrong' 'surprised' 'speechless' 'like' 'his' 'happy'
#  'glad' 'amaze' 'a']
# [0.78 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.026719034224624
# Word 431
#
# audio
# ['head' 'mind' 'brain' 'school' 'perception' 'emotion' 'ego']
# [0.6  0.22 0.1  0.02 0.02 0.02 0.02]
# 1.1828238251718013
#
# text
# ['head' 'mind' 'thought' 'confidence' 'identity' 'feeling']
# [0.74 0.14 0.04 0.04 0.02 0.02]
# 0.9120645547588805
# Word 441
#
# audio
# ['radio' 'in' 'league' 'market' 'broadcaster' 'star' 'city' 'player'
#  'intern' 'business' 'comedian' 'degree' 'dj' 'famous' 'graduate' 'work'
#  'try' 'miss' 'mover' 'network' 'news' 'presenter' 'qualify' 'sophomore'
#  'stress' 'announcer']
# [0.16 0.14 0.14 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.8958280809118957
#
# text
# ['news' 'in' 'radio' 'black' 'confuse' 'league' 'record' 'player' 'deal'
#  'dj' 'white' 'fool' 'celebrity' 'college' 'dumb' 'intern' 'guy' 'here'
#  'tired' 'member' 'mess' 'now' 'student' 'time' 'and']
# [0.12 0.12 0.1  0.08 0.06 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.967416369150647
# Word 446
#
# audio
# ['dream' 'life' 'career' 'own' 'university' 'time' 'they' 'self' 'radio'
#  'new' 'market' 'choose' 'and']
# [0.44 0.18 0.14 0.06 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.818119743842137
#
# text
# ['dream' 'life' 'career' 'voice' 'subject' 'station' 'perfect' 'people'
#  'own' 'field' 'choice' 'carer']
# [0.5  0.18 0.14 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.6346572482057824
# Word 462
#
# audio
# ['say' 'think' 'decide' 'start' 'tell' 'make' 'ask' 'listen' 'I' 'take'
#  'turn' 'have' 'go' 'tap' 'debate' 'brain' 'try' 'want']
# [0.26 0.12 0.12 0.08 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.4996641775517463
#
# text
# ['think' 'say' 'ask' 'go' 'tell' 'be' 'decide' 'feel' 'try' 'become'
#  'black' 'cry' 'fret' 'get' 'turn' 'guess' 'keep' 'leave' 'make' 'quit'
#  'socialize' 'start' 'take' 'hear']
# [0.18 0.1  0.08 0.06 0.06 0.06 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.8873656675517942
# Word 470
#
# audio
# ['know' 'think' 'tell' 'want' 'didnt' 'plan' 'to' 'show' 'realize' 'not'
#  'let' 'imagine' 'go' 'get' 'care']
# [0.26 0.2  0.12 0.08 0.08 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 2.2541582952603036
#
# text
# ['know' 'want' 'think' 'tell' 'plan' 'expect' 'understand' 'say' 'need'
#  'get' 'anticipate']
# [0.42 0.14 0.14 0.08 0.08 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.83893575484724
# Word 476
#
# audio
# ['go' 'excite' 'plan' 'determine' 'try' 'certain' 'remember' 'nervous'
#  'say' 'so' 'even' 'embrace' 'think' 'decide' 'confuse' 'confident' 'work']
# [0.56 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 1.869168193520354
#
# text
# ['go' 'black' 'plan' 'secretly' 'not' 'white' 'too' 'sure' 'so' 'silent'
#  'secret' 'gay' 'excite' 'eager' 'determine' 'about']
# [0.44 0.18 0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 1.9901085786955806
# Word 483
#
# audio
# ['air' 'internet' 'radio' 'show' 'they' 'slyly' 'regular' 'outside' 'news'
#  'new' 'mother' 'like' 'fact' 'down' 'broadcast' 'airway']
# [0.28 0.22 0.16 0.08 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 2.1742099103394694
#
# text
# ['radio' 'show' 'the' 'subject' 'secret' 'plan' 'fly' 'airwave' 'air']
# [0.7  0.16 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.0905687157167827
# Word 496
#
# audio
# ['first' 'plan' 'friend' 'think' 'fan' 'brain' 'thought' 'start' 'next'
#  'listener' 'goal' 'father' 'family' 'boss']
# [0.46 0.14 0.08 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.926805334480831
#
# text
# ['plan' 'listener' 'mission' 'color' 'first' 'fan' 'identity' 'word'
#  'hint' 'ethnicity' 'friend' 'job' 'secret' 'journey' 'next' 'people'
#  'radio' 'audience']
# [0.28 0.16 0.14 0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.380663636514387
# Word 504
#
# audio
# ['write' 'read' 'see' 'mission' 'like' 'five' 'black']
# [0.46 0.44 0.02 0.02 0.02 0.02 0.02]
# 1.1096369866230782
#
# text
# ['read' 'write' 'start' 'publish' 'play' 'love' 'like']
# [0.66 0.24 0.02 0.02 0.02 0.02 0.02]
# 1.007950418911149
# Word 507
#
# audio
# ['magazine' 'of' 'on' 'book' 'to' 'say' 'ready' 'please' 'describe'
#  'criticize' 'call' 'anybody' 'about']
# [0.68 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.392729336924274
#
# text
# ['magazine' 'about' 'with' 'where' 'weekly' 'tone' 'to' 'that' 'say'
#  'paper' 'loudly' 'book']
# [0.68 0.12 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.2990867123817895
# Word 517
#
# audio
# ['course' 'black' 'the' 'of' 'all' 'people' 'year' 'for' 'america' 'be'
#  'choice' 'culture' 'local' 'have' 'write' 'magazine' 'many' 'missouri'
#  'staple' 'would' 'about']
# [0.34 0.1  0.08 0.08 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.4723369548839558
#
# text
# ['course' 'black' 'missouri' 'the' 'essence' 'st' 'color' 'white'
#  'america' 'choice' 'culture' 'interest' 'fame' 'which' 'mississippi' 'my'
#  'predominantly' 'this' 'africa']
# [0.34 0.16 0.08 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.3560218739033876
# Word 528
#
# audio
# ['know' 'will' 'would' 'realize' 'must' 'get' 'listen' 'decide']
# [0.62 0.16 0.06 0.04 0.04 0.04 0.02 0.02]
# 1.3011458929913016
#
# text
# ['know' 'will' 'would' 'realize' 'think' 'get' 'understand' 'that'
#  'notice' 'must' 'catch']
# [0.46 0.18 0.12 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.737815594107969
# Word 534
#
# audio
# ['know' 'realize' 'magazine' 'it' 'hint' 'have' 'guess' 'figure' 'black']
# [0.84 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.7723805260701166
#
# text
# ['know' 'realize' 'understand' 'hear' 'guess' 'see' 'message' 'listen'
#  'learn' 'debate' 'believe' 'be' 'appeal' 'africa']
# [0.58 0.1  0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.6766791210276988
# Word 540
#
# audio
# ['rest' 'audience' 'room' 'two' 'test' 'end' 'real' 'vote' 'work'
#  'magazine' 'black' 'close' 'crowd' 'group' 'like' 'live' 'radio' 'purse'
#  'put' 'race' 'relatable' 'rumor' 'start' 'take' 'the' 'to' 'and']
# [0.3  0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.82914503434532
#
# text
# ['end' 'rest' 'test' 'halt' 'stop' 'close' 'bed' 'black' 'audience'
#  'large' 'trial' 'group' 'finish' 'person' 'crowd' 'community' 'quick'
#  'second' 'side' 'vote']
# [0.2  0.16 0.12 0.06 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.6228563302257433
# Word 547
#
# audio
# ['drop' 'black' 'get' 'talk' 'tell' 'prove' 'try' 'color' 'the' 'this'
#  'be' 'make' 'life' 'give' 'hint' 'keep' 'know' 'race' 'transparency'
#  'read' 'recognition' 'rest' 'reveal' 'tease' 'that' 'these' 'to' 'about']
# [0.12 0.1  0.08 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.137440693888508
#
# text
# ['let' 'the' 'essence' 'be' 'make' 'black' 'do' 'drop' 'get' 'honesty'
#  'try' 'show' 'my' 'finish' 'too' 'clue' 'convince' 'to' 'tell' 'talk'
#  'everywhere' 'sure' 'read' 'hint' 'sound' 'inform' 'it' 'town' 'listen'
#  'know']
# [0.1  0.08 0.08 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 3.241548281306284
# Word 562
#
# audio
# ['grocery' 'top' 'store' 'doctor' 'shop' 'garage' 'diner' 'drive'
#  'drugstore' 'fill' 'first' 'gala' 'why' 'great' 'typical' 'limit' 'mall'
#  'market' 'mayor' 'point' 'this' 'deli']
# [0.32 0.18 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.4697348285283254
#
# text
# ['store' 'top' 'shop' 'peak' 'end' 'station' 'bar' 'stage' 'supermarket'
#  'mall' 'height' 'grocery' 'coffee' 'diner' 'edge' 'market' 'event'
#  'office' 'place' 'point' 'start' 'bank']
# [0.24 0.1  0.08 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.7560742342467552
# Word 567
#
# audio
# ['dog' 'tail' 'dream' 'cat' 'kid' 'world' 'fan' 'cab' 'career' 'child'
#  'errand' 'friend' 'voice' 'grocery' 'mailman' 'oil' 'story' 'the' 'thing'
#  'bus']
# [0.34 0.12 0.1  0.08 0.06 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.395955254688578
#
# text
# ['dream' 'dog' 'tail' 'kid' 'child' 'cart' 'time' 'sound' 'son' 'shadow'
#  'receipt' 'paperboy' 'order']
# [0.3  0.26 0.16 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.9786419537238273
# Word 572
#
# audio
# ['park' 'fair' 'zoo' 'school' 'playground' 'mall' 'market' 'sport'
#  'monument' 'missouri' 'town' 'kid' 'high' 'stadium' 'college' 'church'
#  'bus' 'bowling' 'beach' 'baseball' 'ball']
# [0.3  0.1  0.08 0.08 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.55729769421232
#
# text
# ['market' 'park' 'mall' 'zoo' 'playground' 'missouri' 'fair' 'store'
#  'school' 'new' 'college']
# [0.34 0.28 0.12 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02]
# 1.8456888808621135
# Word 576
#
# audio
# ['I' 'and' 'to' 'get' 'people' 'tell' 'say' 'call' 'stop' 'shout' 'park'
#  'out' 'loudly' 'come' 'but' 'also']
# [0.22 0.18 0.16 0.1  0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 2.346236784592521
#
# text
# ['stop' 'and' 'I' 'to' 'run' 'talk' 'come' 'people' 'ask' 'black' 'but'
#  'call' 'hey' 'yell' 'scream' 'when' 'someone' 'suddenly' 'tell' 'then'
#  'try' 'wait' 'slow']
# [0.22 0.14 0.12 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.720227202027716
# Word 580
#
# audio
# ['voice' 'god' 'zoo' 'tone' 'taxi' 'kid' 'image' 'face' 'dog']
# [0.82 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.8391680235082158
#
# text
# ['voice' 'life']
# [0.98 0.02]
# 0.098039113279732
# Word 588
#
# audio
# ['air' 'radio' 'internet' 'tonight' 'tell' 'stage' 'other' 'live' 'it'
#  'audience' 'airway']
# [0.7  0.08 0.06 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.2464590761758785
#
# text
# ['radio' 'air' 'show' 'weekend' 'tv' 'listener' 'line' 'internet' 'day']
# [0.56 0.24 0.08 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.3387073348913208
# Word 598
#
# audio
# ['my' 'myself' 'a' 'story' 'dinner' 'hair' 'it' 'how' 'africa' 'be' 'day'
#  'food' 'word' 'what' 'not' 'place' 'something' 'upbringe' 'voice' 'look']
# [0.4  0.12 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.321898673489505
#
# text
# ['my' 'myself' 'hair' 'I' 'the' 'another' 'how' 'food' 'a' 'african'
#  'dinner' 'fashion' 'trip' 'to' 'kid' 'life' 'music' 'thing' 'it']
# [0.3  0.14 0.08 0.06 0.06 0.06 0.06 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.4526100260598014
# Word 603
#
# audio
# ['recipe' 'voice' 'homemade' 'green' 'cornbread' 'meal' 'famous' 'child'
#  'chicken' 'christmas' 'church' 'favorite' 'chitterling' 'country' 'curse'
#  'day' 'dinner' 'casserole' 'cleaner' 'wish' 'food' 'gumbo' 'hope' 'hot'
#  'macaroni' 'maiden' 'mother' 'own' 'pie' 'secret' 'soda' 'soup' 'stew'
#  'accuse']
# [0.14 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 3.3414067865858423
#
# text
# ['recipe' 'hair' 'day' 'food' 'voice' 'chicken' 'cornbread' 'famous'
#  'favorite' 'green' 'cake' 'mac' 'lunch' 'secret' 'roast' 'place' 'dinner'
#  'dish' 'dream' 'dress' 'dumpling' 'pie' 'nap' 'name' 'money' 'gumbo'
#  'main' 'happy' 'tea' 'jollof' 'jumbalaya' 'lasagna' 'jambalaya']
# [0.1  0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 3.3592477916676913
# Word 609
#
# audio
# ['know' 'now' 'get' 'then' 'it' 'hear' 'fry' 'boom' 'and']
# [0.78 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.9608022969045374
#
# text
# ['know' 'hear' 'realize' 'find' 'their' 'talk' 'learn' 'however']
# [0.7  0.1  0.08 0.04 0.02 0.02 0.02 0.02]
# 1.1237061350301574
# Word 619
#
# audio
# ['woman' 'person' 'that' 'black']
# [0.9  0.06 0.02 0.02]
# 0.4201100273147717
#
# text
# ['woman' 'man' 'person' 'southern' 'right' 'lady' 'guy' 'girl' 'citizen']
# [0.68 0.16 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.1536613147979846
# Word 626
#
# audio
# ['people' 'event' 'white' 'listener' 'day' 'place' 'hint' 'time' 'caller'
#  'famous' 'fund' 'fundraiser' 'meet' 'man' 'meeting' 'notice' 'on' 'one'
#  'recognize' 'show' 'swap' 'black']
# [0.28 0.16 0.06 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.597639282937335
#
# text
# ['event' 'fundraiser' 'place' 'people' 'mission' 'debate' 'will' 'visit'
#  'time' 'show' 'shop' 'session' 'market' 'folk' 'convention']
# [0.58 0.08 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 1.7371843262568085
# Word 638
#
# audio
# ['state' 'small' 'sort' 'rush' 'seat' 'discussion' 'stupor' 'doesnt'
#  'just' 'good' 'few' 'conversation' 'meet' 'circle' 'car' 'cafe' 'booth'
#  'audience' 'listen' 'program' 'mood' 'much' 'quandary' 'say' 'seminar'
#  'sense' 'session' 'side' 'situation' 'slump' 'spin' 'start' 'a']
# [0.24 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 3.1388251232693483
#
# text
# ['group' 'room' 'bar' 'rush' 'hurry' 'mood' 'meet' 'taxi' 'shock' 'ditch'
#  'bathroom' 'bit' 'booth' 'car' 'chair' 'conversation' 'crowd' 'daze'
#  'debate' 'discussion' 'great' 'school' 'team' 'hall' 'tiswa' 'talk'
#  'panel' 'pickle' 'queue' 'store' 'round' 'shop' 'woman']
# [0.14 0.08 0.06 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 3.285955012141047
# Word 645
#
# audio
# ['talk' 'discuss' 'all' 'not' 'go' 'the' 'speak' 'they' 'just' 'here'
#  'various' 'get' 'together' 'definitely' 'debate' 'chat' 'black' 'be'
#  'around' 'very']
# [0.38 0.18 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 2.276267257659497
#
# text
# ['talk' 'discuss' 'chat' 'all' 'debate' 'together' 'minority' 'have'
#  'black']
# [0.54 0.22 0.06 0.06 0.04 0.02 0.02 0.02 0.02]
# 1.4451747759075957
# Word 663
#
# audio
# ['color' 'race' 'kind' 'type' 'ethnicity' 'black' 'age' 'skin' 'ok'
#  'group' 'community' 'background']
# [0.52 0.12 0.1  0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.7309543292166072
#
# text
# ['age' 'color' 'race' 'kind' 'ethnicity' 'education' 'yourself' 'type'
#  'skin' 'people' 'background' 'accent']
# [0.32 0.26 0.18 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.8792296957837034
# Word 670
#
# audio
# ['feel' 'say' 'do' 'think' 'mean' 'kind' 'imply' 'hear' 'groan'
#  'experience']
# [0.56 0.18 0.12 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.4354769195021455
#
# text
# ['say' 'feel' 'think' 'hear' 'do' 'mean' 'know']
# [0.5  0.2  0.08 0.08 0.06 0.04 0.04]
# 1.498892464851172
# Word 673
#
# audio
# ['feel' 'what' 'smell' 'sense' 'I']
# [0.92 0.02 0.02 0.02 0.02]
# 0.3896729206581786
#
# text
# ['feel' 'tell' 'sense' 'really' 'hear' 'almost' 'understand' 'see'
#  'relate' 'not' 'have' 'shout' 'get']
# [0.46 0.06 0.06 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02]
# 2.001482543388315
# Word 677
#
# audio
# ['stomach' 'soul' 'skin' 'spine' 'self' 'bone' 'toe' 'spirit' 'sole'
#  'skull' 'mind' 'education' 'core']
# [0.4  0.22 0.1  0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.9038808329826158
#
# text
# ['bone' 'heart' 'soul' 'head' 'stomach' 'life' 'body']
# [0.44 0.3  0.16 0.04 0.02 0.02 0.02]
# 1.3791127317286525
# Word 681
#
# audio
# ['head' 'throat' 'core' 'chest' 'mouth' 'heart' 'set' 'lung' 'hear' 'bone'
#  'air']
# [0.34 0.16 0.12 0.12 0.1  0.06 0.02 0.02 0.02 0.02 0.02]
# 1.9591370206020289
#
# text
# ['throat' 'head' 'chest' 'mouth' 'heart' 'stomach' 'level' 'face' 'core']
# [0.34 0.26 0.2  0.06 0.06 0.02 0.02 0.02 0.02]
# 1.6894931422700508
# Word 687
#
# audio
# ['say' 'think' 'stand' 'feel' 'try' 'stop' 'still' 'stare' 'spirit' 'snap'
#  'noise' 'churn']
# [0.7  0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.3019108506206742
#
# text
# ['feel' 'say' 'be' 'reply' 'get' 'could' 'couldnt' 'know' 'yell' 'head'
#  'choke' 'cry' 'enjoy' 'gasp' 'hate' 'just' 'hit' 'want' 'lose' 'love'
#  'nervous' 'retch' 'scream' 'shout' 'think' 'vomit' 'ache']
# [0.16 0.14 0.08 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.9809702526946706
# Word 696
#
# audio
# ['refer' 'talk' 'want' 'throat' 'think' 'people' 'now' 'nil' 'mean'
#  'black']
# [0.62 0.22 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.2554139786317138
#
# text
# ['talk' 'refer' 'say' 'from' 'like' 'yes' 'think' 'then' 'represent'
#  'reference' 'mean' 'listen' 'call']
# [0.4  0.28 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.8152346818517064
# Word 707
#
# audio
# ['know' 'black']
# [0.98 0.02]
# 0.098039113279732
#
# text
# ['know' 'do' 'sound' 'have' 'black' 'be' 'understand' 'try' 'think' 'look'
#  'like' 'hate' 'feel' 'care']
# [0.56 0.1  0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.7359502894993417
# Word 713
#
# audio
# ['want' 'wasnt' 'will' 'say' 'ready' 'know' 'be' 'I']
# [0.76 0.12 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.9324463877287262
#
# text
# ['want' 'didnt' 'pretend' 'think' 'still' 'say' 'ignore' 'be' 'wasnt'
#  'press' 'know' 'just' 'forgot' 'do' 'couldnt' 'ask']
# [0.42 0.14 0.08 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 2.1113631757149847
# Word 724
#
# audio
# ['want' 'I' 'think' 'let' 'he' 'black' 'be' 'and']
# [0.84 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.7446546388477189
#
# text
# ['want' 'wait' 'ask' 'need' 'tell' 'stare' 'stand' 'know' 'hope' 'urge'
#  'have' 'get' 'expect' 'dont' 'demand' 'black' 'be' 'he']
# [0.48 0.14 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.0204871214509037
# Word 727
#
# audio
# ['say' 'speak' 'tell' 'explain' 'voice' 'see' 'mouth' 'mind' 'mean']
# [0.72 0.1  0.04 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.1154938040515412
#
# text
# ['say' 'admit' 'speak' 'realize' 'explain' 'yes' 'spell' 'shout' 'loud'
#  'know' 'incriminate' 'feel' 'confirm' 'apologize' 'acknowledge']
# [0.4  0.22 0.1  0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 1.9697975703027022
# Word 731
#
# audio
# ['say' 'stand' 'squirm' 'prevaricate']
# [0.94 0.02 0.02 0.02]
# 0.29288425982069105
#
# text
# ['say' 'do' 'didnt' 'know' 'refuse' 'wouldnt' 'could' 'couldnt' 'hesitate'
# ...
# 2.6185692086879175
# Word 1291
#
# audio
# ['around' 'part' 'in' 'want' 'wait' 'there' 'tell' 'rude' 'read' 'now'
#  'list' 'go' 'big' 'await' 'available']
# [0.68 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 1.4586460742443605
#
# text
# ['around' 'there' 'here' 'wait' 'list' 'do' 'name' 'aware' 'famous' 'in'
#  'involve' 'work' 'on' 'want' 'racist' 'really' 'record' 'see' 'so'
#  'speak' 'protest']
# [0.26 0.16 0.1  0.08 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.5469355611438873
# Word 1300
#
# audio
# ['and']
# [1.]
# 0.0
#
# text
# ['and']
# [1.]
# 0.0
# Word 1311
#
# audio
# ['leave' 'he' 'then' 'listen' 'sit' 'talk' 'say' 'chat' 'close' 'look'
#  'what' 'and' 'bow' 'discuss' 'go' 'make' 'void' 'my' 'now' 'run' 'slowly'
#  'speak' 'agree']
# [0.14 0.1  0.1  0.1  0.08 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.869040375730903
#
# text
# ['leave' 'then' 'he' 'go' 'talk' 'speak' 'listen' 'discuss' 'chat' 'start'
#  'say' 'play' 'have' 'call' 'close' 'walk' 'end' 'return' 'stop' 'the'
#  'after']
# [0.18 0.1  0.08 0.08 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.807857007288076
# Word 1318
#
# audio
# ['week' 'moment' 'day' 'word' 'minute' 'hour' 'step' 'wee' 'thing'
#  'second' 'reminder' 'point' 'fuel' 'call' 'ago']
# [0.2  0.16 0.14 0.12 0.12 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 2.3227030221356015
#
# text
# ['day' 'moment' 'more' 'minute' 'week' 'second' 'hour' 'people' 'year'
#  'thing' 'could']
# [0.34 0.18 0.1  0.1  0.06 0.06 0.06 0.04 0.02 0.02 0.02]
# 2.0058663628590354
# Word 1325
#
# audio
# ['house' 'studio' 'station' 'office' 'show' 'meet' 'world' 'we' 'to'
#  'shop' 'seminar' 'round' 'radio' 'home' 'broadcast']
# [0.3  0.2  0.18 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 2.122221990813272
#
# text
# ['studio' 'station' 'office' 'house' 'door' 'town' 'to' 'radio' 'event']
# [0.48 0.22 0.1  0.08 0.04 0.02 0.02 0.02 0.02]
# 1.5594469794900914
# Word 1328
#
# audio
# ['interview' 'drink' 'visit' 'story' 'second' 'chat' 'service' 'survey'
#  'sunday' 'job' 'dinner' 'first' 'work' 'delivery' 'certain' 'break' 'bbq'
#  'collection' 'reservation' 'meal' 'meet' 'repair' 'sermon' 'simple'
#  'small' 'special' 'spot' 'stir' 'supper' 'to' 'after']
# [0.08 0.08 0.06 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 3.2879195222566278
#
# text
# ['chat' 'meal' 'coffee' 'meet' 'drink' 'visit' 'interview' 'party'
#  'dinner' 'cup' 'lunch' 'quick' 'hour' 'gather' 'repair' 'discussion'
#  'delivery' 'view' 'word']
# [0.18 0.12 0.1  0.08 0.08 0.08 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 2.6587626083007962
# Word 1336
#
# audio
# ['car' 'studio' 'last' 'grandmother' 'father' 'can']
# [0.9  0.02 0.02 0.02 0.02 0.02]
# 0.48602676463485817
#
# text
# ['car' 'want' 'truck' 'room']
# [0.94 0.02 0.02 0.02]
# 0.29288425982069105
# Word 1343
#
# audio
# ['driveway' 'garage' 'I' 'drive' 'front' 'he' 'interstate' 'car' 'driver'
#  'freeway' 'hear' 'in' 'time' 'tidy' 'news' 'outside' 'parking' 'pay'
#  'repair' 'speak' 'start' 'take' 'the' 'there' 'lot']
# [0.32 0.1  0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.676565573983037
#
# text
# ['garage' 'driveway' 'drive' 'middle' 'car' 'yellow' 'yard' 'windshield'
#  'windscreen' 'street' 'page' 'front' 'back']
# [0.38 0.28 0.08 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.8496539676205503
# Word 1358
#
# audio
# ['feel' 'friend' 'phone' 'have' 'funny' 'word' 'a' 'break' 'clue' 'cup'
#  'faulty' 'favor' 'front' 'few' 'window' 'glass' 'havent' 'phonebook'
#  'then' 'think' 'I']
# [0.36 0.2  0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.327794492319524
#
# text
# ['friend' 'car' 'daughter' 'problem' 'black' 'radio' 'question' 'few'
#  'history' 'bone' 'business' 'cousin' 'degree' 'wife' 'job' 'want' 'nice'
#  'part' 'record' 'remove' 'sister' 'spare' 'think' 'new']
# [0.18 0.14 0.14 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.7948474535624612
# Word 1369
#
# audio
# ['friend' 'neighbor' 'person' 'man' 'woman' 'night' 'nasty' 'lady' 'car'
#  'nice' 'reporter' 'news' 'new' 'who' 'movement' 'the' 'he' 'to' 'black'
#  'arent' 'area']
# [0.14 0.12 0.08 0.08 0.08 0.06 0.06 0.06 0.06 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.8004809650815172
#
# text
# ['you' 'car' 'he' 'there' 'the' 'woman' 'neighbor' 'company' 'debate'
#  'friend' 'garage' 'his' 'once' 'neighborhood' 'protest' 'she' 'that'
#  'they' 'this' 'weather' 'when' 'before']
# [0.34 0.1  0.1  0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.5054743741973304
# Word 1376
#
# audio
# ['know' 'want' 'recognize' 'news' 'live']
# [0.92 0.02 0.02 0.02 0.02]
# 0.3896729206581786
#
# text
# ['know' 'work' 'understand' 'really' 'listen' 'her']
# [0.9  0.02 0.02 0.02 0.02 0.02]
# 0.48602676463485817
# Word 1380
#
# audio
# ['say' 'start' 'smile' 'lady' 'do']
# [0.92 0.02 0.02 0.02 0.02]
# 0.3896729206581786
#
# text
# ['say' 'laugh' 'tell' 'reply' 'be' 'stop' 'look' 'here' 'do']
# [0.74 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02]
# 1.09084935108414
# Word 1388
#
# audio
# ['say' 'sit' 'over']
# [0.96 0.02 0.02]
# 0.19567003495657082
#
# text
# ['say' 'tell' 'be' 'know' 'wish' 'wait' 'stand' 'speak' 'reply' 'quote'
#  'explain' 'dont' 'admit']
# [0.6  0.1  0.08 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.5717313490754536
# Word 1394
#
# audio
# ['news' 'woman' 'lady' 'person' 'one' 'newslady' 'pride' 'newswoman'
#  'newsreader' 'live']
# [0.32 0.3  0.14 0.08 0.04 0.04 0.02 0.02 0.02 0.02]
# 1.7735968097786223
#
# text
# ['lady' 'news' 'woman' 'person' 'black' 'way' 'unsure' 'new' 'holiday']
# [0.38 0.32 0.14 0.04 0.04 0.02 0.02 0.02 0.02]
# 1.578028606915629
# Word 1408
#
# audio
# ['look' 'like' 'shock' 'say' 'get' 'ignorance' 'black' 'carol' 'delight'
#  'hesitate' 'unbelieve' 'there' 'not' 'presume' 'rigid' 'surprised' 'ask']
# [0.5  0.1  0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 1.9752859784162489
#
# text
# ['surprised' 'shock' 'look' 'confuse' 'black' 'white' 'that' 'starstruck'
#  'stare' 'shake' 'question' 'my' 'laugh' 'holiday' 'go' 'amaze']
# [0.3  0.24 0.1  0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02]
# 2.1827271960423817
# Word 1412
#
# audio
# ['think' 'stare' 'say' 'surprised' 'wonder' 'try' 'still' 'speak' 'sound'
#  'shock' 'see' 'ok' 'look' 'about']
# [0.44 0.18 0.14 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.856310593939826
#
# text
# ['stare' 'shock' 'think' 'look' 'wonder' 'surprised' 'confuse' 'doubt'
#  'angry' 'ask' 'come' 'just' 'gape' 'happy' 'white' 'not' 'size' 'about']
# [0.16 0.16 0.14 0.12 0.08 0.06 0.06 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.5164261313857237
# Word 1416
#
# audio
# ['look' 'think' 'judge' 'try' 'say' 'see' 'wonder' 'check' 'work' 'size'
#  'stare' 'start' 'struggle' 'feel' 'decide' 'weigh' 'beam' 'assess']
# [0.2  0.12 0.1  0.08 0.08 0.06 0.06 0.06 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.6005419750943224
#
# text
# ['say' 'be' 'look' 'want' 'doesnt' 'just' 'think' 'smile' 'put' 'know'
#  'gaze' 'eye' 'come' 'cant' 'I']
# [0.44 0.14 0.08 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 2.009073994330581
# Word 1421
#
# audio
# ['driveway' 'own' 'front' 'drive' 'mind' 'garage' 'yard' 'garden'
#  'backyard' 'condition' 'eye' 'height' 'head' 'world' 'home' 'look'
#  'pocket' 'radio' 'size' 'town' 'back']
# [0.26 0.24 0.08 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.4546773659822416
#
# text
# ['driveway' 'own' 'house' 'garden' 'home' 'entirety' 'skin' 'room' 'car'
#  'dress' 'jean' 'drive' 'clothe' 'coat' 'yard' 'garage' 'word' 'look'
#  'mind' 'old' 'presence' 'bathrobe']
# [0.22 0.14 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.7584180521254043
# Word 1430
#
# audio
# ['white' 'lie' 'worried' 'want' 'wait' 'react' 'pretend' 'not' 'kid'
#  'joke']
# [0.8  0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.9331935549145991
#
# text
# ['white' 'someone' 'lie' 'joke' 'black' 'there' 'nothing' 'look' 'go'
#  'ashamed' 'a']
# [0.7  0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.2741849633982767
# Word 1436
#
# audio
# ['find' 'that' 'black' 'see' 'I' 'white' 'to' 'the' 'news' 'know' 'few'
#  'color' 'a']
# [0.56 0.1  0.1  0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.668649122798416
#
# text
# ['see' 'find' 'know' 'learn' 'this' 'that' 'say' 'discover']
# [0.6  0.18 0.1  0.04 0.02 0.02 0.02 0.02]
# 1.2871344740445256
# Word 1440
#
# audio
# ['black' 'not' 'white' 'lack' 'know' 'african']
# [0.86 0.06 0.02 0.02 0.02 0.02]
# 0.6114741686115958
#
# text
# ['black' 'white' 'score' 'human' 'carol']
# [0.92 0.02 0.02 0.02 0.02]
# 0.3896729206581786
# Word 1445
#
# audio
# ['truth' 'nerve' 'man' 'cheek' 'time' 'that' 'thing' 'moment' 'this' 'day'
#  'type' 'do' 'chance' 'driveway' 'easy' 'gall' 'gosh' 'know' 'apparently'
#  'you' 'say' 'only' 'reason' 'yes' 'secret' 'shock' 'surely' 'treatment'
#  'trouble' 'true' 'whole' 'would' 'I']
# [0.1  0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02]
# 3.3592477916676917
#
# text
# ['man' 'time' 'same' 'nerve' 'world' 'way' 'audacity' 'good' 'clue'
#  'people' 'only' 'difference' 'dude' 'craziness' 'day' 'hint' 'cheek'
#  'bad' 'apparently' 'guy' 'moment' 'idea' 'inevitable' 'whole' 'most'
#  'news' 'next' 'plan' 'point' 'secret' 'shame' 'thing' 'trouble' 'answer']
# [0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02]
# 3.40928803402151
# Word 1454
#
# audio
# ['form' 'way' 'place' 'people' 'corner' 'quarter' 'part' 'know' 'circle'
#  'dark' 'hall' 'one' 'mind' 'town' 'sense' 'serious' 'thing' 'capacity']
# [0.36 0.16 0.08 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.278780578039882
#
# text
# ['way' 'form' 'people' 'place' 'mind' 'shape' 'quarter' 'town' 'overtime'
#  'doubt' 'aspect' 'area']
# [0.36 0.18 0.14 0.08 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02]
# 1.97128926714279
# Word 1456
#
# audio
# ['or' 'other' 'way' 'another' 'stereotype' 'of' 'fashion' 'identity'
#  'area' 'arrogance' 'but' 'context' 'conversation' 'discussion'
#  'disrespect' 'form' 'who' 'individual' 'it' 'medium' 'notion' 'pin'
#  'some' 'still' 'thing' 'topic' 'judge']
# [0.18 0.16 0.08 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.9238139869619815
#
# text
# ['another' 'other' 'shape' 'way' 'fashion' 'time' 'not']
# [0.46 0.28 0.1  0.08 0.04 0.02 0.02]
# 1.4311863864530656
# Word 1465
#
# audio
# ['ever' 'even' 'understand' 'convince' 'do' 'handle' 'utter' 'almost'
#  'begin' 'believe' 'change' 'convey' 'deal' 'defeat' 'easily' 'express'
#  'unsure' 'help' 'honestly' 'keep' 'not' 'only' 'say' 'stop' 'think'
#  'tolerate' 'adjust']
# [0.2  0.16 0.08 0.06 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.88652327950609
#
# text
# ['convince' 'change' 'end' 'tell' 'continue' 'do' 'fix' 'believe' 'say'
#  'keep' 'understand' 'ever' 'explain' 'agree' 'carry' 'deal' 'win'
#  'fathom' 'get' 'go' 'make' 'put' 'resolve' 'shake' 'still' 'stop'
#  'transition' 'accept']
# [0.1  0.08 0.08 0.06 0.06 0.06 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.165166581110906
# Word 1473
#
# audio
# ['lot' 'long' 'whole' 'line' 'little' 'bag' 'basically' 'black' 'bunch'
#  'deeply' 'divide' 'fashion' 'fine' 'you' 'word' 'matter' 'problem'
#  'racist' 'real' 'solution' 'stereotype' 'strong' 'undertow' 'about']
# [0.48 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.3033795051939387
#
# text
# ['stigma' 'problem' 'debate' 'whole' 'thing' 'chance' 'say' 'real'
#  'difference' 'history' 'good' 'frustration' 'doubt' 'continuous' 'lack'
#  'cloud' 'certain' 'block' 'belief' 'interesting' 'nothing' 'moral'
#  'never' 'way' 'number' 'permanent' 'person' 'ready' 'realization'
#  'reason' 'revolution' 'slight' 'social' 'stereotype' 'view' 'assumption']
# [0.08 0.08 0.08 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 3.440682922647383
# Word 1476
#
# audio
# ['stake' 'when' 'that' 'than' 'seem' 'sea' 'play' 'on' 'need' 'large'
#  'could']
# [0.8  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.9609194421369969
#
# text
# ['stake' 'the' 'risk' 'work' 'this' 'steak' 'pressure' 'play'
#  'mississippi' 'large' 'home' 'hand' 'educate' 'activity']
# [0.7  0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.3678275879407609
# Word 1479
#
# audio
# ['lot' 'at' 'you' 'to' 'theirs' 'more' 'lose' 'debate' 'black' 'achieve'
#  'a']
# [0.78 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.026719034224624
#
# text
# ['whole' 'lot' 'time' 'big' 'chance' 'debate' 'future' 'world' 'limit'
#  'hell' 'history' 'hope' 'huge' 'major' 'moment' 'much' 'person' 'place'
#  'principle' 'problem' 'question' 'reason' 'awful']
# [0.28 0.2  0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.5739404984250753
# Word 1488
#
# audio
# ['lot' 'whole' 'very' 'thing' 'there' 'life' 'do' 'big' 'a']
# [0.84 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 0.7723805260701166
#
# text
# ['lot' 'way' 'long' 'baby' 'child' 'whole' 'big' 'challenge' 'chance'
#  'world' 'man' 'mountain' 'perception' 'real' 'time' 'twist' 'mission']
# [0.54 0.06 0.06 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 1.9172599614784418
# Word 1496
#
# audio
# ['dont' 'want' 'cant' 'can' 'couldnt' 'feel' 'wasnt' 'find' 'be' 'carry'
#  'didnt' 'excite' 'hope' 'just' 'know' 'look' 'need' 'pray' 'realize'
#  'really' 'say' 'try' 'I']
# [0.2  0.16 0.14 0.08 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.6800125959584324
#
# text
# ['need' 'dont' 'have' 'cant' 'can' 'hope' 'want' 'wish' 'think' 'know'
#  'live' 'realize' 'say' 'stand' 'feel' 'start' 'couldnt' 'could']
# [0.24 0.12 0.12 0.1  0.06 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02]
# 2.5201331721888067
# Word 1507
#
# audio
# ['idea' 'know' 'can' 'do' 'feel' 'think' 'time' 'nil' 'obsession'
#  'realize' 'find' 'stake' 'dont' 'swear' 'couldnt' 'cant' 'just']
# [0.38 0.2  0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02]
# 2.1557988885364114
#
# text
# ['know' 'can' 'cant' 'guess' 'be' 'think' 'believe' 'just' 'where' 'find'
#  'close' 'couldnt' 'feel' 'hard' 'want' 'never' 'rude' 'say' 'swear'
#  'teach' 'understand' 'admit']
# [0.28 0.14 0.08 0.06 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.6129356971688598
# Word 1516
#
# audio
# ['job' 'opportunity' 'life' 'platform' 'moment' 'place' 'treatment' 'to'
#  'there' 'role' 'feel' 'chance']
# [0.54 0.1  0.08 0.06 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02]
# 1.7008643957902359
#
# text
# ['life' 'job' 'place' 'opportunity' 'reward' 'treatment' 'success' 'space'
#  'shot' 'respect' 'position' 'peace' 'chance' 'career' 'break']
# [0.42 0.2  0.08 0.06 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02]
# 1.9682603895534234
# Word 1530
#
# audio
# ['job' 'call']
# [0.98 0.02]
# 0.098039113279732
#
# text
# ['job' 'feel' 'because' 'urge' 'type' 'other']
# [0.82 0.06 0.06 0.02 0.02 0.02]
# 0.7350604360904405
# Word 1539
#
# audio
# ['thank' 'and' 'I' 'yes' 'good' 'that' 'here' 'job' 'do' 'deserve']
# [0.4  0.2  0.14 0.06 0.06 0.04 0.04 0.02 0.02 0.02]
# 1.7935004074550278
#
# text
# ['I' 'thank' 'and' 'anyway' 'so' 'yes' 'period' 'that' 'the' 'regardless'
#  'really' 'yep' 'one' 'nobody' 'my' 'finally' 'competence' 'be' 'this'
#  'truly' 'also']
# [0.48 0.04 0.04 0.04 0.04 0.04 0.04 0.02 0.02 0.02 0.02 0.02 0.02 0.02
#  0.02 0.02 0.02 0.02 0.02 0.02 0.02]
# 2.2202018435267457

# %% [markdown]
# ## Analyze and compile human and LLM data

# %% [markdown]
# ### Set LLM model names

# %%
PROSODY_MODELS = [
    'helsinki-prosody_scratch-gpt2_joint-loss_prosody-embed',
    'helsinki-prosody_scratch-gpt2_clm-loss_prosody-embed',
    'helsinki-prosody_scratch-gpt2_clm-loss_no-prosody-embed',

    ################### GIGASPEECH ############
    
    'gigaspeech-prosody_scratch-gpt2_joint-loss_prosody-embed',
    'gigaspeech-prosody_scratch-gpt2_clm-loss_prosody-embed',
    'gigaspeech-prosody_scratch-gpt2_clm-loss_no-prosody-embed',
]

model_names = PROSODY_MODELS


# # get all MLM models except BERT
# MLM_MODELS = list(nlp.MLM_MODELS_DICT.keys())[1:]
# CLM_MODELS = list(nlp.CLM_MODELS_DICT.keys()) 
# model_names = CLM_MODELS + MLM_MODELS

# print (f'Loading the following models')
# print (f'MLM models: {MLM_MODELS}')
# print (f'CLM models: {CLM_MODELS}')

# %% [markdown]
# ### Cleaned responses - Load and merge human and LLM data

# %%
# load lemmatized file and analyze human results --> use all words
cleaned_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior.csv')
df_cleaned_results = pd.read_csv(cleaned_fn)

# combine the data and lemmatize model results
df_human_model = compare_human_model_accuracy(df_cleaned_results, model_names, word_model_info, task=TASK, top_n=1, window_size=25, lemmatize=False)

# save combined human-model results
out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-analyzed-behavior_human-model.csv')
df_human_model.to_csv(out_fn, index=False)
# Out:
# Total missing values: 21

# %% [markdown]
# ### Lemmatization - Load and merge human and LLM data

# %%
WINDOW_SIZE = 100

# load lemmatized file and analyze human results --> use all words
lemmatized_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior_lemmatized.csv')
df_lemmatized_results = pd.read_csv(lemmatized_fn)

# combine the data and lemmatize model results
df_human_model_lemmatized = compare_human_model_accuracy(df_lemmatized_results, model_names, word_model_info, task=TASK, top_n=1, window_size=WINDOW_SIZE, lemmatize=True)

# save lemmatized human-model results
if 'prosody' in model_names[0]:
    out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-analyzed-behavior_window-size-{WINDOW_SIZE}_human-prosody-model-lemmatized.csv')
else:
    out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-analyzed-behavior_window-size-{WINDOW_SIZE}_human-model-lemmatized.csv')

df_human_model_lemmatized.to_csv(out_fn, index=False)
# Out:
# Word 4
# Word 11
# Word 30
# Word 34
# Word 38
# Word 47
# Word 51
# Word 61
# Word 64
# Word 70
# Word 78
# Word 83
# Word 87
# Word 99
# Word 125
# Word 130
# Word 136
# Word 151
# Word 165
# Word 182
# Word 198
# Word 202
# Word 213
# Word 217
# Word 227
# Word 242
# Word 257
# Word 261
# Word 268
# Word 272
# Word 276
# Word 282
# Word 292
# Word 306
# Word 319
# Word 323
# Word 329
# Word 341
# Word 344
# Word 351
# Word 355
# Word 359
# Word 363
# Word 367
# Word 372
# Word 376
# Word 382
# Word 389
# Word 396
# Word 406
# Word 413
# Word 425
# Word 432
# Word 435
# Word 441
# Word 445
# Word 448
# Word 453
# Word 459
# Word 469
# Word 484
# Word 490
# Word 496
# Word 504
# Word 518
# Word 525
# Word 528
# Word 531
# Word 535
# Word 539
# Word 544
# Word 548
# Word 552
# Word 562
# Word 567
# Word 582
# Word 589
# Word 595
# Word 601
# Word 606
# Word 617
# Word 621
# Word 628
# Word 632
# Word 639
# Word 646
# Word 650
# Word 661
# Word 664
# Word 670
# Word 675
# Word 685
# Word 691
# Word 696
# Word 699
# Word 711
# Word 724
# Word 727
# Word 736
# Word 742
# Word 748
# Word 756
# Word 760
# Word 769
# Word 778
# Word 781
# Word 786
# Word 793
# Word 802
# Word 806
# Word 809
# Word 817
# Word 826
# Word 830
# Word 835
# Word 842
# Word 848
# Word 852
# Word 863
# Word 870
# Word 877
# Word 881
# Word 889
# Word 893
# Word 907
# Word 914
# Word 921
# Word 924
# Word 928
# Word 933
# Word 940
# Word 943
# Word 955
# Word 959
# Word 966
# Word 975
# Word 994
# Word 997
# Word 1005
# Word 1008
# Word 1016
# Word 1021
# Word 1037
# Word 1054
# Word 1062
# Word 1090
# Word 1094
# Word 1099
# Word 1103
# Word 1110
# Word 1114
# Word 1122
# Word 1130
# Word 1151
# Word 1160
# Word 1172
# Word 1179
# Word 1183
# Word 1198
# Word 1203
# Word 1207
# Word 1213
# Word 1217
# Word 1222
# Word 1225
# Word 1239
# Word 1245
# Word 1249
# Word 1255
# Word 1259
# Word 1270
# Word 1273
# Word 1285
# Word 1290
# Word 1299
# Word 1318
# Word 1327
# Word 1330
# Word 1337
# Word 1345
# Word 1352
# Word 1367
# Word 1371
# Word 1375
# Word 1378
# Word 1389
# Word 1397
# Word 1406
# Word 1419
# Word 1428
# Word 1443
# Word 1447
# Word 1451
# Word 1469
# Word 1476
# Word 1481
# Word 1504
# Word 1513
# Word 1516
# Word 1529
# Word 1532
# Word 1542
# Word 1551
# Word 1557
# Word 1560
# Word 1565
# Word 1568
# Word 1573
# Word 1577
# Word 1590
# Word 1596
# Word 1601
# Word 1605
# Word 1610
# Word 1622
# Word 1627
# Word 1634
# Word 1637
# Word 1646
# Word 1649
# Word 1655
# Word 1662
# Word 1669
# Word 1673
# Word 1678
# Word 1683
# Word 1688
# Word 1701
# Word 1710
# Word 1722
# Word 1727
# Word 1732
# Word 1738
# Word 1745
# Word 1758
# Word 1783
# Word 1817
# Word: down 	 Lemma: down
# GT: secretly 	 GTLemma: secretly
# Word: eyes 	 Lemma: eye
# GT: foot 	 GTLemma: foot
# Word: doubt 	 Lemma: doubt
# GT: shoe 	 GTLemma: shoe
# Word: so 	 Lemma: so
# GT: cry 	 GTLemma: cry
# Word: longer 	 Lemma: long
# GT: wallet 	 GTLemma: wallet
# Word: eyes 	 Lemma: eye
# GT: cigarette 	 GTLemma: cigarette
# Word: get 	 Lemma: get
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: temper 	 GTLemma: temper
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: play 	 GTLemma: play
# Word: nan 	 Lemma: nan
# GT: learn 	 GTLemma: learn
# Word: nan 	 Lemma: nan
# GT: real 	 GTLemma: real
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: sometimes 	 GTLemma: sometimes
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: night 	 GTLemma: night
# Word: nan 	 Lemma: nan
# GT: silent 	 GTLemma: silent
# Word: nan 	 Lemma: nan
# GT: sprinkler 	 GTLemma: sprinkler
# Word: nan 	 Lemma: nan
# GT: enjoy 	 GTLemma: enjoy
# Word: nan 	 Lemma: nan
# GT: freedom 	 GTLemma: freedom
# Word: nan 	 Lemma: nan
# GT: perfect 	 GTLemma: perfect
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: occur 	 GTLemma: occur
# Word: nan 	 Lemma: nan
# GT: horrify 	 GTLemma: horrify
# Word: nan 	 Lemma: nan
# GT: light 	 GTLemma: light
# Word: nan 	 Lemma: nan
# GT: figure 	 GTLemma: figure
# Word: nan 	 Lemma: nan
# GT: dog 	 GTLemma: dog
# Word: nan 	 Lemma: nan
# GT: suburban 	 GTLemma: suburban
# Word: nan 	 Lemma: nan
# GT: person 	 GTLemma: person
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: hand 	 GTLemma: hand
# Word: nan 	 Lemma: nan
# GT: face 	 GTLemma: face
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: compose 	 GTLemma: compose
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: cry 	 GTLemma: cry
# Word: nan 	 Lemma: nan
# GT: street 	 GTLemma: street
# Word: nan 	 Lemma: nan
# GT: never 	 GTLemma: never
# Word: nan 	 Lemma: nan
# GT: pass 	 GTLemma: pass
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: cutoff 	 GTLemma: cutoff
# Word: nan 	 Lemma: nan
# GT: dig 	 GTLemma: dig
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: vest 	 GTLemma: vest
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: pocket 	 GTLemma: pocket
# Word: nan 	 Lemma: nan
# GT: check 	 GTLemma: check
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: front 	 GTLemma: front
# Word: nan 	 Lemma: nan
# GT: launder 	 GTLemma: launder
# Word: nan 	 Lemma: nan
# GT: open 	 GTLemma: open
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: hunker 	 GTLemma: hunker
# Word: nan 	 Lemma: nan
# GT: crouch 	 GTLemma: crouch
# Word: nan 	 Lemma: nan
# GT: ground 	 GTLemma: ground
# Word: nan 	 Lemma: nan
# GT: wind 	 GTLemma: wind
# Word: nan 	 Lemma: nan
# GT: stop 	 GTLemma: stop
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: brand 	 GTLemma: brand
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: strike 	 GTLemma: strike
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: tell 	 GTLemma: tell
# Word: nan 	 Lemma: nan
# GT: immediately 	 GTLemma: immediately
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: happen 	 GTLemma: happen
# Word: nan 	 Lemma: nan
# GT: close 	 GTLemma: close
# Word: nan 	 Lemma: nan
# GT: lucky 	 GTLemma: lucky
# Word: nan 	 Lemma: nan
# GT: surprise 	 GTLemma: surprise
# Word: nan 	 Lemma: nan
# GT: fight 	 GTLemma: fight
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: mean 	 GTLemma: mean
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: north 	 GTLemma: north
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: find 	 GTLemma: find
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cool 	 GTLemma: cool
# Word: nan 	 Lemma: nan
# GT: horse 	 GTLemma: horse
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: ice 	 GTLemma: ice
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: stuff 	 GTLemma: stuff
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: thing 	 GTLemma: thing
# Word: nan 	 Lemma: nan
# GT: home 	 GTLemma: home
# Word: nan 	 Lemma: nan
# GT: ugly 	 GTLemma: ugly
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: sweet 	 GTLemma: sweet
# Word: nan 	 Lemma: nan
# GT: almost 	 GTLemma: almost
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: year 	 GTLemma: year
# Word: nan 	 Lemma: nan
# GT: license 	 GTLemma: license
# Word: nan 	 Lemma: nan
# GT: right 	 GTLemma: right
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: give 	 GTLemma: give
# Word: nan 	 Lemma: nan
# GT: ride 	 GTLemma: ride
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: lot 	 GTLemma: lot
# Word: nan 	 Lemma: nan
# GT: road 	 GTLemma: road
# Word: nan 	 Lemma: nan
# GT: car 	 GTLemma: car
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: place 	 GTLemma: place
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: horrible 	 GTLemma: horrible
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: quietly 	 GTLemma: quietly
# Word: nan 	 Lemma: nan
# GT: soon 	 GTLemma: soon
# Word: nan 	 Lemma: nan
# GT: blare 	 GTLemma: blare
# Word: nan 	 Lemma: nan
# GT: blue 	 GTLemma: blue
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: turn 	 GTLemma: turn
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: pull 	 GTLemma: pull
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: threat 	 GTLemma: threat
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: hard 	 GTLemma: hard
# Word: nan 	 Lemma: nan
# GT: heat 	 GTLemma: heat
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: afraid 	 GTLemma: afraid
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: crook 	 GTLemma: crook
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: carton 	 GTLemma: carton
# Word: nan 	 Lemma: nan
# GT: kiss 	 GTLemma: kiss
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: outside 	 GTLemma: outside
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: beautiful 	 GTLemma: beautiful
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: keep 	 GTLemma: keep
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: beer 	 GTLemma: beer
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: sorry 	 GTLemma: sorry
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: morning 	 GTLemma: morning
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: map 	 GTLemma: map
# Word: nan 	 Lemma: nan
# GT: mile 	 GTLemma: mile
# Word: nan 	 Lemma: nan
# GT: half 	 GTLemma: half
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: pretty 	 GTLemma: pretty
# Word: nan 	 Lemma: nan
# GT: fine 	 GTLemma: fine
# Word: nan 	 Lemma: nan
# GT: paper 	 GTLemma: paper
# Word: nan 	 Lemma: nan
# GT: third 	 GTLemma: third
# Word: nan 	 Lemma: nan
# GT: pack 	 GTLemma: pack
# Word: nan 	 Lemma: nan
# GT: new 	 GTLemma: new
# Word: nan 	 Lemma: nan
# GT: match 	 GTLemma: match
# Word: nan 	 Lemma: nan
# GT: goodbye 	 GTLemma: goodbye
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: walk 	 GTLemma: walk
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: seem 	 GTLemma: seem
# Word: nan 	 Lemma: nan
# GT: visit 	 GTLemma: visit
# Word: nan 	 Lemma: nan
# GT: scary 	 GTLemma: scary
# Word: nan 	 Lemma: nan
# GT: opposite 	 GTLemma: opposite
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: grim 	 GTLemma: grim
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: apartment 	 GTLemma: apartment
# Word: nan 	 Lemma: nan
# GT: yard 	 GTLemma: yard
# Word: nan 	 Lemma: nan
# GT: loose 	 GTLemma: loose
# Word: nan 	 Lemma: nan
# GT: use 	 GTLemma: use
# Word: nan 	 Lemma: nan
# GT: would 	 GTLemma: would
# Word: nan 	 Lemma: nan
# GT: gas 	 GTLemma: gas
# Word: nan 	 Lemma: nan
# GT: baby 	 GTLemma: baby
# Word: nan 	 Lemma: nan
# GT: seven 	 GTLemma: seven
# Word: nan 	 Lemma: nan
# GT: hold 	 GTLemma: hold
# Word: nan 	 Lemma: nan
# GT: quit 	 GTLemma: quit
# Word: found 	 Lemma: find
# GT: secretly 	 GTLemma: secretly
# Word: eyes 	 Lemma: eye
# GT: foot 	 GTLemma: foot
# Word: doubt 	 Lemma: doubt
# GT: shoe 	 GTLemma: shoe
# Word: so 	 Lemma: so
# GT: cry 	 GTLemma: cry
# Word: doubt 	 Lemma: doubt
# GT: wallet 	 GTLemma: wallet
# Word: head 	 Lemma: head
# GT: cigarette 	 GTLemma: cigarette
# Word: get 	 Lemma: get
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: temper 	 GTLemma: temper
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: play 	 GTLemma: play
# Word: nan 	 Lemma: nan
# GT: learn 	 GTLemma: learn
# Word: nan 	 Lemma: nan
# GT: real 	 GTLemma: real
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: sometimes 	 GTLemma: sometimes
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: night 	 GTLemma: night
# Word: nan 	 Lemma: nan
# GT: silent 	 GTLemma: silent
# Word: nan 	 Lemma: nan
# GT: sprinkler 	 GTLemma: sprinkler
# Word: nan 	 Lemma: nan
# GT: enjoy 	 GTLemma: enjoy
# Word: nan 	 Lemma: nan
# GT: freedom 	 GTLemma: freedom
# Word: nan 	 Lemma: nan
# GT: perfect 	 GTLemma: perfect
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: occur 	 GTLemma: occur
# Word: nan 	 Lemma: nan
# GT: horrify 	 GTLemma: horrify
# Word: nan 	 Lemma: nan
# GT: light 	 GTLemma: light
# Word: nan 	 Lemma: nan
# GT: figure 	 GTLemma: figure
# Word: nan 	 Lemma: nan
# GT: dog 	 GTLemma: dog
# Word: nan 	 Lemma: nan
# GT: suburban 	 GTLemma: suburban
# Word: nan 	 Lemma: nan
# GT: person 	 GTLemma: person
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: hand 	 GTLemma: hand
# Word: nan 	 Lemma: nan
# GT: face 	 GTLemma: face
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: compose 	 GTLemma: compose
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: cry 	 GTLemma: cry
# Word: nan 	 Lemma: nan
# GT: street 	 GTLemma: street
# Word: nan 	 Lemma: nan
# GT: never 	 GTLemma: never
# Word: nan 	 Lemma: nan
# GT: pass 	 GTLemma: pass
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: cutoff 	 GTLemma: cutoff
# Word: nan 	 Lemma: nan
# GT: dig 	 GTLemma: dig
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: vest 	 GTLemma: vest
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: pocket 	 GTLemma: pocket
# Word: nan 	 Lemma: nan
# GT: check 	 GTLemma: check
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: front 	 GTLemma: front
# Word: nan 	 Lemma: nan
# GT: launder 	 GTLemma: launder
# Word: nan 	 Lemma: nan
# GT: open 	 GTLemma: open
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: hunker 	 GTLemma: hunker
# Word: nan 	 Lemma: nan
# GT: crouch 	 GTLemma: crouch
# Word: nan 	 Lemma: nan
# GT: ground 	 GTLemma: ground
# Word: nan 	 Lemma: nan
# GT: wind 	 GTLemma: wind
# Word: nan 	 Lemma: nan
# GT: stop 	 GTLemma: stop
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: brand 	 GTLemma: brand
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: strike 	 GTLemma: strike
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: tell 	 GTLemma: tell
# Word: nan 	 Lemma: nan
# GT: immediately 	 GTLemma: immediately
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: happen 	 GTLemma: happen
# Word: nan 	 Lemma: nan
# GT: close 	 GTLemma: close
# Word: nan 	 Lemma: nan
# GT: lucky 	 GTLemma: lucky
# Word: nan 	 Lemma: nan
# GT: surprise 	 GTLemma: surprise
# Word: nan 	 Lemma: nan
# GT: fight 	 GTLemma: fight
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: mean 	 GTLemma: mean
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: north 	 GTLemma: north
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: find 	 GTLemma: find
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cool 	 GTLemma: cool
# Word: nan 	 Lemma: nan
# GT: horse 	 GTLemma: horse
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: ice 	 GTLemma: ice
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: stuff 	 GTLemma: stuff
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: thing 	 GTLemma: thing
# Word: nan 	 Lemma: nan
# GT: home 	 GTLemma: home
# Word: nan 	 Lemma: nan
# GT: ugly 	 GTLemma: ugly
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: sweet 	 GTLemma: sweet
# Word: nan 	 Lemma: nan
# GT: almost 	 GTLemma: almost
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: year 	 GTLemma: year
# Word: nan 	 Lemma: nan
# GT: license 	 GTLemma: license
# Word: nan 	 Lemma: nan
# GT: right 	 GTLemma: right
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: give 	 GTLemma: give
# Word: nan 	 Lemma: nan
# GT: ride 	 GTLemma: ride
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: lot 	 GTLemma: lot
# Word: nan 	 Lemma: nan
# GT: road 	 GTLemma: road
# Word: nan 	 Lemma: nan
# GT: car 	 GTLemma: car
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: place 	 GTLemma: place
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: horrible 	 GTLemma: horrible
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: quietly 	 GTLemma: quietly
# Word: nan 	 Lemma: nan
# GT: soon 	 GTLemma: soon
# Word: nan 	 Lemma: nan
# GT: blare 	 GTLemma: blare
# Word: nan 	 Lemma: nan
# GT: blue 	 GTLemma: blue
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: turn 	 GTLemma: turn
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: pull 	 GTLemma: pull
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: threat 	 GTLemma: threat
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: hard 	 GTLemma: hard
# Word: nan 	 Lemma: nan
# GT: heat 	 GTLemma: heat
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: afraid 	 GTLemma: afraid
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: crook 	 GTLemma: crook
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: carton 	 GTLemma: carton
# Word: nan 	 Lemma: nan
# GT: kiss 	 GTLemma: kiss
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: outside 	 GTLemma: outside
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: beautiful 	 GTLemma: beautiful
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: keep 	 GTLemma: keep
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: beer 	 GTLemma: beer
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: sorry 	 GTLemma: sorry
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: morning 	 GTLemma: morning
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: map 	 GTLemma: map
# Word: nan 	 Lemma: nan
# GT: mile 	 GTLemma: mile
# Word: nan 	 Lemma: nan
# GT: half 	 GTLemma: half
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: pretty 	 GTLemma: pretty
# Word: nan 	 Lemma: nan
# GT: fine 	 GTLemma: fine
# Word: nan 	 Lemma: nan
# GT: paper 	 GTLemma: paper
# Word: nan 	 Lemma: nan
# GT: third 	 GTLemma: third
# Word: nan 	 Lemma: nan
# GT: pack 	 GTLemma: pack
# Word: nan 	 Lemma: nan
# GT: new 	 GTLemma: new
# Word: nan 	 Lemma: nan
# GT: match 	 GTLemma: match
# Word: nan 	 Lemma: nan
# GT: goodbye 	 GTLemma: goodbye
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: walk 	 GTLemma: walk
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: seem 	 GTLemma: seem
# Word: nan 	 Lemma: nan
# GT: visit 	 GTLemma: visit
# Word: nan 	 Lemma: nan
# GT: scary 	 GTLemma: scary
# Word: nan 	 Lemma: nan
# GT: opposite 	 GTLemma: opposite
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: grim 	 GTLemma: grim
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: apartment 	 GTLemma: apartment
# Word: nan 	 Lemma: nan
# GT: yard 	 GTLemma: yard
# Word: nan 	 Lemma: nan
# GT: loose 	 GTLemma: loose
# Word: nan 	 Lemma: nan
# GT: use 	 GTLemma: use
# Word: nan 	 Lemma: nan
# GT: would 	 GTLemma: would
# Word: nan 	 Lemma: nan
# GT: gas 	 GTLemma: gas
# Word: nan 	 Lemma: nan
# GT: baby 	 GTLemma: baby
# Word: nan 	 Lemma: nan
# GT: seven 	 GTLemma: seven
# Word: nan 	 Lemma: nan
# GT: hold 	 GTLemma: hold
# Word: nan 	 Lemma: nan
# GT: quit 	 GTLemma: quit
# Word: down 	 Lemma: down
# GT: secretly 	 GTLemma: secretly
# Word: eyes 	 Lemma: eye
# GT: foot 	 GTLemma: foot
# Word: one 	 Lemma: one
# GT: shoe 	 GTLemma: shoe
# Word: in 	 Lemma: in
# GT: cry 	 GTLemma: cry
# Word: doubt 	 Lemma: doubt
# GT: wallet 	 GTLemma: wallet
# Word: eyes 	 Lemma: eye
# GT: cigarette 	 GTLemma: cigarette
# Word: get 	 Lemma: get
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: temper 	 GTLemma: temper
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: play 	 GTLemma: play
# Word: nan 	 Lemma: nan
# GT: learn 	 GTLemma: learn
# Word: nan 	 Lemma: nan
# GT: real 	 GTLemma: real
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: sometimes 	 GTLemma: sometimes
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: night 	 GTLemma: night
# Word: nan 	 Lemma: nan
# GT: silent 	 GTLemma: silent
# Word: nan 	 Lemma: nan
# GT: sprinkler 	 GTLemma: sprinkler
# Word: nan 	 Lemma: nan
# GT: enjoy 	 GTLemma: enjoy
# Word: nan 	 Lemma: nan
# GT: freedom 	 GTLemma: freedom
# Word: nan 	 Lemma: nan
# GT: perfect 	 GTLemma: perfect
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: occur 	 GTLemma: occur
# Word: nan 	 Lemma: nan
# GT: horrify 	 GTLemma: horrify
# Word: nan 	 Lemma: nan
# GT: light 	 GTLemma: light
# Word: nan 	 Lemma: nan
# GT: figure 	 GTLemma: figure
# Word: nan 	 Lemma: nan
# GT: dog 	 GTLemma: dog
# Word: nan 	 Lemma: nan
# GT: suburban 	 GTLemma: suburban
# Word: nan 	 Lemma: nan
# GT: person 	 GTLemma: person
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: hand 	 GTLemma: hand
# Word: nan 	 Lemma: nan
# GT: face 	 GTLemma: face
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: compose 	 GTLemma: compose
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: cry 	 GTLemma: cry
# Word: nan 	 Lemma: nan
# GT: street 	 GTLemma: street
# Word: nan 	 Lemma: nan
# GT: never 	 GTLemma: never
# Word: nan 	 Lemma: nan
# GT: pass 	 GTLemma: pass
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: cutoff 	 GTLemma: cutoff
# Word: nan 	 Lemma: nan
# GT: dig 	 GTLemma: dig
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: vest 	 GTLemma: vest
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: pocket 	 GTLemma: pocket
# Word: nan 	 Lemma: nan
# GT: check 	 GTLemma: check
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: front 	 GTLemma: front
# Word: nan 	 Lemma: nan
# GT: launder 	 GTLemma: launder
# Word: nan 	 Lemma: nan
# GT: open 	 GTLemma: open
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: hunker 	 GTLemma: hunker
# Word: nan 	 Lemma: nan
# GT: crouch 	 GTLemma: crouch
# Word: nan 	 Lemma: nan
# GT: ground 	 GTLemma: ground
# Word: nan 	 Lemma: nan
# GT: wind 	 GTLemma: wind
# Word: nan 	 Lemma: nan
# GT: stop 	 GTLemma: stop
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: brand 	 GTLemma: brand
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: strike 	 GTLemma: strike
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: tell 	 GTLemma: tell
# Word: nan 	 Lemma: nan
# GT: immediately 	 GTLemma: immediately
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: happen 	 GTLemma: happen
# Word: nan 	 Lemma: nan
# GT: close 	 GTLemma: close
# Word: nan 	 Lemma: nan
# GT: lucky 	 GTLemma: lucky
# Word: nan 	 Lemma: nan
# GT: surprise 	 GTLemma: surprise
# Word: nan 	 Lemma: nan
# GT: fight 	 GTLemma: fight
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: mean 	 GTLemma: mean
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: north 	 GTLemma: north
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: find 	 GTLemma: find
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cool 	 GTLemma: cool
# Word: nan 	 Lemma: nan
# GT: horse 	 GTLemma: horse
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: ice 	 GTLemma: ice
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: stuff 	 GTLemma: stuff
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: thing 	 GTLemma: thing
# Word: nan 	 Lemma: nan
# GT: home 	 GTLemma: home
# Word: nan 	 Lemma: nan
# GT: ugly 	 GTLemma: ugly
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: sweet 	 GTLemma: sweet
# Word: nan 	 Lemma: nan
# GT: almost 	 GTLemma: almost
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: year 	 GTLemma: year
# Word: nan 	 Lemma: nan
# GT: license 	 GTLemma: license
# Word: nan 	 Lemma: nan
# GT: right 	 GTLemma: right
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: give 	 GTLemma: give
# Word: nan 	 Lemma: nan
# GT: ride 	 GTLemma: ride
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: lot 	 GTLemma: lot
# Word: nan 	 Lemma: nan
# GT: road 	 GTLemma: road
# Word: nan 	 Lemma: nan
# GT: car 	 GTLemma: car
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: place 	 GTLemma: place
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: horrible 	 GTLemma: horrible
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: quietly 	 GTLemma: quietly
# Word: nan 	 Lemma: nan
# GT: soon 	 GTLemma: soon
# Word: nan 	 Lemma: nan
# GT: blare 	 GTLemma: blare
# Word: nan 	 Lemma: nan
# GT: blue 	 GTLemma: blue
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: turn 	 GTLemma: turn
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: pull 	 GTLemma: pull
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: threat 	 GTLemma: threat
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: hard 	 GTLemma: hard
# Word: nan 	 Lemma: nan
# GT: heat 	 GTLemma: heat
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: afraid 	 GTLemma: afraid
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: crook 	 GTLemma: crook
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: carton 	 GTLemma: carton
# Word: nan 	 Lemma: nan
# GT: kiss 	 GTLemma: kiss
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: outside 	 GTLemma: outside
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: beautiful 	 GTLemma: beautiful
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: keep 	 GTLemma: keep
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: beer 	 GTLemma: beer
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: sorry 	 GTLemma: sorry
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: morning 	 GTLemma: morning
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: map 	 GTLemma: map
# Word: nan 	 Lemma: nan
# GT: mile 	 GTLemma: mile
# Word: nan 	 Lemma: nan
# GT: half 	 GTLemma: half
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: pretty 	 GTLemma: pretty
# Word: nan 	 Lemma: nan
# GT: fine 	 GTLemma: fine
# Word: nan 	 Lemma: nan
# GT: paper 	 GTLemma: paper
# Word: nan 	 Lemma: nan
# GT: third 	 GTLemma: third
# Word: nan 	 Lemma: nan
# GT: pack 	 GTLemma: pack
# Word: nan 	 Lemma: nan
# GT: new 	 GTLemma: new
# Word: nan 	 Lemma: nan
# GT: match 	 GTLemma: match
# Word: nan 	 Lemma: nan
# GT: goodbye 	 GTLemma: goodbye
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: walk 	 GTLemma: walk
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: seem 	 GTLemma: seem
# Word: nan 	 Lemma: nan
# GT: visit 	 GTLemma: visit
# Word: nan 	 Lemma: nan
# GT: scary 	 GTLemma: scary
# Word: nan 	 Lemma: nan
# GT: opposite 	 GTLemma: opposite
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: grim 	 GTLemma: grim
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: apartment 	 GTLemma: apartment
# Word: nan 	 Lemma: nan
# GT: yard 	 GTLemma: yard
# Word: nan 	 Lemma: nan
# GT: loose 	 GTLemma: loose
# Word: nan 	 Lemma: nan
# GT: use 	 GTLemma: use
# Word: nan 	 Lemma: nan
# GT: would 	 GTLemma: would
# Word: nan 	 Lemma: nan
# GT: gas 	 GTLemma: gas
# Word: nan 	 Lemma: nan
# GT: baby 	 GTLemma: baby
# Word: nan 	 Lemma: nan
# GT: seven 	 GTLemma: seven
# Word: nan 	 Lemma: nan
# GT: hold 	 GTLemma: hold
# Word: nan 	 Lemma: nan
# GT: quit 	 GTLemma: quit
# Word: over 	 Lemma: over
# GT: secretly 	 GTLemma: secretly
# Word: or 	 Lemma: or
# GT: foot 	 GTLemma: foot
# Word: way 	 Lemma: way
# GT: shoe 	 GTLemma: shoe
# Word: a 	 Lemma: a
# GT: cry 	 GTLemma: cry
# Word: way 	 Lemma: way
# GT: wallet 	 GTLemma: wallet
# Word: little 	 Lemma: little
# GT: cigarette 	 GTLemma: cigarette
# Word: i 	 Lemma: I
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: temper 	 GTLemma: temper
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: play 	 GTLemma: play
# Word: nan 	 Lemma: nan
# GT: learn 	 GTLemma: learn
# Word: nan 	 Lemma: nan
# GT: real 	 GTLemma: real
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: sometimes 	 GTLemma: sometimes
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: night 	 GTLemma: night
# Word: nan 	 Lemma: nan
# GT: silent 	 GTLemma: silent
# Word: nan 	 Lemma: nan
# GT: sprinkler 	 GTLemma: sprinkler
# Word: nan 	 Lemma: nan
# GT: enjoy 	 GTLemma: enjoy
# Word: nan 	 Lemma: nan
# GT: freedom 	 GTLemma: freedom
# Word: nan 	 Lemma: nan
# GT: perfect 	 GTLemma: perfect
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: occur 	 GTLemma: occur
# Word: nan 	 Lemma: nan
# GT: horrify 	 GTLemma: horrify
# Word: nan 	 Lemma: nan
# GT: light 	 GTLemma: light
# Word: nan 	 Lemma: nan
# GT: figure 	 GTLemma: figure
# Word: nan 	 Lemma: nan
# GT: dog 	 GTLemma: dog
# Word: nan 	 Lemma: nan
# GT: suburban 	 GTLemma: suburban
# Word: nan 	 Lemma: nan
# GT: person 	 GTLemma: person
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: hand 	 GTLemma: hand
# Word: nan 	 Lemma: nan
# GT: face 	 GTLemma: face
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: compose 	 GTLemma: compose
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: cry 	 GTLemma: cry
# Word: nan 	 Lemma: nan
# GT: street 	 GTLemma: street
# Word: nan 	 Lemma: nan
# GT: never 	 GTLemma: never
# Word: nan 	 Lemma: nan
# GT: pass 	 GTLemma: pass
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: cutoff 	 GTLemma: cutoff
# Word: nan 	 Lemma: nan
# GT: dig 	 GTLemma: dig
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: vest 	 GTLemma: vest
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: pocket 	 GTLemma: pocket
# Word: nan 	 Lemma: nan
# GT: check 	 GTLemma: check
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: front 	 GTLemma: front
# Word: nan 	 Lemma: nan
# GT: launder 	 GTLemma: launder
# Word: nan 	 Lemma: nan
# GT: open 	 GTLemma: open
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: hunker 	 GTLemma: hunker
# Word: nan 	 Lemma: nan
# GT: crouch 	 GTLemma: crouch
# Word: nan 	 Lemma: nan
# GT: ground 	 GTLemma: ground
# Word: nan 	 Lemma: nan
# GT: wind 	 GTLemma: wind
# Word: nan 	 Lemma: nan
# GT: stop 	 GTLemma: stop
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: brand 	 GTLemma: brand
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: strike 	 GTLemma: strike
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: tell 	 GTLemma: tell
# Word: nan 	 Lemma: nan
# GT: immediately 	 GTLemma: immediately
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: happen 	 GTLemma: happen
# Word: nan 	 Lemma: nan
# GT: close 	 GTLemma: close
# Word: nan 	 Lemma: nan
# GT: lucky 	 GTLemma: lucky
# Word: nan 	 Lemma: nan
# GT: surprise 	 GTLemma: surprise
# Word: nan 	 Lemma: nan
# GT: fight 	 GTLemma: fight
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: mean 	 GTLemma: mean
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: north 	 GTLemma: north
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: find 	 GTLemma: find
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cool 	 GTLemma: cool
# Word: nan 	 Lemma: nan
# GT: horse 	 GTLemma: horse
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: ice 	 GTLemma: ice
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: stuff 	 GTLemma: stuff
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: thing 	 GTLemma: thing
# Word: nan 	 Lemma: nan
# GT: home 	 GTLemma: home
# Word: nan 	 Lemma: nan
# GT: ugly 	 GTLemma: ugly
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: sweet 	 GTLemma: sweet
# Word: nan 	 Lemma: nan
# GT: almost 	 GTLemma: almost
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: year 	 GTLemma: year
# Word: nan 	 Lemma: nan
# GT: license 	 GTLemma: license
# Word: nan 	 Lemma: nan
# GT: right 	 GTLemma: right
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: give 	 GTLemma: give
# Word: nan 	 Lemma: nan
# GT: ride 	 GTLemma: ride
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: lot 	 GTLemma: lot
# Word: nan 	 Lemma: nan
# GT: road 	 GTLemma: road
# Word: nan 	 Lemma: nan
# GT: car 	 GTLemma: car
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: place 	 GTLemma: place
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: horrible 	 GTLemma: horrible
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: quietly 	 GTLemma: quietly
# Word: nan 	 Lemma: nan
# GT: soon 	 GTLemma: soon
# Word: nan 	 Lemma: nan
# GT: blare 	 GTLemma: blare
# Word: nan 	 Lemma: nan
# GT: blue 	 GTLemma: blue
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: turn 	 GTLemma: turn
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: pull 	 GTLemma: pull
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: threat 	 GTLemma: threat
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: hard 	 GTLemma: hard
# Word: nan 	 Lemma: nan
# GT: heat 	 GTLemma: heat
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: afraid 	 GTLemma: afraid
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: crook 	 GTLemma: crook
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: carton 	 GTLemma: carton
# Word: nan 	 Lemma: nan
# GT: kiss 	 GTLemma: kiss
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: outside 	 GTLemma: outside
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: beautiful 	 GTLemma: beautiful
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: keep 	 GTLemma: keep
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: beer 	 GTLemma: beer
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: sorry 	 GTLemma: sorry
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: morning 	 GTLemma: morning
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: map 	 GTLemma: map
# Word: nan 	 Lemma: nan
# GT: mile 	 GTLemma: mile
# Word: nan 	 Lemma: nan
# GT: half 	 GTLemma: half
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: pretty 	 GTLemma: pretty
# Word: nan 	 Lemma: nan
# GT: fine 	 GTLemma: fine
# Word: nan 	 Lemma: nan
# GT: paper 	 GTLemma: paper
# Word: nan 	 Lemma: nan
# GT: third 	 GTLemma: third
# Word: nan 	 Lemma: nan
# GT: pack 	 GTLemma: pack
# Word: nan 	 Lemma: nan
# GT: new 	 GTLemma: new
# Word: nan 	 Lemma: nan
# GT: match 	 GTLemma: match
# Word: nan 	 Lemma: nan
# GT: goodbye 	 GTLemma: goodbye
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: walk 	 GTLemma: walk
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# ...
# GT: quietly 	 GTLemma: quietly
# Word: nan 	 Lemma: nan
# GT: soon 	 GTLemma: soon
# Word: nan 	 Lemma: nan
# GT: blare 	 GTLemma: blare
# Word: nan 	 Lemma: nan
# GT: blue 	 GTLemma: blue
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: turn 	 GTLemma: turn
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: pull 	 GTLemma: pull
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: threat 	 GTLemma: threat
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: hard 	 GTLemma: hard
# Word: nan 	 Lemma: nan
# GT: heat 	 GTLemma: heat
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: afraid 	 GTLemma: afraid
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: crook 	 GTLemma: crook
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: carton 	 GTLemma: carton
# Word: nan 	 Lemma: nan
# GT: kiss 	 GTLemma: kiss
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: outside 	 GTLemma: outside
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: beautiful 	 GTLemma: beautiful
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: keep 	 GTLemma: keep
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: beer 	 GTLemma: beer
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: sorry 	 GTLemma: sorry
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: morning 	 GTLemma: morning
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: map 	 GTLemma: map
# Word: nan 	 Lemma: nan
# GT: mile 	 GTLemma: mile
# Word: nan 	 Lemma: nan
# GT: half 	 GTLemma: half
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: pretty 	 GTLemma: pretty
# Word: nan 	 Lemma: nan
# GT: fine 	 GTLemma: fine
# Word: nan 	 Lemma: nan
# GT: paper 	 GTLemma: paper
# Word: nan 	 Lemma: nan
# GT: third 	 GTLemma: third
# Word: nan 	 Lemma: nan
# GT: pack 	 GTLemma: pack
# Word: nan 	 Lemma: nan
# GT: new 	 GTLemma: new
# Word: nan 	 Lemma: nan
# GT: match 	 GTLemma: match
# Word: nan 	 Lemma: nan
# GT: goodbye 	 GTLemma: goodbye
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: walk 	 GTLemma: walk
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: seem 	 GTLemma: seem
# Word: nan 	 Lemma: nan
# GT: visit 	 GTLemma: visit
# Word: nan 	 Lemma: nan
# GT: scary 	 GTLemma: scary
# Word: nan 	 Lemma: nan
# GT: opposite 	 GTLemma: opposite
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: grim 	 GTLemma: grim
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: apartment 	 GTLemma: apartment
# Word: nan 	 Lemma: nan
# GT: yard 	 GTLemma: yard
# Word: nan 	 Lemma: nan
# GT: loose 	 GTLemma: loose
# Word: nan 	 Lemma: nan
# GT: use 	 GTLemma: use
# Word: nan 	 Lemma: nan
# GT: would 	 GTLemma: would
# Word: nan 	 Lemma: nan
# GT: gas 	 GTLemma: gas
# Word: nan 	 Lemma: nan
# GT: baby 	 GTLemma: baby
# Word: nan 	 Lemma: nan
# GT: seven 	 GTLemma: seven
# Word: nan 	 Lemma: nan
# GT: hold 	 GTLemma: hold
# Word: nan 	 Lemma: nan
# GT: quit 	 GTLemma: quit
# Word: over 	 Lemma: over
# GT: secretly 	 GTLemma: secretly
# Word: name 	 Lemma: name
# GT: foot 	 GTLemma: foot
# Word: more 	 Lemma: more
# GT: shoe 	 GTLemma: shoe
# Word: a 	 Lemma: a
# GT: cry 	 GTLemma: cry
# Word: more 	 Lemma: more
# GT: wallet 	 GTLemma: wallet
# Word: life 	 Lemma: life
# GT: cigarette 	 GTLemma: cigarette
# Word: been 	 Lemma: be
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: temper 	 GTLemma: temper
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: play 	 GTLemma: play
# Word: nan 	 Lemma: nan
# GT: learn 	 GTLemma: learn
# Word: nan 	 Lemma: nan
# GT: real 	 GTLemma: real
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: run 	 GTLemma: run
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: sometimes 	 GTLemma: sometimes
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: night 	 GTLemma: night
# Word: nan 	 Lemma: nan
# GT: silent 	 GTLemma: silent
# Word: nan 	 Lemma: nan
# GT: sprinkler 	 GTLemma: sprinkler
# Word: nan 	 Lemma: nan
# GT: enjoy 	 GTLemma: enjoy
# Word: nan 	 Lemma: nan
# GT: freedom 	 GTLemma: freedom
# Word: nan 	 Lemma: nan
# GT: perfect 	 GTLemma: perfect
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: occur 	 GTLemma: occur
# Word: nan 	 Lemma: nan
# GT: horrify 	 GTLemma: horrify
# Word: nan 	 Lemma: nan
# GT: light 	 GTLemma: light
# Word: nan 	 Lemma: nan
# GT: figure 	 GTLemma: figure
# Word: nan 	 Lemma: nan
# GT: dog 	 GTLemma: dog
# Word: nan 	 Lemma: nan
# GT: suburban 	 GTLemma: suburban
# Word: nan 	 Lemma: nan
# GT: person 	 GTLemma: person
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: hand 	 GTLemma: hand
# Word: nan 	 Lemma: nan
# GT: face 	 GTLemma: face
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: compose 	 GTLemma: compose
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: shoe 	 GTLemma: shoe
# Word: nan 	 Lemma: nan
# GT: cry 	 GTLemma: cry
# Word: nan 	 Lemma: nan
# GT: street 	 GTLemma: street
# Word: nan 	 Lemma: nan
# GT: never 	 GTLemma: never
# Word: nan 	 Lemma: nan
# GT: pass 	 GTLemma: pass
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: cutoff 	 GTLemma: cutoff
# Word: nan 	 Lemma: nan
# GT: dig 	 GTLemma: dig
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: vest 	 GTLemma: vest
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: pocket 	 GTLemma: pocket
# Word: nan 	 Lemma: nan
# GT: check 	 GTLemma: check
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: front 	 GTLemma: front
# Word: nan 	 Lemma: nan
# GT: launder 	 GTLemma: launder
# Word: nan 	 Lemma: nan
# GT: open 	 GTLemma: open
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: hunker 	 GTLemma: hunker
# Word: nan 	 Lemma: nan
# GT: crouch 	 GTLemma: crouch
# Word: nan 	 Lemma: nan
# GT: ground 	 GTLemma: ground
# Word: nan 	 Lemma: nan
# GT: wind 	 GTLemma: wind
# Word: nan 	 Lemma: nan
# GT: stop 	 GTLemma: stop
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: brand 	 GTLemma: brand
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: strike 	 GTLemma: strike
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: tell 	 GTLemma: tell
# Word: nan 	 Lemma: nan
# GT: immediately 	 GTLemma: immediately
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: happen 	 GTLemma: happen
# Word: nan 	 Lemma: nan
# GT: close 	 GTLemma: close
# Word: nan 	 Lemma: nan
# GT: lucky 	 GTLemma: lucky
# Word: nan 	 Lemma: nan
# GT: surprise 	 GTLemma: surprise
# Word: nan 	 Lemma: nan
# GT: fight 	 GTLemma: fight
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: mean 	 GTLemma: mean
# Word: nan 	 Lemma: nan
# GT: bad 	 GTLemma: bad
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: start 	 GTLemma: start
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: north 	 GTLemma: north
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: find 	 GTLemma: find
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cool 	 GTLemma: cool
# Word: nan 	 Lemma: nan
# GT: horse 	 GTLemma: horse
# Word: nan 	 Lemma: nan
# GT: love 	 GTLemma: love
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: ice 	 GTLemma: ice
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: want 	 GTLemma: want
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: stuff 	 GTLemma: stuff
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: thing 	 GTLemma: thing
# Word: nan 	 Lemma: nan
# GT: home 	 GTLemma: home
# Word: nan 	 Lemma: nan
# GT: ugly 	 GTLemma: ugly
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: still 	 GTLemma: still
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: sweet 	 GTLemma: sweet
# Word: nan 	 Lemma: nan
# GT: almost 	 GTLemma: almost
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: year 	 GTLemma: year
# Word: nan 	 Lemma: nan
# GT: license 	 GTLemma: license
# Word: nan 	 Lemma: nan
# GT: right 	 GTLemma: right
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: give 	 GTLemma: give
# Word: nan 	 Lemma: nan
# GT: ride 	 GTLemma: ride
# Word: nan 	 Lemma: nan
# GT: get 	 GTLemma: get
# Word: nan 	 Lemma: nan
# GT: lot 	 GTLemma: lot
# Word: nan 	 Lemma: nan
# GT: road 	 GTLemma: road
# Word: nan 	 Lemma: nan
# GT: car 	 GTLemma: car
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: one 	 GTLemma: one
# Word: nan 	 Lemma: nan
# GT: place 	 GTLemma: place
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: horrible 	 GTLemma: horrible
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: fifty 	 GTLemma: fifty
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: live 	 GTLemma: live
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: door 	 GTLemma: door
# Word: nan 	 Lemma: nan
# GT: quietly 	 GTLemma: quietly
# Word: nan 	 Lemma: nan
# GT: soon 	 GTLemma: soon
# Word: nan 	 Lemma: nan
# GT: blare 	 GTLemma: blare
# Word: nan 	 Lemma: nan
# GT: blue 	 GTLemma: blue
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: turn 	 GTLemma: turn
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: pull 	 GTLemma: pull
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: threat 	 GTLemma: threat
# Word: nan 	 Lemma: nan
# GT: take 	 GTLemma: take
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: hard 	 GTLemma: hard
# Word: nan 	 Lemma: nan
# GT: heat 	 GTLemma: heat
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: afraid 	 GTLemma: afraid
# Word: nan 	 Lemma: nan
# GT: see 	 GTLemma: see
# Word: nan 	 Lemma: nan
# GT: crook 	 GTLemma: crook
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: girl 	 GTLemma: girl
# Word: nan 	 Lemma: nan
# GT: carton 	 GTLemma: carton
# Word: nan 	 Lemma: nan
# GT: kiss 	 GTLemma: kiss
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: smoke 	 GTLemma: smoke
# Word: nan 	 Lemma: nan
# GT: outside 	 GTLemma: outside
# Word: nan 	 Lemma: nan
# GT: little 	 GTLemma: little
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: beautiful 	 GTLemma: beautiful
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: keep 	 GTLemma: keep
# Word: nan 	 Lemma: nan
# GT: cigarette 	 GTLemma: cigarette
# Word: nan 	 Lemma: nan
# GT: beer 	 GTLemma: beer
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: long 	 GTLemma: long
# Word: nan 	 Lemma: nan
# GT: come 	 GTLemma: come
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: sorry 	 GTLemma: sorry
# Word: nan 	 Lemma: nan
# GT: need 	 GTLemma: need
# Word: nan 	 Lemma: nan
# GT: morning 	 GTLemma: morning
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: map 	 GTLemma: map
# Word: nan 	 Lemma: nan
# GT: mile 	 GTLemma: mile
# Word: nan 	 Lemma: nan
# GT: half 	 GTLemma: half
# Word: nan 	 Lemma: nan
# GT: back 	 GTLemma: back
# Word: nan 	 Lemma: nan
# GT: pretty 	 GTLemma: pretty
# Word: nan 	 Lemma: nan
# GT: fine 	 GTLemma: fine
# Word: nan 	 Lemma: nan
# GT: paper 	 GTLemma: paper
# Word: nan 	 Lemma: nan
# GT: third 	 GTLemma: third
# Word: nan 	 Lemma: nan
# GT: pack 	 GTLemma: pack
# Word: nan 	 Lemma: nan
# GT: new 	 GTLemma: new
# Word: nan 	 Lemma: nan
# GT: match 	 GTLemma: match
# Word: nan 	 Lemma: nan
# GT: goodbye 	 GTLemma: goodbye
# Word: nan 	 Lemma: nan
# GT: great 	 GTLemma: great
# Word: nan 	 Lemma: nan
# GT: know 	 GTLemma: know
# Word: nan 	 Lemma: nan
# GT: say 	 GTLemma: say
# Word: nan 	 Lemma: nan
# GT: walk 	 GTLemma: walk
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: kind 	 GTLemma: kind
# Word: nan 	 Lemma: nan
# GT: think 	 GTLemma: think
# Word: nan 	 Lemma: nan
# GT: vet 	 GTLemma: vet
# Word: nan 	 Lemma: nan
# GT: cross 	 GTLemma: cross
# Word: nan 	 Lemma: nan
# GT: seem 	 GTLemma: seem
# Word: nan 	 Lemma: nan
# GT: visit 	 GTLemma: visit
# Word: nan 	 Lemma: nan
# GT: scary 	 GTLemma: scary
# Word: nan 	 Lemma: nan
# GT: opposite 	 GTLemma: opposite
# Word: nan 	 Lemma: nan
# GT: man 	 GTLemma: man
# Word: nan 	 Lemma: nan
# GT: grim 	 GTLemma: grim
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: nice 	 GTLemma: nice
# Word: nan 	 Lemma: nan
# GT: go 	 GTLemma: go
# Word: nan 	 Lemma: nan
# GT: apartment 	 GTLemma: apartment
# Word: nan 	 Lemma: nan
# GT: yard 	 GTLemma: yard
# Word: nan 	 Lemma: nan
# GT: loose 	 GTLemma: loose
# Word: nan 	 Lemma: nan
# GT: use 	 GTLemma: use
# Word: nan 	 Lemma: nan
# GT: would 	 GTLemma: would
# Word: nan 	 Lemma: nan
# GT: gas 	 GTLemma: gas
# Word: nan 	 Lemma: nan
# GT: baby 	 GTLemma: baby
# Word: nan 	 Lemma: nan
# GT: seven 	 GTLemma: seven
# Word: nan 	 Lemma: nan
# GT: hold 	 GTLemma: hold
# Word: nan 	 Lemma: nan
# GT: quit 	 GTLemma: quit
# Total missing values: 1380

# %% [markdown]
# ## Analyze human vs. GPT2-XL distributions

# %% [markdown]
# ### Load file of cleaned data

# %%
# save lemmatized human-model results
human_cleaned_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior_lemmatized.csv')
df_human_cleaned = pd.read_csv(human_cleaned_fn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # save lemmatized human-model results
# ----> 2 human_cleaned_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-cleaned-behavior_lemmatized.csv')
#       3 df_human_cleaned = pd.read_csv(human_cleaned_fn)
#
# NameError: name 'behavioral_dir' is not defined

# %% [markdown]
# ### Compare human and model prediction distributions and save

# %%
WINDOW_SIZE = 25

df_comparison = []
df_human_cleaned['response'] = df_human_cleaned['response'].apply(lambda x: strip_punctuation(x) if isinstance(x, str) else '')
    
for model_name in model_names:

    print (f'{model_name}')

    # now load a model to compare to 
    tokenizer, model = nlp.load_clm_model(
        model_name='gpt2' if 'prosody' in model_name else model_name, 
        cache_dir=CACHE_DIR)
    
    # go through the each modality word index
    for (modality, response_index), df in df_human_cleaned.groupby(['modality', 'word_index']):
        
        # get all responses for current index across both modalities
        all_responses = df_human_cleaned[df_human_cleaned['word_index'] == response_index]['response'].tolist()
        all_responses = list(filter(None, all_responses))
    
        # grab responses for the current modality
        modality_responses = df['response'].apply(strip_punctuation)
        ground_truth = df['ground_truth'].unique().tolist()[0]
        
        # prosody models can't be run with less than 4 tokens
        if 'prosody' in model_name and response_index < 4:
            continue

        # load the logits for the current response
        model_logits = load_logits(models_dir, model_name, TASK, WINDOW_SIZE, response_index) #response_index - 1)
        
        # now compare the two and add it to the dataframe
        df_compare = compare_human_model_distributions(tokenizer, word_model, modality_responses, all_responses, model_logits, ground_truth)
        df_compare['model_name'] = model_name
        df_compare['modality'] = modality
        df_compare['word_index'] = response_index
        df_compare[['entropy_group', 'accuracy_group', 'ground_truth']] = df[['entropy_group', 'accuracy_group', 'ground_truth']].iloc[0]
        
        df_comparison.append(df_compare)

# lastly 
df_comparison = pd.concat(df_comparison).reset_index(drop=True)

if 'prosody' in model_names[0]:
    out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-analyzed-behavior_window-size-{WINDOW_SIZE}_human-prosody-model-distributions-lemmatized.csv')
else:
    out_fn = os.path.join(behavioral_dir, f'task-{TASK}_group-analyzed-behavior_window-size-{WINDOW_SIZE}_human-model-distributions-lemmatized.csv')

df_comparison.to_csv(out_fn, index=False)
# Out:
# helsinki-prosody_scratch-gpt2_joint-loss_prosody-embed
# helsinki-prosody_scratch-gpt2_clm-loss_prosody-embed
# helsinki-prosody_scratch-gpt2_clm-loss_no-prosody-embed
# gigaspeech-prosody_scratch-gpt2_joint-loss_prosody-embed
# gigaspeech-prosody_scratch-gpt2_clm-loss_prosody-embed
# gigaspeech-prosody_scratch-gpt2_clm-loss_no-prosody-embed
