# %%
# %load_ext autoreload
import os, sys, glob
import json
import re
import numpy as np
import pandas as pd
import ast

sys.path.append('/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavioral/code/utils/')
sys.path.append('/dartfs/rc/lab/F/FinnLab/tommy/utils/gentle')

import gentle
from narratives_utils import *
from text_utils import get_pos_tags, get_lemma
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set directories

# %%
EXPERIMENT_NAME = 'next-word-prediction'
EXPERIMENT_VERSION = 'pilot-version-04'
TASK = 'black'

base_dir = '/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavioral/'
gentle_dir = os.path.join(base_dir, 'stimuli', 'gentle')
results_dir = os.path.join(base_dir, 'experiments',  EXPERIMENT_NAME, 'results', EXPERIMENT_VERSION, TASK)
preproc_dir = os.path.join(base_dir, 'stimuli', 'preprocessed')

out_dir = os.path.join(base_dir, 'derivatives', EXPERIMENT_NAME, EXPERIMENT_VERSION, TASK)
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# for huggingface
cache_dir = '/dartfs/rc/lab/F/FinnLab/tommy/models/huggingface/transformers'

# %% [markdown]
# Load transcript

# %%
transcript = pd.read_csv(os.path.join(preproc_dir, TASK, f'{TASK}_transcript_preprocessed.csv'))
transcript_words = transcript['Word_Written'].values

# %% [markdown]
# # Get data for stories

# %%
def load_participant_results(sub_dir, sub):
    # load and filter down to response trials
    df_results = pd.read_csv(os.path.join(sub_dir, f'{sub}_next-word-prediction.csv')).fillna(False)
    prolific_id = list(set(df_results['prolific_id']))
    
    df_results = df_results[df_results['critical_trial']]
    
    # convert string to dictionary
    df_results['response'] = df_results['response'].apply(ast.literal_eval)

    # filter down to the expeirment get the responses
    df_results = df_results[df_results['experiment_phase'] == 'experiment']
    df_results['response'] = [d.get('Q0') for d in df_results['response']]
    
    df_results['transcript_index'] = df_results['transcript_index'].astype(int) - 1
    
    return prolific_id[0], df_results

def add_word_response(dict, key, value):
    
    if key in dict:
        dict[key].append(value)
    else:
        dict[key] = [value]
        
    return dict

# %% [markdown]
# Load data for all modalities

# %%
MODALITIES = ['audio', 'text']

# modalities_dict = {}

df_results = pd.DataFrame(columns=['modality', 'subject',  'transcript_index', 'response', 'ground_truth'])

for mod in MODALITIES:
    
    # go through each task and get participant data
    sub_dirs = sorted(glob.glob(os.path.join(results_dir, mod, '*sub*')))

    accuracy_stack = []
    transcript_responses = {}
    transcript_accuracy = {}

    for sub_dir in sub_dirs:
        sub = os.path.basename(sub_dir)
        
        prolific_id, results = load_participant_results(sub_dir, sub)
        results['response'] = results['response'].str.lower()
        
        # calculate prediction accuracy
#         accuracy = np.sum(results['current_word'] == results['response']) / len(results['current_word'])
#         accuracy = np.asarray(results['current_word'] == results['response']) #/ len(results['current_word'])
#         accuracy_stack.append(accuracy)
        
        for index, response in results[['transcript_index', 'response']].values:
            
            df_results.loc[len(df_results)] = {
                'modality': mod,
                'subject': sub,
                'transcript_index': index,
                'response': response,
                'ground_truth': transcript_words[index].lower()
            }
#             transcript_responses = add_word_response(transcript_responses, index, response)
            
#             accuracy = np.asarray(response == transcript_words[index])
            
#             transcript_accuracy = add_word_response(transcript_accuracy, index, accuracy)
            
#     modalities_dict[mod] = {
#         'transcript': transcript_words,
#         'accuracy': transcript_accuracy, #np.stack(accuracy_stack),
#         'responses': transcript_responses
#     }

# %% [markdown]
# # Check variation in first letter

# %%
df_stack = []

for mod in MODALITIES:
    
    transcript_words = modalities_dict[mod]['transcript']
    
    phoneme_counts = []
    phoneme_accuracy = []
    phoneme_wrong_accuracy = []
    phoneme_wrong_variation = []
    
    for idx, responses in modalities_dict[mod]['responses'].items():
        # grab the first letter of the provided word
        predicted_phoneme = [word[:1] for word in responses]
        unique, counts = np.unique(predicted_phoneme, return_counts=True)
        
        phoneme_counts.append(variation)
        
        
        variation = len(unique) / len(responses)
        
        all_accuracy = np.asarray([word[:1] == transcript_words[idx][:1] for word in responses])
        all_accuracy = np.sum(all_accuracy) / len(all_accuracy)
        
        phoneme_accuracy.append(all_accuracy)
        
        
        # now look at wrong responses
        wrong_responses = np.where(np.asarray(responses) != transcript_words[idx])[0]
        
        if len(wrong_responses) >= 1:
            predicted_wrong_responses = [word[:1] for word in np.asarray(responses)[wrong_responses].tolist()]

            wrong_unique = np.unique(predicted_wrong_responses)
            wrong_variation = len(wrong_unique) / len(wrong_responses)

            wrong_accuracy = np.asarray([phoneme == transcript_words[idx][:1] for phoneme in predicted_wrong_responses])
            wrong_accuracy = np.sum(wrong_accuracy) / len(wrong_accuracy)
        else:
            wrong_variation = np.nan
            wrong_accuracy = np.nan
        
        phoneme_wrong_accuracy.append(wrong_accuracy)
        phoneme_wrong_variation.append(wrong_variation)
        

        
    modalities_dict[mod]['phoneme_counts'] = phoneme_counts.copy()
        
    df = pd.DataFrame(
        np.stack((np.repeat(mod, len(phoneme_counts)),
                  np.asarray(phoneme_counts),
                  np.asarray(phoneme_accuracy),
                  np.asarray(phoneme_wrong_variation), 
                  np.asarray(phoneme_wrong_accuracy))).T, 
        columns=['modality', 'phoneme_counts', 'phoneme_accuracy', 'wrong_variation', 'wrong_accuracy']
    )
    
    df_stack.append(df)
    
df_stack = pd.concat(df_stack).reset_index()
df_stack['phoneme_counts'] = df_stack['phoneme_counts'].astype(float)
df_stack['phoneme_accuracy'] = df_stack['phoneme_accuracy'].astype(float)
df_stack['wrong_accuracy'] = df_stack['wrong_accuracy'].astype(float)
df_stack['wrong_variation'] = df_stack['wrong_variation'].astype(float)

# %% [markdown]
# Plot wrong answers

# %%
sns.displot(df_stack, x="wrong_variation", hue="modality", kind='hist', alpha=0.5)
plt.xlabel('Wrong Variation (0-1)')
plt.title('Phoneme variation by condition - wrong answers')
# Out:
# Text(0.5, 1.0, 'Phoneme variation by condition - wrong answers')

# %%
sns.displot(df_stack, x="wrong_accuracy", hue="modality", kind='hist', alpha=0.5)
plt.xlabel('Wrong Accuracy (0-1)')
plt.title('Phoneme accuracy by condition - wrong answers')
# Out:
# Text(0.5, 1.0, 'Phoneme accuracy by condition - wrong answers')

# %%
sns.displot(df_stack, x="phoneme_accuracy", hue="modality", kind='kde')
plt.xlabel('Accuracy (0-1)')
plt.title('Phoneme accuracy by condition - Before')
# Out:
# Text(0.5, 1.0, 'Phoneme accuracy by condition - Before')

# %%
sns.displot(df_stack, x="phoneme_counts", hue="modality", kind='kde')
plt.xlabel('Variation (0-1)')
plt.title('Phoneme variation by condition - Before')
# Out:
# Text(0.5, 1.0, 'Phoneme variation by condition - Before')

# %% [markdown]
# # Find overlap in modality distributions

# %%
def get_phoneme_counts(response):
    predicted_phoneme = [word[:1] for word in response]
    unique, counts = np.unique(predicted_phoneme, return_counts=True) 
    return unique, counts

# %%
def get_phoneme_stats(responses, ground_truth):
    
    phonemes, counts = get_phoneme_counts(responses)
    
    # get the variation in responses
    # this is the number of unique phonemes over the number of responses 
    # 0 = less variation, 
    # 1 = more varation variation
    variation = len(phonemes) / len(responses)
    
    # number of correct
    accuracy = np.asarray([word[:1] == ground_truth[:1] for word in responses])
    accuracy = np.sum(accuracy) / len(accuracy)
    
    # get wrong answers
    wrong_idxs = np.where(np.asarray(responses) != ground_truth)[0]
    wrong_responses = np.asarray(responses)[wrong_idxs].tolist()
    
    wrong_phonemes, wrong_counts = get_phoneme_counts(wrong_responses)
    
    try:
    
        wrong_variation = len(wrong_unique) / len(wrong_responses)

        wrong_accuracy = np.asarray([word[:1] == ground_truth[:1] for word in wrong_responses])
        wrong_accuracy = np.sum(wrong_accuracy) / len(wrong_accuracy)
    except:
        wrong_variation = np.nan
        wrong_accuracy = np.nan
    
    
    return (phonemes, counts, variation, accuracy), (wrong_phonemes, wrong_counts, wrong_variation, wrong_accuracy)
    
#     # look at wrong responses 
#     wrong_idxs = np.where(np.asarray(responses) != ground_truth)[0]
#     wrong_responses = 
    
#     if len(wrong_responses) >= 1:
#         predicted_wrong_responses = [word[:1] for word in np.asarray(responses)[wrong_idxs].tolist()]

#         wrong_unique = np.unique(predicted_wrong_responses)
#         wrong_variation = len(wrong_unique) / len(wrong_responses)

#         wrong_accuracy = np.asarray([phoneme == transcript_words[idx][:1] for phoneme in predicted_wrong_responses])
#         wrong_accuracy = np.sum(wrong_accuracy) / len(wrong_accuracy)
#     else:
#         wrong_variation = np.nan
#         wrong_accuracy = np.nan

# %%
audio_response
# Out:
# ['right',
#  'road',
#  'road',
#  'really',
#  'road',
#  'road',
#  'real',
#  'road',
#  'race',
#  'real',
#  'road',
#  'really',
#  'really big ',
#  'road',
#  'regular',
#  'real',
#  'road',
#  'rural',
#  'road',
#  'road',
#  'rich',
#  'really',
#  'long',
#  'radio',
#  'road']

# %%
audio_wrong
# Out:
# (array(['c', 'h', 'i', 'o', 's'], dtype='<U1'),
#  array([1, 1, 1, 1, 2]),
#  0.5,
#  0.16666666666666666)

# %%
fisher_exact(np.stack([audio_dist, text_dist]))
# Out:
# (nan, 1.0)

# %%
def compare_frequency_correct(correct, a, b):
    
    union = np.union1d(text_wrong[0],audio_wrong[0])
    
    correct_idx = np.where(union != correct)[0]
    
    if len(a[0]):
        a_correct_idx = np.where(a[0] == correct)[0]
        a_incorrect_idx = np.where(a[0] != correct)[0]
        
        if len(a_correct_idx):
            a_correct = a[1][a_correct_idx][0]
        else:
            a_correct = 0
            
        if len(a_incorrect_idx):
            a_incorrect = np.sum(a[1][a_incorrect_idx])
        else:
            a_incorrect = 0
    else:
        a_correct = 0
        a_incorrect = 0
        
    if len(b[0]):
        b_correct_idx = np.where(b[0] == correct)[0]
        b_incorrect_idx = np.where(b[0] != correct)[0]
        
        if len(b_correct_idx):
            b_correct = b[1][b_correct_idx][0]
        else:
            b_correct = 0
        
        if len(b_incorrect_idx):
            b_incorrect = np.sum(b[1][b_incorrect_idx])
        else:
            b_incorrect = 0
    else:
        b_correct = 0
        b_incorrect = 0
    
    return (a_correct+1, a_incorrect+1), (b_correct+1, b_incorrect+1)

# %%
from scipy.stats import ttest_ind, f_oneway
from scipy.stats import chisquare, fisher_exact, power_divergence

## different ways to threshold
threshold = lambda x: len(x) < 8
max_threshold = lambda x: (max(x) / sum(x)) < 0.7
pval_threshold = lambda x: x > 0.15
number_threshold = lambda x: np.sum(x) >= 5 # and np.sum(x) <= 2
item_threshold = lambda x,y: abs(x-y) <= 8


# set up dataframes
response_idxs = sorted(df_results['transcript_index'].unique())
valid_idxs = []

df_valid = pd.DataFrame(
    columns=['idx', 'modality', 'phonemes', 'counts', 'variation', 'accuracy']
)

for idx in response_idxs:
    
    # get ground truth word
    ground_truth = transcript_words[idx]
    correct_phoneme = ground_truth[:1]
    
    # get responses for each
    
    audio_response = modalities_dict['audio']['responses'][idx]
    text_response = modalities_dict['text']['responses'][idx]
#     audio_text_response = modalities_dict['audio-text']['responses'][idx]
    
    # phonemes, counts, variation, accuracy
    audio_stats, audio_wrong = get_phoneme_stats(audio_response, ground_truth)
    text_stats, text_wrong = get_phoneme_stats(text_response, ground_truth)
#     audio_text_stats, audio_text_wrong = get_phoneme_stats(audio_text_response, ground_truth)
    
    audio_dist, text_dist =  compare_frequency_correct(correct_phoneme, audio_wrong, text_wrong)
    
    stat, pval = fisher_exact(np.stack([audio_dist, text_dist]), alternative='two-sided')
    
#     stat, pval = chisquare(audio_dist, text_dist)
    
    item_bool = np.all([item_threshold(x,y) for x, y in zip(audio_dist, text_dist)])
    
#     if not (number_threshold(audio_wrong[1]) and number_threshold(text_wrong[1])):
#         continue

    if np.isnan(pval):
        pval=0
    
    lengths_equal = (threshold(audio_stats[1]) and 
                     threshold(text_stats[1]) and
                     threshold(audio_text_stats[1]))
    
    max_equal = (max_threshold(audio_stats[1]) and 
                 max_threshold(text_stats[1]) and
                 max_threshold(audio_text_stats[1])
                )
    
#     if (audio_dist[0] <= text_dist[0]):
    if pval_threshold(pval): # and item_bool: # and max_equal:
#         print (audio_dist, text_dist)
        
        df_valid.loc[len(df_valid)] = [idx, 'audio', *audio_wrong]
        df_valid.loc[len(df_valid)] = [idx, 'text', *text_wrong]
#         df_valid.loc[len(df_valid)] = [idx, 'audio_text', *audio_text_wrong]

# %%
len(np.unique(df_valid['idx'])) / len(response_idxs)
# Out:
# 0.42414355628058725

# %%
sns.displot(df_valid, x='variation', hue='modality', kind='kde')
plt.xlabel('Variation (0-1)')
plt.title('Wrong answers variation - After Fishers Exact >0.15 (40% of words left)')
# Out:
# Text(0.5, 1.0, 'Wrong answers variation - After Fishers Exact >0.15 (40% of words left)')

# %%
sns.displot(df_valid, x='accuracy', hue='modality', kind='kde')
plt.xlabel('Accuracy (0-1)')
plt.title('Phoneme accuracy - Fishers Exact >0.15 (40% of words left)')
# Out:
# Text(0.5, 1.0, 'Phoneme accuracy - Fishers Exact >0.15 (40% of words left)')

# %% [markdown]
# # Test transformer predictions

# %%
import torch
from torch.nn import functional as F
from scipy.special import rel_entr
from scipy import stats

def get_transformer_model(model_name, cache_dir=None):
    '''
    Use a model from the sentence-transformers library to get
    sentence embeddings. Models used are trained on a next-sentence
    prediction task and evaluate the likelihood of S2 following S1.
    '''
    # set the path of where to download models
    # this NEEDS to be run before loading from transformers
    if cache_dir:
        os.environ['TRANSFORMERS_CACHE'] = cache_dir
    from transformers import AutoTokenizer, AutoModelForCausalLM

    # load a tokenizer and a model
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name)
    
    return tokenizer, model

def get_model_prediction(inputs, model, tokenizer, out_fn=None):
    
    tokens = tokenizer(inputs, return_tensors="pt")
    
    with torch.no_grad():
        logits = model(**tokens).logits[:, -1, :]
    
    probs = F.softmax(logits, dim=-1)
    pred_id = logits.argmax().item()
    pred_word = tokenizer.decode(pred_id)
    pred_prob = probs.max()
    
    # if we provide we save logits out
    if out_fn:
        torch.save(logits, out_fn)
    
    return pred_word, pred_prob, probs

def get_segment_indices(n_words, window_size):
    
    temp_window = 0
    indices = [
        np.arange(i-window_size, i) if i > window_size else np.arange(0, i)
        for i in range(1, n_words)
    ]
    return indices

def process_transcript(transcript, model, tokenizer, window_size, transcript_name, out_dir=None):
    
    prev_dist = None
    kl_divergence = None
    segments = get_segment_indices(n_words=len(transcript), window_size=window_size)
    df = pd.DataFrame([np.concatenate((np.array([transcript[0]]), np.repeat(np.nan, 3)))],
        columns=['predicted_word', 'probability', 'entropy', 'kl_divergence'])
    
    if out_dir and not os.path.exists(out_dir):
        # add the window size to the name
        out_dir = os.path.join(out_dir, f'window-size-{window_size}')
        os.makedirs(out_dir)
        
    out_fn = None
    
    for i, seg in enumerate(segments):
        inputs = transcript[seg].tolist()
        inputs = ' '.join(inputs)
        
        if out_dir:
            out_fn = os.path.join(out_dir, f'{transcript_name}_window-size-{window_size}_logits-{str(i).zfill(5)}.pt')
        
        word, prob, dist = get_model_prediction(inputs=inputs, model=model, tokenizer=tokenizer, out_fn=out_fn)
        entropy = stats.entropy(dist, axis=-1)[0]

        # set as previous distribution
        if not i or prev_dist is None:
            prev_dist = dist
        else:
            kl_divergence = rel_entr(dist, prev_dist).sum()

        df.loc[len(df)] = {
            'predicted_word': word,
            'probability': prob.item(),
            'entropy': entropy,
            'kl_divergence': kl_divergence.item() if kl_divergence is not None else None,
        }
        print (f'Processed segment {i+1}/{len(segments)}')
    return df

# %% [markdown]
# Get the tokenizer and model for GPT2

# %%
tokenizer, model = get_transformer_model(model_name='gpt2', cache_dir=cache_dir)

# %%
window_size = 100
# words = transcript['Word_Written'].values
model_out_dir = os.path.join(base_dir, 'derivatives', 'model-predictions', TASK, 'gpt2')

df = process_transcript(transcript=transcript, model=model, tokenizer=tokenizer, window_size=window_size, transcript_name=f'task-{TASK}', out_dir=model_out_dir)

out_fn = f'task-{TASK}_gpt2-predictions_context-{window_size}.csv'
df.to_csv(out_fn)
# Out:
# Processed segment 1/1540
# Processed segment 2/1540
# Processed segment 3/1540
# Processed segment 4/1540
# Processed segment 5/1540
# Processed segment 6/1540
# Processed segment 7/1540
# Processed segment 8/1540
# Processed segment 9/1540
# Processed segment 10/1540
# Processed segment 11/1540
# Processed segment 12/1540
# Processed segment 13/1540
# Processed segment 14/1540
# Processed segment 15/1540
# Processed segment 16/1540
# Processed segment 17/1540
# Processed segment 18/1540
# Processed segment 19/1540
# Processed segment 20/1540
# Processed segment 21/1540
# Processed segment 22/1540
# Processed segment 23/1540
# Processed segment 24/1540
# Processed segment 25/1540
# Processed segment 26/1540
# Processed segment 27/1540
# Processed segment 28/1540
# Processed segment 29/1540
# Processed segment 30/1540
# Processed segment 31/1540
# Processed segment 32/1540
# Processed segment 33/1540
# Processed segment 34/1540
# Processed segment 35/1540
# Processed segment 36/1540
# Processed segment 37/1540
# Processed segment 38/1540
# Processed segment 39/1540
# Processed segment 40/1540
# Processed segment 41/1540
# Processed segment 42/1540
# Processed segment 43/1540
# Processed segment 44/1540
# Processed segment 45/1540
# Processed segment 46/1540
# Processed segment 47/1540
# Processed segment 48/1540
# Processed segment 49/1540
# Processed segment 50/1540
# Processed segment 51/1540
# Processed segment 52/1540
# Processed segment 53/1540
# Processed segment 54/1540
# Processed segment 55/1540
# Processed segment 56/1540
# Processed segment 57/1540
# Processed segment 58/1540
# Processed segment 59/1540
# Processed segment 60/1540
# Processed segment 61/1540
# Processed segment 62/1540
# Processed segment 63/1540
# Processed segment 64/1540
# Processed segment 65/1540
# Processed segment 66/1540
# Processed segment 67/1540
# Processed segment 68/1540
# Processed segment 69/1540
# Processed segment 70/1540
# Processed segment 71/1540
# Processed segment 72/1540
# Processed segment 73/1540
# Processed segment 74/1540
# Processed segment 75/1540
# Processed segment 76/1540
# Processed segment 77/1540
# Processed segment 78/1540
# Processed segment 79/1540
# Processed segment 80/1540
# Processed segment 81/1540
# Processed segment 82/1540
# Processed segment 83/1540
# Processed segment 84/1540
# Processed segment 85/1540
# Processed segment 86/1540
# Processed segment 87/1540
# Processed segment 88/1540
# Processed segment 89/1540
# Processed segment 90/1540
# Processed segment 91/1540
# Processed segment 92/1540
# Processed segment 93/1540
# Processed segment 94/1540
# Processed segment 95/1540
# Processed segment 96/1540
# Processed segment 97/1540
# Processed segment 98/1540
# Processed segment 99/1540
# Processed segment 100/1540
# Processed segment 101/1540
# Processed segment 102/1540
# Processed segment 103/1540
# Processed segment 104/1540
# Processed segment 105/1540
# Processed segment 106/1540
# Processed segment 107/1540
# Processed segment 108/1540
# Processed segment 109/1540
# Processed segment 110/1540
# Processed segment 111/1540
# Processed segment 112/1540
# Processed segment 113/1540
# Processed segment 114/1540
# Processed segment 115/1540
# Processed segment 116/1540
# Processed segment 117/1540
# Processed segment 118/1540
# Processed segment 119/1540
# Processed segment 120/1540
# Processed segment 121/1540
# Processed segment 122/1540
# Processed segment 123/1540
# Processed segment 124/1540
# Processed segment 125/1540
# Processed segment 126/1540
# Processed segment 127/1540
# Processed segment 128/1540
# Processed segment 129/1540
# Processed segment 130/1540
# Processed segment 131/1540
# Processed segment 132/1540
# Processed segment 133/1540
# Processed segment 134/1540
# Processed segment 135/1540
# Processed segment 136/1540
# Processed segment 137/1540
# Processed segment 138/1540
# Processed segment 139/1540
# Processed segment 140/1540
# Processed segment 141/1540
# Processed segment 142/1540
# Processed segment 143/1540
# Processed segment 144/1540
# Processed segment 145/1540
# Processed segment 146/1540
# Processed segment 147/1540
# Processed segment 148/1540
# Processed segment 149/1540
# Processed segment 150/1540
# Processed segment 151/1540
# Processed segment 152/1540
# Processed segment 153/1540
# Processed segment 154/1540
# Processed segment 155/1540
# Processed segment 156/1540
# Processed segment 157/1540
# Processed segment 158/1540
# Processed segment 159/1540
# Processed segment 160/1540
# Processed segment 161/1540
# Processed segment 162/1540
# Processed segment 163/1540
# Processed segment 164/1540
# Processed segment 165/1540
# Processed segment 166/1540
# Processed segment 167/1540
# Processed segment 168/1540
# Processed segment 169/1540
# Processed segment 170/1540
# Processed segment 171/1540
# Processed segment 172/1540
# Processed segment 173/1540
# Processed segment 174/1540
# Processed segment 175/1540
# Processed segment 176/1540
# Processed segment 177/1540
# Processed segment 178/1540
# Processed segment 179/1540
# Processed segment 180/1540
# Processed segment 181/1540
# Processed segment 182/1540
# Processed segment 183/1540
# Processed segment 184/1540
# Processed segment 185/1540
# Processed segment 186/1540
# Processed segment 187/1540
# Processed segment 188/1540
# Processed segment 189/1540
# Processed segment 190/1540
# Processed segment 191/1540
# Processed segment 192/1540
# Processed segment 193/1540
# Processed segment 194/1540
# Processed segment 195/1540
# Processed segment 196/1540
# Processed segment 197/1540
# Processed segment 198/1540
# Processed segment 199/1540
# Processed segment 200/1540
# Processed segment 201/1540
# Processed segment 202/1540
# Processed segment 203/1540
# Processed segment 204/1540
# Processed segment 205/1540
# Processed segment 206/1540
# Processed segment 207/1540
# Processed segment 208/1540
# Processed segment 209/1540
# Processed segment 210/1540
# Processed segment 211/1540
# Processed segment 212/1540
# Processed segment 213/1540
# Processed segment 214/1540
# Processed segment 215/1540
# Processed segment 216/1540
# Processed segment 217/1540
# Processed segment 218/1540
# Processed segment 219/1540
# Processed segment 220/1540
# Processed segment 221/1540
# Processed segment 222/1540
# Processed segment 223/1540
# Processed segment 224/1540
# Processed segment 225/1540
# Processed segment 226/1540
# Processed segment 227/1540
# Processed segment 228/1540
# Processed segment 229/1540
# Processed segment 230/1540
# Processed segment 231/1540
# Processed segment 232/1540
# Processed segment 233/1540
# Processed segment 234/1540
# Processed segment 235/1540
# Processed segment 236/1540
# Processed segment 237/1540
# Processed segment 238/1540
# Processed segment 239/1540
# Processed segment 240/1540
# Processed segment 241/1540
# Processed segment 242/1540
# Processed segment 243/1540
# Processed segment 244/1540
# Processed segment 245/1540
# Processed segment 246/1540
# Processed segment 247/1540
# Processed segment 248/1540
# Processed segment 249/1540
# Processed segment 250/1540
# Processed segment 251/1540
# Processed segment 252/1540
# Processed segment 253/1540
# Processed segment 254/1540
# Processed segment 255/1540
# Processed segment 256/1540
# Processed segment 257/1540
# Processed segment 258/1540
# Processed segment 259/1540
# Processed segment 260/1540
# Processed segment 261/1540
# Processed segment 262/1540
# Processed segment 263/1540
# Processed segment 264/1540
# Processed segment 265/1540
# Processed segment 266/1540
# Processed segment 267/1540
# Processed segment 268/1540
# Processed segment 269/1540
# Processed segment 270/1540
# Processed segment 271/1540
# Processed segment 272/1540
# Processed segment 273/1540
# Processed segment 274/1540
# Processed segment 275/1540
# Processed segment 276/1540
# Processed segment 277/1540
# Processed segment 278/1540
# Processed segment 279/1540
# Processed segment 280/1540
# Processed segment 281/1540
# Processed segment 282/1540
# Processed segment 283/1540
# Processed segment 284/1540
# Processed segment 285/1540
# Processed segment 286/1540
# Processed segment 287/1540
# Processed segment 288/1540
# Processed segment 289/1540
# Processed segment 290/1540
# Processed segment 291/1540
# Processed segment 292/1540
# Processed segment 293/1540
# Processed segment 294/1540
# Processed segment 295/1540
# Processed segment 296/1540
# Processed segment 297/1540
# Processed segment 298/1540
# Processed segment 299/1540
# Processed segment 300/1540
# Processed segment 301/1540
# Processed segment 302/1540
# Processed segment 303/1540
# Processed segment 304/1540
# Processed segment 305/1540
# Processed segment 306/1540
# Processed segment 307/1540
# Processed segment 308/1540
# Processed segment 309/1540
# Processed segment 310/1540
# Processed segment 311/1540
# Processed segment 312/1540
# Processed segment 313/1540
# Processed segment 314/1540
# Processed segment 315/1540
# Processed segment 316/1540
# Processed segment 317/1540
# Processed segment 318/1540
# Processed segment 319/1540
# Processed segment 320/1540
# Processed segment 321/1540
# Processed segment 322/1540
# Processed segment 323/1540
# Processed segment 324/1540
# Processed segment 325/1540
# Processed segment 326/1540
# Processed segment 327/1540
# Processed segment 328/1540
# Processed segment 329/1540
# Processed segment 330/1540
# Processed segment 331/1540
# Processed segment 332/1540
# Processed segment 333/1540
# Processed segment 334/1540
# Processed segment 335/1540
# Processed segment 336/1540
# Processed segment 337/1540
# Processed segment 338/1540
# Processed segment 339/1540
# Processed segment 340/1540
# Processed segment 341/1540
# Processed segment 342/1540
# Processed segment 343/1540
# Processed segment 344/1540
# Processed segment 345/1540
# Processed segment 346/1540
# Processed segment 347/1540
# Processed segment 348/1540
# Processed segment 349/1540
# Processed segment 350/1540
# Processed segment 351/1540
# Processed segment 352/1540
# Processed segment 353/1540
# Processed segment 354/1540
# Processed segment 355/1540
# Processed segment 356/1540
# Processed segment 357/1540
# Processed segment 358/1540
# Processed segment 359/1540
# Processed segment 360/1540
# Processed segment 361/1540
# Processed segment 362/1540
# Processed segment 363/1540
# Processed segment 364/1540
# Processed segment 365/1540
# Processed segment 366/1540
# Processed segment 367/1540
# Processed segment 368/1540
# Processed segment 369/1540
# Processed segment 370/1540
# Processed segment 371/1540
# Processed segment 372/1540
# Processed segment 373/1540
# Processed segment 374/1540
# Processed segment 375/1540
# Processed segment 376/1540
# Processed segment 377/1540
# Processed segment 378/1540
# Processed segment 379/1540
# Processed segment 380/1540
# Processed segment 381/1540
# Processed segment 382/1540
# Processed segment 383/1540
# Processed segment 384/1540
# Processed segment 385/1540
# Processed segment 386/1540
# Processed segment 387/1540
# Processed segment 388/1540
# Processed segment 389/1540
# Processed segment 390/1540
# Processed segment 391/1540
# Processed segment 392/1540
# Processed segment 393/1540
# Processed segment 394/1540
# Processed segment 395/1540
# Processed segment 396/1540
# Processed segment 397/1540
# Processed segment 398/1540
# Processed segment 399/1540
# Processed segment 400/1540
# Processed segment 401/1540
# Processed segment 402/1540
# Processed segment 403/1540
# Processed segment 404/1540
# Processed segment 405/1540
# Processed segment 406/1540
# Processed segment 407/1540
# Processed segment 408/1540
# Processed segment 409/1540
# Processed segment 410/1540
# Processed segment 411/1540
# Processed segment 412/1540
# Processed segment 413/1540
# Processed segment 414/1540
# Processed segment 415/1540
# Processed segment 416/1540
# Processed segment 417/1540
# Processed segment 418/1540
# Processed segment 419/1540
# Processed segment 420/1540
# Processed segment 421/1540
# Processed segment 422/1540
# Processed segment 423/1540
# Processed segment 424/1540
# Processed segment 425/1540
# Processed segment 426/1540
# Processed segment 427/1540
# Processed segment 428/1540
# Processed segment 429/1540
# Processed segment 430/1540
# Processed segment 431/1540
# Processed segment 432/1540
# Processed segment 433/1540
# Processed segment 434/1540
# Processed segment 435/1540
# Processed segment 436/1540
# Processed segment 437/1540
# Processed segment 438/1540
# Processed segment 439/1540
# Processed segment 440/1540
# Processed segment 441/1540
# Processed segment 442/1540
# Processed segment 443/1540
# Processed segment 444/1540
# Processed segment 445/1540
# Processed segment 446/1540
# Processed segment 447/1540
# Processed segment 448/1540
# Processed segment 449/1540
# Processed segment 450/1540
# Processed segment 451/1540
# Processed segment 452/1540
# Processed segment 453/1540
# Processed segment 454/1540
# Processed segment 455/1540
# Processed segment 456/1540
# Processed segment 457/1540
# Processed segment 458/1540
# Processed segment 459/1540
# Processed segment 460/1540
# Processed segment 461/1540
# Processed segment 462/1540
# Processed segment 463/1540
# Processed segment 464/1540
# Processed segment 465/1540
# Processed segment 466/1540
# Processed segment 467/1540
# Processed segment 468/1540
# Processed segment 469/1540
# Processed segment 470/1540
# Processed segment 471/1540
# Processed segment 472/1540
# Processed segment 473/1540
# Processed segment 474/1540
# Processed segment 475/1540
# Processed segment 476/1540
# Processed segment 477/1540
# Processed segment 478/1540
# Processed segment 479/1540
# Processed segment 480/1540
# Processed segment 481/1540
# Processed segment 482/1540
# Processed segment 483/1540
# Processed segment 484/1540
# Processed segment 485/1540
# Processed segment 486/1540
# Processed segment 487/1540
# Processed segment 488/1540
# Processed segment 489/1540
# Processed segment 490/1540
# Processed segment 491/1540
# Processed segment 492/1540
# Processed segment 493/1540
# Processed segment 494/1540
# Processed segment 495/1540
# Processed segment 496/1540
# Processed segment 497/1540
# Processed segment 498/1540
# Processed segment 499/1540
# Processed segment 500/1540
# Processed segment 501/1540
# Processed segment 502/1540
# Processed segment 503/1540
# Processed segment 504/1540
# Processed segment 505/1540
# Processed segment 506/1540
# Processed segment 507/1540
# Processed segment 508/1540
# Processed segment 509/1540
# Processed segment 510/1540
# Processed segment 511/1540
# Processed segment 512/1540
# Processed segment 513/1540
# Processed segment 514/1540
# Processed segment 515/1540
# Processed segment 516/1540
# Processed segment 517/1540
# Processed segment 518/1540
# Processed segment 519/1540
# Processed segment 520/1540
# Processed segment 521/1540
# Processed segment 522/1540
# Processed segment 523/1540
# Processed segment 524/1540
# Processed segment 525/1540
# Processed segment 526/1540
# Processed segment 527/1540
# Processed segment 528/1540
# Processed segment 529/1540
# Processed segment 530/1540
# Processed segment 531/1540
# Processed segment 532/1540
# Processed segment 533/1540
# Processed segment 534/1540
# Processed segment 535/1540
# Processed segment 536/1540
# Processed segment 537/1540
# Processed segment 538/1540
# Processed segment 539/1540
# Processed segment 540/1540
# Processed segment 541/1540
# Processed segment 542/1540
# Processed segment 543/1540
# Processed segment 544/1540
# Processed segment 545/1540
# Processed segment 546/1540
# Processed segment 547/1540
# Processed segment 548/1540
# Processed segment 549/1540
# Processed segment 550/1540
# Processed segment 551/1540
# Processed segment 552/1540
# Processed segment 553/1540
# Processed segment 554/1540
# Processed segment 555/1540
# Processed segment 556/1540
# Processed segment 557/1540
# Processed segment 558/1540
# Processed segment 559/1540
# Processed segment 560/1540
# Processed segment 561/1540
# Processed segment 562/1540
# Processed segment 563/1540
# Processed segment 564/1540
# Processed segment 565/1540
# Processed segment 566/1540
# Processed segment 567/1540
# Processed segment 568/1540
# Processed segment 569/1540
# Processed segment 570/1540
# Processed segment 571/1540
# Processed segment 572/1540
# Processed segment 573/1540
# Processed segment 574/1540
# Processed segment 575/1540
# Processed segment 576/1540
# Processed segment 577/1540
# Processed segment 578/1540
# Processed segment 579/1540
# Processed segment 580/1540
# Processed segment 581/1540
# Processed segment 582/1540
# Processed segment 583/1540
# Processed segment 584/1540
# Processed segment 585/1540
# Processed segment 586/1540
# Processed segment 587/1540
# Processed segment 588/1540
# Processed segment 589/1540
# Processed segment 590/1540
# Processed segment 591/1540
# Processed segment 592/1540
# Processed segment 593/1540
# Processed segment 594/1540
# Processed segment 595/1540
# Processed segment 596/1540
# Processed segment 597/1540
# Processed segment 598/1540
# Processed segment 599/1540
# Processed segment 600/1540
# Processed segment 601/1540
# Processed segment 602/1540
# Processed segment 603/1540
# Processed segment 604/1540
# Processed segment 605/1540
# Processed segment 606/1540
# Processed segment 607/1540
# Processed segment 608/1540
# Processed segment 609/1540
# Processed segment 610/1540
# Processed segment 611/1540
# Processed segment 612/1540
# Processed segment 613/1540
# Processed segment 614/1540
# Processed segment 615/1540
# Processed segment 616/1540
# Processed segment 617/1540
# Processed segment 618/1540
# Processed segment 619/1540
# Processed segment 620/1540
# Processed segment 621/1540
# Processed segment 622/1540
# Processed segment 623/1540
# Processed segment 624/1540
# Processed segment 625/1540
# Processed segment 626/1540
# Processed segment 627/1540
# Processed segment 628/1540
# Processed segment 629/1540
# Processed segment 630/1540
# Processed segment 631/1540
# Processed segment 632/1540
# Processed segment 633/1540
# Processed segment 634/1540
# Processed segment 635/1540
# Processed segment 636/1540
# Processed segment 637/1540
# Processed segment 638/1540
# Processed segment 639/1540
# Processed segment 640/1540
# Processed segment 641/1540
# Processed segment 642/1540
# Processed segment 643/1540
# Processed segment 644/1540
# Processed segment 645/1540
# Processed segment 646/1540
# Processed segment 647/1540
# Processed segment 648/1540
# Processed segment 649/1540
# Processed segment 650/1540
# Processed segment 651/1540
# Processed segment 652/1540
# Processed segment 653/1540
# Processed segment 654/1540
# Processed segment 655/1540
# Processed segment 656/1540
# Processed segment 657/1540
# Processed segment 658/1540
# Processed segment 659/1540
# Processed segment 660/1540
# Processed segment 661/1540
# Processed segment 662/1540
# Processed segment 663/1540
# Processed segment 664/1540
# Processed segment 665/1540
# Processed segment 666/1540
# Processed segment 667/1540
# Processed segment 668/1540
# Processed segment 669/1540
# Processed segment 670/1540
# Processed segment 671/1540
# Processed segment 672/1540
# Processed segment 673/1540
# Processed segment 674/1540
# Processed segment 675/1540
# Processed segment 676/1540
# Processed segment 677/1540
# Processed segment 678/1540
# Processed segment 679/1540
# Processed segment 680/1540
# Processed segment 681/1540
# Processed segment 682/1540
# Processed segment 683/1540
# Processed segment 684/1540
# Processed segment 685/1540
# Processed segment 686/1540
# Processed segment 687/1540
# Processed segment 688/1540
# Processed segment 689/1540
# Processed segment 690/1540
# Processed segment 691/1540
# Processed segment 692/1540
# Processed segment 693/1540
# Processed segment 694/1540
# Processed segment 695/1540
# Processed segment 696/1540
# Processed segment 697/1540
# Processed segment 698/1540
# Processed segment 699/1540
# Processed segment 700/1540
# Processed segment 701/1540
# Processed segment 702/1540
# Processed segment 703/1540
# Processed segment 704/1540
# Processed segment 705/1540
# Processed segment 706/1540
# Processed segment 707/1540
# Processed segment 708/1540
# Processed segment 709/1540
# Processed segment 710/1540
# Processed segment 711/1540
# Processed segment 712/1540
# Processed segment 713/1540
# Processed segment 714/1540
# Processed segment 715/1540
# Processed segment 716/1540
# Processed segment 717/1540
# Processed segment 718/1540
# Processed segment 719/1540
# Processed segment 720/1540
# Processed segment 721/1540
# Processed segment 722/1540
# Processed segment 723/1540
# Processed segment 724/1540
# Processed segment 725/1540
# Processed segment 726/1540
# Processed segment 727/1540
# Processed segment 728/1540
# Processed segment 729/1540
# Processed segment 730/1540
# Processed segment 731/1540
# Processed segment 732/1540
# Processed segment 733/1540
# Processed segment 734/1540
# Processed segment 735/1540
# Processed segment 736/1540
# Processed segment 737/1540
# Processed segment 738/1540
# Processed segment 739/1540
# Processed segment 740/1540
# Processed segment 741/1540
# Processed segment 742/1540
# Processed segment 743/1540
# Processed segment 744/1540
# Processed segment 745/1540
# Processed segment 746/1540
# Processed segment 747/1540
# Processed segment 748/1540
# Processed segment 749/1540
# Processed segment 750/1540
# Processed segment 751/1540
# Processed segment 752/1540
# Processed segment 753/1540
# Processed segment 754/1540
# Processed segment 755/1540
# Processed segment 756/1540
# Processed segment 757/1540
# Processed segment 758/1540
# Processed segment 759/1540
# Processed segment 760/1540
# Processed segment 761/1540
# Processed segment 762/1540
# Processed segment 763/1540
# Processed segment 764/1540
# Processed segment 765/1540
# Processed segment 766/1540
# Processed segment 767/1540
# Processed segment 768/1540
# Processed segment 769/1540
# Processed segment 770/1540
# Processed segment 771/1540
# Processed segment 772/1540
# Processed segment 773/1540
# Processed segment 774/1540
# Processed segment 775/1540
# Processed segment 776/1540
# Processed segment 777/1540
# Processed segment 778/1540
# Processed segment 779/1540
# Processed segment 780/1540
# Processed segment 781/1540
# Processed segment 782/1540
# Processed segment 783/1540
# Processed segment 784/1540
# Processed segment 785/1540
# Processed segment 786/1540
# Processed segment 787/1540
# Processed segment 788/1540
# Processed segment 789/1540
# Processed segment 790/1540
# Processed segment 791/1540
# Processed segment 792/1540
# Processed segment 793/1540
# Processed segment 794/1540
# Processed segment 795/1540
# Processed segment 796/1540
# Processed segment 797/1540
# Processed segment 798/1540
# Processed segment 799/1540
# Processed segment 800/1540
# Processed segment 801/1540
# Processed segment 802/1540
# Processed segment 803/1540
# Processed segment 804/1540
# Processed segment 805/1540
# Processed segment 806/1540
# Processed segment 807/1540
# Processed segment 808/1540
# Processed segment 809/1540
# Processed segment 810/1540
# Processed segment 811/1540
# Processed segment 812/1540
# Processed segment 813/1540
# Processed segment 814/1540
# Processed segment 815/1540
# Processed segment 816/1540
# Processed segment 817/1540
# Processed segment 818/1540
# Processed segment 819/1540
# Processed segment 820/1540
# Processed segment 821/1540
# Processed segment 822/1540
# Processed segment 823/1540
# Processed segment 824/1540
# Processed segment 825/1540
# Processed segment 826/1540
# Processed segment 827/1540
# Processed segment 828/1540
# Processed segment 829/1540
# Processed segment 830/1540
# Processed segment 831/1540
# Processed segment 832/1540
# Processed segment 833/1540
# Processed segment 834/1540
# Processed segment 835/1540
# Processed segment 836/1540
# Processed segment 837/1540
# Processed segment 838/1540
# Processed segment 839/1540
# Processed segment 840/1540
# Processed segment 841/1540
# Processed segment 842/1540
# Processed segment 843/1540
# Processed segment 844/1540
# Processed segment 845/1540
# Processed segment 846/1540
# Processed segment 847/1540
# Processed segment 848/1540
# Processed segment 849/1540
# Processed segment 850/1540
# Processed segment 851/1540
# Processed segment 852/1540
# Processed segment 853/1540
# Processed segment 854/1540
# Processed segment 855/1540
# Processed segment 856/1540
# Processed segment 857/1540
# Processed segment 858/1540
# Processed segment 859/1540
# Processed segment 860/1540
# Processed segment 861/1540
# Processed segment 862/1540
# Processed segment 863/1540
# Processed segment 864/1540
# Processed segment 865/1540
# Processed segment 866/1540
# Processed segment 867/1540
# Processed segment 868/1540
# Processed segment 869/1540
# Processed segment 870/1540
# Processed segment 871/1540
# Processed segment 872/1540
# Processed segment 873/1540
# Processed segment 874/1540
# Processed segment 875/1540
# Processed segment 876/1540
# Processed segment 877/1540
# Processed segment 878/1540
# Processed segment 879/1540
# Processed segment 880/1540
# Processed segment 881/1540
# Processed segment 882/1540
# Processed segment 883/1540
# Processed segment 884/1540
# Processed segment 885/1540
# Processed segment 886/1540
# Processed segment 887/1540
# Processed segment 888/1540
# Processed segment 889/1540
# Processed segment 890/1540
# Processed segment 891/1540
# Processed segment 892/1540
# Processed segment 893/1540
# Processed segment 894/1540
# Processed segment 895/1540
# Processed segment 896/1540
# Processed segment 897/1540
# Processed segment 898/1540
# Processed segment 899/1540
# Processed segment 900/1540
# Processed segment 901/1540
# Processed segment 902/1540
# Processed segment 903/1540
# Processed segment 904/1540
# Processed segment 905/1540
# Processed segment 906/1540
# Processed segment 907/1540
# Processed segment 908/1540
# Processed segment 909/1540
# Processed segment 910/1540
# Processed segment 911/1540
# Processed segment 912/1540
# Processed segment 913/1540
# Processed segment 914/1540
# Processed segment 915/1540
# Processed segment 916/1540
# Processed segment 917/1540
# Processed segment 918/1540
# Processed segment 919/1540
# Processed segment 920/1540
# Processed segment 921/1540
# Processed segment 922/1540
# Processed segment 923/1540
# Processed segment 924/1540
# Processed segment 925/1540
# Processed segment 926/1540
# Processed segment 927/1540
# Processed segment 928/1540
# Processed segment 929/1540
# Processed segment 930/1540
# Processed segment 931/1540
# Processed segment 932/1540
# Processed segment 933/1540
# Processed segment 934/1540
# Processed segment 935/1540
# Processed segment 936/1540
# Processed segment 937/1540
# Processed segment 938/1540
# Processed segment 939/1540
# Processed segment 940/1540
# Processed segment 941/1540
# Processed segment 942/1540
# Processed segment 943/1540
# Processed segment 944/1540
# Processed segment 945/1540
# Processed segment 946/1540
# Processed segment 947/1540
# Processed segment 948/1540
# Processed segment 949/1540
# Processed segment 950/1540
# Processed segment 951/1540
# Processed segment 952/1540
# Processed segment 953/1540
# Processed segment 954/1540
# Processed segment 955/1540
# Processed segment 956/1540
# Processed segment 957/1540
# Processed segment 958/1540
# Processed segment 959/1540
# Processed segment 960/1540
# Processed segment 961/1540
# Processed segment 962/1540
# Processed segment 963/1540
# Processed segment 964/1540
# Processed segment 965/1540
# Processed segment 966/1540
# Processed segment 967/1540
# Processed segment 968/1540
# Processed segment 969/1540
# Processed segment 970/1540
# Processed segment 971/1540
# Processed segment 972/1540
# Processed segment 973/1540
# Processed segment 974/1540
# Processed segment 975/1540
# Processed segment 976/1540
# Processed segment 977/1540
# Processed segment 978/1540
# Processed segment 979/1540
# Processed segment 980/1540
# Processed segment 981/1540
# Processed segment 982/1540
# Processed segment 983/1540
# Processed segment 984/1540
# Processed segment 985/1540
# Processed segment 986/1540
# Processed segment 987/1540
# Processed segment 988/1540
# Processed segment 989/1540
# Processed segment 990/1540
# Processed segment 991/1540
# Processed segment 992/1540
# Processed segment 993/1540
# Processed segment 994/1540
# Processed segment 995/1540
# Processed segment 996/1540
# Processed segment 997/1540
# Processed segment 998/1540
# Processed segment 999/1540
# Processed segment 1000/1540
# Processed segment 1001/1540
# Processed segment 1002/1540
# Processed segment 1003/1540
# Processed segment 1004/1540
# Processed segment 1005/1540
# Processed segment 1006/1540
# Processed segment 1007/1540
# Processed segment 1008/1540
# Processed segment 1009/1540
# Processed segment 1010/1540
# Processed segment 1011/1540
# Processed segment 1012/1540
# Processed segment 1013/1540
# Processed segment 1014/1540
# Processed segment 1015/1540
# Processed segment 1016/1540
# Processed segment 1017/1540
# Processed segment 1018/1540
# Processed segment 1019/1540
# Processed segment 1020/1540
# Processed segment 1021/1540
# Processed segment 1022/1540
# Processed segment 1023/1540
# Processed segment 1024/1540
# Processed segment 1025/1540
# Processed segment 1026/1540
# Processed segment 1027/1540
# Processed segment 1028/1540
# Processed segment 1029/1540
# Processed segment 1030/1540
# Processed segment 1031/1540
# Processed segment 1032/1540
# Processed segment 1033/1540
# Processed segment 1034/1540
# Processed segment 1035/1540
# Processed segment 1036/1540
# Processed segment 1037/1540
# Processed segment 1038/1540
# Processed segment 1039/1540
# Processed segment 1040/1540
# Processed segment 1041/1540
# Processed segment 1042/1540
# Processed segment 1043/1540
# Processed segment 1044/1540
# Processed segment 1045/1540
# Processed segment 1046/1540
# Processed segment 1047/1540
# Processed segment 1048/1540
# Processed segment 1049/1540
# Processed segment 1050/1540
# Processed segment 1051/1540
# Processed segment 1052/1540
# Processed segment 1053/1540
# Processed segment 1054/1540
# Processed segment 1055/1540
# Processed segment 1056/1540
# Processed segment 1057/1540
# Processed segment 1058/1540
# Processed segment 1059/1540
# Processed segment 1060/1540
# Processed segment 1061/1540
# Processed segment 1062/1540
# Processed segment 1063/1540
# Processed segment 1064/1540
# Processed segment 1065/1540
# Processed segment 1066/1540
# Processed segment 1067/1540
# Processed segment 1068/1540
# Processed segment 1069/1540
# Processed segment 1070/1540
# Processed segment 1071/1540
# Processed segment 1072/1540
# Processed segment 1073/1540
# Processed segment 1074/1540
# Processed segment 1075/1540
# Processed segment 1076/1540
# Processed segment 1077/1540
# Processed segment 1078/1540
# Processed segment 1079/1540
# Processed segment 1080/1540
# Processed segment 1081/1540
# Processed segment 1082/1540
# Processed segment 1083/1540
# Processed segment 1084/1540
# Processed segment 1085/1540
# Processed segment 1086/1540
# Processed segment 1087/1540
# Processed segment 1088/1540
# Processed segment 1089/1540
# Processed segment 1090/1540
# Processed segment 1091/1540
# Processed segment 1092/1540
# Processed segment 1093/1540
# Processed segment 1094/1540
# Processed segment 1095/1540
# Processed segment 1096/1540
# Processed segment 1097/1540
# Processed segment 1098/1540
# Processed segment 1099/1540
# Processed segment 1100/1540
# Processed segment 1101/1540
# Processed segment 1102/1540
# Processed segment 1103/1540
# Processed segment 1104/1540
# Processed segment 1105/1540
# Processed segment 1106/1540
# Processed segment 1107/1540
# Processed segment 1108/1540
# Processed segment 1109/1540
# Processed segment 1110/1540
# Processed segment 1111/1540
# Processed segment 1112/1540
# Processed segment 1113/1540
# Processed segment 1114/1540
# Processed segment 1115/1540
# Processed segment 1116/1540
# Processed segment 1117/1540
# Processed segment 1118/1540
# Processed segment 1119/1540
# Processed segment 1120/1540
# Processed segment 1121/1540
# Processed segment 1122/1540
# Processed segment 1123/1540
# Processed segment 1124/1540
# Processed segment 1125/1540
# Processed segment 1126/1540
# Processed segment 1127/1540
# Processed segment 1128/1540
# Processed segment 1129/1540
# Processed segment 1130/1540
# Processed segment 1131/1540
# Processed segment 1132/1540
# Processed segment 1133/1540
# Processed segment 1134/1540
# Processed segment 1135/1540
# Processed segment 1136/1540
# Processed segment 1137/1540
# Processed segment 1138/1540
# Processed segment 1139/1540
# Processed segment 1140/1540
# Processed segment 1141/1540
# Processed segment 1142/1540
# Processed segment 1143/1540
# Processed segment 1144/1540
# Processed segment 1145/1540
# Processed segment 1146/1540
# Processed segment 1147/1540
# Processed segment 1148/1540
# Processed segment 1149/1540
# Processed segment 1150/1540
# Processed segment 1151/1540
# Processed segment 1152/1540
# Processed segment 1153/1540
# Processed segment 1154/1540
# Processed segment 1155/1540
# Processed segment 1156/1540
# Processed segment 1157/1540
# Processed segment 1158/1540
# Processed segment 1159/1540
# Processed segment 1160/1540
# Processed segment 1161/1540
# Processed segment 1162/1540
# Processed segment 1163/1540
# Processed segment 1164/1540
# Processed segment 1165/1540
# Processed segment 1166/1540
# Processed segment 1167/1540
# Processed segment 1168/1540
# Processed segment 1169/1540
# Processed segment 1170/1540
# Processed segment 1171/1540
# Processed segment 1172/1540
# Processed segment 1173/1540
# Processed segment 1174/1540
# Processed segment 1175/1540
# Processed segment 1176/1540
# Processed segment 1177/1540
# Processed segment 1178/1540
# Processed segment 1179/1540
# Processed segment 1180/1540
# Processed segment 1181/1540
# Processed segment 1182/1540
# Processed segment 1183/1540
# Processed segment 1184/1540
# Processed segment 1185/1540
# Processed segment 1186/1540
# Processed segment 1187/1540
# Processed segment 1188/1540
# Processed segment 1189/1540
# Processed segment 1190/1540
# Processed segment 1191/1540
# Processed segment 1192/1540
# Processed segment 1193/1540
# Processed segment 1194/1540
# Processed segment 1195/1540
# Processed segment 1196/1540
# Processed segment 1197/1540
# Processed segment 1198/1540
# Processed segment 1199/1540
# Processed segment 1200/1540
# Processed segment 1201/1540
# Processed segment 1202/1540
# Processed segment 1203/1540
# Processed segment 1204/1540
# Processed segment 1205/1540
# Processed segment 1206/1540
# Processed segment 1207/1540
# Processed segment 1208/1540
# Processed segment 1209/1540
# Processed segment 1210/1540
# Processed segment 1211/1540
# Processed segment 1212/1540
# Processed segment 1213/1540
# Processed segment 1214/1540
# Processed segment 1215/1540
# Processed segment 1216/1540
# Processed segment 1217/1540
# Processed segment 1218/1540
# Processed segment 1219/1540
# Processed segment 1220/1540
# Processed segment 1221/1540
# Processed segment 1222/1540
# Processed segment 1223/1540
# Processed segment 1224/1540
# Processed segment 1225/1540
# Processed segment 1226/1540
# Processed segment 1227/1540
# Processed segment 1228/1540
# Processed segment 1229/1540
# Processed segment 1230/1540
# Processed segment 1231/1540
# Processed segment 1232/1540
# Processed segment 1233/1540
# Processed segment 1234/1540
# Processed segment 1235/1540
# Processed segment 1236/1540
# Processed segment 1237/1540
# Processed segment 1238/1540
# Processed segment 1239/1540
# Processed segment 1240/1540
# Processed segment 1241/1540
# Processed segment 1242/1540
# Processed segment 1243/1540
# Processed segment 1244/1540
# Processed segment 1245/1540
# Processed segment 1246/1540
# Processed segment 1247/1540
# Processed segment 1248/1540
# Processed segment 1249/1540
# Processed segment 1250/1540
# Processed segment 1251/1540
# Processed segment 1252/1540
# Processed segment 1253/1540
# Processed segment 1254/1540
# Processed segment 1255/1540
# Processed segment 1256/1540
# Processed segment 1257/1540
# Processed segment 1258/1540
# Processed segment 1259/1540
# Processed segment 1260/1540
# Processed segment 1261/1540
# Processed segment 1262/1540
# Processed segment 1263/1540
# Processed segment 1264/1540
# Processed segment 1265/1540
# Processed segment 1266/1540
# Processed segment 1267/1540
# Processed segment 1268/1540
# Processed segment 1269/1540
# Processed segment 1270/1540
# Processed segment 1271/1540
# Processed segment 1272/1540
# Processed segment 1273/1540
# Processed segment 1274/1540
# Processed segment 1275/1540
# Processed segment 1276/1540
# Processed segment 1277/1540
# Processed segment 1278/1540
# Processed segment 1279/1540
# Processed segment 1280/1540
# Processed segment 1281/1540
# Processed segment 1282/1540
# Processed segment 1283/1540
# Processed segment 1284/1540
# Processed segment 1285/1540
# Processed segment 1286/1540
# Processed segment 1287/1540
# Processed segment 1288/1540
# Processed segment 1289/1540
# Processed segment 1290/1540
# Processed segment 1291/1540
# Processed segment 1292/1540
# Processed segment 1293/1540
# Processed segment 1294/1540
# Processed segment 1295/1540
# Processed segment 1296/1540
# Processed segment 1297/1540
# Processed segment 1298/1540
# Processed segment 1299/1540
# Processed segment 1300/1540
# Processed segment 1301/1540
# Processed segment 1302/1540
# Processed segment 1303/1540
# Processed segment 1304/1540
# Processed segment 1305/1540
# Processed segment 1306/1540
# Processed segment 1307/1540
# Processed segment 1308/1540
# Processed segment 1309/1540
# Processed segment 1310/1540
# Processed segment 1311/1540
# Processed segment 1312/1540
# Processed segment 1313/1540
# Processed segment 1314/1540
# Processed segment 1315/1540
# Processed segment 1316/1540
# Processed segment 1317/1540
# Processed segment 1318/1540
# Processed segment 1319/1540
# Processed segment 1320/1540
# Processed segment 1321/1540
# Processed segment 1322/1540
# Processed segment 1323/1540
# Processed segment 1324/1540
# Processed segment 1325/1540
# Processed segment 1326/1540
# Processed segment 1327/1540
# Processed segment 1328/1540
# Processed segment 1329/1540
# Processed segment 1330/1540
# Processed segment 1331/1540
# Processed segment 1332/1540
# Processed segment 1333/1540
# Processed segment 1334/1540
# Processed segment 1335/1540
# Processed segment 1336/1540
# Processed segment 1337/1540
# Processed segment 1338/1540
# Processed segment 1339/1540
# Processed segment 1340/1540
# Processed segment 1341/1540
# Processed segment 1342/1540
# Processed segment 1343/1540
# Processed segment 1344/1540
# Processed segment 1345/1540
# Processed segment 1346/1540
# Processed segment 1347/1540
# Processed segment 1348/1540
# Processed segment 1349/1540
# Processed segment 1350/1540
# Processed segment 1351/1540
# Processed segment 1352/1540
# Processed segment 1353/1540
# Processed segment 1354/1540
# Processed segment 1355/1540
# Processed segment 1356/1540
# Processed segment 1357/1540
# Processed segment 1358/1540
# Processed segment 1359/1540
# Processed segment 1360/1540
# Processed segment 1361/1540
# Processed segment 1362/1540
# Processed segment 1363/1540
# Processed segment 1364/1540
# Processed segment 1365/1540
# Processed segment 1366/1540
# Processed segment 1367/1540
# Processed segment 1368/1540
# Processed segment 1369/1540
# Processed segment 1370/1540
# Processed segment 1371/1540
# Processed segment 1372/1540
# Processed segment 1373/1540
# Processed segment 1374/1540
# Processed segment 1375/1540
# Processed segment 1376/1540
# Processed segment 1377/1540
# Processed segment 1378/1540
# Processed segment 1379/1540
# Processed segment 1380/1540
# Processed segment 1381/1540
# Processed segment 1382/1540
# Processed segment 1383/1540
# Processed segment 1384/1540
# Processed segment 1385/1540
# Processed segment 1386/1540
# Processed segment 1387/1540
# Processed segment 1388/1540
# Processed segment 1389/1540
# Processed segment 1390/1540
# Processed segment 1391/1540
# Processed segment 1392/1540
# Processed segment 1393/1540
# Processed segment 1394/1540
# Processed segment 1395/1540
# Processed segment 1396/1540
# Processed segment 1397/1540
# Processed segment 1398/1540
# Processed segment 1399/1540
# Processed segment 1400/1540
# Processed segment 1401/1540
# Processed segment 1402/1540
# Processed segment 1403/1540
# Processed segment 1404/1540
# Processed segment 1405/1540
# Processed segment 1406/1540
# Processed segment 1407/1540
# Processed segment 1408/1540
# Processed segment 1409/1540
# Processed segment 1410/1540
# Processed segment 1411/1540
# Processed segment 1412/1540
# Processed segment 1413/1540
# Processed segment 1414/1540
# Processed segment 1415/1540
# Processed segment 1416/1540
# Processed segment 1417/1540
# Processed segment 1418/1540
# Processed segment 1419/1540
# Processed segment 1420/1540
# Processed segment 1421/1540
# Processed segment 1422/1540
# Processed segment 1423/1540
# Processed segment 1424/1540
# Processed segment 1425/1540
# Processed segment 1426/1540
# Processed segment 1427/1540
# Processed segment 1428/1540
# Processed segment 1429/1540
# Processed segment 1430/1540
# Processed segment 1431/1540
# Processed segment 1432/1540
# Processed segment 1433/1540
# Processed segment 1434/1540
# Processed segment 1435/1540
# Processed segment 1436/1540
# Processed segment 1437/1540
# Processed segment 1438/1540
# Processed segment 1439/1540
# Processed segment 1440/1540
# Processed segment 1441/1540
# Processed segment 1442/1540
# Processed segment 1443/1540
# Processed segment 1444/1540
# Processed segment 1445/1540
# Processed segment 1446/1540
# Processed segment 1447/1540
# Processed segment 1448/1540
# Processed segment 1449/1540
# Processed segment 1450/1540
# Processed segment 1451/1540
# Processed segment 1452/1540
# Processed segment 1453/1540
# Processed segment 1454/1540
# Processed segment 1455/1540
# Processed segment 1456/1540
# Processed segment 1457/1540
# Processed segment 1458/1540
# Processed segment 1459/1540
# Processed segment 1460/1540
# Processed segment 1461/1540
# Processed segment 1462/1540
# Processed segment 1463/1540
# Processed segment 1464/1540
# Processed segment 1465/1540
# Processed segment 1466/1540
# Processed segment 1467/1540
# Processed segment 1468/1540
# Processed segment 1469/1540
# Processed segment 1470/1540
# Processed segment 1471/1540
# Processed segment 1472/1540
# Processed segment 1473/1540
# Processed segment 1474/1540
# Processed segment 1475/1540
# Processed segment 1476/1540
# Processed segment 1477/1540
# Processed segment 1478/1540
# Processed segment 1479/1540
# Processed segment 1480/1540
# Processed segment 1481/1540
# Processed segment 1482/1540
# Processed segment 1483/1540
# Processed segment 1484/1540
# Processed segment 1485/1540
# Processed segment 1486/1540
# Processed segment 1487/1540
# Processed segment 1488/1540
# Processed segment 1489/1540
# Processed segment 1490/1540
# Processed segment 1491/1540
# Processed segment 1492/1540
# Processed segment 1493/1540
# Processed segment 1494/1540
# Processed segment 1495/1540
# Processed segment 1496/1540
# Processed segment 1497/1540
# Processed segment 1498/1540
# Processed segment 1499/1540
# Processed segment 1500/1540
# Processed segment 1501/1540
# Processed segment 1502/1540
# Processed segment 1503/1540
# Processed segment 1504/1540
# Processed segment 1505/1540
# Processed segment 1506/1540
# Processed segment 1507/1540
# Processed segment 1508/1540
# Processed segment 1509/1540
# Processed segment 1510/1540
# Processed segment 1511/1540
# Processed segment 1512/1540
# Processed segment 1513/1540
# Processed segment 1514/1540
# Processed segment 1515/1540
# Processed segment 1516/1540
# Processed segment 1517/1540
# Processed segment 1518/1540
# Processed segment 1519/1540
# Processed segment 1520/1540
# Processed segment 1521/1540
# Processed segment 1522/1540
# Processed segment 1523/1540
# Processed segment 1524/1540
# Processed segment 1525/1540
# Processed segment 1526/1540
# Processed segment 1527/1540
# Processed segment 1528/1540
# Processed segment 1529/1540
# Processed segment 1530/1540
# Processed segment 1531/1540
# Processed segment 1532/1540
# Processed segment 1533/1540
# Processed segment 1534/1540
# Processed segment 1535/1540
# Processed segment 1536/1540
# Processed segment 1537/1540
# Processed segment 1538/1540
# Processed segment 1539/1540
# Processed segment 1540/1540

# %% [markdown]
# # Process participant data

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Trim to be only the valid indices from phonemes

# %%
valid_idxs = np.unique(df_valid['idx'])
df_valid_results =  df_results[df_results['transcript_index'].isin(valid_idxs)].reset_index(drop=True)
df_valid_results['accuracy'] = df_valid_results['response'] == df_valid_results['ground_truth']
df_valid_results['accuracy'] = df_valid_results['accuracy'].astype(int)

# %%
df_valid_results.to_csv(os.path.join(out_dir, f'valid-results-accuracy.csv'), index=False)

# %% [markdown]
# Now generate accuracy per participant

# %%
df_accuracy = df_valid_results.groupby(['modality', 'subject'])['accuracy'].mean().reset_index()

# %%
f_oneway(*[df_accuracy[df_accuracy['modality'] == mod]['accuracy'] for mod in np.unique(df_accuracy['modality'])])
# Out:
# F_onewayResult(statistic=34.33852628916861, pvalue=1.882820513691619e-08)

# %%
import statsmodels.stats.multicomp as mc

comp = mc.MultiComparison(df_accuracy['accuracy'], df_accuracy['modality'])
tbl, a1, a2 = comp.allpairtest(stats.ttest_ind, method= "bonf")

tbl
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
sns.set(style='white', rc={'figure.figsize':(6,6), "axes.titlesize":18}, font_scale=1.25)

ax = sns.barplot(data=df_accuracy, x='modality', y='accuracy', palette='BuPu', alpha=0.75) #, kwargs=dict(alpha=0.5))
ax = sns.stripplot(data=df_accuracy, x='modality', y='accuracy', palette='BuPu', size=5, edgecolor='black', linewidth=1,  dodge=True, alpha=0.6, ax=ax)
plt.xlabel('Story')
plt.ylabel('Accuracy')
plt.title('Next word prediction accuracy')
# plt.ylim(0, 0.4)

sns.despine()

# %% [markdown]
# # Plot example word distributions

# %%
import random

# %%
sns.set(style='white', rc={'figure.figsize':(12,4), "axes.titlesize":12})

n_indices = 3

fig, axes = plt.subplots(1, n_indices)
axes = axes.flatten()
counter = 0

# for task in tasks:
task = tasks[1]

cmap = sns.color_palette("BuPu",n_indices) #Splitting the palette in the same amount of numbers bins


task_transcript = modalities_dict[mod]['transcript']
task_responses = modalities_dict[mod]['responses']
response_indices = random.sample(list(task_responses.keys()), n_indices)

for ax, cm, idx in zip(axes, cmap, response_indices):
    sns.histplot(task_responses[idx], stat="probability", ax=ax, color=cm, alpha=0.8)
    ax.set_ylabel('Probability')
    ax.tick_params(axis='x', rotation=45)
    ax.legend()
    
    sns.despine()
    ax.title.set_text(f'Correct word: {task_transcript[idx]}')
    counter += 1
    
plt.tight_layout()
plt.suptitle(f'Behavioral predictions - {task.capitalize()}', y=1.05)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_40383/1574981569.py in <module>
#       8
#       9 # for task in tasks:
# ---> 10 task = tasks[1]
#      11
#      12 cmap = sns.color_palette("BuPu",n_indices) #Splitting the palette in the same amount of numbers bins
#
# IndexError: list index out of range

# %% [markdown]
# # Compare responses to GPT

# %%
from scipy.stats import pearsonr

window_size = 100
model_fn = f'task-{TASK}_gpt2-predictions_context-{window_size}.csv'
df_model = pd.read_csv(model_fn)

# %%
df_comparison = pd.DataFrame(
    columns=['modality', 'ground_truth', 'prob_human', 'prob_model', 'pred_human', 'pred_model', 'entropy', 'kl_divergence']
)

valid_idxs = np.unique(df_valid['idx'])

# valid_idxs = response_idxs

for mod in MODALITIES:
    transcript = modalities_dict[mod]['transcript']
    modality_responses = modalities_dict[mod]['responses']
    
    response_idxs = list(modality_responses.keys())
    
    for idx in valid_idxs: #response_idxs:

        unique, counts = np.unique(modality_responses[idx], return_counts=True)
        probs = counts / sum(counts)

        ground_truth = transcript[idx]

        pred_human = unique[probs.argmax()]
        pred_model = df_model.loc[idx]['predicted_word']

        prob_human = probs.max()
        prob_model = df_model.loc[idx]['probability']

        df_comparison.loc[len(df_comparison)] = {
            'modality' : mod,
            'ground_truth': ground_truth,
            'prob_human': prob_human,
            'prob_model': prob_model,
            'pred_human': pred_human,
            'pred_model': pred_model,
            'entropy': df_model.loc[idx]['entropy'],
            'kl_divergence': df_model.loc[idx]['kl_divergence'],
        }
        
df_comparison['pred_model'] = df_comparison['pred_model'].str.strip()

# %%
df_comparison.to_csv(os.path.join(out_dir, f'valid-results_model-top-prob.csv'))

# %% [markdown]
# Check distributions of human probabilities across modalities

# %%
sns.displot(data=df_comparison, x="prob_human", hue="modality", kind="kde")

# %% [markdown]
# Check the correlation between human and model predictions for each modality

# %%
from scipy.stats import pearsonr, spearmanr

for mod in MODALITIES:
    
    df_modality = df_comparison[df_comparison['modality'] == mod]

    r, pval = pearsonr(df_modality['prob_human'], df_modality['prob_model'])
    
    print (mod, r, pval)
# Out:
# audio 0.3803102851583819 2.2577550531380408e-10
# text 0.4774362581033449 3.2953666251106184e-16

# %%
colors = df_comparison['prob_human'] - df_comparison['prob_model']
cmap = sns.color_palette("BuPu",9) #Splitting the palette in the same amount of numbers bins

# %%
sns.lmplot(data=df_comparison, x="prob_human", y="prob_model", hue='modality',  scatter_kws={"s": 2}) #, scatter=False, label=f'Pearson r = {r:.2f}', color=".1", ax=ax)
plt.title('Similarity between human and model predictions')
plt.ylabel('Model - top prediction probability ')
plt.xlabel('Human - top prediction probability ')

for mod in MODALITIES:
    
    df_modality = df_comparison[df_comparison['modality'] == mod]

    r, pval = pearsonr(df_modality['prob_human'], df_modality['prob_model'])
    
    print (mod, r, pval)
# Out:
# audio 0.3803102851583819 2.2577550531380408e-10
# text 0.4774362581033449 3.2953666251106184e-16

# %% [markdown]
# # Alignment
#
# 1. correlation of human probability and model probability of the most probable human word (e.g., dog) --> pull out probability of that word from model distribution
# 2. KL divergence over human distribution and model distribution (normalized to the words humans predicted)

# %%
def get_word_prob(tokenizer, words, logits):
    
    # use the tokenizer to find the index of each word, 
    idxs = tokenizer(words, add_prefix_space=True)['input_ids']
    probs = F.softmax(logits, dim=-1)
    word_prob = probs[:, idxs]
    
    return word_prob.squeeze().mean().item()

# %%
logits_dir = os.path.join(model_out_dir, f'window-size-{window_size}')


# here prob model is the probability of the top human word

df_human_preds = pd.DataFrame(
    columns=['modality', 'prob_human', 'prob_model', 'kl_divergence']
)

for mod in MODALITIES:
    
    modality_responses = modalities_dict[mod]['responses']
    
    for idx in df_valid['idx'].unique():

        unique, counts = np.unique(modality_responses[idx], return_counts=True)
        probs_dist_human = counts / sum(counts)
        
        pred_human = unique[probs_dist_human.argmax()]

        top_prob_human = probs_dist_human.max()

        # load logits
        logits_fn = glob.glob(os.path.join(logits_dir, f'*{str(idx).zfill(5)}*'))[0]
        logits = torch.load(logits_fn)

#         top_prob_model = get_word_prob(tokenizer, word=pred_human, logits=logits)
        
        prob_dist_model = np.asarray([get_word_prob(tokenizer, word=word, logits=logits) for word in unique])
        
        # normalize to the samples
        prob_dist_model = prob_dist_model / prob_dist_model.sum()
        top_prob_model = prob_dist_model[probs_dist_human.argmax()]
        
        stat, pval = kstest(probs_dist_human, prob_dist_model)
        
        kl_divergence = rel_entr(prob_dist_model, probs_dist_human).sum()
        
        df_human_preds.loc[len(df_human_preds)] = {
            'modality': mod,
            'prob_human': top_prob_human,
            'prob_model': top_prob_model,
            'kl_divergence': kl_divergence
        }

# %%
df_human_preds.to_csv(os.path.join(out_dir, f'valid-results_human-model-top-prob.csv'))

# %% [markdown]
# Plot KL divergence
#
# lower numbers mean better fits

# %%
sns.set(style='white', rc={'figure.figsize':(6,6), "axes.titlesize":18}, font_scale=1.25)

ax = sns.barplot(data=df_human_preds, x='modality', y='kl_divergence', palette='BuPu', alpha=0.75) #, kwargs=dict(alpha=0.5))
ax = sns.stripplot(data=df_human_preds, x='modality', y='kl_divergence', palette='BuPu', size=5, edgecolor='black', linewidth=1,  dodge=True, alpha=0.6, ax=ax)
plt.xlabel('Story')
plt.ylabel('KL Divergence')
plt.title('Relative entropy of model distribution to human distribution')
# plt.ylim(0, 0.4)

sns.despine()

# %%
sns.lmplot(data=df_human_preds, x="prob_human", y="prob_model", hue='modality',  scatter_kws={"s": 4}) #, scatter=False, label=f'Pearson r = {r:.2f}', color=".1", ax=ax)
plt.title('Relationship of probability of top human word')
plt.ylabel('GPT')
plt.xlabel('Human')

for mod in MODALITIES:
    print (mod)
    df_mod = df_human_preds[df_human_preds['modality'] == mod]
    print(pearsonr(df_mod['prob_human'], df_mod['prob_model']))
#     sys.exit(0)
# Out:
# audio
# (0.3435226587004578, 1.2971959624129681e-08)
# text
# (0.43883965904823824, 1.1547263210213855e-13)

# %%
f_oneway(*[df_human_preds[df_human_preds['modality'] == mod]['prob_human'] for mod in np.unique(df_human_preds['modality'])])
# Out:
# F_onewayResult(statistic=25.028780411842607, pvalue=2.9236963887791237e-11)

# %%
import statsmodels.stats.multicomp as mc

comp = mc.MultiComparison(df_human_preds['prob_human'], df_human_preds['modality'])
tbl, a1, a2 = comp.allpairtest(stats.ttest_ind, method= "bonf")

tbl
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # Accuracy
#
# 1. raw binarized accuracy (useful but not overly informative) --> number of hits (accurate predictions) normalized by number of predictions
# 2. continuous accuracy --> cosine similarity between contextual embeddings of predicted word and true word

# %% [markdown]
# # Variation
#
# 1. average number of unique words predicted per word
# 2. variance of cosine similarity of the predicted set of words

# %%
from scipy.spatial.distance import pdist
from scipy.spatial.distance import cdist

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

def get_bert_model(model_name='sentence-transformers/all-MiniLM-L6-v2', cache_dir=None):
    '''
    Use a model from the sentence-transformers library to get
    sentence embeddings. Models used are trained on a next-sentence
    prediction task and evaluate the likelihood of S2 following S1.
    '''
    # set the path of where to download models
    # this NEEDS to be run before loading from transformers
    if cache_dir:
        os.environ['TRANSFORMERS_CACHE'] = cache_dir
    from transformers import AutoTokenizer, AutoModel

    # Load model from HuggingFace Hub
    tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
    model = AutoModel.from_pretrained(model_name)
    
    return tokenizer, model

def get_bert_encoding(model, tokenizer, sentences):

    # Tokenize sentences
    encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')
    
    # Compute token embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    # Perform pooling
    embeddings = mean_pooling(model_output, encoded_input['attention_mask'])
    
    # Normalize embeddings
    embeddings = F.normalize(embeddings, p=2, dim=1)
    
    return embeddings

def extract_word_id_indices(word_ids, mask):
    
    # turn none ids into -1
    ids = torch.tensor([id if id is not None else -1 for id in word_ids])
    
    # mask based on our context tokens
    mask = torch.logical_and(ids >=0, ~torch.isin(ids, mask))
    
    return mask

def extract_response_embeddings(tokenizer, model, sentences, mask):
    
    # Tokenize full sentences -- this is what we will run through the model
    encoded_inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')
    
    # generate mask of the embeddings we're interested in
    id_indices = [extract_word_id_indices(encoded_inputs.word_ids(i), mask) for i in range(len(encoded_inputs['input_ids']))]
    id_indices = torch.stack(id_indices)
    
    with torch.no_grad():
        model_output = model(**encoded_inputs)
        
    # then mask each embedding by the words of interest, take the mean across them
    embeddings = torch.stack([embeddings[mask].sum(0) for embeddings, mask in zip(model_output['last_hidden_state'], id_indices)])
    
    return embeddings

# %% [markdown]
# Load BERT

# %%
# load bert model
bert_tokenizer, bert_model = get_bert_model(model_name='bert-base-uncased', cache_dir=cache_dir)

# %% [markdown]
# Go through each index and run through BERT

# %%
from scipy.spatial.distance import pdist, cdist

sentence_window = 25

# generate segments at the window size
segments = get_segment_indices(n_words=len(transcript), window_size=sentence_window)

df_bert_responses = pd.DataFrame(
    columns=['modality', 'transcript_index', 'n_unique', 'avg_cosine_responses', 'std_cosine_responses', 'avg_cosine_gt', 'std_cosine_gt']
)


for mod in MODALITIES:
    for idx in valid_idxs:

        # get responses for the current index
        df_subset = df_valid_results[
            (df_valid_results['modality'] == mod) &
            (df_valid_results['transcript_index'] == idx)
        ]

        responses = df_subset['response'].tolist()
        
        unique, unique_idxs = np.unique(responses, return_index=True)
        
        # get the current segment and join it together
        sentence_context = transcript[segments[current_index-1]]
        context_indices = torch.arange(len(sentence_context))

        # join and add responses
        sentence_context = ' '.join(sentence_context)
        response_sentences = [f'{sentence_context} {word}' for word in responses]
        
        ground_truth_sentence = [f'{sentence_context} {transcript[idx]}']

        response_embeddings = extract_response_embeddings(bert_tokenizer, bert_model, response_sentences, context_indices)
        ground_truth_embedding = extract_response_embeddings(bert_tokenizer, bert_model, ground_truth_sentence, context_indices)
        
        # calculate variation in response similarity
        avg_response_similarity = np.nanmean(1 - pdist(response_embeddings, metric='cosine'))
        
        std_response_similarity = np.nanstd(1 - pdist(response_embeddings[unique_idxs], metric='cosine'))
        
        # response similarity to ground truth
        avg_response_ground_truth_similarity = np.nanmean(1 - cdist(response_embeddings, ground_truth_embedding, metric='cosine'))
        
        std_response_ground_truth_similarity = np.nanstd(1 - cdist(response_embeddings[unique_idxs], ground_truth_embedding, metric='cosine'))
        
        df_bert_responses.loc[len(df_bert_responses)] = {
            'modality': mod,
            'transcript_index': idx,
            'n_unique': len(unique),
            'avg_cosine_responses': avg_response_similarity,
            'std_cosine_responses': std_response_similarity,
            'avg_cosine_gt': avg_response_ground_truth_similarity,
            'std_cosine_gt': std_response_ground_truth_similarity
        }
# Out:
# /dartfs-hpc/rc/home/w/f003rjw/.local/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1671: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %%
df_bert_responses.to_csv(os.path.join(out_dir, f'valid-results_responses-bert-similarity.csv'))

# %% [markdown]
# Look at average cosine similarity to ground truth embedding

# %%
import statsmodels.stats.multicomp as mc

comp = mc.MultiComparison(df_bert_responses['avg_cosine_gt'], df_bert_responses['modality'])
tbl, a1, a2 = comp.allpairtest(stats.ttest_ind, method= "bonf")

tbl
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
sns.displot(df_bert_responses, x='avg_cosine_gt', hue='modality', kind='kde')

# %%
sns.displot(df_bert_responses, x='avg_cosine_responses', hue='modality', kind='kde')

# %% [markdown]
# Separate correlation by both correct, humans, models, neither

# %% [markdown]
# # Show some probability distributions

# %%
df = df.append(last.iloc[-1], ignore_index=True)

# %%
from matplotlib import pyplot as plt

# %%
trial_index = 35
sns.histplot(transcript_responses[trial_index], stat="probability")
plt.title(f'Correct word: {all_words[trial_index]}')

# %%
sns.histplot(transcript_responses[45])

# %%
all_words[35]

# %%
import seaborn as sns

# %%
transcript_responses[26]

# %%
sns.histplot(transcript_responses[26])

# %%
for k, v in transcript_responses.items():
    print (len(v))

# %%
results

# %%
accuracy_stack

# %%
critical_trials.response.iloc[0]

# %%
df.apply(lambda x: ast.literal_eval(x))

# %%
dist.sum()
# Out:
# tensor(1.0000)

# %%
[d.get('Q0') for d in df_results.response]

# %%
task = 'black' # replace this string with those above

# set directories
base_dir = '/dartfs/rc/lab/F/FinnLab/tommy/isc_asynchrony_behavioral/'
# narratives_dir = '/dartfs/rc/lab/D/DBIC/DBIC/archive/narratives'

gentle_dir = os.path.join(base_dir, 'stimuli', 'gentle')
preproc_dir = os.path.join(base_dir, 'stimuli', 'preprocessed')

task_out_dir = os.path.join(preproc_dir, task)

if not os.path.exists(task_out_dir):
    os.makedirs(task_out_dir)
